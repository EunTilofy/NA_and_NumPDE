# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 400)

f = 1 / (1 + x*x)
p2 = -0.0384615*x**2+1
p4 = 0.00530504*x**4-0.171088*x**2+1
p6 = -0.000840633*x**6+8.67362e-19*x**5+0.0335319*x**4+2.08167e-17*x**3-0.351364*x**2+2.77556e-17*x+1
p8 = 0.000137445*x**8-0.00658016*x**6+0.0981875*x**4-6.93889e-17*x**3-0.528121*x**2+2.77556e-17*x+1

plt.figure()
plt.plot(x, f, label='$f(x)$', linestyle='--')
plt.plot(x, p2, label='$p_{2}(x)$')
plt.plot(x, p4, label='$p_{4}(x)$')
plt.plot(x, p6, label='$p_{6}(x)$')
plt.plot(x, p8, label='$p_{8}(x)$')

plt.title('Results of Problem B')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1, 1, 400)

f = 1 / (1 + 25*x*x)
p5 = -5.17224e-16*x**5+0.711567*x**4+2.9326e-16*x**3-1.09581*x**2+1.63088e-16*x+0.444089
p10 = -46.6329*x**10+3.55271e-14*x**9+130.106*x**8-4.26326e-14*x**7-133.445*x**6+1.56319e-13*x**5+61.443*x**4-2.13163e-14*x**3-12.4765*x**2+1.77636e-15*x+1
p15 = 5.85464e-13*x**15-108.93*x**14-2.33045e-12*x**13+440.077*x**12+2.57202e-12*x**11-725.649*x**10-5.15846e-12*x**9+628.141*x**8+7.81847e-13*x**7-305.961*x**6-3.69476e-13*x**5+83.7238*x**4+4.86983e-14*x**3-12.2846*x**2-1.77185e-15*x+0.916893
p20 = 6466.55*x**20-4.54747e-12*x**19-34208.1*x**18+7.27596e-11*x**17+77754.5*x**16+1.30967e-10*x**15-99300.1*x**14+8.00355e-11*x**13+78236.3*x**12-1.20053e-10*x**11-39333.3*x**10-4.00178e-11*x**9+12635.6*x**8+2.50111e-12*x**7-2537.27*x**6-1.08002e-12*x**5+306.629*x**4-2.66454e-14*x**3-21.7623*x**2+2.498e-15*x+1

plt.figure()

plt.plot(x, f, label='$f(x)$', linestyle='--')
plt.plot(x, p5, label='$p_{5}(x)$')
plt.plot(x, p10, label='$p_{10}(x)$')
plt.plot(x, p15, label='$p_{15}(x)$')
plt.plot(x, p20, label='$p_{20}(x)$')

plt.title('Results of Problem C')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 13, 400)

f=-2.02236e-05*x**9+0.00104059*x**8-0.0218757*x**7+0.243041*x**6-1.5383*x**5+5.50812*x**4-10.0953*x**3+7.16191*x**2+75*x
f_=-0.000182013*x**8+0.00832472*x**7-0.15313*x**6+1.45825*x**5-7.69148*x**4+22.0325*x**3-30.2859*x**2+14.3238*x+75

plt.figure()
plt.plot(x, f, label='$p(x)$')
plt.title("p(x)")
plt.show()
plt.figure()
plt.plot(x, f_, label='$p\'(x)$')
plt.title("p\'(x)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 28, 400)

f1=4.1477e-05*x**6-0.00371557*x**5+0.128281*x**4-2.11512*x**3+16.2855*x**2-43.0127*x+6.67
f2=8.6768e-06*x**6-0.000777473*x**5+0.0265858*x**4-0.424283*x**3+2.98227*x**2-5.85018*x+6.67

plt.figure()
plt.plot(x, f1, label='$p_1(x)$')
plt.plot(x, f2, label='$p_2(x)$')
plt.legend()
plt.title("Result of Problem E")
plt.show()
