# %%
import matplotlib as plt

import numpy as np
import matplotlib.pyplot as plt
import math as Math

# %% [markdown]
# # A. ppForm

# %%
x = np.linspace(-1, 1, 500)

N = [6, 11, 21, 41, 81]
s6linear = (1.5384615384615385e-01*x+1.9230769230769232e-01)*((x>=-1)&(x<-5.9999999999999998e-01))+(1.0000000000000002e+00*x+7.0000000000000007e-01)*((x>=-5.9999999999999998e-01)&(x<-1.9999999999999996e-01))+(-1.3877787807814453e-15*x+4.9999999999999983e-01)*((x>=-1.9999999999999996e-01)&(x<2.0000000000000018e-01))+(-9.9999999999999911e-01*x+6.9999999999999951e-01)*((x>=2.0000000000000018e-01)&(x<6.0000000000000009e-01))+(-1.5384615384615383e-01*x+1.9230769230769229e-01)*((x>=6.0000000000000009e-01)&(x<=1))

s6CompleteCubic = (2.6089295320064569e+00*x**3+6.9829209252286226e+00*x**2+6.2130177514792946e+00*x+1.8774878967186670e+00)*((x>=-1)&(x<-5.9999999999999998e-01))+(-3.5368477676170040e+00*x**3-4.0794782140936068e+00*x**2-4.2442173211404333e-01*x+5.4999999999999971e-01)*((x>=-5.9999999999999998e-01)&(x<-1.9999999999999996e-01))+(9.8069700508555458e-15*x**3-1.9573695535233990e+00*x**2-1.2656542480726795e-15*x+5.7829478214093599e-01)*((x>=-1.9999999999999996e-01)&(x<2.0000000000000018e-01))+(3.5368477676169907e+00*x**3-4.0794782140935890e+00*x**2+4.2442173211403722e-01*x+5.4999999999999993e-01)*((x>=2.0000000000000018e-01)&(x<6.0000000000000009e-01))+(-2.6089295320064512e+00*x**3+6.9829209252286075e+00*x**2-6.2130177514792813e+00*x+1.8774878967186637e+00)*((x>=6.0000000000000009e-01)&(x<=1))

s6NatureCubic = (1.7206477732793533e+00*x**3+5.1619433198380600e+00*x**2+5.0404858299595174e+00*x+1.6376518218623490e+00)*((x>=-1)&(x<-5.9999999999999998e-01))+(-3.3147773279352273e+00*x**3-3.9018218623481848e+00*x**2-3.9777327935222972e-01*x+5.4999999999999993e-01)*((x>=-5.9999999999999998e-01)&(x<-1.9999999999999996e-01))+(8.8817841970012492e-15*x**3-1.9129554655870438e+00*x**2-1.2656542480726793e-15*x+5.7651821862348163e-01)*((x>=-1.9999999999999996e-01)&(x<2.0000000000000018e-01))+(3.3147773279352157e+00*x**3-3.9018218623481697e+00*x**2+3.9777327935222434e-01*x+5.4999999999999993e-01)*((x>=2.0000000000000018e-01)&(x<6.0000000000000009e-01))+(-1.7206477732793501e+00*x**3+5.1619433198380502e+00*x**2-5.0404858299595077e+00*x+1.6376518218623466e+00)*((x>=6.0000000000000009e-01)&(x<=1))

s6SecondDerivativesCubic = (1.6847136046762341e+00*x**3+5.0882782742016657e+00*x**2+4.9930527274034002e+00*x+1.6279495963395068e+00)*((x>=-1)&(x<-5.9999999999999998e-01))+(-3.3057937857844473e+00*x**3-3.8946350286275608e+00*x**2-3.9669525429413621e-01*x+5.4999999999999982e-01)*((x>=-5.9999999999999998e-01)&(x<-1.9999999999999996e-01))+(8.6967470262303892e-15*x**3-1.9111587571568878e+00*x**2-1.3988810110276982e-15*x+5.7644635028627544e-01)*((x>=-1.9999999999999996e-01)&(x<2.0000000000000018e-01))+(3.3057937857844362e+00*x**3-3.8946350286275457e+00*x**2+3.9669525429413083e-01*x+5.4999999999999993e-01)*((x>=2.0000000000000018e-01)&(x<6.0000000000000009e-01))+(-1.6847136046762312e+00*x**3+5.0882782742016568e+00*x**2-4.9930527274033913e+00*x+1.6279495963395045e+00)*((x>=6.0000000000000009e-01)&(x<=1))

s11linear = (1.0180995475113123e-01*x+1.4027149321266968e-01)*((x>=-1)&(x<-8.0000000000000004e-01))+(2.0588235294117643e-01*x+2.2352941176470587e-01)*((x>=-8.0000000000000004e-01)&(x<-5.9999999999999998e-01))+(5.0000000000000011e-01*x+4.0000000000000002e-01)*((x>=-5.9999999999999998e-01)&(x<-3.9999999999999991e-01))+(1.5000000000000007e+00*x+8.0000000000000016e-01)*((x>=-3.9999999999999991e-01)&(x<-1.9999999999999996e-01))+(2.5000000000000000e+00*x+1)*((x>=-1.9999999999999996e-01)&(x<0))+(-2.5000000000000000e+00*x+1)*((x>=0)&(x<2.0000000000000018e-01))+(-1.4999999999999987e+00*x+7.9999999999999960e-01)*((x>=2.0000000000000018e-01)&(x<4.0000000000000013e-01))+(-4.9999999999999972e-01*x+3.9999999999999986e-01)*((x>=4.0000000000000013e-01)&(x<6.0000000000000009e-01))+(-2.0588235294117641e-01*x+2.2352941176470584e-01)*((x>=6.0000000000000009e-01)&(x<8.0000000000000004e-01))+(-1.0180995475113123e-01*x+1.4027149321266968e-01)*((x>=8.0000000000000004e-01)&(x<=1))

s11CompleteCubic = (8.2249853028609293e-02*x**3+3.6952687702866160e-01*x**2+5.6626869201291552e-01*x+3.1745320647440162e-01)*((x>=-1)&(x<-8.0000000000000004e-01))+(9.6278751017974618e-01*x**3+2.4828172541913900e+00*x**2+2.2569009937430984e+00*x+7.6828848693578378e-01)*((x>=-8.0000000000000004e-01)&(x<-5.9999999999999998e-01))+(8.1773132797186465e-01*x**3+2.2217161262172036e+00*x**2+2.1002403169585864e+00*x+7.3695635157888140e-01)*((x>=-5.9999999999999998e-01)&(x<-3.9999999999999991e-01))+(1.3413346001462211e+01*x**3+1.7336453734405616e+01*x**2+8.1461353602339504e+00*x+1.5430756906822631e+00)*((x>=-3.9999999999999991e-01)&(x<-1.9999999999999996e-01))+(-5.4471115333820734e+01*x**3-2.3394223066764141e+01*x**2+8.8817841970012523e-16*x+9.9999999999999956e-01)*((x>=-1.9999999999999996e-01)&(x<0))+(5.4471115333820670e+01*x**3-2.3394223066764138e+01*x**2+8.8817841970012523e-16*x+1)*((x>=0)&(x<2.0000000000000018e-01))+(-1.3413346001462225e+01*x**3+1.7336453734405637e+01*x**2-8.1461353602339592e+00*x+1.5430756906822642e+00)*((x>=2.0000000000000018e-01)&(x<4.0000000000000013e-01))+(-8.1773132797185555e-01*x**3+2.2217161262171876e+00*x**2-2.1002403169585775e+00*x+7.3695635157887973e-01)*((x>=4.0000000000000013e-01)&(x<6.0000000000000009e-01))+(-9.6278751017974773e-01*x**3+2.4828172541913940e+00*x**2-2.2569009937431010e+00*x+7.6828848693578444e-01)*((x>=6.0000000000000009e-01)&(x<8.0000000000000004e-01))+(-8.2249853028608808e-02*x**3+3.6952687702866027e-01*x**2-5.6626869201291430e-01*x+3.1745320647440128e-01)*((x>=8.0000000000000004e-01)&(x<=1))

s11NatureCubic = (3.4171020724481876e-01*x**3+1.0251306217344562e+00*x**2+1.1132721681957947e+00*x+4.6831329216769574e-01)*((x>=-1)&(x<-8.0000000000000004e-01))+(8.9325891852703643e-01*x**3+2.3488475288117785e+00*x**2+2.1722456938576529e+00*x+7.5070623234419120e-01)*((x>=-8.0000000000000004e-01)&(x<-5.9999999999999998e-01))+(8.3638534036649459e-01*x**3+2.2464750881228035e+00*x**2+2.1108222294442678e+00*x+7.3842153946151412e-01)*((x>=-5.9999999999999998e-01)&(x<-3.9999999999999991e-01))+(1.3408258543536405e+01*x**3+1.7332722931926693e+01*x**2+8.1453213669658222e+00*x+1.5430214244643881e+00)*((x>=-3.9999999999999991e-01)&(x<-1.9999999999999996e-01))+(-5.4469419514512133e+01*x**3-2.3393883902902420e+01*x**2+1.7763568394002505e-15*x+1)*((x>=-1.9999999999999996e-01)&(x<0))+(5.4469419514512083e+01*x**3-2.3393883902902420e+01*x**2+1.3322676295501878e-15*x+1)*((x>=0)&(x<2.0000000000000018e-01))+(-1.3408258543536421e+01*x**3+1.7332722931926714e+01*x**2-8.1453213669658311e+00*x+1.5430214244643889e+00)*((x>=2.0000000000000018e-01)&(x<4.0000000000000013e-01))+(-8.3638534036648426e-01*x**3+2.2464750881227857e+00*x**2-2.1108222294442576e+00*x+7.3842153946151234e-01)*((x>=4.0000000000000013e-01)&(x<6.0000000000000009e-01))+(-8.9325891852703843e-01*x**3+2.3488475288117834e+00*x**2-2.1722456938576564e+00*x+7.5070623234419198e-01)*((x>=6.0000000000000009e-01)&(x<8.0000000000000004e-01))+(-3.4171020724481838e-01*x**3+1.0251306217344551e+00*x**2-1.1132721681957938e+00*x+4.6831329216769541e-01)*((x>=8.0000000000000004e-01)&(x<=1))

s11SecondDerivativesCubic = (2.6956888947598784e-01*x**3+8.4284412860092672e-01*x**2+9.6118129591138901e-01*x+4.2636759524798851e-01)*((x>=-1)&(x<-8.0000000000000004e-01))+(9.1259090564155965e-01*x**3+2.3860969673982990e+00*x**2+2.1957835669492871e+00*x+7.5559486752476146e-01)*((x>=-8.0000000000000004e-01)&(x<-5.9999999999999998e-01))+(8.3119870967723208e-01*x**3+2.2395910146625093e+00*x**2+2.1078799953078131e+00*x+7.3801415319646668e-01)*((x>=-5.9999999999999998e-01)&(x<-3.9999999999999991e-01))+(1.3409673079178930e+01*x**3+1.7333760258064544e+01*x**2+8.1455476926686252e+00*x+1.5430365128445749e+00)*((x>=-3.9999999999999991e-01)&(x<-1.9999999999999996e-01))+(-5.4469891026392965e+01*x**3-2.3393978205278586e+01*x**2+2.6645352591003757e-15*x+1)*((x>=-1.9999999999999996e-01)&(x<0))+(5.4469891026392922e+01*x**3-2.3393978205278586e+01*x**2+8.8817841970012523e-16*x+1)*((x>=0)&(x<2.0000000000000018e-01))+(-1.3409673079178951e+01*x**3+1.7333760258064572e+01*x**2-8.1455476926686359e+00*x+1.5430365128445760e+00)*((x>=2.0000000000000018e-01)&(x<4.0000000000000013e-01))+(-8.3119870967722120e-01*x**3+2.2395910146624911e+00*x**2-2.1078799953078029e+00*x+7.3801415319646468e-01)*((x>=4.0000000000000013e-01)&(x<6.0000000000000009e-01))+(-9.1259090564156164e-01*x**3+2.3860969673983039e+00*x**2-2.1957835669492907e+00*x+7.5559486752476213e-01)*((x>=6.0000000000000009e-01)&(x<8.0000000000000004e-01))+(-2.6956888947598745e-01*x**3+8.4284412860092550e-01*x**2-9.6118129591138779e-01*x+4.2636759524798823e-01)*((x>=8.0000000000000004e-01)&(x<=1))

s21linear = (8.5972850678733018e-02*x+1.2443438914027148e-01)*((x>=-1)&(x<-9.0000000000000002e-01))+(1.1764705882352944e-01*x+1.5294117647058825e-01)*((x>=-9.0000000000000002e-01)&(x<-8.0000000000000004e-01))+(1.6648168701442825e-01*x+1.9200887902330732e-01)*((x>=-8.0000000000000004e-01)&(x<-6.9999999999999996e-01))+(2.4528301886792467e-01*x+2.4716981132075483e-01)*((x>=-6.9999999999999996e-01)&(x<-5.9999999999999998e-01))+(3.7931034482758624e-01*x+3.2758620689655171e-01)*((x>=-5.9999999999999998e-01)&(x<-5.0000000000000000e-01))+(6.2068965517241392e-01*x+4.4827586206896558e-01)*((x>=-5.0000000000000000e-01)&(x<-3.9999999999999991e-01))+(1.0769230769230773e+00*x+6.3076923076923097e-01)*((x>=-3.9999999999999991e-01)&(x<-2.9999999999999993e-01))+(1.9230769230769238e+00*x+8.8461538461538480e-01)*((x>=-2.9999999999999993e-01)&(x<-1.9999999999999996e-01))+(3*x+1.1000000000000001e+00)*((x>=-1.9999999999999996e-01)&(x<-9.9999999999999978e-02))+(2*x+1)*((x>=-9.9999999999999978e-02)&(x<0))+(-2.0000000000000009e+00*x+1)*((x>=0)&(x<1.0000000000000009e-01))+(-2.9999999999999991e+00*x+1.0999999999999999e+00)*((x>=1.0000000000000009e-01)&(x<2.0000000000000018e-01))+(-1.9230769230769216e+00*x+8.8461538461538414e-01)*((x>=2.0000000000000018e-01)&(x<3.0000000000000004e-01))+(-1.0769230769230766e+00*x+6.3076923076923075e-01)*((x>=3.0000000000000004e-01)&(x<4.0000000000000013e-01))+(-6.2068965517241359e-01*x+4.4827586206896541e-01)*((x>=4.0000000000000013e-01)&(x<5.0000000000000000e-01))+(-3.7931034482758608e-01*x+3.2758620689655166e-01)*((x>=5.0000000000000000e-01)&(x<6.0000000000000009e-01))+(-2.4528301886792439e-01*x+2.4716981132075463e-01)*((x>=6.0000000000000009e-01)&(x<7.0000000000000018e-01))+(-1.6648168701442834e-01*x+1.9200887902330738e-01)*((x>=7.0000000000000018e-01)&(x<8.0000000000000004e-01))+(-1.1764705882352944e-01*x+1.5294117647058825e-01)*((x>=8.0000000000000004e-01)&(x<9.0000000000000013e-01))+(-8.5972850678732976e-02*x+1.2443438914027144e-01)*((x>=9.0000000000000013e-01)&(x<=1))

s21CompleteCubic = (1.6461313177715647e-01*x**3+5.9746161852688273e-01*x**2+7.7504833876371615e-01*x+3.8066139047552838e-01)*((x>=-1)&(x<-9.0000000000000002e-01))+(2.7191069168559429e-01*x**3+8.8716503027966487e-01*x**2+1.0357814093412201e+00*x+4.5888131164877966e-01)*((x>=-9.0000000000000002e-01)&(x<-8.0000000000000004e-01))+(4.6378610609070314e-01*x**3+1.3476660248519261e+00*x**2+1.4041822049990293e+00*x+5.5712152382419533e-01)*((x>=-8.0000000000000004e-01)&(x<-6.9999999999999996e-01))+(8.6961525021134867e-01*x**3+2.1999072275052818e+00*x**2+2.0007510468563781e+00*x+6.9632092025757664e-01)*((x>=-6.9999999999999996e-01)&(x<-5.9999999999999998e-01))+(1.5803523036804277e+00*x**3+3.4792339237496241e+00*x**2+2.7683470646029833e+00*x+8.4984012380689777e-01)*((x>=-5.9999999999999998e-01)&(x<-5.0000000000000000e-01))+(3.5441739735835398e+00*x**3+6.4249664286042920e+00*x**2+4.2412133170303168e+00*x+1.0953178325447868e+00)*((x>=-5.0000000000000000e-01)&(x<-3.9999999999999991e-01))+(5.7283629425689631e+00*x**3+9.0459931913867990e+00*x**2+5.2896240221433199e+00*x+1.2351059265598536e+00)*((x>=-3.9999999999999991e-01)&(x<-2.9999999999999993e-01))+(1.2534416696458960e+01*x**3+1.5171441569887795e+01*x**2+7.1272585356936178e+00*x+1.4188693779148833e+00)*((x>=-2.9999999999999993e-01)&(x<-1.9999999999999996e-01))+(-3.2789106651481823e+01*x**3-1.2022672438876668e+01*x**2+1.6884357339407279e+00*x+1.0562811911313574e+00)*((x>=-1.9999999999999996e-01)&(x<-9.9999999999999978e-02))+(-8.9070297782839404e+01*x**3-2.8907029778283938e+01*x**2+9.9999999999999989e-01)*((x>=-9.9999999999999978e-02)&(x<0))+(8.9070297782839376e+01*x**3-2.8907029778283938e+01*x**2+1)*((x>=0)&(x<1.0000000000000009e-01))+(3.2789106651481745e+01*x**3-1.2022672438876636e+01*x**2-1.6884357339407312e+00*x+1.0562811911313579e+00)*((x>=1.0000000000000009e-01)&(x<2.0000000000000018e-01))+(-1.2534416696459054e+01*x**3+1.5171441569887868e+01*x**2-7.1272585356936364e+00*x+1.4188693779148851e+00)*((x>=2.0000000000000018e-01)&(x<3.0000000000000004e-01))+(-5.7283629425688858e+00*x**3+9.0459931913867155e+00*x**2-5.2896240221432897e+00*x+1.2351059265598505e+00)*((x>=3.0000000000000004e-01)&(x<4.0000000000000013e-01))+(-3.5441739735835713e+00*x**3+6.4249664286043373e+00*x**2-4.2412133170303390e+00*x+1.0953178325447901e+00)*((x>=4.0000000000000013e-01)&(x<5.0000000000000000e-01))+(-1.5803523036804166e+00*x**3+3.4792339237496051e+00*x**2-2.7683470646029726e+00*x+8.4984012380689566e-01)*((x>=5.0000000000000000e-01)&(x<6.0000000000000009e-01))+(-8.6961525021135833e-01*x**3+2.1999072275053000e+00*x**2-2.0007510468563892e+00*x+6.9632092025757908e-01)*((x>=6.0000000000000009e-01)&(x<7.0000000000000018e-01))+(-4.6378610609069088e-01*x**3+1.3476660248518981e+00*x**2-1.4041822049990078e+00*x+5.5712152382419000e-01)*((x>=7.0000000000000018e-01)&(x<8.0000000000000004e-01))+(-2.7191069168559817e-01*x**3+8.8716503027967553e-01*x**2-1.0357814093412299e+00*x+4.5888131164878254e-01)*((x>=8.0000000000000004e-01)&(x<9.0000000000000013e-01))+(-1.6461313177715856e-01*x**3+5.9746161852688862e-01*x**2-7.7504833876372170e-01*x+3.8066139047553005e-01)*((x>=9.0000000000000013e-01)&(x<=1))

s21NatureCubic = (6.0257217917665096e-01*x**3+1.8077165375299529e+00*x**2+1.8876636664169193e+00*x+7.2098084652515593e-01)*((x>=-1)&(x<-9.0000000000000002e-01))+(1.5455991859638865e-01*x**3+5.9808343396324459e-01*x**2+7.9899387320688198e-01*x+3.9437990856214478e-01)*((x>=-9.0000000000000002e-01)&(x<-8.0000000000000004e-01))+(4.9523015104803148e-01*x**3+1.4156919918471875e+00*x**2+1.4530807195140363e+00*x+5.6880306757738586e-01)*((x>=-8.0000000000000004e-01)&(x<-6.9999999999999996e-01))+(8.6118984347124117e-01*x**3+2.1842073459359277e+00*x**2+1.9910414673761543e+00*x+6.9432724207854668e-01)*((x>=-6.9999999999999996e-01)&(x<-5.9999999999999998e-01))+(1.5826098856835262e+00*x**3+3.4827634219180412e+00*x**2+2.7701751129654224e+00*x+8.5015397119640046e-01)*((x>=-5.9999999999999998e-01)&(x<-5.0000000000000000e-01))+(3.5435690523112555e+00*x**3+6.4242021718596352e+00*x**2+4.2408944879362194e+00*x+1.0952738670248665e+00)*((x>=-5.0000000000000000e-01)&(x<-3.9999999999999991e-01))+(5.7285250456550001e+00*x**3+9.0461493638721269e+00*x**2+5.2896733647412155e+00*x+1.2351110505988661e+00)*((x>=-3.9999999999999991e-01)&(x<-2.9999999999999993e-01))+(1.2534373205387093e+01*x**3+1.5171412707631010e+01*x**2+7.1272523678688806e+00*x+1.4188689509116323e+00)*((x>=-2.9999999999999993e-01)&(x<-1.9999999999999996e-01))+(-3.2789094790280409e+01*x**3-1.2022668089769482e+01*x**2+1.6884362083887838e+00*x+1.0562812069462928e+00)*((x>=-1.9999999999999996e-01)&(x<-9.9999999999999978e-02))+(-8.9070301736573185e+01*x**3-2.8907030173657311e+01*x**2+8.8817841970012523e-16*x+9.9999999999999989e-01)*((x>=-9.9999999999999978e-02)&(x<0))+(8.9070301736573171e+01*x**3-2.8907030173657315e+01*x**2+1)*((x>=0)&(x<1.0000000000000009e-01))+(3.2789094790280330e+01*x**3-1.2022668089769450e+01*x**2-1.6884362083887881e+00*x+1.0562812069462930e+00)*((x>=1.0000000000000009e-01)&(x<2.0000000000000018e-01))+(-1.2534373205387192e+01*x**3+1.5171412707631088e+01*x**2-7.1272523678689002e+00*x+1.4188689509116339e+00)*((x>=2.0000000000000018e-01)&(x<3.0000000000000004e-01))+(-5.7285250456549219e+00*x**3+9.0461493638720416e+00*x**2-5.2896733647411853e+00*x+1.2351110505988627e+00)*((x>=3.0000000000000004e-01)&(x<4.0000000000000013e-01))+(-3.5435690523112870e+00*x**3+6.4242021718596796e+00*x**2-4.2408944879362407e+00*x+1.0952738670248698e+00)*((x>=4.0000000000000013e-01)&(x<5.0000000000000000e-01))+(-1.5826098856835145e+00*x**3+3.4827634219180208e+00*x**2-2.7701751129654109e+00*x+8.5015397119639824e-01)*((x>=5.0000000000000000e-01)&(x<6.0000000000000009e-01))+(-8.6118984347125149e-01*x**3+2.1842073459359472e+00*x**2-1.9910414673761667e+00*x+6.9432724207854934e-01)*((x>=6.0000000000000009e-01)&(x<7.0000000000000018e-01))+(-4.9523015104801921e-01*x**3+1.4156919918471593e+00*x**2-1.4530807195140150e+00*x+5.6880306757738053e-01)*((x>=7.0000000000000018e-01)&(x<8.0000000000000004e-01))+(-1.5455991859639304e-01*x**3+5.9808343396325658e-01*x**2-7.9899387320689275e-01*x+3.9437990856214789e-01)*((x>=8.0000000000000004e-01)&(x<9.0000000000000013e-01))+(-6.0257217917665173e-01*x**3+1.8077165375299553e+00*x**2-1.8876636664169220e+00*x+7.2098084652515670e-01)*((x>=9.0000000000000013e-01)&(x<=1))

s21SecondDerivativesCubic = (4.5829029564868895e-01*x**3+1.4090083471190300e+00*x**2+1.5211220089969428e+00*x+6.0886549598814033e-01)*((x>=-1)&(x<-9.0000000000000002e-01))+(1.9322013277693620e-01*x**3+6.9331890736529767e-01*x**2+8.7700151321858377e-01*x+4.1562934725463263e-01)*((x>=-9.0000000000000002e-01)&(x<-8.0000000000000004e-01))+(4.8487117785380335e-01*x**3+1.3932814155497788e+00*x**2+1.4369715197661690e+00*x+5.6495468233398860e-01)*((x>=-8.0000000000000004e-01)&(x<-6.9999999999999996e-01))+(8.6396552206760724e-01*x**3+2.1893795383987671e+00*x**2+1.9942402057604602e+00*x+6.9498404239932321e-01)*((x>=-6.9999999999999996e-01)&(x<-5.9999999999999998e-01))+(1.5818661444922890e+00*x**3+3.4816006587631940e+00*x**2+2.7695728779791167e+00*x+8.5005057684305463e-01)*((x>=-5.9999999999999998e-01)&(x<-5.0000000000000000e-01))+(3.5437683384798362e+00*x**3+6.4244539497445148e+00*x**2+4.2409995234697773e+00*x+1.0952883510914979e+00)*((x>=-5.0000000000000000e-01)&(x<-3.9999999999999991e-01))+(5.7284716421719155e+00*x**3+9.0460979141750091e+00*x**2+5.2896571092419746e+00*x+1.2351093625277909e+00)*((x>=-3.9999999999999991e-01)&(x<-2.9999999999999993e-01))+(1.2534387533150850e+01*x**3+1.5171422216056049e+01*x**2+7.1272543998062865e+00*x+1.4188690915842221e+00)*((x>=-2.9999999999999993e-01)&(x<-1.9999999999999996e-01))+(-3.2789098697852332e+01*x**3-1.2022669522545856e+01*x**2+1.6884360520859070e+00*x+1.0562812017361969e+00)*((x>=-1.9999999999999996e-01)&(x<-9.9999999999999978e-02))+(-8.9070300434049230e+01*x**3-2.8907030043404923e+01*x**2+4.4408920985006262e-16*x+1)*((x>=-9.9999999999999978e-02)&(x<0))+(8.9070300434049201e+01*x**3-2.8907030043404919e+01*x**2+1)*((x>=0)&(x<1.0000000000000009e-01))+(3.2789098697852260e+01*x**3-1.2022669522545824e+01*x**2-1.6884360520859107e+00*x+1.0562812017361971e+00)*((x>=1.0000000000000009e-01)&(x<2.0000000000000018e-01))+(-1.2534387533150948e+01*x**3+1.5171422216056126e+01*x**2-7.1272543998063052e+00*x+1.4188690915842235e+00)*((x>=2.0000000000000018e-01)&(x<3.0000000000000004e-01))+(-5.7284716421718365e+00*x**3+9.0460979141749220e+00*x**2-5.2896571092419444e+00*x+1.2351093625277874e+00)*((x>=3.0000000000000004e-01)&(x<4.0000000000000013e-01))+(-3.5437683384798677e+00*x**3+6.4244539497445601e+00*x**2-4.2409995234697977e+00*x+1.0952883510915012e+00)*((x>=4.0000000000000013e-01)&(x<5.0000000000000000e-01))+(-1.5818661444922775e+00*x**3+3.4816006587631745e+00*x**2-2.7695728779791056e+00*x+8.5005057684305241e-01)*((x>=5.0000000000000000e-01)&(x<6.0000000000000009e-01))+(-8.6396552206761823e-01*x**3+2.1893795383987875e+00*x**2-1.9942402057604733e+00*x+6.9498404239932599e-01)*((x>=6.0000000000000009e-01)&(x<7.0000000000000018e-01))+(-4.8487117785379003e-01*x**3+1.3932814155497484e+00*x**2-1.4369715197661457e+00*x+5.6495468233398283e-01)*((x>=7.0000000000000018e-01)&(x<8.0000000000000004e-01))+(-1.9322013277694092e-01*x**3+6.9331890736531032e-01*x**2-8.7700151321859532e-01*x+4.1562934725463607e-01)*((x>=8.0000000000000004e-01)&(x<9.0000000000000013e-01))+(-4.5829029564868945e-01*x**3+1.4090083471190316e+00*x**2-1.5211220089969446e+00*x+6.0886549598814077e-01)*((x>=9.0000000000000013e-01)&(x<=1))

s41linear = (7.9575596816975971e-02*x+1.1803713527851444e-01)*((x>=-1)&(x<-9.4999999999999996e-01))+(9.2370104540490092e-02*x+1.3019191761585286e-01)*((x>=-9.4999999999999996e-01)&(x<-9.0000000000000002e-01))+(1.0800385728061708e-01*x+1.4426229508196714e-01)*((x>=-9.0000000000000002e-01)&(x<-8.4999999999999998e-01))+(1.2729026036644181e-01*x+1.6065573770491814e-01)*((x>=-8.4999999999999998e-01)&(x<-8.0000000000000004e-01))+(1.5133024164022443e-01*x+1.7988772272394427e-01)*((x>=-8.0000000000000004e-01)&(x<-7.5000000000000000e-01))+(1.8163313238863205e-01*x+2.0261489078524997e-01)*((x>=-7.5000000000000000e-01)&(x<-6.9999999999999996e-01))+(2.2029576746557930e-01*x+2.2967873533911304e-01)*((x>=-6.9999999999999996e-01)&(x<-6.4999999999999991e-01))+(2.7027027027027006e-01*x+2.6216216216216204e-01)*((x>=-6.4999999999999991e-01)&(x<-5.9999999999999998e-01))+(3.3576642335766421e-01*x+3.0145985401459852e-01)*((x>=-5.9999999999999998e-01)&(x<-5.5000000000000004e-01))+(4.2285426629750811e-01*x+3.4935816763151267e-01)*((x>=-5.5000000000000004e-01)&(x<-5.0000000000000000e-01))+(5.4034838250977613e-01*x+4.0810522573764668e-01)*((x>=-5.0000000000000000e-01)&(x<-4.4999999999999996e-01))+(7.0103092783505172e-01*x+4.8041237113402069e-01)*((x>=-4.4999999999999996e-01)&(x<-3.9999999999999991e-01))+(9.2307692307692324e-01*x+5.6923076923076921e-01)*((x>=-3.9999999999999991e-01)&(x<-3.4999999999999998e-01))+(1.2307692307692308e+00*x+6.7692307692307696e-01)*((x>=-3.4999999999999998e-01)&(x<-2.9999999999999993e-01))+(1.6510318949343350e+00*x+8.0300187617260810e-01)*((x>=-2.9999999999999993e-01)&(x<-2.5000000000000000e-01))+(2.1951219512195124e+00*x+9.3902439024390250e-01)*((x>=-2.5000000000000000e-01)&(x<-1.9999999999999996e-01))+(2.7999999999999998e+00*x+1.0600000000000001e+00)*((x>=-1.9999999999999996e-01)&(x<-1.4999999999999991e-01))+(3.2000000000000006e+00*x+1.1200000000000001e+00)*((x>=-1.4999999999999991e-01)&(x<-9.9999999999999978e-02))+(2.8235294117647065e+00*x+1.0823529411764707e+00)*((x>=-9.9999999999999978e-02)&(x<-4.9999999999999933e-02))+(1.1764705882352915e+00*x+1)*((x>=-4.9999999999999933e-02)&(x<0))+(-1.1764705882352933e+00*x+1)*((x>=0)&(x<5.0000000000000044e-02))+(-2.8235294117647087e+00*x+1.0823529411764707e+00)*((x>=5.0000000000000044e-02)&(x<1.0000000000000009e-01))+(-3.1999999999999980e+00*x+1.1199999999999997e+00)*((x>=1.0000000000000009e-01)&(x<1.5000000000000013e-01))+(-2.7999999999999998e+00*x+1.0600000000000001e+00)*((x>=1.5000000000000013e-01)&(x<2.0000000000000018e-01))+(-2.1951219512195110e+00*x+9.3902439024390216e-01)*((x>=2.0000000000000018e-01)&(x<2.5000000000000000e-01))+(-1.6510318949343334e+00*x+8.0300187617260776e-01)*((x>=2.5000000000000000e-01)&(x<3.0000000000000004e-01))+(-1.2307692307692308e+00*x+6.7692307692307696e-01)*((x>=3.0000000000000004e-01)&(x<3.5000000000000009e-01))+(-9.2307692307692235e-01*x+5.6923076923076898e-01)*((x>=3.5000000000000009e-01)&(x<4.0000000000000013e-01))+(-7.0103092783505061e-01*x+4.8041237113402024e-01)*((x>=4.0000000000000013e-01)&(x<4.5000000000000018e-01))+(-5.4034838250977624e-01*x+4.0810522573764674e-01)*((x>=4.5000000000000018e-01)&(x<5.0000000000000000e-01))+(-4.2285426629750811e-01*x+3.4935816763151267e-01)*((x>=5.0000000000000000e-01)&(x<5.5000000000000004e-01))+(-3.3576642335766405e-01*x+3.0145985401459846e-01)*((x>=5.5000000000000004e-01)&(x<6.0000000000000009e-01))+(-2.7027027027027034e-01*x+2.6216216216216220e-01)*((x>=6.0000000000000009e-01)&(x<6.5000000000000013e-01))+(-2.2029576746557847e-01*x+2.2967873533911248e-01)*((x>=6.5000000000000013e-01)&(x<7.0000000000000018e-01))+(-1.8163313238863230e-01*x+2.0261489078525013e-01)*((x>=7.0000000000000018e-01)&(x<7.5000000000000000e-01))+(-1.5133024164022443e-01*x+1.7988772272394427e-01)*((x>=7.5000000000000000e-01)&(x<8.0000000000000004e-01))+(-1.2729026036644167e-01*x+1.6065573770491803e-01)*((x>=8.0000000000000004e-01)&(x<8.5000000000000009e-01))+(-1.0800385728061722e-01*x+1.4426229508196725e-01)*((x>=8.5000000000000009e-01)&(x<9.0000000000000013e-01))+(-9.2370104540489884e-02*x+1.3019191761585264e-01)*((x>=9.0000000000000013e-01)&(x<9.5000000000000018e-01))+(-7.9575596816976041e-02*x+1.1803713527851450e-01)*((x>=9.5000000000000018e-01)&(x<=1))

s41CompleteCubic = (1.4730851129169745e-01*x**3+5.4678210382162440e-01*x**2+7.2560317080957648e-01*x+3.6459111674118805e-01)*((x>=-1)&(x<-9.4999999999999996e-01))+(1.8699773508588005e-01*x**3+6.5989639163504488e-01*x**2+8.3306174423232604e-01*x+3.9861966499172541e-01)*((x>=-9.4999999999999996e-01)&(x<-9.0000000000000002e-01))+(2.4039855500993057e-01*x**3+8.0407860542998122e-01*x**2+9.6282573664776860e-01*x+4.3754886271635818e-01)*((x>=-9.0000000000000002e-01)&(x<-8.4999999999999998e-01))+(3.1246818315349517e-01*x**3+9.8785615719607089e-01*x**2+1.1190366556489448e+00*x+4.8180862310002481e-01)*((x>=-8.4999999999999998e-01)&(x<-8.0000000000000004e-01))+(4.1115998755924793e-01*x**3+1.2247164877698775e+00*x**2+1.3085249201079903e+00*x+5.3233882695577028e-01)*((x>=-8.0000000000000004e-01)&(x<-7.5000000000000000e-01))+(5.4805565645949283e-01*x**3+1.5327317427954288e+00*x**2+1.5395363613771536e+00*x+5.9009168727306105e-01)*((x>=-7.5000000000000000e-01)&(x<-6.9999999999999996e-01))+(7.4051511801863246e-01*x**3+1.9368966120696218e+00*x**2+1.8224517698690885e+00*x+6.5610528258784595e-01)*((x>=-6.9999999999999996e-01)&(x<-6.4999999999999991e-01))+(1.0146309625633960e+00*x**3+2.4714225089319108e+00*x**2+2.1698936028295766e+00*x+7.3138434639595151e-01)*((x>=-6.4999999999999991e-01)&(x<-5.9999999999999998e-01))+(1.4096211448091756e+00*x**3+3.1824048369743139e+00*x**2+2.5964829996550183e+00*x+8.1670222576103990e-01)*((x>=-5.9999999999999998e-01)&(x<-5.5000000000000004e-01))+(1.9835603991797806e+00*x**3+4.1294046066858119e+00*x**2+3.1173328729963421e+00*x+9.1219136920694943e-01)*((x>=-5.5000000000000004e-01)&(x<-5.0000000000000000e-01))+(2.8186465674412875e+00*x**3+5.3820338590780725e+00*x**2+3.7436474991924724e+00*x+1.0165771402396377e+00)*((x>=-5.0000000000000000e-01)&(x<-4.4999999999999996e-01))+(4.0172249762580767e+00*x**3+7.0001147109807373e+00*x**2+4.4717838825486718e+00*x+1.1257975977430676e+00)*((x>=-4.4999999999999996e-01)&(x<-3.9999999999999991e-01))+(5.6578334941648292e+00*x**3+8.9688449324688406e+00*x**2+5.2592759711439125e+00*x+1.2307965428890997e+00)*((x>=-3.9999999999999991e-01)&(x<-3.4999999999999998e-01))+(7.6099660272571086e+00*x**3+1.1018584092215733e+01*x**2+5.9766846770553252e+00*x+1.3144942252454312e+00)*((x>=-3.4999999999999998e-01)&(x<-2.9999999999999993e-01))+(8.9304449859253356e+00*x**3+1.2207015155017139e+01*x**2+6.3332139958957470e+00*x+1.3501471571294734e+00)*((x>=-2.9999999999999993e-01)&(x<-2.5000000000000000e-01))+(6.1992108770709224e+00*x**3+1.0158589573376329e+01*x**2+5.8211076004855435e+00*x+1.3074716241786231e+00)*((x>=-2.5000000000000000e-01)&(x<-1.9999999999999996e-01))+(-9.4120914960853046e+00*x**3+7.9180814948259304e-01*x**2+3.9477513157067978e+00*x+1.1825812051933733e+00)*((x>=-1.9999999999999996e-01)&(x<-1.4999999999999991e-01))+(-5.0502064404924091e+01*x**3-1.7698679659494850e+01*x**2+1.1741781443601824e+00*x+1.0439025466260425e+00)*((x>=-1.4999999999999991e-01)&(x<-9.9999999999999978e-02))+(-9.9167886178336701e+01*x**3-3.2298426191518629e+01*x**2-2.8579650884219499e-01*x+9.9523672485263026e-01)*((x>=-9.9999999999999978e-02)&(x<-4.9999999999999933e-02))+(-6.1061684999377100e+01*x**3-2.6582496014674700e+01*x**2+7.7715611723760958e-16*x+1)*((x>=-4.9999999999999933e-02)&(x<0))+(6.1061684999376894e+01*x**3-2.6582496014674700e+01*x**2+2.2204460492503131e-16*x+1)*((x>=0)&(x<5.0000000000000044e-02))+(9.9167886178337525e+01*x**3-3.2298426191518800e+01*x**2+2.8579650884220553e-01*x+9.9523672485262993e-01)*((x>=5.0000000000000044e-02)&(x<1.0000000000000009e-01))+(5.0502064404922635e+01*x**3-1.7698679659494317e+01*x**2-1.1741781443602439e+00*x+1.0439025466260450e+00)*((x>=1.0000000000000009e-01)&(x<1.5000000000000013e-01))+(9.4120914960863349e+00*x**3+7.9180814948203082e-01*x**2-3.9477513157066983e+00*x+1.1825812051933680e+00)*((x>=1.5000000000000013e-01)&(x<2.0000000000000018e-01))+(-6.1992108770713541e+00*x**3+1.0158589573376652e+01*x**2-5.8211076004856253e+00*x+1.3074716241786295e+00)*((x>=2.0000000000000018e-01)&(x<2.5000000000000000e-01))+(-8.9304449859255577e+00*x**3+1.2207015155017306e+01*x**2-6.3332139958957869e+00*x+1.3501471571294765e+00)*((x>=2.5000000000000000e-01)&(x<3.0000000000000004e-01))+(-7.6099660272567711e+00*x**3+1.1018584092215399e+01*x**2-5.9766846770552151e+00*x+1.3144942252454193e+00)*((x>=3.0000000000000004e-01)&(x<3.5000000000000009e-01))+(-5.6578334941649260e+00*x**3+8.9688449324689596e+00*x**2-5.2592759711439614e+00*x+1.2307965428891063e+00)*((x>=3.5000000000000009e-01)&(x<4.0000000000000013e-01))+(-4.0172249762581700e+00*x**3+7.0001147109808519e+00*x**2-4.4717838825487179e+00*x+1.1257975977430739e+00)*((x>=4.0000000000000013e-01)&(x<4.5000000000000018e-01))+(-2.8186465674411489e+00*x**3+5.3820338590778727e+00*x**2-3.7436474991923774e+00*x+1.0165771402396226e+00)*((x>=4.5000000000000018e-01)&(x<5.0000000000000000e-01))+(-1.9835603991798145e+00*x**3+4.1294046066858714e+00*x**2-3.1173328729963767e+00*x+9.1219136920695576e-01)*((x>=5.0000000000000000e-01)&(x<5.5000000000000004e-01))+(-1.4096211448092999e+00*x**3+3.1824048369745221e+00*x**2-2.5964829996551346e+00*x+8.1670222576106144e-01)*((x>=5.5000000000000004e-01)&(x<6.0000000000000009e-01))+(-1.0146309625631142e+00*x**3+2.4714225089313882e+00*x**2-2.1698936028292537e+00*x+7.3138434639588534e-01)*((x>=6.0000000000000009e-01)&(x<6.5000000000000013e-01))+(-7.4051511801896519e-01*x**3+1.9368966120702971e+00*x**2-1.8224517698695446e+00*x+6.5610528258794831e-01)*((x>=6.5000000000000013e-01)&(x<7.0000000000000018e-01))+(-5.4805565645926546e-01*x**3+1.5327317427949276e+00*x**2-1.5395363613767861e+00*x+5.9009168727297123e-01)*((x>=7.0000000000000018e-01)&(x<7.5000000000000000e-01))+(-4.1115998755931304e-01*x**3+1.2247164877700345e+00*x**2-1.3085249201081164e+00*x+5.3233882695580392e-01)*((x>=7.5000000000000000e-01)&(x<8.0000000000000004e-01))+(-3.1246818315354485e-01*x**3+9.8785615719619091e-01*x**2-1.1190366556490414e+00*x+4.8180862310005057e-01)*((x>=8.0000000000000004e-01)&(x<8.5000000000000009e-01))+(-2.4039855500982768e-01*x**3+8.0407860542971199e-01*x**2-9.6282573664753435e-01*x+4.3754886271629012e-01)*((x>=8.5000000000000009e-01)&(x<9.0000000000000013e-01))+(-1.8699773508598883e-01*x**3+6.5989639163534708e-01*x**2-8.3306174423260582e-01*x+3.9861966499181167e-01)*((x>=9.0000000000000013e-01)&(x<9.5000000000000018e-01))+(-1.4730851129160150e-01*x**3+5.4678210382134318e-01*x**2-7.2560317080930203e-01*x+3.6459111674109879e-01)*((x>=9.5000000000000018e-01)&(x<=1))

s41NatureCubic = (1.0336605325237151e+00*x**3+3.1009815975711454e+00*x**2+3.1779730430568121e+00*x+1.1491135164709203e+00)*((x>=-1)&(x<-9.4999999999999996e-01))+(-5.0499573212932518e-02*x**3+1.1125296221699749e-02*x**2+2.4260955677483881e-01*x+2.1958174581496212e-01)*((x>=-9.4999999999999996e-01)&(x<-9.0000000000000002e-01))+(3.0403576697316259e-01*x**3+9.6837071472415648e-01*x**2+1.1041304334270499e+00*x+4.7803800881062547e-01)*((x>=-9.0000000000000002e-01)&(x<-8.4999999999999998e-01))+(2.9541664359937919e-01*x**3+9.4639195012100885e-01*x**2+1.0854484835143743e+00*x+4.7274478966870070e-01)*((x>=-8.4999999999999998e-01)&(x<-8.0000000000000004e-01))+(4.1572893381248033e-01*x**3+1.2351414466324515e+00*x**2+1.3164480807235286e+00*x+5.3434468225780862e-01)*((x>=-8.0000000000000004e-01)&(x<-7.5000000000000000e-01))+(5.4683141100067834e-01*x**3+1.5301220203058969e+00*x**2+1.5376835109786127e+00*x+5.8965353982157964e-01)*((x>=-7.5000000000000000e-01)&(x<-6.9999999999999996e-01))+(7.4084315360065822e-01*x**3+1.9375466797658549e+00*x**2+1.8228807726005831e+00*x+6.5619956753337272e-01)*((x>=-6.9999999999999996e-01)&(x<-6.4999999999999991e-01))+(1.0145430656941052e+00*x**3+2.4712615083480767e+00*x**2+2.1697954111790274e+00*x+7.3136440589203544e-01)*((x>=-6.4999999999999991e-01)&(x<-5.9999999999999998e-01))+(1.4096446967043192e+00*x**3+3.1824444441664617e+00*x**2+2.5965051726700583e+00*x+8.1670635819024173e-01)*((x>=-5.9999999999999998e-01)&(x<-5.5000000000000004e-01))+(1.9835540884684981e+00*x**3+4.1293949405773569e+00*x**2+3.1173279456960508e+00*x+9.1219053324500698e-01)*((x>=-5.5000000000000004e-01)&(x<-5.0000000000000000e-01))+(2.8186482583912777e+00*x**3+5.3820361954615263e+00*x**2+3.7436485731381355e+00*x+1.0165773044853545e+00)*((x>=-5.0000000000000000e-01)&(x<-4.4999999999999996e-01))+(4.0172245231693946e+00*x**3+7.0001141529119835e+00*x**2+4.4717836539908413e+00*x+1.1257975666132602e+00)*((x>=-4.4999999999999996e-01)&(x<-3.9999999999999991e-01))+(5.6578336155695723e+00*x**3+8.9688450637921964e+00*x**2+5.2592760183429261e+00*x+1.2307965485268717e+00)*((x>=-3.9999999999999991e-01)&(x<-3.4999999999999998e-01))+(7.6099659947267959e+00*x**3+1.1018584061907282e+01*x**2+5.9766846676832053e+00*x+1.3144942242832376e+00)*((x>=-3.4999999999999998e-01)&(x<-2.9999999999999993e-01))+(8.9304449946418174e+00*x**3+1.2207015161830800e+01*x**2+6.3332139976602608e+00*x+1.3501471572809429e+00)*((x>=-2.9999999999999993e-01)&(x<-2.5000000000000000e-01))+(6.1992108747353329e+00*x**3+1.0158589571900936e+01*x**2+5.8211076001777950e+00*x+1.3074716241574043e+00)*((x>=-2.5000000000000000e-01)&(x<-1.9999999999999996e-01))+(-9.4120914954594230e+00*x**3+7.9180814978408520e-01*x**2+3.9477513157544259e+00*x+1.1825812051958464e+00)*((x>=-1.9999999999999996e-01)&(x<-1.4999999999999991e-01))+(-5.0502064405092028e+01*x**3-1.7698679659550578e+01*x**2+1.1741781443542272e+00*x+1.0439025466258367e+00)*((x>=-1.4999999999999991e-01)&(x<-9.9999999999999978e-02))+(-9.9167886178290885e+01*x**3-3.2298426191510231e+01*x**2-2.8579650884173624e-01*x+9.9523672485263759e-01)*((x>=-9.9999999999999978e-02)&(x<-4.9999999999999933e-02))+(-6.1061684999392384e+01*x**3-2.6582496014675463e+01*x**2+7.2164496600635175e-16*x+9.9999999999999989e-01)*((x>=-4.9999999999999933e-02)&(x<0))+(6.1061684999392178e+01*x**3-2.6582496014675463e+01*x**2+2.2204460492503131e-16*x+1)*((x>=0)&(x<5.0000000000000044e-02))+(9.9167886178291724e+01*x**3-3.2298426191510401e+01*x**2+2.8579650884174745e-01*x+9.9523672485263737e-01)*((x>=5.0000000000000044e-02)&(x<1.0000000000000009e-01))+(5.0502064405090550e+01*x**3-1.7698679659550038e+01*x**2-1.1741781443542902e+00*x+1.0439025466258389e+00)*((x>=1.0000000000000009e-01)&(x<1.5000000000000013e-01))+(9.4120914954604533e+00*x**3+7.9180814978352299e-01*x**2-3.9477513157543269e+00*x+1.1825812051958409e+00)*((x>=1.5000000000000013e-01)&(x<2.0000000000000018e-01))+(-6.1992108747357646e+00*x**3+1.0158589571901263e+01*x**2-5.8211076001778759e+00*x+1.3074716241574107e+00)*((x>=2.0000000000000018e-01)&(x<2.5000000000000000e-01))+(-8.9304449946420288e+00*x**3+1.2207015161830959e+01*x**2-6.3332139976602999e+00*x+1.3501471572809463e+00)*((x>=2.5000000000000000e-01)&(x<3.0000000000000004e-01))+(-7.6099659947264700e+00*x**3+1.1018584061906958e+01*x**2-5.9766846676830996e+00*x+1.3144942242832260e+00)*((x>=3.0000000000000004e-01)&(x<3.5000000000000009e-01))+(-5.6578336155696727e+00*x**3+8.9688450637923207e+00*x**2-5.2592760183429768e+00*x+1.2307965485268784e+00)*((x>=3.5000000000000009e-01)&(x<4.0000000000000013e-01))+(-4.0172245231694843e+00*x**3+7.0001141529120936e+00*x**2-4.4717836539908848e+00*x+1.1257975666132660e+00)*((x>=4.0000000000000013e-01)&(x<4.5000000000000018e-01))+(-2.8186482583911405e+00*x**3+5.3820361954613283e+00*x**2-3.7436485731380404e+00*x+1.0165773044853395e+00)*((x>=4.5000000000000018e-01)&(x<5.0000000000000000e-01))+(-1.9835540884685317e+00*x**3+4.1293949405774146e+00*x**2-3.1173279456960841e+00*x+9.1219053324501331e-01)*((x>=5.0000000000000000e-01)&(x<5.5000000000000004e-01))+(-1.4096446967044443e+00*x**3+3.1824444441666708e+00*x**2-2.5965051726701747e+00*x+8.1670635819026338e-01)*((x>=5.5000000000000004e-01)&(x<6.0000000000000009e-01))+(-1.0145430656938212e+00*x**3+2.4712615083475491e+00*x**2-2.1697954111787014e+00*x+7.3136440589196872e-01)*((x>=6.0000000000000009e-01)&(x<6.5000000000000013e-01))+(-7.4084315360099195e-01*x**3+1.9375466797665322e+00*x**2-1.8228807726010405e+00*x+6.5619956753347541e-01)*((x>=6.5000000000000013e-01)&(x<7.0000000000000018e-01))+(-5.4683141100045030e-01*x**3+1.5301220203053947e+00*x**2-1.5376835109782443e+00*x+5.8965353982148960e-01)*((x>=7.0000000000000018e-01)&(x<7.5000000000000000e-01))+(-4.1572893381254644e-01*x**3+1.2351414466326109e+00*x**2-1.3164480807236565e+00*x+5.3434468225784260e-01)*((x>=7.5000000000000000e-01)&(x<8.0000000000000004e-01))+(-2.9541664359942738e-01*x**3+9.4639195012112509e-01*x**2-1.0854484835144678e+00*x+4.7274478966872568e-01)*((x>=8.0000000000000004e-01)&(x<8.5000000000000009e-01))+(-3.0403576697306417e-01*x**3+9.6837071472389902e-01*x**2-1.1041304334268256e+00*x+4.7803800881056036e-01)*((x>=8.5000000000000009e-01)&(x<9.0000000000000013e-01))+(5.0499573212839516e-02*x**3+1.1125296221958902e-02*x**2-2.4260955677507934e-01*x+2.1958174581503648e-01)*((x>=9.0000000000000013e-01)&(x<9.5000000000000018e-01))+(-1.0336605325236807e+00*x**3+3.1009815975710424e+00*x**2-3.1779730430567090e+00*x+1.1491135164708859e+00)*((x>=9.5000000000000018e-01)&(x<=1))

s41SecondDerivativesCubic = (7.4509676547066073e-01*x**3+2.2694277565849452e+00*x**2+2.3795711986525596e+00*x+8.9370174599981345e-01)*((x>=-1)&(x<-9.4999999999999996e-01))+(2.6820855133816008e-02*x**3+2.2234141212493796e-01*x**2+4.3483917141555273e-01*x+2.7786993737476134e-01)*((x>=-9.4999999999999996e-01)&(x<-9.0000000000000002e-01))+(2.8331782063922312e-01*x**3+9.1488321898953717e-01*x**2+1.0581267975936921e+00*x+4.6485622522820313e-01)*((x>=-9.0000000000000002e-01)&(x<-8.4999999999999998e-01))+(3.0096800058838918e-01*x**3+9.5989117785991052e-01*x**2+1.0963835626335094e+00*x+4.7569564198948472e-01)*((x>=-8.4999999999999998e-01)&(x<-8.0000000000000004e-01))+(4.1424145219037883e-01*x**3+1.2317474617046857e+00*x**2+1.3138685897093296e+00*x+5.3369164920970347e-01)*((x>=-8.0000000000000004e-01)&(x<-7.5000000000000000e-01))+(5.4722998050007565e-01*x**3+1.5309716504015038e+00*x**2+1.5382867312319430e+00*x+5.8979618459035676e-01)*((x>=-7.5000000000000000e-01)&(x<-6.9999999999999996e-01))+(7.4073635722516806e-01*x**3+1.9373350415241977e+00*x**2+1.8227411050178288e+00*x+6.5616887180706351e-01)*((x>=-6.9999999999999996e-01)&(x<-6.4999999999999991e-01))+(1.0145716816966717e+00*x**3+2.4713139242436295e+00*x**2+2.1698273787854596e+00*x+7.3137089779005016e-01)*((x>=-6.4999999999999991e-01)&(x<-5.9999999999999998e-01))+(1.4096370290695417e+00*x**3+3.1824315495147957e+00*x**2+2.5964979539481590e+00*x+8.1670501282259012e-01)*((x>=-5.9999999999999998e-01)&(x<-5.5000000000000004e-01))+(1.9835561430050428e+00*x**3+4.1293980875083722e+00*x**2+3.1173295498446265e+00*x+9.1219080540360897e-01)*((x>=-5.5000000000000004e-01)&(x<-5.0000000000000000e-01))+(2.8186477078798693e+00*x**3+5.3820354348206125e+00*x**2+3.7436482235007462e+00*x+1.0165772510129623e+00)*((x>=-5.0000000000000000e-01)&(x<-4.4999999999999996e-01))+(4.0172246706784840e+00*x**3+7.0001143345987416e+00*x**2+4.4717837284009043e+00*x+1.1257975767479862e+00)*((x>=-4.4999999999999996e-01)&(x<-3.9999999999999991e-01))+(5.6578335760446263e+00*x**3+8.9688450210381117e+00*x**2+5.2592760029766517e+00*x+1.2307965466914190e+00)*((x>=-3.9999999999999991e-01)&(x<-3.4999999999999998e-01))+(7.6099660053174825e+00*x**3+1.1018584071774612e+01*x**2+5.9766846707344268e+00*x+1.3144942245964928e+00)*((x>=-3.4999999999999998e-01)&(x<-2.9999999999999993e-01))+(8.9304449918040465e+00*x**3+1.2207015159612521e+01*x**2+6.3332139970857995e+00*x+1.3501471572316299e+00)*((x>=-2.9999999999999993e-01)&(x<-2.5000000000000000e-01))+(6.1992108754957087e+00*x**3+1.0158589572381265e+01*x**2+5.8211076002779860e+00*x+1.3074716241643123e+00)*((x>=-2.5000000000000000e-01)&(x<-1.9999999999999996e-01))+(-9.4120914956631765e+00*x**3+7.9180814968593616e-01*x**2+3.9477513157389215e+00*x+1.1825812051950413e+00)*((x>=-1.9999999999999996e-01)&(x<-1.4999999999999991e-01))+(-5.0502064405037352e+01*x**3-1.7698679659532434e+01*x**2+1.1741781443561665e+00*x+1.0439025466259035e+00)*((x>=-1.4999999999999991e-01)&(x<-9.9999999999999978e-02))+(-9.9167886178305821e+01*x**3-3.2298426191512974e+01*x**2-2.8579650884188590e-01*x+9.9523672485263537e-01)*((x>=-9.9999999999999978e-02)&(x<-4.9999999999999933e-02))+(-6.1061684999387431e+01*x**3-2.6582496014675218e+01*x**2+5.5511151231257827e-16*x+1)*((x>=-4.9999999999999933e-02)&(x<0))+(6.1061684999387246e+01*x**3-2.6582496014675218e+01*x**2+6.6613381477509392e-16*x+1)*((x>=0)&(x<5.0000000000000044e-02))+(9.9167886178306603e+01*x**3-3.2298426191513130e+01*x**2+2.8579650884189589e-01*x+9.9523672485263504e-01)*((x>=5.0000000000000044e-02)&(x<1.0000000000000009e-01))+(5.0502064405035895e+01*x**3-1.7698679659531901e+01*x**2-1.1741781443562276e+00*x+1.0439025466259060e+00)*((x>=1.0000000000000009e-01)&(x<1.5000000000000013e-01))+(9.4120914956642121e+00*x**3+7.9180814968537216e-01*x**2-3.9477513157388220e+00*x+1.1825812051950357e+00)*((x>=1.5000000000000013e-01)&(x<2.0000000000000018e-01))+(-6.1992108754961457e+00*x**3+1.0158589572381594e+01*x**2-5.8211076002780668e+00*x+1.3074716241643187e+00)*((x>=2.0000000000000018e-01)&(x<2.5000000000000000e-01))+(-8.9304449918042632e+00*x**3+1.2207015159612682e+01*x**2-6.3332139970858385e+00*x+1.3501471572316333e+00)*((x>=2.5000000000000000e-01)&(x<3.0000000000000004e-01))+(-7.6099660053171476e+00*x**3+1.1018584071774278e+01*x**2-5.9766846707343184e+00*x+1.3144942245964808e+00)*((x>=3.0000000000000004e-01)&(x<3.5000000000000009e-01))+(-5.6578335760447294e+00*x**3+8.9688450210382378e+00*x**2-5.2592760029767041e+00*x+1.2307965466914261e+00)*((x>=3.5000000000000009e-01)&(x<4.0000000000000013e-01))+(-4.0172246706785728e+00*x**3+7.0001143345988499e+00*x**2-4.4717837284009487e+00*x+1.1257975767479920e+00)*((x>=4.0000000000000013e-01)&(x<4.5000000000000018e-01))+(-2.8186477078797321e+00*x**3+5.3820354348204145e+00*x**2-3.7436482235006521e+00*x+1.0165772510129474e+00)*((x>=4.5000000000000018e-01)&(x<5.0000000000000000e-01))+(-1.9835561430050783e+00*x**3+4.1293980875084344e+00*x**2-3.1173295498446616e+00*x+9.1219080540361563e-01)*((x>=5.0000000000000000e-01)&(x<5.5000000000000004e-01))+(-1.4096370290696651e+00*x**3+3.1824315495150022e+00*x**2-2.5964979539482740e+00*x+8.1670501282261143e-01)*((x>=5.5000000000000004e-01)&(x<6.0000000000000009e-01))+(-1.0145716816963892e+00*x**3+2.4713139242431055e+00*x**2-2.1698273787851363e+00*x+7.3137089778998376e-01)*((x>=6.0000000000000009e-01)&(x<6.5000000000000013e-01))+(-7.4073635722550002e-01*x**3+1.9373350415248716e+00*x**2-1.8227411050182838e+00*x+6.5616887180716565e-01)*((x>=6.5000000000000013e-01)&(x<7.0000000000000018e-01))+(-5.4722998049984939e-01*x**3+1.5309716504010051e+00*x**2-1.5382867312315773e+00*x+5.8979618459026750e-01)*((x>=7.0000000000000018e-01)&(x<7.5000000000000000e-01))+(-4.1424145219044384e-01*x**3+1.2317474617048425e+00*x**2-1.3138685897094553e+00*x+5.3369164920973700e-01)*((x>=7.5000000000000000e-01)&(x<8.0000000000000004e-01))+(-3.0096800058843792e-01*x**3+9.5989117786002842e-01*x**2-1.0963835626336040e+00*x+4.7569564198950998e-01)*((x>=8.0000000000000004e-01)&(x<8.5000000000000009e-01))+(-2.8331782063912431e-01*x**3+9.1488321898927860e-01*x**2-1.0581267975934667e+00*x+4.6485622522813774e-01)*((x>=8.5000000000000009e-01)&(x<9.0000000000000013e-01))+(-2.6820855133909208e-02*x**3+2.2234141212519770e-01*x**2-4.3483917141579381e-01*x+2.7786993737483584e-01)*((x>=9.0000000000000013e-01)&(x<9.5000000000000018e-01))+(-7.4509676547062487e-01*x**3+2.2694277565848378e+00*x**2-2.3795711986524521e+00*x+8.9370174599977770e-01)*((x>=9.5000000000000018e-01)&(x<=1))

s81linear = (7.6680417374423646e-02*x+1.1514195583596211e-01)*((x>=-1)&(x<-9.7499999999999998e-01))+(8.2470776259528297e-02*x+1.2078755574893915e-01)*((x>=-9.7499999999999998e-01)&(x<-9.4999999999999996e-01))+(8.8849235804021084e-02*x+1.2684709231620730e-01)*((x>=-9.4999999999999996e-01)&(x<-9.2500000000000004e-01))+(9.5890973276959085e-02*x+1.3336069947867496e-01)*((x>=-9.2500000000000004e-01)&(x<-9.0000000000000002e-01))+(1.0368274540227253e-01*x+1.4037329439145704e-01)*((x>=-9.0000000000000002e-01)&(x<-8.7500000000000000e-01))+(1.1232496915896163e-01*x+1.4793524017856002e-01)*((x>=-8.7500000000000000e-01)&(x<-8.4999999999999998e-01))+(1.2193422717643193e-01*x+1.5610310949340978e-01)*((x>=-8.4999999999999998e-01)&(x<-8.2499999999999996e-01))+(1.3264629355645172e-01*x+1.6494056425692608e-01)*((x>=-8.2499999999999996e-01)&(x<-8.0000000000000004e-01))+(1.4461979913916775e-01*x+1.7451936872309892e-01)*((x>=-8.0000000000000004e-01)&(x<-7.7500000000000002e-01))+(1.5804068414128111e-01*x+1.8492055459973678e-01)*((x>=-7.7500000000000002e-01)&(x<-7.5000000000000000e-01))+(1.7312762201691850e-01*x+1.9623575800646481e-01)*((x>=-7.5000000000000000e-01)&(x<-7.2499999999999998e-01))+(1.9013864276034559e-01*x+2.0856874804544945e-01)*((x>=-7.2499999999999998e-01)&(x<-6.9999999999999996e-01))+(2.0937923814509116e-01*x+2.2203716481477137e-01)*((x>=-6.9999999999999996e-01)&(x<-6.7500000000000004e-01))+(2.3121229678606736e-01*x+2.3677447939743029e-01)*((x>=-6.7500000000000004e-01)&(x<-6.4999999999999991e-01))+(2.5607029380614243e-01*x+2.5293217746047908e-01)*((x>=-6.4999999999999991e-01)&(x<-6.2500000000000000e-01))+(2.8447024673439764e-01*x+2.7068214804063856e-01)*((x>=-6.2500000000000000e-01)&(x<-5.9999999999999998e-01))+(3.1703204047217576e-01*x+2.9021922428330549e-01)*((x>=-5.9999999999999998e-01)&(x<-5.7499999999999996e-01))+(3.5450080624315278e-01*x+3.1176376460161725e-01)*((x>=-5.7499999999999996e-01)&(x<-5.5000000000000004e-01))+(3.9777408397774061e-01*x+3.3556406735564054e-01)*((x>=-5.5000000000000004e-01)&(x<-5.2499999999999991e-01))+(4.4793444861727588e-01*x+3.6189825879139659e-01)*((x>=-5.2499999999999991e-01)&(x<-5.0000000000000000e-01))+(5.0628803245436016e-01*x+3.9107505070993870e-01)*((x>=-5.0000000000000000e-01)&(x<-4.7499999999999998e-01))+(5.7440873256519198e-01*x+4.2343238326258381e-01)*((x>=-4.7499999999999998e-01)&(x<-4.4999999999999996e-01))+(6.5418650156245539e-01*x+4.5933237931135235e-01)*((x>=-4.4999999999999996e-01)&(x<-4.2499999999999993e-01))+(7.4787535410764816e-01*x+4.9915014164305926e-01)*((x>=-4.2499999999999993e-01)&(x<-3.9999999999999991e-01))+(8.5813148788927396e-01*x+5.4325259515570956e-01)*((x>=-3.9999999999999991e-01)&(x<-3.7500000000000000e-01))+(9.8802235826457219e-01*x+5.9196167154644641e-01)*((x>=-3.7500000000000000e-01)&(x<-3.4999999999999998e-01))+(1.1409706173654677e+00*x+6.4549356223175991e-01)*((x>=-3.4999999999999998e-01)&(x<-3.2499999999999996e-01))+(1.3205678441729940e+00*x+7.0386266094420580e-01)*((x>=-3.2499999999999996e-01)&(x<-2.9999999999999993e-01))+(1.5301455301455311e+00*x+7.6673596673596700e-01)*((x>=-2.9999999999999993e-01)&(x<-2.7499999999999991e-01))+(1.7719182597231393e+00*x+8.3322346736980923e-01)*((x>=-2.7499999999999991e-01)&(x<-2.5000000000000000e-01))+(2.0454163162321253e+00*x+9.0159798149705572e-01)*((x>=-2.5000000000000000e-01)&(x<-2.2499999999999998e-01))+(2.3448275862068990e+00*x+9.6896551724137980e-01)*((x>=-2.2499999999999998e-01)&(x<-1.9999999999999996e-01))+(2.6548672566371656e+00*x+1.0309734513274331e+00)*((x>=-1.9999999999999996e-01)&(x<-1.7499999999999993e-01))+(2.9451327433628345e+00*x+1.0817699115044253e+00)*((x>=-1.7499999999999993e-01)&(x<-1.4999999999999991e-01))+(3.1640449438202256e+00*x+1.1146067415730339e+00)*((x>=-1.4999999999999991e-01)&(x<-1.2500000000000000e-01))+(3.2359550561797752e+00*x+1.1235955056179776e+00)*((x>=-1.2500000000000000e-01)&(x<-9.9999999999999978e-02))+(3.0684931506849340e+00*x+1.1068493150684935e+00)*((x>=-9.9999999999999978e-02)&(x<-7.4999999999999956e-02))+(2.5785656728444795e+00*x+1.0701047542304594e+00)*((x>=-7.4999999999999956e-02)&(x<-4.9999999999999933e-02))+(1.7375565610859651e+00*x+1.0280542986425336e+00)*((x>=-4.9999999999999933e-02)&(x<-2.4999999999999911e-02))+(6.1538461538461542e-01*x+1)*((x>=-2.4999999999999911e-02)&(x<0))+(-6.1538461538461875e-01*x+1)*((x>=0)&(x<2.5000000000000133e-02))+(-1.7375565610859729e+00*x+1.0280542986425341e+00)*((x>=2.5000000000000133e-02)&(x<5.0000000000000044e-02))+(-2.5785656728444821e+00*x+1.0701047542304596e+00)*((x>=5.0000000000000044e-02)&(x<7.4999999999999956e-02))+(-3.0684931506849336e+00*x+1.1068493150684933e+00)*((x>=7.4999999999999956e-02)&(x<1.0000000000000009e-01))+(-3.2359550561797761e+00*x+1.1235955056179776e+00)*((x>=1.0000000000000009e-01)&(x<1.2500000000000000e-01))+(-3.1640449438202198e+00*x+1.1146067415730330e+00)*((x>=1.2500000000000000e-01)&(x<1.5000000000000013e-01))+(-2.9451327433628345e+00*x+1.0817699115044253e+00)*((x>=1.5000000000000013e-01)&(x<1.7500000000000004e-01))+(-2.6548672566371669e+00*x+1.0309734513274333e+00)*((x>=1.7500000000000004e-01)&(x<2.0000000000000018e-01))+(-2.3448275862068941e+00*x+9.6896551724137880e-01)*((x>=2.0000000000000018e-01)&(x<2.2500000000000009e-01))+(-2.0454163162321275e+00*x+9.0159798149705628e-01)*((x>=2.2500000000000009e-01)&(x<2.5000000000000000e-01))+(-1.7719182597231369e+00*x+8.3322346736980868e-01)*((x>=2.5000000000000000e-01)&(x<2.7500000000000013e-01))+(-1.5301455301455289e+00*x+7.6673596673596633e-01)*((x>=2.7500000000000013e-01)&(x<3.0000000000000004e-01))+(-1.3205678441729947e+00*x+7.0386266094420613e-01)*((x>=3.0000000000000004e-01)&(x<3.2500000000000018e-01))+(-1.1409706173654661e+00*x+6.4549356223175924e-01)*((x>=3.2500000000000018e-01)&(x<3.5000000000000009e-01))+(-9.8802235826457219e-01*x+5.9196167154644641e-01)*((x>=3.5000000000000009e-01)&(x<3.7500000000000000e-01))+(-8.5813148788927307e-01*x+5.4325259515570923e-01)*((x>=3.7500000000000000e-01)&(x<4.0000000000000013e-01))+(-7.4787535410764816e-01*x+4.9915014164305926e-01)*((x>=4.0000000000000013e-01)&(x<4.2500000000000004e-01))+(-6.5418650156245362e-01*x+4.5933237931135157e-01)*((x>=4.2500000000000004e-01)&(x<4.5000000000000018e-01))+(-5.7440873256519120e-01*x+4.2343238326258348e-01)*((x>=4.5000000000000018e-01)&(x<4.7500000000000009e-01))+(-5.0628803245436127e-01*x+3.9107505070993925e-01)*((x>=4.7500000000000009e-01)&(x<5.0000000000000000e-01))+(-4.4793444861727522e-01*x+3.6189825879139625e-01)*((x>=5.0000000000000000e-01)&(x<5.2500000000000013e-01))+(-3.9777408397774078e-01*x+3.3556406735564065e-01)*((x>=5.2500000000000013e-01)&(x<5.5000000000000004e-01))+(-3.5450080624315294e-01*x+3.1176376460161731e-01)*((x>=5.5000000000000004e-01)&(x<5.7500000000000018e-01))+(-3.1703204047217493e-01*x+2.9021922428330493e-01)*((x>=5.7500000000000018e-01)&(x<6.0000000000000009e-01))+(-2.8447024673439780e-01*x+2.7068214804063873e-01)*((x>=6.0000000000000009e-01)&(x<6.2500000000000000e-01))+(-2.5607029380614293e-01*x+2.5293217746047941e-01)*((x>=6.2500000000000000e-01)&(x<6.5000000000000013e-01))+(-2.3121229678606664e-01*x+2.3677447939742979e-01)*((x>=6.5000000000000013e-01)&(x<6.7500000000000004e-01))+(-2.0937923814509041e-01*x+2.2203716481477084e-01)*((x>=6.7500000000000004e-01)&(x<7.0000000000000018e-01))+(-1.9013864276034642e-01*x+2.0856874804545006e-01)*((x>=7.0000000000000018e-01)&(x<7.2500000000000009e-01))+(-1.7312762201691817e-01*x+1.9623575800646459e-01)*((x>=7.2500000000000009e-01)&(x<7.5000000000000000e-01))+(-1.5804068414128153e-01*x+1.8492055459973708e-01)*((x>=7.5000000000000000e-01)&(x<7.7500000000000013e-01))+(-1.4461979913916731e-01*x+1.7451936872309856e-01)*((x>=7.7500000000000013e-01)&(x<8.0000000000000004e-01))+(-1.3264629355645138e-01*x+1.6494056425692583e-01)*((x>=8.0000000000000004e-01)&(x<8.2500000000000018e-01))+(-1.2193422717643192e-01*x+1.5610310949340978e-01)*((x>=8.2500000000000018e-01)&(x<8.5000000000000009e-01))+(-1.1232496915896185e-01*x+1.4793524017856019e-01)*((x>=8.5000000000000009e-01)&(x<8.7500000000000000e-01))+(-1.0368274540227262e-01*x+1.4037329439145713e-01)*((x>=8.7500000000000000e-01)&(x<9.0000000000000013e-01))+(-9.5890973276958960e-02*x+1.3336069947867482e-01)*((x>=9.0000000000000013e-01)&(x<9.2500000000000004e-01))+(-8.8849235804020849e-02*x+1.2684709231620706e-01)*((x>=9.2500000000000004e-01)&(x<9.5000000000000018e-01))+(-8.2470776259528658e-02*x+1.2078755574893948e-01)*((x>=9.5000000000000018e-01)&(x<9.7500000000000009e-01))+(-7.6680417374423437e-02*x+1.1514195583596190e-01)*((x>=9.7500000000000009e-01)&(x<=1))

s81CompleteCubic = (1.3908374259572481e-01*x**3+5.2241094754242223e-01*x**2+7.0153516433909013e-01*x+3.5666949785393115e-01)*((x>=-1)&(x<-9.7499999999999998e-01))+(1.5637792276899046e-01*x**3+5.7299642454922428e-01*x**2+7.5085600442072198e-01*x+3.7269877088046155e-01)*((x>=-9.7499999999999998e-01)&(x<-9.4999999999999996e-01))+(1.7636562134934944e-01*x**3+6.2996136550324733e-01*x**2+8.0497269832704399e-01*x+3.8983572395079680e-01)*((x>=-9.4999999999999996e-01)&(x<-9.2500000000000004e-01))+(1.9940427734595978e-01*x**3+6.9389363589384101e-01*x**2+8.6411004843834316e-01*x+4.0806974023511400e-01)*((x>=-9.2500000000000004e-01)&(x<-9.0000000000000002e-01))+(2.2607271306749055e-01*x**3+7.6589841234197409e-01*x**2+9.2891434724166300e-01*x+4.2751102987611000e-01)*((x>=-9.0000000000000002e-01)&(x<-8.7500000000000000e-01))+(2.5702748058513669e-01*x**3+8.4715467707579517e-01*x**2+1.0000135788837563e+00*x+4.4824830577172059e-01)*((x>=-8.7500000000000000e-01)&(x<-8.4999999999999998e-01))+(2.9307218184186962e-01*x**3+9.3906866528046429e-01*x**2+1.0781404688577250e+00*x+4.7038425793101168e-01)*((x>=-8.4999999999999998e-01)&(x<-8.2499999999999996e-01))+(3.3517717212659620e-01*x**3+1.0432785162351625e+00*x**2+1.1641135958953512e+00*x+4.9402686786635885e-01)*((x>=-8.2499999999999996e-01)&(x<-8.0000000000000004e-01))+(3.8452185396575839e-01*x**3+1.1617057526491517e+00*x**2+1.2588553850265427e+00*x+5.1929134496800988e-01)*((x>=-8.0000000000000004e-01)&(x<-7.7500000000000002e-01))+(4.4254248304604044e-01*x**3+1.2966037152608074e+00*x**2+1.3634013060505759e+00*x+5.4629904123255191e-01)*((x>=-7.7500000000000002e-01)&(x<-7.5000000000000000e-01))+(5.1099281148852682e-01*x**3+1.4506169542564018e+00*x**2+1.4789112352972715e+00*x+5.7517652354422577e-01)*((x>=-7.5000000000000000e-01)&(x<-7.2499999999999998e-01))+(5.9201885946335853e-01*x**3+1.6268486086016607e+00*x**2+1.6066791846975841e+00*x+6.0605377798263471e-01)*((x>=-7.2499999999999998e-01)&(x<-6.9999999999999996e-01))+(6.8825117676767389e-01*x**3+1.8289364749407229e+00*x**2+1.7481406911349275e+00*x+6.3906146281801490e-01)*((x>=-6.9999999999999996e-01)&(x<-6.7500000000000004e-01))+(8.0291764343490557e-01*x**3+2.0611360699418673e+00*x**2+1.9048754177606999e+00*x+6.7432677630881366e-01)*((x>=-6.7500000000000004e-01)&(x<-6.4999999999999991e-01))+(9.3997965605086486e-01*x**3+2.3284069945429877e+00*x**2+2.0786015187514284e+00*x+7.1196743152347142e-01)*((x>=-6.4999999999999991e-01)&(x<-6.2500000000000000e-01))+(1.1042931854499625e+00*x**3+2.6364948621662960e+00*x**2+2.2711564360159961e+00*x+7.5208303928692299e-01)*((x>=-6.2500000000000000e-01)&(x<-5.9999999999999998e-01))+(1.3017928973858357e+00*x**3+2.9919943436508678e+00*x**2+2.4844561249067389e+00*x+7.9474297706507158e-01)*((x>=-5.9999999999999998e-01)&(x<-5.7499999999999996e-01))+(1.5396904781250502e+00*x**3+3.4023676704260128e+00*x**2+2.7204207878024471e+00*x+8.3996953745341574e-01)*((x>=-5.7499999999999996e-01)&(x<-5.5000000000000004e-01))+(1.8266643318911553e+00*x**3+3.8758745291400860e+00*x**2+2.9808495600951876e+00*x+8.8771481237375149e-01)*((x>=-5.5000000000000004e-01)&(x<-5.2499999999999991e-01))+(2.1729912422261726e+00*x**3+4.4213394129177379e+00*x**2+3.2672186240784553e+00*x+9.3782939857082326e-01)*((x>=-5.2499999999999991e-01)&(x<-5.0000000000000000e-01))+(2.5905214152827942e+00*x**3+5.0476346725026708e+00*x**2+3.5803662538709213e+00*x+9.9002067020290085e-01)*((x>=-5.0000000000000000e-01)&(x<-4.7499999999999998e-01))+(3.0923091346385068e+00*x**3+5.7626821725845607e+00*x**2+3.9200138164098193e+00*x+1.0437982009382263e+00)*((x>=-4.7499999999999998e-01)&(x<-4.4999999999999996e-01))+(3.6915522644536591e+00*x**3+6.5716603978350170e+00*x**2+4.2840540177725241e+00*x+1.0984042311426321e+00)*((x>=-4.4999999999999996e-01)&(x<-4.2499999999999993e-01))+(4.3992154842338040e+00*x**3+7.4739310030547017e+00*x**2+4.6675190249908898e+00*x+1.1527284404985674e+00)*((x>=-4.2499999999999993e-01)&(x<-3.9999999999999991e-01))+(5.2192357769043225e+00*x**3+8.4579553542593224e+00*x**2+5.0611287654727377e+00*x+1.2052097392294803e+00)*((x>=-3.9999999999999991e-01)&(x<-3.7500000000000000e-01))+(6.1394199580249635e+00*x**3+9.4931625580200443e+00*x**2+5.4493314668830095e+00*x+1.2537350769057642e+00)*((x>=-3.7500000000000000e-01)&(x<-3.4999999999999998e-01))+(7.1149063519508831e+00*x**3+1.0517423271642260e+01*x**2+5.8078227166507848e+00*x+1.2955590560453381e+00)*((x>=-3.4999999999999998e-01)&(x<-3.2499999999999996e-01))+(8.0393029647807754e+00*x**3+1.1418709969151406e+01*x**2+6.1007408933412570e+00*x+1.3272918585201392e+00)*((x>=-3.2499999999999996e-01)&(x<-2.9999999999999993e-01))+(8.6966164529432692e+00*x**3+1.2010292108497650e+01*x**2+6.2782155351451294e+00*x+1.3450393227005266e+00)*((x>=-2.9999999999999993e-01)&(x<-2.7499999999999991e-01))+(8.6863009915604597e+00*x**3+1.2001781852856832e+01*x**2+6.2758752148439054e+00*x+1.3448247933395809e+00)*((x>=-2.7499999999999991e-01)&(x<-2.5000000000000000e-01))+(7.3187026710195902e+00*x**3+1.0976083112451178e+01*x**2+6.0194505297424916e+00*x+1.3234560695811299e+00)*((x>=-2.5000000000000000e-01)&(x<-2.2499999999999998e-01))+(3.5000298696206724e+00*x**3+8.3984789715069095e+00*x**2+5.4394895980300317e+00*x+1.2799589997026954e+00)*((x>=-2.2499999999999998e-01)&(x<-1.9999999999999996e-01))+(-4.3133814207137737e+00*x**3+3.7104321973062433e+00*x**2+4.5018802431898983e+00*x+1.2174517093800199e+00)*((x>=-1.9999999999999996e-01)&(x<-1.7499999999999993e-01))+(-1.7885198114121881e+01*x**3-3.4147715667330116e+00*x**2+3.2549695844830300e+00*x+1.1447152542887857e+00)*((x>=-1.7499999999999993e-01)&(x<-1.4999999999999991e-01))+(-3.8311084152042085e+01*x**3-1.2606420283797098e+01*x**2+1.8762222769234174e+00*x+1.0757778889108049e+00)*((x>=-1.4999999999999991e-01)&(x<-1.2500000000000000e-01))+(-6.4073806234257418e+01*x**3-2.2267441064627850e+01*x**2+6.6859467931957361e-01*x+1.0254600723439784e+00)*((x>=-1.2500000000000000e-01)&(x<-9.9999999999999978e-02))+(-8.8388919477952996e+01*x**3-2.9561975037736520e+01*x**2-6.0858717991293609e-02*x+1.0011449591002828e+00)*((x>=-9.9999999999999978e-02)&(x<-7.4999999999999956e-02))+(-9.8315431606911034e+01*x**3-3.1795440266752077e+01*x**2-2.2836861016746046e-01*x+9.9695721179587848e-01)*((x>=-7.4999999999999956e-02)&(x<-4.9999999999999933e-02))+(-8.0079968363297638e+01*x**3-2.9060120780210070e+01*x**2-9.1602635840359770e-02*x+9.9923664470133045e-01)*((x>=-4.9999999999999933e-02)&(x<-2.4999999999999911e-02))+(-3.1225229248437657e+01*x**3-2.5396015346595586e+01*x**2+1.6306400674181987e-15*x+1.0000000000000002e+00)*((x>=-2.4999999999999911e-02)&(x<0))+(3.1225229248436339e+01*x**3-2.5396015346595586e+01*x**2+1.3322676295501878e-15*x+1)*((x>=0)&(x<2.5000000000000133e-02))+(8.0079968363299415e+01*x**3-2.9060120780210337e+01*x**2+9.1602635840371038e-02*x+9.9923664470133022e-01)*((x>=2.5000000000000133e-02)&(x<5.0000000000000044e-02))+(9.8315431606913023e+01*x**3-3.1795440266752379e+01*x**2+2.2836861016747312e-01*x+9.9695721179587848e-01)*((x>=5.0000000000000044e-02)&(x<7.4999999999999956e-02))+(8.8388919477948434e+01*x**3-2.9561975037735348e+01*x**2+6.0858717991194800e-02*x+1.0011449591002854e+00)*((x>=7.4999999999999956e-02)&(x<1.0000000000000009e-01))+(6.4073806234264168e+01*x**3-2.2267441064630059e+01*x**2-6.6859467931933358e-01*x+1.0254600723439700e+00)*((x>=1.0000000000000009e-01)&(x<1.2500000000000000e-01))+(3.8311084152033999e+01*x**3-1.2606420283793749e+01*x**2-1.8762222769238730e+00*x+1.0757778889108256e+00)*((x>=1.2500000000000000e-01)&(x<1.5000000000000013e-01))+(1.7885198114124982e+01*x**3-3.4147715667346823e+00*x**2-3.2549695844827333e+00*x+1.1447152542887686e+00)*((x>=1.5000000000000013e-01)&(x<1.7500000000000004e-01))+(4.3133814207178753e+00*x**3+3.7104321973040499e+00*x**2-4.5018802431895129e+00*x+1.2174517093799972e+00)*((x>=1.7500000000000004e-01)&(x<2.0000000000000018e-01))+(-3.5000298696282077e+00*x**3+8.3984789715117039e+00*x**2-5.4394895980310443e+00*x+1.2799589997027663e+00)*((x>=2.0000000000000018e-01)&(x<2.2500000000000009e-01))+(-7.3187026710129670e+00*x**3+1.0976083112446418e+01*x**2-6.0194505297413547e+00*x+1.3234560695810398e+00)*((x>=2.2500000000000009e-01)&(x<2.5000000000000000e-01))+(-8.6863009915637104e+00*x**3+1.2001781852859475e+01*x**2-6.2758752148446195e+00*x+1.3448247933396451e+00)*((x>=2.5000000000000000e-01)&(x<2.7500000000000013e-01))+(-8.6966164529441361e+00*x**3+1.2010292108498327e+01*x**2-6.2782155351453035e+00*x+1.3450393227005411e+00)*((x>=2.7500000000000013e-01)&(x<3.0000000000000004e-01))+(-8.0393029647778445e+00*x**3+1.1418709969148663e+01*x**2-6.1007408933404044e+00*x+1.3272918585200510e+00)*((x>=3.0000000000000004e-01)&(x<3.2500000000000018e-01))+(-7.1149063519532882e+00*x**3+1.0517423271644722e+01*x**2-5.8078227166516232e+00*x+1.2955590560454331e+00)*((x>=3.2500000000000018e-01)&(x<3.5000000000000009e-01))+(-6.1394199580234456e+00*x**3+9.4931625580183869e+00*x**2-5.4493314668824064e+00*x+1.2537350769056912e+00)*((x>=3.5000000000000009e-01)&(x<3.7500000000000000e-01))+(-5.2192357769057987e+00*x**3+8.4579553542610331e+00*x**2-5.0611287654733985e+00*x+1.2052097392295651e+00)*((x>=3.7500000000000000e-01)&(x<4.0000000000000013e-01))+(-4.3992154842319282e+00*x**3+7.4739310030523889e+00*x**2-4.6675190249899403e+00*x+1.1527284404984375e+00)*((x>=4.0000000000000013e-01)&(x<4.2500000000000004e-01))+(-3.6915522644551264e+00*x**3+6.5716603978369665e+00*x**2-4.2840540177733857e+00*x+1.0984042311427589e+00)*((x>=4.2500000000000004e-01)&(x<4.5000000000000018e-01))+(-3.0923091346388376e+00*x**3+5.7626821725849755e+00*x**2-3.9200138164099902e+00*x+1.0437982009382496e+00)*((x>=4.5000000000000018e-01)&(x<4.7500000000000009e-01))+(-2.5905214152810472e+00*x**3+5.0476346725001244e+00*x**2-3.5803662538696854e+00*x+9.9002067020270135e-01)*((x>=4.7500000000000009e-01)&(x<5.0000000000000000e-01))+(-2.1729912422277224e+00*x**3+4.4213394129201369e+00*x**2-3.2672186240796925e+00*x+9.3782939857103575e-01)*((x>=5.0000000000000000e-01)&(x<5.2500000000000013e-01))+(-1.8266643318905704e+00*x**3+3.8758745291391223e+00*x**2-2.9808495600946596e+00*x+8.8771481237365490e-01)*((x>=5.2500000000000013e-01)&(x<5.5000000000000004e-01))+(-1.5396904781245866e+00*x**3+3.4023676704252495e+00*x**2-2.7204207878020292e+00*x+8.3996953745333935e-01)*((x>=5.5000000000000004e-01)&(x<5.7500000000000018e-01))+(-1.3017928973867223e+00*x**3+2.9919943436524337e+00*x**2-2.4844561249076600e+00*x+7.9474297706525210e-01)*((x>=5.7500000000000018e-01)&(x<6.0000000000000009e-01))+(-1.1042931854497484e+00*x**3+2.6364948621658804e+00*x**2-2.2711564360157279e+00*x+7.5208303928686548e-01)*((x>=6.0000000000000009e-01)&(x<6.2500000000000000e-01))+(-9.3997965605015110e-01*x**3+2.3284069945416350e+00*x**2-2.0786015187505749e+00*x+7.1196743152329200e-01)*((x>=6.2500000000000000e-01)&(x<6.5000000000000013e-01))+(-8.0291764343532268e-01*x**3+2.0611360699427199e+00*x**2-1.9048754177612799e+00*x+6.7432677630894478e-01)*((x>=6.5000000000000013e-01)&(x<6.7500000000000004e-01))+(-6.8825117676866687e-01*x**3+1.8289364749427417e+00*x**2-1.7481406911362944e+00*x+6.3906146281832310e-01)*((x>=6.7500000000000004e-01)&(x<7.0000000000000018e-01))+(-5.9201885946158039e-01*x**3+1.6268486085978600e+00*x**2-1.6066791846948774e+00*x+6.0605377798199234e-01)*((x>=7.0000000000000018e-01)&(x<7.2500000000000009e-01))+(-5.1099281149007747e-01*x**3+1.4506169542598411e+00*x**2-1.4789112352998135e+00*x+5.7517652354485194e-01)*((x>=7.2500000000000009e-01)&(x<7.5000000000000000e-01))+(-4.4254248304482086e-01*x**3+1.2966037152580139e+00*x**2-1.3634013060484431e+00*x+5.4629904123200934e-01)*((x>=7.5000000000000000e-01)&(x<7.7500000000000013e-01))+(-3.8452185396649208e-01*x**3+1.1617057526508994e+00*x**2-1.2588553850279294e+00*x+5.1929134496837670e-01)*((x>=7.7500000000000013e-01)&(x<8.0000000000000004e-01))+(-3.3517717212648962e-01*x**3+1.0432785162348934e+00*x**2-1.1641135958951248e+00*x+4.9402686786629540e-01)*((x>=8.0000000000000004e-01)&(x<8.2500000000000018e-01))+(-2.9307218184187050e-01*x**3+9.3906866528046118e-01*x**2-1.0781404688577181e+00*x+4.7038425793100846e-01)*((x>=8.2500000000000018e-01)&(x<8.5000000000000009e-01))+(-2.5702748058500907e-01*x**3+8.4715467707546444e-01*x**2-1.0000135788834708e+00*x+4.4824830577163849e-01)*((x>=8.5000000000000009e-01)&(x<8.7500000000000000e-01))+(-2.2607271306750024e-01*x**3+7.6589841234200373e-01*x**2-9.2891434724169264e-01*x+4.2751102987611989e-01)*((x>=8.7500000000000000e-01)&(x<9.0000000000000013e-01))+(-1.9940427734588442e-01*x**3+6.9389363589364106e-01*x**2-8.6411004843816630e-01*x+4.0806974023506198e-01)*((x>=9.0000000000000013e-01)&(x<9.2500000000000004e-01))+(-1.7636562134984970e-01*x**3+6.2996136550464465e-01*x**2-8.0497269832834473e-01*x+3.8983572395120025e-01)*((x>=9.2500000000000004e-01)&(x<9.5000000000000018e-01))+(-1.5637792276818516e-01*x**3+5.7299642454690058e-01*x**2-7.5085600441848777e-01*x+3.7269877087974557e-01)*((x>=9.5000000000000018e-01)&(x<9.7500000000000009e-01))+(-1.3908374259652073e-01*x**3+5.2241094754478223e-01*x**2-7.0153516434142238e-01*x+3.5666949785469937e-01)*((x>=9.7500000000000009e-01)&(x<=1))

s81NatureCubic = (1.9169128324617173e+00*x**3+5.7507384973851519e+00*x**2+5.8262208442392867e+00*x+2.0308567177773909e+00)*((x>=-1)&(x<-9.7499999999999998e-01))+(-3.1998994614115972e-01*x**3-7.9220213002826323e-01*x**2-5.5314626748879270e-01*x-4.2437593534235041e-02)*((x>=-9.7499999999999998e-01)&(x<-9.4999999999999996e-01))+(3.0400800712395959e-01*x**3+9.8619203677732670e-01*x**2+1.1363281909765179e+00*x+4.9256265164644658e-01)*((x>=-9.4999999999999996e-01)&(x<-9.2500000000000004e-01))+(1.6520260315767130e-01*x**3+6.0100704077087663e-01*x**2+7.8003206967055139e-01*x+3.8270468091044030e-01)*((x>=-9.2500000000000004e-01)&(x<-9.0000000000000002e-01))+(2.3523702404603455e-01*x**3+7.9009997716945757e-01*x**2+9.5021571242927416e-01*x+4.3375977373805719e-01)*((x>=-9.0000000000000002e-01)&(x<-8.7500000000000000e-01))+(2.5457191085924791e-01*x**3+8.4085405505414257e-01*x**2+9.9462553057837355e-01*x+4.4671263736487782e-01)*((x>=-8.7500000000000000e-01)&(x<-8.4999999999999998e-01))+(2.9373014976688033e-01*x**3+9.4070756426860536e-01*x**2+1.0795010134106668e+00*x+4.7076069083402761e-01)*((x>=-8.4999999999999998e-01)&(x<-8.2499999999999996e-01))+(3.3500087015244401e-01*x**3+1.0428525972228753e+00*x**2+1.1637706655979398e+00*x+4.9393484518552760e-01)*((x>=-8.2499999999999996e-01)&(x<-8.0000000000000004e-01))+(3.8456909393735583e-01*x**3+1.1618163343066636e+00*x**2+1.2589416552649704e+00*x+5.1931377576340243e-01)*((x>=-8.0000000000000004e-01)&(x<-7.7500000000000002e-01))+(4.4252982513380057e-01*x**3+1.2965750343383977e+00*x**2+1.3633796477895643e+00*x+5.4629359049892257e-01)*((x>=-7.7500000000000002e-01)&(x<-7.5000000000000000e-01))+(5.1099620316588945e-01*x**3+1.4506243849105978e+00*x**2+1.4789166607187143e+00*x+5.7517784373121006e-01)*((x>=-7.5000000000000000e-01)&(x<-7.2499999999999998e-01))+(5.9201795066614704e-01*x**3+1.6268466857236579e+00*x**2+1.6066778288081829e+00*x+6.0605345935283161e-01)*((x>=-7.2499999999999998e-01)&(x<-6.9999999999999996e-01))+(6.8825142027915520e-01*x**3+1.8289369719109749e+00*x**2+1.7481410291393049e+00*x+6.3906153943009336e-01)*((x>=-6.9999999999999996e-01)&(x<-6.7500000000000004e-01))+(8.0291757818619980e-01*x**3+2.0611359416727404e+00*x**2+1.9048753337284965e+00*x+6.7432675796266150e-01)*((x>=-6.7500000000000004e-01)&(x<-6.4999999999999991e-01))+(9.3997967353420264e-01*x**3+2.3284070276013460e+00*x**2+2.0786015395820900e+00*x+7.1196743589760680e-01)*((x>=-6.4999999999999991e-01)&(x<-6.2500000000000000e-01))+(1.1042931807653156e+00*x**3+2.6364948536596824e+00*x**2+2.2711564308685506e+00*x+7.5208303824895273e-01)*((x>=-6.2500000000000000e-01)&(x<-5.9999999999999998e-01))+(1.3017928986410849e+00*x**3+2.9919943458360674e+00*x**2+2.4844561261743818e+00*x+7.9474297731011889e-01)*((x>=-5.9999999999999998e-01)&(x<-5.7499999999999996e-01))+(1.5396904777887059e+00*x**3+3.4023676698657139e+00*x**2+2.7204207874914283e+00*x+8.3996953739588620e-01)*((x>=-5.7499999999999996e-01)&(x<-5.5000000000000004e-01))+(1.8266643319812788e+00*x**3+3.8758745292834584e+00*x**2+2.9808495601711877e+00*x+8.8771481238717542e-01)*((x>=-5.5000000000000004e-01)&(x<-5.2499999999999991e-01))+(2.1729912422020230e+00*x**3+4.4213394128811307e+00*x**2+3.2672186240599657e+00*x+9.3782939856771153e-01)*((x>=-5.2499999999999991e-01)&(x<-5.0000000000000000e-01))+(2.5905214152892633e+00*x**3+5.0476346725119914e+00*x**2+3.5803662538753960e+00*x+9.9002067020361662e-01)*((x>=-5.0000000000000000e-01)&(x<-4.7499999999999998e-01))+(3.0923091346367779e+00*x**3+5.7626821725821991e+00*x**2+3.9200138164087450e+00*x+1.0437982009380635e+00)*((x>=-4.7499999999999998e-01)&(x<-4.4999999999999996e-01))+(3.6915522644541241e+00*x**3+6.5716603978356165e+00*x**2+4.2840540177727826e+00*x+1.0984042311426692e+00)*((x>=-4.4999999999999996e-01)&(x<-4.2499999999999993e-01))+(4.3992154842336673e+00*x**3+7.4739310030545338e+00*x**2+4.6675190249908223e+00*x+1.1527284404985583e+00)*((x>=-4.2499999999999993e-01)&(x<-3.9999999999999991e-01))+(5.2192357769043705e+00*x**3+8.4579553542593793e+00*x**2+5.0611287654727599e+00*x+1.2052097392294832e+00)*((x>=-3.9999999999999991e-01)&(x<-3.7500000000000000e-01))+(6.1394199580249404e+00*x**3+9.4931625580200194e+00*x**2+5.4493314668829997e+00*x+1.2537350769057631e+00)*((x>=-3.7500000000000000e-01)&(x<-3.4999999999999998e-01))+(7.1149063519508955e+00*x**3+1.0517423271642272e+01*x**2+5.8078227166507883e+00*x+1.2955590560453385e+00)*((x>=-3.4999999999999998e-01)&(x<-3.2499999999999996e-01))+(8.0393029647807754e+00*x**3+1.1418709969151406e+01*x**2+6.1007408933412570e+00*x+1.3272918585201392e+00)*((x>=-3.2499999999999996e-01)&(x<-2.9999999999999993e-01))+(8.6966164529432692e+00*x**3+1.2010292108497650e+01*x**2+6.2782155351451294e+00*x+1.3450393227005266e+00)*((x>=-2.9999999999999993e-01)&(x<-2.7499999999999991e-01))+(8.6863009915604597e+00*x**3+1.2001781852856832e+01*x**2+6.2758752148439054e+00*x+1.3448247933395809e+00)*((x>=-2.7499999999999991e-01)&(x<-2.5000000000000000e-01))+(7.3187026710195902e+00*x**3+1.0976083112451178e+01*x**2+6.0194505297424916e+00*x+1.3234560695811299e+00)*((x>=-2.5000000000000000e-01)&(x<-2.2499999999999998e-01))+(3.5000298696206724e+00*x**3+8.3984789715069095e+00*x**2+5.4394895980300317e+00*x+1.2799589997026954e+00)*((x>=-2.2499999999999998e-01)&(x<-1.9999999999999996e-01))+(-4.3133814207137737e+00*x**3+3.7104321973062433e+00*x**2+4.5018802431898983e+00*x+1.2174517093800199e+00)*((x>=-1.9999999999999996e-01)&(x<-1.7499999999999993e-01))+(-1.7885198114121881e+01*x**3-3.4147715667330116e+00*x**2+3.2549695844830300e+00*x+1.1447152542887857e+00)*((x>=-1.7499999999999993e-01)&(x<-1.4999999999999991e-01))+(-3.8311084152042085e+01*x**3-1.2606420283797098e+01*x**2+1.8762222769234174e+00*x+1.0757778889108049e+00)*((x>=-1.4999999999999991e-01)&(x<-1.2500000000000000e-01))+(-6.4073806234257418e+01*x**3-2.2267441064627850e+01*x**2+6.6859467931957361e-01*x+1.0254600723439784e+00)*((x>=-1.2500000000000000e-01)&(x<-9.9999999999999978e-02))+(-8.8388919477952996e+01*x**3-2.9561975037736520e+01*x**2-6.0858717991293609e-02*x+1.0011449591002828e+00)*((x>=-9.9999999999999978e-02)&(x<-7.4999999999999956e-02))+(-9.8315431606911034e+01*x**3-3.1795440266752077e+01*x**2-2.2836861016746046e-01*x+9.9695721179587848e-01)*((x>=-7.4999999999999956e-02)&(x<-4.9999999999999933e-02))+(-8.0079968363297638e+01*x**3-2.9060120780210070e+01*x**2-9.1602635840359770e-02*x+9.9923664470133045e-01)*((x>=-4.9999999999999933e-02)&(x<-2.4999999999999911e-02))+(-3.1225229248437657e+01*x**3-2.5396015346595586e+01*x**2+1.6306400674181987e-15*x+1.0000000000000002e+00)*((x>=-2.4999999999999911e-02)&(x<0))+(3.1225229248436339e+01*x**3-2.5396015346595586e+01*x**2+1.3322676295501878e-15*x+1)*((x>=0)&(x<2.5000000000000133e-02))+(8.0079968363299415e+01*x**3-2.9060120780210337e+01*x**2+9.1602635840371038e-02*x+9.9923664470133022e-01)*((x>=2.5000000000000133e-02)&(x<5.0000000000000044e-02))+(9.8315431606913023e+01*x**3-3.1795440266752379e+01*x**2+2.2836861016747312e-01*x+9.9695721179587848e-01)*((x>=5.0000000000000044e-02)&(x<7.4999999999999956e-02))+(8.8388919477948434e+01*x**3-2.9561975037735348e+01*x**2+6.0858717991194800e-02*x+1.0011449591002854e+00)*((x>=7.4999999999999956e-02)&(x<1.0000000000000009e-01))+(6.4073806234264168e+01*x**3-2.2267441064630059e+01*x**2-6.6859467931933358e-01*x+1.0254600723439700e+00)*((x>=1.0000000000000009e-01)&(x<1.2500000000000000e-01))+(3.8311084152033999e+01*x**3-1.2606420283793749e+01*x**2-1.8762222769238730e+00*x+1.0757778889108256e+00)*((x>=1.2500000000000000e-01)&(x<1.5000000000000013e-01))+(1.7885198114124982e+01*x**3-3.4147715667346823e+00*x**2-3.2549695844827333e+00*x+1.1447152542887686e+00)*((x>=1.5000000000000013e-01)&(x<1.7500000000000004e-01))+(4.3133814207178753e+00*x**3+3.7104321973040499e+00*x**2-4.5018802431895129e+00*x+1.2174517093799972e+00)*((x>=1.7500000000000004e-01)&(x<2.0000000000000018e-01))+(-3.5000298696282077e+00*x**3+8.3984789715117039e+00*x**2-5.4394895980310443e+00*x+1.2799589997027663e+00)*((x>=2.0000000000000018e-01)&(x<2.2500000000000009e-01))+(-7.3187026710129670e+00*x**3+1.0976083112446418e+01*x**2-6.0194505297413547e+00*x+1.3234560695810398e+00)*((x>=2.2500000000000009e-01)&(x<2.5000000000000000e-01))+(-8.6863009915637104e+00*x**3+1.2001781852859475e+01*x**2-6.2758752148446195e+00*x+1.3448247933396451e+00)*((x>=2.5000000000000000e-01)&(x<2.7500000000000013e-01))+(-8.6966164529441361e+00*x**3+1.2010292108498327e+01*x**2-6.2782155351453035e+00*x+1.3450393227005411e+00)*((x>=2.7500000000000013e-01)&(x<3.0000000000000004e-01))+(-8.0393029647778445e+00*x**3+1.1418709969148663e+01*x**2-6.1007408933404044e+00*x+1.3272918585200510e+00)*((x>=3.0000000000000004e-01)&(x<3.2500000000000018e-01))+(-7.1149063519532882e+00*x**3+1.0517423271644722e+01*x**2-5.8078227166516232e+00*x+1.2955590560454331e+00)*((x>=3.2500000000000018e-01)&(x<3.5000000000000009e-01))+(-6.1394199580234394e+00*x**3+9.4931625580183798e+00*x**2-5.4493314668824038e+00*x+1.2537350769056910e+00)*((x>=3.5000000000000009e-01)&(x<3.7500000000000000e-01))+(-5.2192357769058280e+00*x**3+8.4579553542610668e+00*x**2-5.0611287654734110e+00*x+1.2052097392295669e+00)*((x>=3.7500000000000000e-01)&(x<4.0000000000000013e-01))+(-4.3992154842318074e+00*x**3+7.4739310030522423e+00*x**2-4.6675190249898817e+00*x+1.1527284404984297e+00)*((x>=4.0000000000000013e-01)&(x<4.2500000000000004e-01))+(-3.6915522644555914e+00*x**3+6.5716603978375661e+00*x**2-4.2840540177736433e+00*x+1.0984042311427960e+00)*((x>=4.2500000000000004e-01)&(x<4.5000000000000018e-01))+(-3.0923091346371030e+00*x**3+5.7626821725826058e+00*x**2-3.9200138164089120e+00*x+1.0437982009380860e+00)*((x>=4.5000000000000018e-01)&(x<4.7500000000000009e-01))+(-2.5905214152875162e+00*x**3+5.0476346725094450e+00*x**2-3.5803662538741605e+00*x+9.9002067020341711e-01)*((x>=4.7500000000000009e-01)&(x<5.0000000000000000e-01))+(-2.1729912422035755e+00*x**3+4.4213394128835342e+00*x**2-3.2672186240612047e+00*x+9.3782939856792447e-01)*((x>=5.0000000000000000e-01)&(x<5.2500000000000013e-01))+(-1.8266643319806939e+00*x**3+3.8758745292824957e+00*x**2-2.9808495601706593e+00*x+8.8771481238707906e-01)*((x>=5.2500000000000013e-01)&(x<5.5000000000000004e-01))+(-1.5396904777882439e+00*x**3+3.4023676698649528e+00*x**2-2.7204207874910109e+00*x+8.3996953739581026e-01)*((x>=5.5000000000000004e-01)&(x<5.7500000000000018e-01))+(-1.3017928986419700e+00*x**3+2.9919943458376306e+00*x**2-2.4844561261753002e+00*x+7.9474297731029897e-01)*((x>=5.7500000000000018e-01)&(x<6.0000000000000009e-01))+(-1.1042931807651015e+00*x**3+2.6364948536592667e+00*x**2-2.2711564308682823e+00*x+7.5208303824889533e-01)*((x>=6.0000000000000009e-01)&(x<6.2500000000000000e-01))+(-9.3997967353348877e-01*x**3+2.3284070275999933e+00*x**2-2.0786015395812365e+00*x+7.1196743589742728e-01)*((x>=6.2500000000000000e-01)&(x<6.5000000000000013e-01))+(-8.0291757818661846e-01*x**3+2.0611359416735962e+00*x**2-1.9048753337290782e+00*x+6.7432675796279307e-01)*((x>=6.5000000000000013e-01)&(x<6.7500000000000004e-01))+(-6.8825142028014519e-01*x**3+1.8289369719129875e+00*x**2-1.7481410291406674e+00*x+6.3906153943040067e-01)*((x>=6.7500000000000004e-01)&(x<7.0000000000000018e-01))+(-5.9201795066437024e-01*x**3+1.6268466857198600e+00*x**2-1.6066778288054782e+00*x+6.0605345935218979e-01)*((x>=7.0000000000000018e-01)&(x<7.2500000000000009e-01))+(-5.1099620316743943e-01*x**3+1.4506243849140357e+00*x**2-1.4789166607212554e+00*x+5.7517784373183600e-01)*((x>=7.2500000000000009e-01)&(x<7.5000000000000000e-01))+(-4.4252982513258105e-01*x**3+1.2965750343356042e+00*x**2-1.3633796477874318e+00*x+5.4629359049838011e-01)*((x>=7.5000000000000000e-01)&(x<7.7500000000000013e-01))+(-3.8456909393809030e-01*x**3+1.1618163343084131e+00*x**2-1.2589416552663586e+00*x+5.1931377576376958e-01)*((x>=7.7500000000000013e-01)&(x<8.0000000000000004e-01))+(-3.3500087015233743e-01*x**3+1.0428525972226061e+00*x**2-1.1637706655977134e+00*x+4.9393484518546416e-01)*((x>=8.0000000000000004e-01)&(x<8.2500000000000018e-01))+(-2.9373014976688089e-01*x**3+9.4070756426860136e-01*x**2-1.0795010134106591e+00*x+4.7076069083402416e-01)*((x>=8.2500000000000018e-01)&(x<8.5000000000000009e-01))+(-2.5457191085912095e-01*x**3+8.4085405505381350e-01*x**2-9.9462553057808956e-01*x+4.4671263736479616e-01)*((x>=8.5000000000000009e-01)&(x<8.7500000000000000e-01))+(-2.3523702404604205e-01*x**3+7.9009997716948133e-01*x**2-9.5021571242929892e-01*x+4.3375977373806551e-01)*((x>=8.7500000000000000e-01)&(x<9.0000000000000013e-01))+(-1.6520260315760504e-01*x**3+6.0100704077070133e-01*x**2-7.8003206967039684e-01*x+3.8270468091039495e-01)*((x>=9.0000000000000013e-01)&(x<9.2500000000000004e-01))+(-3.0400800712442538e-01*x**3+9.8619203677862788e-01*x**2-1.1363281909777290e+00*x+4.9256265164682234e-01)*((x>=9.2500000000000004e-01)&(x<9.5000000000000018e-01))+(3.1998994614184245e-01*x**3-7.9220213003023576e-01*x**2+5.5314626749069173e-01*x-4.2437593534844331e-02)*((x>=9.5000000000000018e-01)&(x<9.7500000000000009e-01))+(-1.9169128324620528e+00*x**3+5.7507384973861582e+00*x**2-5.8262208442402930e+00*x+2.0308567177777261e+00)*((x>=9.7500000000000009e-01)&(x<=1))

s81SecondDerivativesCubic = (1.3397852983556084e+00*x**3+4.0534933552397883e+00*x**2+4.1626204304713790e+00*x+1.4873739120487373e+00)*((x>=-1)&(x<-9.7499999999999998e-01))+(-1.6534908944766266e-01*x**3-3.4902472908477944e-01*x**2-1.2983470174507467e-01*x+9.2325994078389956e-02)*((x>=-9.7499999999999998e-01)&(x<-9.4999999999999996e-01))+(2.6257211445608014e-01*x**3+8.7055070204088747e-01*x**2+1.0287619578243088e+00*x+4.5921493627536136e-01)*((x>=-9.4999999999999996e-01)&(x<-9.2500000000000004e-01))+(1.7630531713569231e-01*x**3+6.3116033947681127e-01*x**2+8.0732587245253828e-01*x+3.9093880995239877e-01)*((x>=-9.2500000000000004e-01)&(x<-9.0000000000000002e-01))+(2.3226206080183012e-01*x**3+7.8224354737538337e-01*x**2+9.4330075956125314e-01*x+4.3173127608501327e-01)*((x>=-9.0000000000000002e-01)&(x<-8.7500000000000000e-01))+(2.5536904985804459e-01*x**3+8.4289939364794630e-01*x**2+9.9637462504974583e-01*x+4.4721115351915697e-01)*((x>=-8.7500000000000000e-01)&(x<-8.4999999999999998e-01))+(2.9351655701589718e-01*x**3+9.4017553690047051e-01*x**2+1.0790593468143912e+00*x+4.7063849135247310e-01)*((x>=-8.4999999999999998e-01)&(x<-8.2499999999999996e-01))+(3.3505810215757909e-01*x**3+1.0429908611261332e+00*x**2+1.1638819893005630e+00*x+4.9396471803617037e-01)*((x>=-8.2499999999999996e-01)&(x<-8.0000000000000004e-01))+(3.8455375866779939e-01*x**3+1.1617804367506619e+00*x**2+1.2589136498001861e+00*x+5.1930649416940322e-01)*((x>=-8.0000000000000004e-01)&(x<-7.7500000000000002e-01))+(4.4253393420689346e-01*x**3+1.2965843448790557e+00*x**2+1.3633866785996913e+00*x+5.4629535994260880e-01)*((x>=-7.7500000000000002e-01)&(x<-7.5000000000000000e-01))+(5.1099510214307209e-01*x**3+1.4506219727354575e+00*x**2+1.4789148994919925e+00*x+5.7517741516568399e-01)*((x>=-7.5000000000000000e-01)&(x<-7.2499999999999998e-01))+(5.9201824568432282e-01*x**3+1.6268473099376779e+00*x**2+1.6066782689636023e+00*x+6.0605356278798972e-01)*((x>=-7.2499999999999998e-01)&(x<-6.9999999999999996e-01))+(6.8825134122927301e-01*x**3+1.8289368105820731e+00*x**2+1.7481409194146789e+00*x+6.3906151455990767e-01)*((x>=-6.9999999999999996e-01)&(x<-6.7500000000000004e-01))+(8.0291759936755058e-01*x**3+2.0611359833120853e+00*x**2+1.9048753610074372e+00*x+6.7432676391827817e-01)*((x>=-6.7500000000000004e-01)&(x<-6.4999999999999991e-01))+(9.3997966785867737e-01*x**3+2.3284070168697824e+00*x**2+2.0786015328199401e+00*x+7.1196743447765387e-01)*((x>=-6.4999999999999991e-01)&(x<-6.2500000000000000e-01))+(1.1042931822860695e+00*x**3+2.6364948564211428e+00*x**2+2.2711564325395406e+00*x+7.5208303858590397e-01)*((x>=-6.2500000000000000e-01)&(x<-5.9999999999999998e-01))+(1.3017928982335991e+00*x**3+2.9919943451266962e+00*x**2+2.4844561257628723e+00*x+7.9474297723057030e-01)*((x>=-5.9999999999999998e-01)&(x<-5.7499999999999996e-01))+(1.5396904778978928e+00*x**3+3.4023676700476022e+00*x**2+2.7204207875923938e+00*x+8.3996953741456193e-01)*((x>=-5.7499999999999996e-01)&(x<-5.5000000000000004e-01))+(1.8266643319520190e+00*x**3+3.8758745292369108e+00*x**2+2.9808495601465133e+00*x+8.8771481238281724e-01)*((x>=-5.5000000000000004e-01)&(x<-5.2499999999999991e-01))+(2.1729912422098656e+00*x**3+4.4213394128930190e+00*x**2+3.2672186240659702e+00*x+9.3782939856872205e-01)*((x>=-5.2499999999999991e-01)&(x<-5.0000000000000000e-01))+(2.5905214152871614e+00*x**3+5.0476346725089627e+00*x**2+3.5803662538739420e+00*x+9.9002067020338402e-01)*((x>=-5.0000000000000000e-01)&(x<-4.7499999999999998e-01))+(3.0923091346373432e+00*x**3+5.7626821725829718e+00*x**2+3.9200138164090963e+00*x+1.0437982009381168e+00)*((x>=-4.7499999999999998e-01)&(x<-4.4999999999999996e-01))+(3.6915522644539673e+00*x**3+6.5716603978354149e+00*x**2+4.2840540177726947e+00*x+1.0984042311426565e+00)*((x>=-4.4999999999999996e-01)&(x<-4.2499999999999993e-01))+(4.3992154842337268e+00*x**3+7.4739310030546076e+00*x**2+4.6675190249908525e+00*x+1.1527284404985623e+00)*((x>=-4.2499999999999993e-01)&(x<-3.9999999999999991e-01))+(5.2192357769043349e+00*x**3+8.4579553542593366e+00*x**2+5.0611287654727439e+00*x+1.2052097392294812e+00)*((x>=-3.9999999999999991e-01)&(x<-3.7500000000000000e-01))+(6.1394199580249635e+00*x**3+9.4931625580200443e+00*x**2+5.4493314668830095e+00*x+1.2537350769057642e+00)*((x>=-3.7500000000000000e-01)&(x<-3.4999999999999998e-01))+(7.1149063519508831e+00*x**3+1.0517423271642260e+01*x**2+5.8078227166507848e+00*x+1.2955590560453381e+00)*((x>=-3.4999999999999998e-01)&(x<-3.2499999999999996e-01))+(8.0393029647807754e+00*x**3+1.1418709969151406e+01*x**2+6.1007408933412570e+00*x+1.3272918585201392e+00)*((x>=-3.2499999999999996e-01)&(x<-2.9999999999999993e-01))+(8.6966164529432692e+00*x**3+1.2010292108497650e+01*x**2+6.2782155351451294e+00*x+1.3450393227005266e+00)*((x>=-2.9999999999999993e-01)&(x<-2.7499999999999991e-01))+(8.6863009915604597e+00*x**3+1.2001781852856832e+01*x**2+6.2758752148439054e+00*x+1.3448247933395809e+00)*((x>=-2.7499999999999991e-01)&(x<-2.5000000000000000e-01))+(7.3187026710195902e+00*x**3+1.0976083112451178e+01*x**2+6.0194505297424916e+00*x+1.3234560695811299e+00)*((x>=-2.5000000000000000e-01)&(x<-2.2499999999999998e-01))+(3.5000298696206724e+00*x**3+8.3984789715069095e+00*x**2+5.4394895980300317e+00*x+1.2799589997026954e+00)*((x>=-2.2499999999999998e-01)&(x<-1.9999999999999996e-01))+(-4.3133814207137737e+00*x**3+3.7104321973062433e+00*x**2+4.5018802431898983e+00*x+1.2174517093800199e+00)*((x>=-1.9999999999999996e-01)&(x<-1.7499999999999993e-01))+(-1.7885198114121881e+01*x**3-3.4147715667330116e+00*x**2+3.2549695844830300e+00*x+1.1447152542887857e+00)*((x>=-1.7499999999999993e-01)&(x<-1.4999999999999991e-01))+(-3.8311084152042085e+01*x**3-1.2606420283797098e+01*x**2+1.8762222769234174e+00*x+1.0757778889108049e+00)*((x>=-1.4999999999999991e-01)&(x<-1.2500000000000000e-01))+(-6.4073806234257418e+01*x**3-2.2267441064627850e+01*x**2+6.6859467931957361e-01*x+1.0254600723439784e+00)*((x>=-1.2500000000000000e-01)&(x<-9.9999999999999978e-02))+(-8.8388919477952996e+01*x**3-2.9561975037736520e+01*x**2-6.0858717991293609e-02*x+1.0011449591002828e+00)*((x>=-9.9999999999999978e-02)&(x<-7.4999999999999956e-02))+(-9.8315431606911034e+01*x**3-3.1795440266752077e+01*x**2-2.2836861016746046e-01*x+9.9695721179587848e-01)*((x>=-7.4999999999999956e-02)&(x<-4.9999999999999933e-02))+(-8.0079968363297638e+01*x**3-2.9060120780210070e+01*x**2-9.1602635840359770e-02*x+9.9923664470133045e-01)*((x>=-4.9999999999999933e-02)&(x<-2.4999999999999911e-02))+(-3.1225229248437657e+01*x**3-2.5396015346595586e+01*x**2+1.6306400674181987e-15*x+1.0000000000000002e+00)*((x>=-2.4999999999999911e-02)&(x<0))+(3.1225229248436339e+01*x**3-2.5396015346595586e+01*x**2+1.3322676295501878e-15*x+1)*((x>=0)&(x<2.5000000000000133e-02))+(8.0079968363299415e+01*x**3-2.9060120780210337e+01*x**2+9.1602635840371038e-02*x+9.9923664470133022e-01)*((x>=2.5000000000000133e-02)&(x<5.0000000000000044e-02))+(9.8315431606913023e+01*x**3-3.1795440266752379e+01*x**2+2.2836861016747312e-01*x+9.9695721179587848e-01)*((x>=5.0000000000000044e-02)&(x<7.4999999999999956e-02))+(8.8388919477948434e+01*x**3-2.9561975037735348e+01*x**2+6.0858717991194800e-02*x+1.0011449591002854e+00)*((x>=7.4999999999999956e-02)&(x<1.0000000000000009e-01))+(6.4073806234264168e+01*x**3-2.2267441064630059e+01*x**2-6.6859467931933358e-01*x+1.0254600723439700e+00)*((x>=1.0000000000000009e-01)&(x<1.2500000000000000e-01))+(3.8311084152033999e+01*x**3-1.2606420283793749e+01*x**2-1.8762222769238730e+00*x+1.0757778889108256e+00)*((x>=1.2500000000000000e-01)&(x<1.5000000000000013e-01))+(1.7885198114124982e+01*x**3-3.4147715667346823e+00*x**2-3.2549695844827333e+00*x+1.1447152542887686e+00)*((x>=1.5000000000000013e-01)&(x<1.7500000000000004e-01))+(4.3133814207178753e+00*x**3+3.7104321973040499e+00*x**2-4.5018802431895129e+00*x+1.2174517093799972e+00)*((x>=1.7500000000000004e-01)&(x<2.0000000000000018e-01))+(-3.5000298696282077e+00*x**3+8.3984789715117039e+00*x**2-5.4394895980310443e+00*x+1.2799589997027663e+00)*((x>=2.0000000000000018e-01)&(x<2.2500000000000009e-01))+(-7.3187026710129670e+00*x**3+1.0976083112446418e+01*x**2-6.0194505297413547e+00*x+1.3234560695810398e+00)*((x>=2.2500000000000009e-01)&(x<2.5000000000000000e-01))+(-8.6863009915637104e+00*x**3+1.2001781852859475e+01*x**2-6.2758752148446195e+00*x+1.3448247933396451e+00)*((x>=2.5000000000000000e-01)&(x<2.7500000000000013e-01))+(-8.6966164529441361e+00*x**3+1.2010292108498327e+01*x**2-6.2782155351453035e+00*x+1.3450393227005411e+00)*((x>=2.7500000000000013e-01)&(x<3.0000000000000004e-01))+(-8.0393029647778445e+00*x**3+1.1418709969148663e+01*x**2-6.1007408933404044e+00*x+1.3272918585200510e+00)*((x>=3.0000000000000004e-01)&(x<3.2500000000000018e-01))+(-7.1149063519532882e+00*x**3+1.0517423271644722e+01*x**2-5.8078227166516232e+00*x+1.2955590560454331e+00)*((x>=3.2500000000000018e-01)&(x<3.5000000000000009e-01))+(-6.1394199580234456e+00*x**3+9.4931625580183869e+00*x**2-5.4493314668824064e+00*x+1.2537350769056912e+00)*((x>=3.5000000000000009e-01)&(x<3.7500000000000000e-01))+(-5.2192357769058102e+00*x**3+8.4579553542610455e+00*x**2-5.0611287654734038e+00*x+1.2052097392295658e+00)*((x>=3.7500000000000000e-01)&(x<4.0000000000000013e-01))+(-4.3992154842318518e+00*x**3+7.4739310030522956e+00*x**2-4.6675190249899030e+00*x+1.1527284404984326e+00)*((x>=4.0000000000000013e-01)&(x<4.2500000000000004e-01))+(-3.6915522644554404e+00*x**3+6.5716603978373715e+00*x**2-4.2840540177735598e+00*x+1.0984042311427840e+00)*((x>=4.2500000000000004e-01)&(x<4.5000000000000018e-01))+(-3.0923091346376652e+00*x**3+5.7626821725833741e+00*x**2-3.9200138164092619e+00*x+1.0437982009381390e+00)*((x>=4.5000000000000018e-01)&(x<4.7500000000000009e-01))+(-2.5905214152854170e+00*x**3+5.0476346725064207e+00*x**2-3.5803662538727083e+00*x+9.9002067020318485e-01)*((x>=4.7500000000000009e-01)&(x<5.0000000000000000e-01))+(-2.1729912422114137e+00*x**3+4.4213394128954153e+00*x**2-3.2672186240672061e+00*x+9.3782939856893432e-01)*((x>=5.0000000000000000e-01)&(x<5.2500000000000013e-01))+(-1.8266643319514360e+00*x**3+3.8758745292359502e+00*x**2-2.9808495601459866e+00*x+8.8771481238272099e-01)*((x>=5.2500000000000013e-01)&(x<5.5000000000000004e-01))+(-1.5396904778974305e+00*x**3+3.4023676700468415e+00*x**2-2.7204207875919764e+00*x+8.3996953741448577e-01)*((x>=5.5000000000000004e-01)&(x<5.7500000000000018e-01))+(-1.3017928982344842e+00*x**3+2.9919943451282589e+00*x**2-2.4844561257637920e+00*x+7.9474297723075038e-01)*((x>=5.7500000000000018e-01)&(x<6.0000000000000009e-01))+(-1.1042931822858555e+00*x**3+2.6364948564207271e+00*x**2-2.2711564325392724e+00*x+7.5208303858584657e-01)*((x>=6.0000000000000009e-01)&(x<6.2500000000000000e-01))+(-9.3997966785796283e-01*x**3+2.3284070168684288e+00*x**2-2.0786015328190857e+00*x+7.1196743447747424e-01)*((x>=6.2500000000000000e-01)&(x<6.5000000000000013e-01))+(-8.0291759936796991e-01*x**3+2.0611359833129423e+00*x**2-1.9048753610080198e+00*x+6.7432676391841007e-01)*((x>=6.5000000000000013e-01)&(x<6.7500000000000004e-01))+(-6.8825134123026377e-01*x**3+1.8289368105840873e+00*x**2-1.7481409194160427e+00*x+6.3906151456021509e-01)*((x>=6.7500000000000004e-01)&(x<7.0000000000000018e-01))+(-5.9201824568254457e-01*x**3+1.6268473099338769e+00*x**2-1.6066782689608954e+00*x+6.0605356278734746e-01)*((x>=7.0000000000000018e-01)&(x<7.2500000000000009e-01))+(-5.1099510214462274e-01*x**3+1.4506219727388969e+00*x**2-1.4789148994945347e+00*x+5.7517741516631027e-01)*((x>=7.2500000000000009e-01)&(x<7.5000000000000000e-01))+(-4.4253393420567466e-01*x**3+1.2965843448762637e+00*x**2-1.3633866785975599e+00*x+5.4629535994206657e-01)*((x>=7.5000000000000000e-01)&(x<7.7500000000000013e-01))+(-3.8455375866853309e-01*x**3+1.1617804367524096e+00*x**2-1.2589136498015729e+00*x+5.1930649416976993e-01)*((x>=7.7500000000000013e-01)&(x<8.0000000000000004e-01))+(-3.3505810215747250e-01*x**3+1.0429908611258640e+00*x**2-1.1638819893003367e+00*x+4.9396471803610698e-01)*((x>=8.0000000000000004e-01)&(x<8.2500000000000018e-01))+(-2.9351655701589774e-01*x**3+9.4017553690046651e-01*x**2-1.0790593468143834e+00*x+4.7063849135246982e-01)*((x>=8.2500000000000018e-01)&(x<8.5000000000000009e-01))+(-2.5536904985791770e-01*x**3+8.4289939364761746e-01*x**2-9.9637462504946184e-01*x+4.4721115351907526e-01)*((x>=8.5000000000000009e-01)&(x<8.7500000000000000e-01))+(-2.3226206080183801e-01*x**3+7.8224354737540824e-01*x**2-9.4330075956127879e-01*x+4.3173127608502193e-01)*((x>=8.7500000000000000e-01)&(x<9.0000000000000013e-01))+(-1.7630531713562572e-01*x**3+6.3116033947663508e-01*x**2-8.0732587245238285e-01*x+3.9093880995235319e-01)*((x>=9.0000000000000013e-01)&(x<9.2500000000000004e-01))+(-2.6257211445654599e-01*x**3+8.7055070204218876e-01*x**2-1.0287619578255200e+00*x+4.5921493627573712e-01)*((x>=9.2500000000000004e-01)&(x<9.5000000000000018e-01))+(1.6534908944834434e-01*x**3-3.4902472908674886e-01*x**2+1.2983470174697082e-01*x+9.2325994077781581e-02)*((x>=9.5000000000000018e-01)&(x<9.7500000000000009e-01))+(-1.3397852983559411e+00*x**3+4.0534933552407866e+00*x**2-4.1626204304723764e+00*x+1.4873739120490697e+00)*((x>=9.7500000000000009e-01)&(x<=1))

err_linear = [0.5, 0.05, 0.0411765, 0.0140271, 0.00380126]

err_complete = [0.421705, 0.0205289, 0.00316894, 0.000275356, 1.609e-05]

err_nature = [0.423482, 0.0205306, 0.00316894, 0.000275356, 1.609e-05]

err_sd = [0.423554, 0.0205301, 0.00316894, 0.000275356, 1.609e-05]

yuan = 1/(1+25*x*x)

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16,3.5))

axes[0].plot(x, yuan, linewidth=0.8)
axes[0].plot(x, s6linear, linewidth=0.8)
# axes[0].legend()
axes[0].set_title('N = 6')

axes[1].plot(x, yuan, linewidth=0.8)
axes[1].plot(x, s11linear, linewidth=0.8)
# axes[1].legend()
axes[1].set_title('N = 11')

axes[2].plot(x, yuan, linewidth=0.8)
axes[2].plot(x, s21linear, linewidth=0.8)
# axes[2].legend()
axes[2].set_title('N = 21')

axes[3].plot(x, yuan, linewidth=0.8)
axes[3].plot(x, s81linear, linewidth=0.8)
# axes[3].legend()
axes[3].set_title('N = 81')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16,3.5))

axes[0].plot(x, yuan, linewidth=0.8)
axes[0].plot(x, s6CompleteCubic, linewidth=0.8)
# axes[0].legend()
axes[0].set_title('N = 6')

axes[1].plot(x, yuan, linewidth=0.8)
axes[1].plot(x, s11CompleteCubic, linewidth=0.8)
# axes[1].legend()
axes[1].set_title('N = 11')

axes[2].plot(x, yuan, linewidth=0.8)
axes[2].plot(x, s21CompleteCubic, linewidth=0.8)
# axes[2].legend()
axes[2].set_title('N = 21')

axes[3].plot(x, yuan, linewidth=0.8)
axes[3].plot(x, s81CompleteCubic, linewidth=0.8)
# axes[3].legend()
axes[3].set_title('N = 81')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16,3.5))

axes[0].plot(x, yuan, linewidth=0.8)
axes[0].plot(x, s6NatureCubic, linewidth=0.8)
# axes[0].legend()
axes[0].set_title('N = 6')

axes[1].plot(x, yuan, linewidth=0.8)
axes[1].plot(x, s11NatureCubic, linewidth=0.8)
# axes[1].legend()
axes[1].set_title('N = 11')

axes[2].plot(x, yuan, linewidth=0.8)
axes[2].plot(x, s21NatureCubic, linewidth=0.8)
# axes[2].legend()
axes[2].set_title('N = 21')

axes[3].plot(x, yuan, linewidth=0.8)
axes[3].plot(x, s81NatureCubic, linewidth=0.8)
# axes[3].legend()
axes[3].set_title('N = 81')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16,3.5))

axes[0].plot(x, yuan, linewidth=0.8)
axes[0].plot(x, s6SecondDerivativesCubic, linewidth=0.8)
# axes[0].legend()
axes[0].set_title('N = 6')

axes[1].plot(x, yuan, linewidth=0.8)
axes[1].plot(x, s11SecondDerivativesCubic, linewidth=0.8)
# axes[1].legend()
axes[1].set_title('N = 11')

axes[2].plot(x, yuan, linewidth=0.8)
axes[2].plot(x, s21SecondDerivativesCubic, linewidth=0.8)
# axes[2].legend()
axes[2].set_title('N = 21')

axes[3].plot(x, yuan, linewidth=0.8)
axes[3].plot(x, s81SecondDerivativesCubic, linewidth=0.8)
# axes[3].legend()
axes[3].set_title('N = 81')

plt.tight_layout()
plt.show()

# %%
import math
plt.xlabel("$\log_2(N)$")
plt.ylabel("$\log_2(\text{Error})$")
plt.plot([math.log2(n) for n in N], [math.log2(err) for err in err_linear], label = "err_linear")
plt.plot([math.log2(n) for n in N], [math.log2(err) for err in err_complete], label = "err_cubic")
plt.legend()
plt.show()

# %% [markdown]
# # B Form

# %%
x = np.linspace(-5, 5, 500)
yuan = 1/(1+x*x)

s1 = (1.5678996544221169e-02*x+1.1685652118264445e-01)*((x>=-5)&(x<-4.7999999999999998e+00))+(1.7645080101155369e-02*x+1.2629372225592839e-01)*((x>=-4.7999999999999998e+00)&(x<-4.5999999999999996e+00))+(1.9947798826891683e-02*x+1.3688622839431541e-01)*((x>=-4.5999999999999996e+00)&(x<-4.4000000000000004e+00))+(2.4269039639431417e-02*x+1.5589968796949039e-01)*((x>=-4.4000000000000004e+00)&(x<-4))+(4.1176470588235300e-02*x+2.2352941176470592e-01)*((x>=-4)&(x<-3))+(1.0000000000000001e-01*x+4.0000000000000008e-01)*((x>=-3)&(x<-2))+(2.9999999999999999e-01*x+8.0000000000000004e-01)*((x>=-2)&(x<-1))+(5.0000000000000000e-01*x+1)*((x>=-1)&(x<0))+(-5.0000000000000000e-01*x+1)*((x>=0)&(x<1))+(-2.9999999999999999e-01*x+8.0000000000000004e-01)*((x>=1)&(x<2))+(-1.0000000000000001e-01*x+4.0000000000000008e-01)*((x>=2)&(x<3))+(-4.1176470588235300e-02*x+2.2352941176470592e-01)*((x>=3)&(x<4))+(-2.4269039639431639e-02*x+1.5589968796949127e-01)*((x>=4)&(x<4.4000000000000004e+00))+(-1.9947798826891822e-02*x+1.3688622839431619e-01)*((x>=4.4000000000000004e+00)&(x<4.5999999999999996e+00))+(-1.7645080101155092e-02*x+1.2629372225592717e-01)*((x>=4.5999999999999996e+00)&(x<4.7999999999999998e+00))+(-1.5678996544220947e-02*x+1.1685652118264311e-01)*((x>=4.7999999999999998e+00)&(x<=5))

s3 = (1.3592073275502381e-03*x**3+2.4546754127150905e-02*x**2+1.5831989111353550e-01*x+3.8629305679424419e-01)*((x>=-5)&(x<-4.7999999999999998e+00))+(7.6961014876286704e-04*x**3+1.6056554752616137e-02*x**2+1.1756693411581409e-01*x+3.2108832559784162e-01)*((x>=-4.7999999999999998e+00)&(x<-4.5999999999999996e+00))+(3.9782312887724491e-03*x**3+6.0335526484748492e-02*x**2+3.2125020408356875e-01*x+6.3340267288176477e-01)*((x>=-4.5999999999999996e+00)&(x<-4.4000000000000004e+00))+(-1.3334626212615913e-03*x**3-9.7788331277002261e-03*x**2+1.2747021788803270e-02*x+1.8093133884946599e-01)*((x>=-4.4000000000000004e+00)&(x<-4))+(7.9822712709378997e-03*x**3+1.0200997357869274e-01*x**2+4.5990224861438045e-01*x+7.7713830795022987e-01)*((x>=-4)&(x<-3))+(6.4667364022011758e-03*x**3+8.8370159760062295e-02*x**2+4.1898280715848935e-01*x+7.3621886649433887e-01)*((x>=-3)&(x<-2))+(1.0732725370849056e-01*x**3+6.9353326359779865e-01*x**2+1.6293090148339620e+00*x+1.5431030049446539e+00)*((x>=-2)&(x<-1))+(-4.3577575123616347e-01*x**3-9.3577575123616352e-01*x**2-1.6653345369377348e-16*x+9.9999999999999989e-01)*((x>=-1)&(x<0))+(4.3577575123616380e-01*x**3-9.3577575123616352e-01*x**2-1.6653345369377348e-16*x+9.9999999999999989e-01)*((x>=0)&(x<1))+(-1.0732725370849269e-01*x**3+6.9353326359780620e-01*x**2-1.6293090148339697e+00*x+1.5431030049446566e+00)*((x>=1)&(x<2))+(-6.4667364021911145e-03*x**3+8.8370159759996653e-02*x**2-4.1898280715835062e-01*x+7.3621886649424373e-01)*((x>=2)&(x<3))+(-7.9822712709955272e-03*x**3+1.0200997357923622e-01*x**2-4.5990224861606943e-01*x+7.7713830795196193e-01)*((x>=3)&(x<4))+(1.3334626223192036e-03*x**3-9.7788331405403994e-03*x**2-1.2747021736959852e-02*x+1.8093133877982304e-01)*((x>=4)&(x<4.4000000000000004e+00))+(-3.9782312915764839e-03*x**3+6.0335526522882432e-02*x**2-3.2125020425601747e-01*x+6.3340267314106313e-01)*((x>=4.4000000000000004e+00)&(x<4.5999999999999996e+00))+(-7.6961015449505954e-04*x**3+1.6056554831163083e-02*x**2-1.1756693447413014e-01*x+3.2108832614214577e-01)*((x>=4.5999999999999996e+00)&(x<4.7999999999999998e+00))+(-1.3592073099228663e-03*x**3+2.4546753869314486e-02*x**2-1.5831988985723733e-01*x+3.8629305475516951e-01)*((x>=4.7999999999999998e+00)&(x<=5))

s5 = (-3.8872535970803646e-02*x**5-9.5041717451428909e-01*x**4-9.2918328459529107e+00*x**3-4.5401376188901736e+01*x**2-1.1084341789151904e+02*x-1.0808926977803594e+02)*((x>=-5)&(x<-4.7999999999999998e+00))+(4.9300603711584845e-02*x**5+1.1657381778630453e+00*x**4+1.1023258536869655e+01*x**3+5.2111062448645981e+01*x**2+1.2318643483859728e+02*x+1.1657938884287125e+02)*((x>=-4.7999999999999998e+00)&(x<-4.5999999999999996e+00))+(-7.4261304628511687e-02*x**5-1.6761857139591616e+00*x**4-1.5122441267894871e+01*x**3-6.8159156653270543e+01*x**2-1.5343506909581276e+02*x-1.3791239477678084e+02)*((x>=-4.5999999999999996e+00)&(x<-4.4000000000000004e+00))+(4.0393378450820354e-02*x**5+8.4621731378612430e-01*x**4+7.0747053762637790e+00*x**3+2.9508288581027397e+01*x**2+6.1433310419643036e+01*x+5.1171779196819983e+01)*((x>=-4.4000000000000004e+00)&(x<-4))+(-1.7018082691031382e-02*x**5-3.0201190905091052e-01*x**4-2.1111284064325040e+00*x**3-7.2350465497577492e+00*x**2-1.2053359841927193e+01*x-7.6175570124362988e+00)*((x>=-4)&(x<-3))+(3.2590092163417531e-02*x**5+4.4211071376582323e-01*x**4+2.3536073304678986e+00*x**3+6.1591606609434573e+00*x**2+8.0379509741246196e+00*x+4.4372294771947898e+00)*((x>=-3)&(x<-2))+(-8.1762362984718159e-02*x**5-7.0141383771553378e-01*x**4-2.2204908754575294e+00*x**3-2.9890357509073988e+00*x**2-1.1102454377262378e+00*x+7.7795091245444725e-01)*((x>=-2)&(x<-1))+(1.4028672456083457e-01*x**5+4.0883160001222990e-01*x**4-2.0018917079589471e-12*x**3-7.6854487545187111e-01*x**2+1.5261333863314519e-12*x+1)*((x>=-1)&(x<0))+(-1.4028672455988275e-01*x**5+4.0883160001222996e-01*x**4-2.0018917079589471e-12*x**3-7.6854487545187111e-01*x**2+1.5261333863314519e-12*x+1)*((x>=0)&(x<1))+(8.1762362981136996e-02*x**5-7.0141383769286914e-01*x**4+2.2204908754081960e+00*x**3-2.9890357508620697e+00*x**2+1.1102454377066253e+00*x+7.7795091245898029e-01)*((x>=1)&(x<2))+(-3.2590092154293683e-02*x**5+4.4211071366143789e-01*x**4-2.3536073300090310e+00*x**3+6.1591606599723852e+00*x**2-8.0379509731278311e+00*x+4.4372294767927620e+00)*((x>=2)&(x<3))+(1.7018082663847904e-02*x**5-3.0201190861068583e-01*x**4+2.1111284036237112e+00*x**3-7.2350465409258433e+00*x**2+1.2053359828219515e+01*x-7.6175570040156453e+00)*((x>=3)&(x<4))+(-4.0393378195618695e-02*x**5+8.4621730857864508e-01*x**4-7.0747053338909431e+00*x**3+2.9508288409132760e+01*x**2-6.1433310071897751e+01*x+5.1171778916078239e+01)*((x>=4)&(x<4.4000000000000004e+00))+(7.4261305212697526e-02*x**5-1.6761857264043032e+00*x**4+1.5122441373959028e+01*x**3-6.8159157105407076e+01*x**2+1.5343507006009099e+02*x-1.3791239560007170e+02)*((x>=4.4000000000000004e+00)&(x<4.5999999999999996e+00))+(-4.9300610966810210e-02*x**5+1.1657383457243946e+00*x**4-1.1023260089625069e+01*x**3+5.2111069627079559e+01*x**2-1.2318645142462879e+02*x+1.1657940416586922e+02)*((x>=4.5999999999999996e+00)&(x<4.7999999999999998e+00))+(3.8872562850351684e-02*x**5-9.5041782588751766e-01*x**4+9.2918391578494273e+00*x**3-4.5401406760797848e+01*x**2+1.1084349190627610e+02*x-1.0808934143179964e+02)*((x>=4.7999999999999998e+00)&(x<=5))

s7 = (2.5129441993262913e-01*x**7+8.5808345218988560e+00*x**6+1.2554184461550270e+02*x**5+1.0201490540746788e+03*x**4+4.9725407963387734e+03*x**3+1.4538936478821968e+04*x**2+2.3610402575076452e+04*x+1.6428181688056982e+04)*((x>=-5)&(x<-4.7999999999999998e+00))+(-1.9980376120997911e-01*x**7-6.5760643644927788e+00*x**6-9.2717499348536919e+01*x**5-7.2592569763763788e+02*x**4-3.4086180118803441e+03*x**3-9.5988008888490767e+03*x**2-1.5009977213197251e+04*x-1.0054364452473546e+04)*((x>=-4.7999999999999998e+00)&(x<-4.5999999999999996e+00))+(1.6869467933337345e-01*x**7+5.2895854210031885e+00*x**6+7.1028467691307284e+01*x**5+5.2946004966783346e+02*x**4+2.3661564257248283e+03*x**3+6.3395765589411667e+03*x**2+9.4288682067478258e+03*x+6.0054482520617876e+03)*((x>=-4.5999999999999996e+00)&(x<-4.4000000000000004e+00))+(-4.8290566569997244e-02*x**7-1.3935601528206374e+00*x**6-1.7189053883167112e+01*x**5-1.1746844187831242e+02*x**4-4.8032893707821592e+02*x**3-1.1751447988588598e+03*x**2-1.5927231180255542e+03*x-9.2240915208147646e+02)*((x>=-4.4000000000000004e+00)&(x<-4))+(1.0976907525872480e-02*x**7+2.6592912186371392e-01*x**6+2.7248174130451144e+00*x**5+1.5290700096435714e+01*x**4+5.0707630820777062e+01*x**3+9.9342964098722348e+01*x**2+1.0659389925122230e+02*x+4.8629143505252046e+01)*((x>=-4)&(x<-3))+(-1.2641885448274721e-02*x**7-2.3006553059337731e-01*x**6-1.7391344590687063e+00*x**5-7.0290592641333953e+00*x**4-1.6251647260930270e+01*x**3-2.1183736448350846e+01*x**2-1.3932801295850906e+01*x-3.0251567292079029e+00)*((x>=-3)&(x<-2))+(1.9151185539090263e-02*x**7+2.1503746322973252e-01*x**6+9.3148350386995227e-01*x**5+1.8730006123288019e+00*x**4+1.5524724919941224e+00*x**3+1.8120725515842509e-01*x**2+3.1049450648861004e-01*x+1.0443563571748151e+00)*((x>=-2)&(x<-1))+(-2.5205171635725224e-02*x**7-9.5457036993975952e-02*x**6+3.1988269225298460e-09*x**5+3.2052811121025981e-01*x**4-9.1244198399155485e-09*x**3-7.5027624551270011e-01*x**2+6.2649018780884524e-09*x+9.9999999999999978e-01)*((x>=-1)&(x<0))+(2.5205170957107819e-02*x**7-9.5457036993975952e-02*x**6+3.1988268253853314e-09*x**5+3.2052811121025987e-01*x**4-9.1244198399155485e-09*x**3-7.5027624551270011e-01*x**2+6.2649018780884524e-09*x+9.9999999999999978e-01)*((x>=0)&(x<1))+(-1.9151183148490750e-02*x**7+2.1503744174521405e-01*x**6-9.3148343301874326e-01*x**5+1.8730005049062095e+00*x**4-1.5524724028203696e+00*x**3+1.8120719070486965e-01*x**2-3.1049447247428791e-01*x+1.0443563541055980e+00)*((x>=1)&(x<2))+(1.2641879614760591e-02*x**7-2.3006543694030485e-01*x**6+1.7391338390943698e+00*x**5-7.0290570688041676e+00*x**4+1.6251642744600382e+01*x**3-2.1183730986200036e+01*x**2+1.3932797645462315e+01*x-3.0251556795905739e+00)*((x>=2)&(x<3))+(-1.0976887987184032e-02*x**7+2.6592868270053222e-01*x**6-2.7248132376731640e+00*x**5+1.5290678315033507e+01*x**4-5.0707563406912627e+01*x**3+9.9342840086523395e+01*x**2-1.0659377342726110e+02*x+4.8629089065862331e+01)*((x>=3)&(x<4))+(4.8290190415120463e-02*x**7-1.3935495125639923e+00*x**6+1.7188925105501145e+01*x**5-1.1746757730612858e+02*x**4+4.8032545907773573e+02*x**3-1.1751364138766319e+03*x**2+1.5927118985236129e+03*x-9.2240272347749328e+02)*((x>=4)&(x<4.4000000000000004e+00))+(-1.6869106631680947e-01*x**7+5.2894731947794416e+00*x**6-7.1026974631432282e+01*x**5+5.2944902076471658e+02*x**4-2.3661075724339807e+03*x**3+6.3394467893143055e+03*x**2-9.4286767994897473e+03*x+6.0053273152737684e+03)*((x>=4.4000000000000004e+00)&(x<4.5999999999999996e+00))+(1.9979480467311489e-01*x**7-6.5757718510961221e+00*x**6+9.2713407001650552e+01*x**5-7.2589390508891734e+02*x**4+3.4084698864927354e+03*x**3-9.5983869973234268e+03*x**2+1.5009335006688101e+04*x-1.0053937585928823e+04)*((x>=4.5999999999999996e+00)&(x<4.7999999999999998e+00))+(-2.5126967917238208e-01*x**7+8.5799948061125750e+00*x**6-1.2552963286215476e+02*x**5+1.0200504138215254e+03*x**4-4.9720628442773814e+03*x**3+1.4537547267294507e+04*x**2-2.3608159816700616e+04*x+1.6426630292966278e+04)*((x>=4.7999999999999998e+00)&(x<=5))

s9 = (1.5795517955929030e+00*x**9+6.8320806885816964e+01*x**8+1.3132337992002642e+03*x**7+1.4723196213790872e+04*x**6+1.0610419618585978e+05*x**5+5.0971741423628642e+05*x**4+1.6322798885344747e+06*x**3+3.3599714098971514e+06*x**2+4.0341912543146070e+06*x+2.1525829455812122e+06)*((x>=-5)&(x<-4.7999999999999998e+00))+(1.0588852972791198e-02*x**9+5.4160776462812055e-01*x**8+1.1873176073438549e+01*x**7+1.4795723477042651e+02*x**6+1.1624755369125196e+03*x**5+5.9971551213397415e+03*x**4+2.0375059366644880e+04*x**3+4.4052904180473823e+04*x**2+5.5089047454593972e+04*x+3.0395101922538252e+04)*((x>=-4.7999999999999998e+00)&(x<-4.5999999999999996e+00))+(-9.0445185885254700e-02*x**9-3.6412014440949800e+00*x**8-6.5090513367066478e+01*x**7-6.7811969855766085e+02*x**6-4.5374553030512852e+03*x**5-2.0222526742493759e+04*x**4-6.0031965015777801e+04*x**3-1.1446380103058797e+05*x**2-1.2720516353812731e+05*x-6.2777494807074720e+04)*((x>=-4.5999999999999996e+00)&(x<-4.4000000000000004e+00))+(2.1232632994558739e-02*x**9+7.8124018354563185e-01*x**8+1.2744459279408279e+01*x**7+1.2098602061281359e+02*x**6+7.3664244347384761e+02*x**5+2.9835033422168276e+03*x**4+8.0390565660399143e+03*x**3+1.3898696809411127e+04*x**2+1.3993584085871809e+04*x+6.2530040313248337e+03)*((x>=-4.4000000000000004e+00)&(x<-4))+(-3.0098031822152027e-03*x**9-9.1487518818230071e-02*x**8-1.2191839584135107e+00*x**7-9.3413162735231126e+00*x**6-4.5321577844172865e+01*x**5-1.4435274305525377e+02*x**4-3.0189299468563701e+02*x**3-4.0007386611838723e+02*x**2-3.0518658965769976e+02*x-1.0200515779939727e+02)*((x>=-4)&(x<-3))+(2.3539565197802214e-03*x**9+5.3333993135646421e-02*x**8+5.1867418503300700e-01*x**7+2.8236907306025105e+00*x**6+9.4209536743924289e+00*x**5+1.9874851500442119e+01*x**4+2.6562194425754857e+01*x**3+2.2225662739116604e+01*x**2+1.1538056985428113e+01*x+3.5697244149787055e+00)*((x>=-3)&(x<-2))+(-2.6761946276170480e-03*x**9-3.7208727517504439e-02*x**8-2.0566758019219997e-01*x**7-5.5657084044845484e-01*x**6-7.1983103876046706e-01*x**5-4.0671792586367517e-01*x**4-4.7989814265287112e-01*x**3-9.5327374809002008e-01*x**2-5.1411258175197198e-02*x+9.9428702751130260e-01)*((x>=-2)&(x<-1))+(3.0367778610805008e-03*x**9+1.4208024880773495e-02*x**8-5.7059908819328208e-07*x**7-7.6681151397860747e-02*x**6+3.4948154243095541e-06*x**5+3.1311660771221628e-01*x**4-8.4536022768010450e-06*x**3-7.4760673849690829e-01*x**2+5.4942230810239838e-06*x+1)*((x>=-1)&(x<0))+(-3.0367075353614852e-03*x**9+1.4208024880773497e-02*x**8-5.7059908818287374e-07*x**7-7.6681151397860747e-02*x**6+3.4948154242124096e-06*x**5+3.1311660771221628e-01*x**4-8.4536022768010450e-06*x**3-7.4760673849690829e-01*x**2+5.4942230810239838e-06*x+1)*((x>=0)&(x<1))+(2.6759441087482495e-03*x**9-3.7205839916214116e-02*x**8+2.0565488858886227e-01*x**7-5.5654388950307843e-01*x**6+7.1979760197325104e-01*x**5-4.0667749944561055e-01*x**4+4.7985428450294115e-01*x**3-9.5326219768485876e-01*x**2+5.1419359020068868e-02*x+9.9428734835589028e-01)*((x>=1)&(x<2))+(-2.3533064373995076e-03*x**9+5.3320669914445520e-02*x**8-5.1855719005641487e-01*x**7+2.8231124775082144e+00*x**6-9.4191714990606297e+00*x**5+1.9871260702622148e+01*x**4-2.6557396651587407e+01*x**3+2.2221524318964008e+01*x**2-1.1535973899304365e+01*x+3.5692636279835428e+00)*((x>=2)&(x<3))+(3.0071805461796362e-03*x**9-9.1412478642191361e-02*x**8+1.2182405926232276e+00*x**7-9.3344720012492832e+00*x**6+4.5289958655348094e+01*x**5-1.4425612976060407e+02*x**4+3.0169738427486504e+02*x**3-3.9982033687218916e+02*x**2+3.0499542199406051e+02*x-1.0194120166980476e+02)*((x>=3)&(x<4))+(-2.1148316071385540e-02*x**9+7.7818539959015487e-01*x**8-1.2695325459094310e+01*x**7+1.2052547781478111e+02*x**6-7.3386974024083440e+02*x**5+2.9723826658241251e+03*x**4-8.0093394039510822e+03*x**3+1.3847671300086573e+04*x**2-1.3942496214964698e+04*x+6.2302773036452027e+03)*((x>=4)&(x<4.4000000000000004e+00))+(8.8997154579921495e-02*x**9-3.5835752382016026e+00*x**8+6.4071661766040648e+01*x**7-6.6761559102993772e+02*x**6+4.4678613141343121e+03*x**5-1.9915233973426512e+04*x**4+5.9127669404517481e+04*x**3-1.1275354531016841e+05*x**2+1.2531884205631587e+05*x-6.1853043628980857e+04)*((x>=4.4000000000000004e+00)&(x<4.5999999999999996e+00))+(-4.0423244314256035e-03*x**9+2.6825919286816635e-01*x**8-6.8020917656430839e+00*x**7+9.3096030210134131e+01*x**6-7.8104887242218774e+02*x**5+4.2297528847333633e+03*x**4-1.4916956960506148e+04*x**3+3.3220146666592365e+04*x**2-4.2550903716959103e+04*x+2.3947048655137463e+04)*((x>=4.5999999999999996e+00)&(x<4.7999999999999998e+00))+(-1.6253567437354253e+00*x**9+7.0309042106800945e+01*x**8-1.3515851237131526e+03*x**7+1.5154665988022241e+04*x**6-1.0922435256866936e+05*x**5+5.2475761062671978e+05*x**4-1.6806061017348627e+06*x**3+3.4597806730595543e+06*x**2-4.1544235353885135e+06*x+2.2169457855466329e+06)*((x>=4.7999999999999998e+00)&(x<=5))

s2 = (4.4304856799097792e-03*x**2+5.9097756207382446e-02*x+2.2318817750070252e-01)*((x>=-5)&(x<-4.7999999999999998e+00))+(5.3999321042418336e-03*x**2+6.8404441880971056e-02*x+2.4552422311731092e-01)*((x>=-4.7999999999999998e+00)&(x<-4.5999999999999996e+00))+(6.1136615248046922e-03*x**2+7.4970752550146180e-02*x+2.6062673765642153e-01)*((x>=-4.5999999999999996e+00)&(x<-4.4000000000000004e+00))+(7.7462712689127522e-03*x**2+8.9337718298298174e-02*x+2.9223406230235405e-01)*((x>=-4.4000000000000004e+00)&(x<-4))+(1.3808922441239095e-02*x**2+1.3783892767690897e-01*x+3.8923648105957542e-01)*((x>=-4)&(x<-3))+(4.5014606970525478e-02*x**2+3.2507303485262740e-01*x+6.7008764182315284e-01)*((x>=-3)&(x<-2))+(1.5498539302947451e-01*x**2+7.6495617908842350e-01*x+1.1099707860589489e+00)*((x>=-2)&(x<-1))+(4.5014606970525506e-02*x**2+5.4501460697052551e-01*x+1)*((x>=-1)&(x<0))+(-1.0450146069705255e+00*x**2+5.4501460697052551e-01*x+1)*((x>=0)&(x<1))+(1.2450146069705257e+00*x**2-4.0350438209115769e+00*x+3.2900292139410512e+00)*((x>=1)&(x<2))+(-1.0450146069705251e+00*x**2+5.1250730348526261e+00*x-5.8700876418231518e+00)*((x>=2)&(x<3))+(1.1038381363822873e+00*x**2-7.7680434252642492e+00*x+1.3469587048352160e+01)*((x>=3)&(x<4))+(-2.7173267635836482e+00*x**2+2.2801275774463235e+01*x-4.7669051351102809e+01)*((x>=4)&(x<4.4000000000000004e+00))+(5.4562597312303982e+00*x**2-4.9126285379900381e+01*x+1.1057158318849716e+02)*((x>=4.4000000000000004e+00)&(x<4.5999999999999996e+00))+(-5.4447461376030031e+00*x**2+5.1162968613366900e+01*x-1.2009370099601757e+02)*((x>=4.5999999999999996e+00)&(x<4.7999999999999998e+00))+(5.4545765553885239e+00*x**2-5.3470529239351741e+01*x+1.3102669385050717e+02)*((x>=4.7999999999999998e+00)&(x<=5))

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(16,2.6))

axes[0].plot(x, yuan, linewidth=0.8)
axes[0].plot(x, s1, linewidth=0.8)
# axes[0].legend()
axes[0].set_title('Order = 1')
axes[1].plot(x, yuan, linewidth=0.8)
axes[1].plot(x, s3, linewidth=0.8)
# axes[1].legend()
axes[1].set_title('Order = 3')
axes[2].plot(x, yuan, linewidth=0.8)
axes[2].plot(x, s5, linewidth=0.8)
# axes[2].legend()
axes[2].set_title('Order = 5')
axes[3].plot(x, yuan, linewidth=0.8)
axes[3].plot(x, s7, linewidth=0.8)
# axes[3].legend()
axes[3].set_title('Order = 7')
axes[4].plot(x, yuan, linewidth=0.8)
axes[4].plot(x, s9, linewidth=0.8)
# axes[4].legend()
axes[4].set_title('Order = 9')


plt.tight_layout()
plt.show()

plt.plot(x, yuan, linewidth = 0.8)
plt.plot(x, s2, linewidth = 0.8)

# %% [markdown]
# # C. Cardinal B Form

# %%
s11Linear = (2.0361990950226241e-02*x+1.4027149321266968e-01)*((x>=-5)&(x<-4))+(4.1176470588235300e-02*x+2.2352941176470592e-01)*((x>=-4)&(x<-3))+(1.0000000000000001e-01*x+4.0000000000000002e-01)*((x>=-3)&(x<-2))+(2.9999999999999999e-01*x+8.0000000000000004e-01)*((x>=-2)&(x<-1))+(5.0000000000000000e-01*x+1)*((x>=-1)&(x<0))+(-5.0000000000000000e-01*x+1)*((x>=0)&(x<1))+(-2.9999999999999999e-01*x+7.9999999999999982e-01)*((x>=1)&(x<2))+(-1.0000000000000001e-01*x+4.0000000000000002e-01)*((x>=2)&(x<3))+(-4.1176470588235300e-02*x+2.2352941176470587e-01)*((x>=3)&(x<4))+(-2.0361990950226241e-02*x+1.4027149321266974e-01)*((x>=4)&(x<=5))


s10Quadratic = (5.4351712838431321e-03*x**2+6.8828697332256383e-02*x+2.4672574302674199e-01)*((x>=-5)&(x<-4))+(1.7697361372981092e-02*x**2+1.6692621804536006e-01*x+4.4292078445294925e-01)*((x>=-4)&(x<-3))+(2.4566507621291492e-02*x**2+2.0814109553522242e-01*x+5.0474310068774286e-01)*((x>=-3)&(x<-2))+(2.6411134025926197e-01*x**2+1.1663204260871043e+00*x+1.4629224312396247e+00)*((x>=-2)&(x<-1))+(-3.1904887278429028e-01*x**2-1.1102230246251565e-16*x+8.7976221819607248e-01)*((x>=-1)&(x<0))+(-3.1904887278429006e-01*x**2-1.1102230246251565e-16*x+8.7976221819607248e-01)*((x>=0)&(x<1))+(2.6411134025926186e-01*x**2-1.1663204260871041e+00*x+1.4629224312396245e+00)*((x>=1)&(x<2))+(2.4566507621291520e-02*x**2-2.0814109553522259e-01*x+5.0474310068774320e-01)*((x>=2)&(x<3))+(1.7697361372981092e-02*x**2-1.6692621804536006e-01*x+4.4292078445294919e-01)*((x>=3)&(x<4))+(5.4351712838431251e-03*x**2-6.8828697332256328e-02*x+2.4672574302674177e-01)*((x>=4)&(x<=5))


s11NatureCubic = (2.7336816579585626e-03*x**3+4.1005224869378437e-02*x**2+2.2265443363915988e-01*x+4.6831329216769718e-01)*((x>=-5)&(x<-4))+(7.1460713482162791e-03*x**3+9.3953901152471028e-02*x**2+4.3444913877153019e-01*x+7.5070623234419076e-01)*((x>=-4)&(x<-3))+(6.6910827229319098e-03*x**3+8.9859003524911760e-02*x**2+4.2216444588885282e-01*x+7.3842153946151456e-01)*((x>=-3)&(x<-2))+(1.0726606834829135e-01*x**3+6.9330891727706856e-01*x**2+1.6290642733931679e+00*x+1.5430214244643945e+00)*((x>=-2)&(x<-1))+(-4.3575535611609717e-01*x**3-9.3575535611609761e-01*x**2-2.4424906541753444e-15*x+1.0000000000000007e+00)*((x>=-1)&(x<0))+(4.3575535611609717e-01*x**3-9.3575535611609717e-01*x**2-1.1768364061026659e-14*x+9.9999999999994960e-01)*((x>=0)&(x<1))+(-1.0726606834829132e-01*x**3+6.9330891727706856e-01*x**2-1.6290642733931582e+00*x+1.5430214244644216e+00)*((x>=1)&(x<2))+(-6.6910827229319046e-03*x**3+8.9859003524911857e-02*x**2-4.2216444588885293e-01*x+7.3842153946150568e-01)*((x>=2)&(x<3))+(-7.1460713482162808e-03*x**3+9.3953901152470959e-02*x**2-4.3444913877153118e-01*x+7.5070623234418854e-01)*((x>=3)&(x<4))+(-2.7336816579585622e-03*x**3+4.1005224869378402e-02*x**2-2.2265443363916002e-01*x+4.6831329216769424e-01)*((x>=4)&(x<=5))


s11SecondDerivativesCubic = (9.5419581966072961e-04*x**3+1.8523224049576396e-02*x**2+1.2886506239710929e-01*x+3.3898072666526619e-01)*((x>=-5)&(x<-4))+(7.6229270303745343e-03*x**3+9.8547998578142046e-02*x**2+4.4896416051137189e-01*x+7.6577952415094974e-01)*((x>=-4)&(x<-3))+(6.5631458325967409e-03*x**3+8.9009967798141937e-02*x**2+4.2035006817137166e-01*x+7.3716543181094973e-01)*((x>=-3)&(x<-2))+(1.0730096022747372e-01*x**3+6.9343685416740364e-01*x**2+1.6292038409098948e+00*x+1.5430679469699660e+00)*((x>=-2)&(x<-1))+(-4.3576698674249137e-01*x**3-9.3576698674249226e-01*x**2-8.8817841970012523e-15*x+9.9999999999997335e-01)*((x>=-1)&(x<0))+(4.3576698674249126e-01*x**3-9.3576698674249270e-01*x**2-9.3258734068513149e-15*x+9.9999999999998435e-01)*((x>=0)&(x<1))+(-1.0730096022747365e-01*x**3+6.9343685416740342e-01*x**2-1.6292038409098910e+00*x+1.5430679469699964e+00)*((x>=1)&(x<2))+(-6.5631458325967756e-03*x**3+8.9009967798142062e-02*x**2-4.2035006817137543e-01*x+7.3716543181094263e-01)*((x>=2)&(x<3))+(-7.6229270303745230e-03*x**3+9.8547998578142060e-02*x**2-4.4896416051136917e-01*x+7.6577952415095174e-01)*((x>=3)&(x<4))+(-9.5419581966073135e-04*x**3+1.8523224049576417e-02*x**2-1.2886506239710946e-01*x+3.3898072666526508e-01)*((x>=4)&(x<=5))


s11CompleteCubic = (6.5799882422887777e-04*x**3+1.4781075081146530e-02*x**2+1.1325373840258346e-01*x+3.1745320647440223e-01)*((x>=-5)&(x<-4))+(7.7023000814379593e-03*x**3+9.9312690167655510e-02*x**2+4.5138019874861940e-01*x+7.6828848693578355e-01)*((x>=-4)&(x<-3))+(6.5418506237748808e-03*x**3+8.8868645048687744e-02*x**2+4.2004806339171563e-01*x+7.3695635157887873e-01)*((x>=-3)&(x<-2))+(1.0730676801169775e-01*x**3+6.9345814937622507e-01*x**2+1.6292270720467912e+00*x+1.5430756906822662e+00)*((x>=-2)&(x<-1))+(-4.3576892267056588e-01*x**3-9.3576892267056633e-01*x**2-3.7747582837255322e-15*x+1.0000000000000127e+00)*((x>=-1)&(x<0))+(4.3576892267056594e-01*x**3-9.3576892267056477e-01*x**2+2.2204460492503131e-15*x+9.9999999999999423e-01)*((x>=0)&(x<1))+(-1.0730676801169775e-01*x**3+6.9345814937622485e-01*x**2-1.6292270720467974e+00*x+1.5430756906822356e+00)*((x>=1)&(x<2))+(-6.5418506237748791e-03*x**3+8.8868645048688077e-02*x**2-4.2004806339171641e-01*x+7.3695635157887684e-01)*((x>=2)&(x<3))+(-7.7023000814379558e-03*x**3+9.9312690167655621e-02*x**2-4.5138019874861696e-01*x+7.6828848693579421e-01)*((x>=3)&(x<4))+(-6.5799882422888645e-04*x**3+1.4781075081146747e-02*x**2-1.1325373840258336e-01*x+3.1745320647440484e-01)*((x>=4)&(x<=5))

# err_points = [-3.5, -3, -2.5, -2, -1.5, -1, -0.5, 0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5]
# err_values_linear = [0.00394007, 0, 0.012069, 0, 0.0423077, 0, 0.05, 0, 0.05, 0, 0.0423077, 0, 0.012069, 0, 0.00394007]
# err_values_Quadratic = [1.38778e-17, 0.00141838, 0, 0.0132731, 0, 0.0607133, 0, 0.120238, 1.11022e-16, 0.0607133, 0, 0.0132731, 0, 0.00141838, 1.38778e-17]
# err_values_Nature = [0.000789971, 1.11022e-16, 0.00214999, 9.71445e-16, 0.0103452, 1.54876e-14, 0.0205306, 4.21885e-15, 0.0205306, 6.66134e-16, 0.0103452, 5.4956e-15, 0.00214999, 2.26208e-15, 0.000789971]
# err_values_SD = [0.00068675, 9.71445e-17, 0.00212237, 9.71445e-16, 0.0103379, 1.54876e-14, 0.0205291, 4.10783e-15, 0.0205291, 6.66134e-16, 0.0103379, 5.4956e-15, 0.00212237, 2.27596e-15, 0.00068675]
# err_values_Complete = [0.000669568, 1.11022e-16, 0.00211777, 9.71445e-16, 0.0103367, 1.54321e-14, 0.0205289, 4.32987e-15, 0.0205289, 5.55112e-16, 0.0103367, 5.4956e-15, 0.00211777, 2.28983e-15, 0.000669568]


fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(16,2.6))

axes[0].plot(x, yuan, linewidth=0.8)
axes[0].plot(x, s11Linear, linewidth=0.8)
# axes[0].legend()
axes[0].set_title('Linear')
axes[1].plot(x, yuan, linewidth=0.8)
axes[1].plot(x, s10Quadratic, linewidth=0.8)
# axes[1].legend()
axes[1].set_title('Quadratic')
axes[2].plot(x, yuan, linewidth=0.8)
axes[2].plot(x, s11NatureCubic, linewidth=0.8)
# axes[2].legend()
axes[2].set_title('Cubic Nature')
axes[3].plot(x, yuan, linewidth=0.8)
axes[3].plot(x, s11SecondDerivativesCubic, linewidth=0.8)
# axes[3].legend()
axes[3].set_title('Cubic 2nd Derivatives')
axes[4].plot(x, yuan, linewidth=0.8)
axes[4].plot(x, s11CompleteCubic, linewidth=0.8)
# axes[4].legend()
axes[4].set_title('Cubic Complete')

plt.tight_layout()
plt.show()

# %% [markdown]
# # E. 曲线拟合

# %%
I = 10.2167502659652243

x = np.linspace(0, I, 400)
px = [1.73205e-08, 0.821954, 1.67246, 1.47753, 0.727556, 1.73205e-08, -0.727556, -1.47753, -1.67246, -0.821954, -1.73205e-08]
py = [1.15479, 1.62081, 1.16243, 0.207804, -0.479244, -1.15461, -0.479244, 0.207804, 1.16243, 1.62081, 1.15479]
X = (6.7469812476815272e-02*x**3+7.3408951481322615e-01*x+1.7320508055584938e-08)*((x>=0)&(x<1.0216750265965224e+00))+(-3.1057329072770407e-01*x**3+1.1587115925633276e+00*x**2-4.4973718233660986e-01*x+4.0316207475258536e-01)*((x>=1.0216750265965224e+00)&(x<2.0433500531930449e+00))+(1.6774113998336343e-01*x**3-1.7733798597460551e+00*x**2+5.5415520427066420e+00*x-3.6776049774764275e+00)*((x>=2.0433500531930449e+00)&(x<3.0650250797895673e+00))+(9.9458014614757589e-02*x**3-1.1455113844024787e+00*x**2+3.6171194189693390e+00*x-1.7114602254364140e+00)*((x>=3.0650250797895673e+00)&(x<4.0867001063860897e+00))+(-2.4095688236598481e-02*x**3+3.6926940735861846e-01*x**2-2.5733354038723424e+00*x+6.7213839022587258e+00)*((x>=4.0867001063860897e+00)&(x<5.1083751329826121e+00))+(-2.4095649383060497e-02*x**3+3.6926881192327654e-01*x**2-2.5733323621652495e+00*x+6.7213787228651007e+00)*((x>=5.1083751329826121e+00)&(x<6.1300501595791346e+00))+(9.9457995502024998e-02*x**3-1.9029013097099314e+00*x**2+1.1355184454543327e+01*x-2.1739456855456623e+01)*((x>=6.1300501595791346e+00)&(x<7.1517251861756570e+00))+(1.6774114509818058e-01*x**3-3.3679282719846086e+00*x**2+2.1832654679069570e+01*x-4.6716786086173187e+01)*((x>=7.1517251861756570e+00)&(x<8.1734002127721794e+00))+(-3.1057329207392309e-01*x**3+8.3604376956788240e+00*x**2-7.4027974216500709e+01*x+2.1445230878433662e+02)*((x>=8.1734002127721794e+00)&(x<9.1950752393687019e+00))+(6.7469812746143401e-02*x**3-2.0679666819563565e+00*x**2+2.1861988662416703e+01*x-7.9452832339635989e+01)*((x>=9.1950752393687019e+00)&(x<=1.0216750265965224e+01))
Y = (-1.9230221308138107e-01*x**3-1.1102230246251565e-16*x**2+6.5686212211710260e-01*x+1.1547882766467819e+00)*((x>=0)&(x<1.0216750265965224e+00))+(9.4709002826707134e-02*x**3-8.7969657493918851e-01*x**2+1.5556261437149685e+00*x+8.4870669142344957e-01)*((x>=1.0216750265965224e+00)&(x<2.0433500531930449e+00))+(2.1493569028744916e-01*x**3-1.6166921995935821e+00*x**2+3.0615661925555626e+00*x-1.7701420154453740e-01)*((x>=2.0433500531930449e+00)&(x<3.0650250797895673e+00))+(-2.3821021389991145e-01*x**3+2.5500184838209607e+00*x**2-9.7095065523371353e+00*x+1.2870871884759829e+01)*((x>=3.0650250797895673e+00)&(x<4.0867001063860897e+00))+(4.9794680153161913e-01*x**3-6.4753403760217472e+00*x**2+2.7174428460354694e+01*x-3.7373655162008610e+01)*((x>=4.0867001063860897e+00)&(x<5.1083751329826121e+00))+(-4.9794680153160920e-01*x**3+8.7868539749322121e+00*x**2-5.0790585636806206e+01*x+9.5384524590183247e+01)*((x>=5.1083751329826121e+00)&(x<6.1300501595791346e+00))+(2.3821021389989974e-01*x**3-4.7511843148314545e+00*x**2+3.2198268141747974e+01*x-7.4190754192655277e+01)*((x>=6.1300501595791346e+00)&(x<7.1517251861756570e+00))+(-2.1493569028751147e-01*x**3+4.9711406131368987e+00*x**2-3.7333127913786711e+01*x+9.1565724607452125e+01)*((x>=7.1517251861756570e+00)&(x<8.1734002127721794e+00))+(-9.4709002826435268e-02*x**3+2.0231581145111317e+00*x**2-1.3238087132270245e+01*x+2.5919587457318343e+01)*((x>=8.1734002127721794e+00)&(x<9.1950752393687019e+00))+(1.9230221308117335e-01*x**3-5.8941110599283402e+00*x**2+5.9561798617035258e+01*x-1.9721388817011797e+02)*((x>=9.1950752393687019e+00)&(x<=1.0216750265965224e+01))

t = np.linspace(0, 2*math.pi, 400)
Q = math.sqrt(3)
ZX = [Q * math.sin(tt) for tt in t]
def abs(x):
    if x < 0:
        return -x
    else :
        return x
ZY = [2/3*((Q * math.cos(tt) + math.sqrt(Q * abs(math.sin(tt))))) for tt in t] 

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(16,10))

axes[0][0].scatter(px, py)
axes[0][0].plot(ZX, ZY)
axes[0][0].plot(X, Y)
axes[0][0].set_title("Nature: N=10")

px = [1.73205e-08, 0.821954, 1.67246, 1.47753, 0.727556, 1.73205e-08, -0.727556, -1.47753, -1.67246, -0.821954, -1.73205e-08]
py = [1.15479, 1.62081, 1.16243, 0.207804, -0.479244, -1.15461, -0.479244, 0.207804, 1.16243, 1.62081, 1.15479]
X = (7.6735281250313070e-01*x**3-1.6918423401199831e+00*x**2+1.7320508075688770e+00*x+1.7320508097218301e-08)*((x>=0)&(x<1.0216750265965224e+00))+(-4.9808911337625972e-01*x**3+2.1867688997175594e+00*x**2-2.2306294340497135e+00*x+1.3495238310702373e+00)*((x>=1.0216750265965224e+00)&(x<2.0433500531930449e+00))+(2.1792143055126889e-01*x**3-2.2024116493457306e+00*x**2+6.7380028743526399e+00*x-4.7591612704106945e+00)*((x>=2.0433500531930449e+00)&(x<3.0650250797895673e+00))+(8.6252674991692660e-02*x**3-9.9170753530138356e-01*x**2+3.0271644006022971e+00*x-9.6789027404643091e-01)*((x>=3.0650250797895673e+00)&(x<4.0867001063860897e+00))+(-2.1454620312244765e-02*x**3+3.2879471023009721e-01*x**2-2.3693322666942636e+00*x+6.3833975607379374e+00)*((x>=4.0867001063860897e+00)&(x<5.1083751329826121e+00))+(-2.1454581457410554e-02*x**3+3.2879411477489073e-01*x**2-2.3693292248856999e+00*x+6.3833923811715145e+00)*((x>=5.1083751329826121e+00)&(x<6.1300501595791346e+00))+(8.6252655875071693e-02*x**3-1.6519581874185416e+00*x**2+9.7727817412618876e+00*x-1.8427190707382010e+01)*((x>=6.1300501595791346e+00)&(x<7.1517251861756570e+00))+(2.1792143568031835e-01*x**3-4.4769349737171433e+00*x**2+2.9976239374195153e+01*x-6.6590382974475943e+01)*((x>=7.1517251861756570e+00)&(x<8.1734002127721794e+00))+(-4.9808911477551304e-01*x**3+1.3079787382611313e+01*x**2-1.1352187886860193e+02*x+3.2436546708488584e+02)*((x>=8.1734002127721794e+00)&(x<9.1950752393687019e+00))+(7.6735281297010505e-01*x**3-2.1827713827406882e+01*x**2+2.0745522117586938e+02*x-6.5943739458954383e+02)*((x>=9.1950752393687019e+00)&(x<=1.0216750265965224e+01))
Y = (-4.2224270477656811e-02*x**3-3.6278288060417352e-01*x**2+8.7085399427377863e-01*x+1.1547882766467816e+00)*((x>=0)&(x<1.0216750265965224e+00))+(5.4492037815251512e-02*x**3-6.5922079114659748e-01*x**2+1.1737172044114272e+00*x+1.0516456838892849e+00)*((x>=1.0216750265965224e+00)&(x<2.0433500531930449e+00))+(2.2572560772954714e-01*x**3-1.7088911637250306e+00*x**2+3.3185612160547322e+00*x-4.0924335787142441e-01)*((x>=2.0433500531930449e+00)&(x<3.0650250797895673e+00))+(-2.4115291865684771e-01*x**3+2.5840920140434571e+00*x**2-9.8395398909203955e+00*x+1.3034059940557118e+01)*((x>=3.0650250797895673e+00)&(x<4.0867001063860897e+00))+(4.9892770311726631e-01*x**3-6.4893706531722106e+00*x**2+2.7240980956480080e+01*x-3.7478262890083933e+01)*((x>=4.0867001063860897e+00)&(x<5.1083751329826121e+00))+(-4.9892770311726159e-01*x**3+8.8028885773899699e+00*x**2-5.0877615824047567e+01*x+9.5541436182297062e+01)*((x>=5.1083751329826121e+00)&(x<6.1300501595791346e+00))+(2.4115291865686217e-01*x**3-4.8073054234337116e+00*x**2+3.2553556082604615e+01*x-7.4937653371118756e+01)*((x>=6.1300501595791346e+00)&(x<7.1517251861756570e+00))+(-2.2572560772970351e-01*x**3+5.2096553246964232e+00*x**2-3.9084994388730607e+01*x+9.5842088531202648e+01)*((x>=7.1517251861756570e+00)&(x<8.1734002127721794e+00))+(-5.4492037814631467e-02*x**3+1.0109738343636545e+00*x**2-4.7674902022821826e+00*x+2.3451898580933346e+00)*((x>=8.1734002127721794e+00)&(x<9.1950752393687019e+00))+(4.2224270476206541e-02*x**3-1.6569673604610549e+00*x**2+1.9764429818342254e+01*x-7.2845760260512236e+01)*((x>=9.1950752393687019e+00)&(x<=1.0216750265965224e+01))

axes[1][0].scatter(px, py)
axes[1][0].plot(ZX, ZY)
axes[1][0].plot(X, Y)
axes[1][0].set_title("Complete: N=10")

px = [1.73205e-08, 0.821954, 1.67246, 1.47753, 0.727556, 1.73205e-08, -0.727556, -1.47753, -1.67246, -0.821954, -1.73205e-08]
py = [1.15479, 1.62081, 1.16243, 0.207804, -0.479244, -1.15461, -0.479244, 0.207804, 1.16243, 1.62081, 1.15479]
X = (6.7469818682030058e-02*x**3-1.5000000019860238e-08*x**2+7.3408952366122504e-01*x+1.7320508083340513e-08)*((x>=0)&(x<1.0216750265965224e+00))+(-3.1057329239023346e-01*x**3+1.1587116016781607e+00*x**2-4.4973719812613322e-01*x+4.0316208314309920e-01)*((x>=1.0216750265965224e+00)&(x<2.0433500531930449e+00))+(1.6774114042826566e-01*x**3-1.7733798635498834e+00*x**2+5.5415520533144615e+00*x-3.6776049870655854e+00)*((x>=2.0433500531930449e+00)&(x<3.0650250797895673e+00))+(9.9458014497678243e-02*x**3-1.1455113830388446e+00*x**2+3.6171194137387586e+00*x-1.7114602188438723e+00)*((x>=3.0650250797895673e+00)&(x<4.0867001063860897e+00))+(-2.4095688213182656e-02*x**3+3.6926940699976862e-01*x**2-2.5733354020636403e+00*x+6.7213838992621238e+00)*((x>=4.0867001063860897e+00)&(x<5.1083751329826121e+00))+(-2.4095649359644561e-02*x**3+3.6926881156442537e-01*x**2-2.5733323603565417e+00*x+6.7213787198684791e+00)*((x>=5.1083751329826121e+00)&(x<6.1300501595791346e+00))+(9.9457995384945486e-02*x**3-1.9029013074850507e+00*x**2+1.1355184440513625e+01*x-2.1739456826089821e+01)*((x>=6.1300501595791346e+00)&(x<7.1517251861756570e+00))+(1.6774114554308300e-01*x**3-3.3679282818171510e+00*x**2+2.1832654751271246e+01*x-4.6716786262374058e+01)*((x>=7.1517251861756570e+00)&(x<8.1734002127721794e+00))+(-3.1057329373645259e-01*x**3+8.3604377375209342e+00*x**2-7.4027974566656681e+01*x+2.1445230975883499e+02)*((x>=8.1734002127721794e+00)&(x<9.1950752393687019e+00))+(6.7469818951358326e-02*x**3-2.0679668571477494e+00*x**2+2.1861990307900165e+01*x-7.9452837481822456e+01)*((x>=9.1950752393687019e+00)&(x<=1.0216750265965224e+01))
Y = (-3.8407443071049419e-01*x**3+4.6357030436539048e-01*x**2+3.8341956842718428e-01*x+1.1547882766467819e+00)*((x>=0)&(x<1.0216750265965224e+00))+(1.4609894349856106e-01*x**3-1.1614243842220231e+00*x**2+2.0436360601089385e+00*x+5.8938770054846812e-01)*((x>=1.0216750265965224e+00)&(x<2.0433500531930449e+00))+(2.0114814522914679e-01*x**3-1.4988787520753046e+00*x**2+2.7331734606121652e+00*x+1.1973227254951485e-01)*((x>=2.0433500531930449e+00)&(x<3.0650250797895673e+00))+(-2.3444997433855605e-01*x**3+2.5064787314772476e+00*x**2-9.5433476799992327e+00*x+1.2662347335396436e+01)*((x>=3.0650250797895673e+00)&(x<4.0867001063860897e+00))+(4.9669338834450028e-01*x**3-6.4574122427037421e+00*x**2+2.7089386517819523e+01*x-3.7239985579083331e+01)*((x>=4.0867001063860897e+00)&(x<5.1083751329826121e+00))+(-4.9669338834448962e-01*x**3+8.7663646797116215e+00*x**2-5.0679376942721689e+01*x+9.5184020215795201e+01)*((x>=5.1083751329826121e+00)&(x<6.1300501595791346e+00))+(2.3444997433854056e-01*x**3-4.6794717815593838e+00*x**2+3.1744275002367591e+01*x-7.3236353370567997e+01)*((x>=6.1300501595791346e+00)&(x<7.1517251861756570e+00))+(-2.0114814522920160e-01*x**3+4.6663623467307467e+00*x**2-3.5094562318744963e+01*x+8.6101312057464696e+01)*((x>=7.1517251861756570e+00)&(x<8.1734002127721794e+00))+(-1.4609894349831370e-01*x**3+3.3165448753102140e+00*x**2-2.4061963910632802e+01*x+5.6043364665366681e+01)*((x>=8.1734002127721794e+00)&(x<9.1950752393687019e+00))+(3.8407443071030600e-01*x**3-1.1308407321964491e+01*x**2+1.1041557191547878e+02*x-3.5613365530996543e+02)*((x>=9.1950752393687019e+00)&(x<=1.0216750265965224e+01))

axes[2][0].scatter(px, py)
axes[2][0].plot(ZX, ZY)
axes[2][0].plot(X, Y)
axes[2][0].set_title("2nd Derivatives: N=10")

px = [1.73205e-08, 0.112768, 0.325975, 0.568435, 0.821954, 1.07573, 1.3171, 1.52596, 1.67246, 1.7311, 1.70377, 1.61224, 1.47753, 1.31395, 1.13062, 0.933651, 0.727556, 0.516479, 0.306009, 0.110125, 1.73205e-08, -0.110125, -0.306009, -0.516479, -0.727556, -0.933651, -1.13062, -1.31395, -1.47753, -1.61224, -1.70377, -1.7311, -1.67246, -1.52596, -1.3171, -1.07573, -0.821954, -0.568435, -0.325975, -0.112768, -1.73205e-08]
py = [1.15479, 1.37612, 1.51469, 1.59338, 1.62081, 1.59645, 1.51499, 1.36981, 1.16243, 0.915368, 0.662388, 0.424489, 0.207804, 0.0118412, -0.165882, -0.328408, -0.479244, -0.62306, -0.767749, -0.93113, -1.15461, -0.93113, -0.767749, -0.62306, -0.479244, -0.328408, -0.165882, 0.0118412, 0.207804, 0.424489, 0.662388, 0.915368, 1.16243, 1.36981, 1.51499, 1.59645, 1.62081, 1.59338, 1.51469, 1.37612, 1.15479]
X = (1.5011561196941376e+00*x**3+3.4356977055152238e-01*x+1.7320508074666896e-08)*((x>=0)&(x<2.5541875664913061e-01))+(-1.4782224166325451e+00*x**3+2.2829674840070044e+00*x**2-2.3954294568394019e-01*x+4.9645992309561113e-02)*((x>=2.5541875664913061e-01)&(x<5.1083751329826121e-01))+(1.3974291265433969e-01*x**3-1.9658467224014409e-01*x**2+1.0271053119066931e+00*x-1.6603782306749659e-01)*((x>=5.1083751329826121e-01)&(x<7.6625626994739182e-01))+(-1.7264358373924615e-01*x**3+5.2151966228530711e-01*x**2+4.7685336310015103e-01*x-2.5493154459574896e-02)*((x>=7.6625626994739182e-01)&(x<1.0216750265965224e+00))+(-9.7478135215164130e-02*x**3+2.9113567742536617e-01*x**2+7.1223092695937140e-01*x-1.0565294739824971e-01)*((x>=1.0216750265965224e+00)&(x<1.2770937832456530e+00))+(-1.9719360849543222e-01*x**3+6.7317371048419261e-01*x**2+2.2433252997653597e-01*x+1.0204438914916381e-01)*((x>=1.2770937832456530e+00)&(x<1.5325125398947836e+00))+(-3.2035285993385187e-01*x**3+1.2394030021845737e+00*x**2-6.4342096001003313e-01*x+5.4532542412979268e-01)*((x>=1.5325125398947836e+00)&(x<1.7879312965439143e+00))+(-3.1278049126822793e-01*x**3+1.1987863774058525e+00*x**2-5.7080122540813250e-01*x+5.0204572538267200e-01)*((x>=1.7879312965439143e+00)&(x<2.0433500531930449e+00))+(4.1018292488352870e-02*x**3-9.7001791342013632e-01*x**2+3.8608251376163025e+00*x-2.5164089294899554e+00)*((x>=2.0433500531930449e+00)&(x<2.2987688098421755e+00))+(2.6238035601251397e-01*x**3-2.4965985353549911e+00*x**2+7.3700810570298358e+00*x-5.2053982805904297e+00)*((x>=2.2987688098421755e+00)&(x<2.5541875664913061e+00))+(2.1536374956492033e-01*x**3-2.1363308405337733e+00*x**2+6.4498897903092711e+00*x-4.4219512498396796e+00)*((x>=2.5541875664913061e+00)&(x<2.8096063231404367e+00))+(1.3864068838418753e-01*x**3-1.4896460470616262e+00*x**2+4.6329601054908949e+00*x-2.7203322061171207e+00)*((x>=2.8096063231404367e+00)&(x<3.0650250797895673e+00))+(8.8060585482232057e-02*x**3-1.0245581952631966e+00*x**2+3.2074541754228676e+00*x-1.2639283971023474e+00)*((x>=3.0650250797895673e+00)&(x<3.3204438364386979e+00))+(5.7145204003397509e-02*x**3-7.1659983161546847e-01*x**2+2.1848957249694649e+00*x-1.3214576236634912e-01)*((x>=3.3204438364386979e+00)&(x<3.5758625930878285e+00))+(4.8966057458019741e-02*x**3-6.2885731909040032e-01*x**2+1.8711405566074291e+00*x+2.4183602761149814e-01)*((x>=3.5758625930878285e+00)&(x<3.8312813497369591e+00))+(1.8697646616967489e-02*x**3-2.8095692526603244e-01*x**2+5.3823626618165576e-01*x+1.9440798105752606e+00)*((x>=3.8312813497369591e+00)&(x<4.0867001063860897e+00))+(1.2472175745159531e-01*x**3-1.5808231603481033e+00*x**2+5.8503997473794414e+00*x-5.2923265440081195e+00)*((x>=4.0867001063860897e+00)&(x<4.3421188630352203e+00))+(-1.8215600563377954e-01*x**3+2.4166760108690895e+00*x**2-1.1507216808930444e+01*x+1.9830618211487192e+01)*((x>=4.3421188630352203e+00)&(x<4.5975376196843509e+00))+(1.4428041630392505e+00*x**3-1.9995770507019564e+01*x**2+9.1534849206226298e+01*x-1.3808264009340664e+02)*((x>=4.5975376196843509e+00)&(x<4.8529563763334815e+00))+(-1.3178711928612916e+00*x**3+2.0196540707193162e+01*x**2-1.0351668378036706e+02*x+1.7744288681356284e+02)*((x>=4.8529563763334815e+00)&(x<5.1083751329826121e+00))+(-1.3178687061814318e+00*x**3+2.0196502598512492e+01*x**2-1.0351648910693038e+02*x+1.7744255532524861e+02)*((x>=5.1083751329826121e+00)&(x<5.3637938896317428e+00))+(1.4428029397101660e+00*x**3-2.4226518518026410e+01*x**2+1.3475944011694287e+02*x-2.4857843574719709e+02)*((x>=5.3637938896317428e+00)&(x<5.6192126462808734e+00))+(-1.8215567790325249e-01*x**3+3.1664455233028264e+00*x**2-1.9167449843211557e+01*x+3.9737539808397514e+01)*((x>=5.6192126462808734e+00)&(x<5.8746314029300040e+00))+(1.2472166970643705e-01*x**3-2.2419283860443500e+00*x**2+1.2604753363426425e+01*x-2.2479121090931585e+01)*((x>=5.8746314029300040e+00)&(x<6.1300501595791346e+00))+(1.8697670049263593e-02*x**3-2.9213107799137106e-01*x**2+6.5239806405020317e-01*x+1.9437247458299680e+00)*((x>=6.1300501595791346e+00)&(x<6.3854689162282652e+00))+(4.8966051270914690e-02*x**3-8.7196450029750849e-01*x**2+4.3549063587759065e+00*x-5.9370257968516853e+00)*((x>=6.3854689162282652e+00)&(x<6.6408876728773958e+00))+(5.7145205821756306e-02*x**3-1.0349150401912084e+00*x**2+5.4370425904457989e+00*x-8.3324741839405760e+00)*((x>=6.6408876728773958e+00)&(x<6.8963064295265264e+00))+(8.8060584555382349e-02*x**3-1.6745208155871296e+00*x**2+9.8479600116702386e+00*x-1.8472153574643016e+01)*((x>=6.8963064295265264e+00)&(x<7.1517251861756570e+00))+(1.3864068865479240e-01*x**3-2.7597258288086550e+00*x**2+1.7609048036889817e+01*x-3.6973876475341058e+01)*((x>=7.1517251861756570e+00)&(x<7.4071439428247876e+00))+(2.1536375026297705e-01*x**3-4.4646221120065661e+00*x**2+3.0237460214125349e+01*x-6.8154032064041530e+01)*((x>=7.4071439428247876e+00)&(x<7.6625626994739182e+00))+(2.6238035510817426e-01*x**3-5.5454251596345330e+00*x**2+3.8519181332356766e+01*x-8.9307101173379124e+01)*((x>=7.6625626994739182e+00)&(x<7.9179814561230488e+00))+(4.1018292573566484e-02*x**3-2.8720304092024662e-01*x**2-3.1153238957990652e+00*x+2.0579978937092164e+01)*((x>=7.9179814561230488e+00)&(x<8.1734002127721794e+00))+(-3.1278049056732193e-01*x**3+8.3880141072865513e+00*x**2-7.4021345580798879e+01*x+2.1376107651276106e+02)*((x>=8.1734002127721794e+00)&(x<8.4288189694213109e+00))+(-3.2035286094729720e-01*x**3+8.5794925245930926e+00*x**2-7.5635282496826676e+01*x+2.1829560387718357e+02)*((x>=8.4288189694213109e+00)&(x<8.6842377260704406e+00))+(-1.9719360736640290e-01*x**3+5.3708598158074778e+00*x**2-4.7770753278088250e+01*x+1.3763487192365574e+02)*((x>=8.6842377260704406e+00)&(x<8.9396564827195704e+00))+(-9.7478136002162152e-02*x**3+2.6965936357812552e+00*x**2-2.3863732285296464e+01*x+6.6394686856753651e+01)*((x>=8.9396564827195704e+00)&(x<9.1950752393687019e+00))+(-1.7264358375660249e-01*x**3+4.7700494782898630e+00*x**2-4.2929314762673357e+01*x+1.2483117531070639e+02)*((x>=9.1950752393687019e+00)&(x<9.4504939960178334e+00))+(1.3974291309550746e-01*x**3-4.0865706605237229e+00*x**2+4.0770120684194978e+01*x-1.3883582874286355e+02)*((x>=9.4504939960178334e+00)&(x<9.7059127526669631e+00))+(-1.4782224168837388e+00*x**3+4.3024920328331923e+01*x**2-4.1648990050169334e+02*x+1.3405394615614312e+03)*((x>=9.7059127526669631e+00)&(x<9.9613315093160928e+00))+(1.5011561197289329e+00*x**3-4.6010811556487681e+01*x**2+4.7042454097757951e+02*x-1.6044101290968911e+03)*((x>=9.9613315093160928e+00)&(x<=1.0216750265965224e+01))
Y = (-1.1196133549946961e+00*x**3-1.7763568394002505e-15*x**2+9.3960169747738598e-01*x+1.1547882766467819e+00)*((x>=0)&(x<2.5541875664913061e-01))+(6.3114328528485686e-01*x**3-1.3415282527662438e+00*x**2+1.2822531758086231e+00*x+1.1256150717936650e+00)*((x>=2.5541875664913061e-01)&(x<5.1083751329826121e-01))+(-3.2137706931312238e-02*x**3-3.2504181472111071e-01*x**2+7.6299377149624448e-01*x+1.2140341327455575e+00)*((x>=5.1083751329826121e-01)&(x<7.6625626994739182e-01))+(1.5908515332874629e-02*x**3-4.3548897189277369e-01*x**2+8.4762459817687485e-01*x+1.1924178322205883e+00)*((x>=7.6625626994739182e-01)&(x<1.0216750265965224e+00))+(-6.4007147024044642e-02*x**3-1.9054546250079341e-01*x**2+5.9737193170420966e-01*x+1.2776434654453830e+00)*((x>=1.0216750265965224e+00)&(x<1.2770937832456530e+00))+(-7.8618260010161478e-02*x**3-1.3456617781825742e-01*x**2+5.2588113524565472e-01*x+1.3080769493508839e+00)*((x>=1.2770937832456530e+00)&(x<1.5325125398947836e+00))+(-1.8518065074712098e-02*x**3-4.1087908498423786e-01*x**2+9.4933413041226800e-01*x+1.0917612743012484e+00)*((x>=1.5325125398947836e+00)&(x<1.7879312965439143e+00))+(2.4382335906206265e-01*x**3-1.8180244127664125e+00*x**2+3.4652133007395207e+00*x-4.0764509468247212e-01)*((x>=1.7879312965439143e+00)&(x<2.0433500531930449e+00))+(3.9429027992986665e-01*x**3-2.7403941850434492e+00*x**2+5.3499376239855962e+00*x-1.6913622767354752e+00)*((x>=2.0433500531930449e+00)&(x<2.2987688098421755e+00))+(2.0559613510476193e-01*x**3-1.4391015408720946e+00*x**2+2.3585666810872823e+00*x+6.0079446399881675e-01)*((x>=2.2987688098421755e+00)&(x<2.5541875664913061e+00))+(4.3434994181251962e-02*x**3-1.9653163112748828e-01*x**2-8.1518993287858166e-01*x+3.3029176914858738e+00)*((x>=2.5541875664913061e+00)&(x<2.8096063231404367e+00))+(-1.1250677169164405e-02*x**3+2.6440399290645222e-01*x**2-2.1102375767250248e+00*x+4.5157757077923089e+00)*((x>=2.8096063231404367e+00)&(x<3.0650250797895673e+00))+(-2.7957852817103168e-02*x**3+4.1802773002659599e-01*x**2-2.5810981838492921e+00*x+4.9968422310991230e+00)*((x>=3.0650250797895673e+00)&(x<3.3204438364386979e+00))+(-2.5955024847958530e-02*x**3+3.9807689666983492e-01*x**2-2.5148525621980014e+00*x+4.9235206090648092e+00)*((x>=3.3204438364386979e+00)&(x<3.5758625930878285e+00))+(-5.0709087522569085e-02*x**3+6.6362827690510784e-01*x**2-3.4644278093241496e+00*x+6.0553708109050888e+00)*((x>=3.5758625930878285e+00)&(x<3.8312813497369591e+00))+(1.8246278370551039e-02*x**3-1.2893394502671640e-01*x**2-4.2789894993063626e-01*x+2.1774386819276401e+00)*((x>=3.8312813497369591e+00)&(x<4.0867001063860897e+00))+(-3.0255479807221430e-01*x**3+3.8041194346555756e+00*x**2-1.6501108615100463e+01*x+2.4072901231465949e+01)*((x>=4.0867001063860897e+00)&(x<4.3421188630352203e+00))+(7.1833065230603310e-01*x**3-9.4942984786011806e+00*x**2+4.1242202654577284e+01*x-5.9503205794594578e+01)*((x>=4.3421188630352203e+00)&(x<4.5975376196843509e+00))+(-3.6400892333315760e+00*x**3+5.0619699681196607e+01*x**2-2.3513416535472891e+02*x+3.6404704391024234e+02)*((x>=4.5975376196843509e+00)&(x<4.8529563763334815e+00))+(1.1356841802739527e+01*x**3-1.6771865660960771e+02*x**2+8.2445235300490106e+02*x-1.3499953396065443e+03)*((x>=4.8529563763334815e+00)&(x<5.1083751329826121e+00))+(-1.1356841802673207e+01*x**3+1.8037139291536801e+02*x**2-9.5372220002717131e+02*x+1.6778655499972920e+03)*((x>=5.1083751329826121e+00)&(x<5.3637938896317428e+00))+(3.6400892332466377e+00*x**3-6.0949948245718346e+01*x**2+3.4067573513040190e+02*x-6.3642902845275194e+02)*((x>=5.3637938896317428e+00)&(x<5.6192126462808734e+00))+(-7.1833065233025462e-01*x**3+1.2522716170788698e+01*x**2-7.2182789914785758e+01*x+1.3688425323350987e+02)*((x>=5.6192126462808734e+00)&(x<5.8746314029300040e+00))+(3.0255479813295771e-01*x**3-5.4692610074678001e+00*x**2+3.3513444217399979e+01*x-7.0091218834617280e+01)*((x>=5.8746314029300040e+00)&(x<6.1300501595791346e+00))+(-1.8246278381654824e-02*x**3+4.3031906337683523e-01*x**2-2.6512775373309410e+00*x+3.8059672866227174e+00)*((x>=6.1300501595791346e+00)&(x<6.3854689162282652e+00))+(5.0709087543383782e-02*x**3-8.9061797378759811e-01*x**2+5.7835248537773225e+00*x-1.4147422207692017e+01)*((x>=6.3854689162282652e+00)&(x<6.6408876728773958e+00))+(2.5955024770206059e-02*x**3-3.9745112281551087e-01*x**2+2.5084591924849633e+00*x-6.8976411483789661e+00)*((x>=6.6408876728773958e+00)&(x<6.8963064295265264e+00))+(2.7957852868000010e-02*x**3-4.3888747167969200e-01*x**2+2.7942169515728210e+00*x-7.5545321721408527e+00)*((x>=6.8963064295265264e+00)&(x<7.1517251861756570e+00))+(1.1250677345781668e-02*x**3-8.0432087763313120e-02*x**2+2.3064255429824243e-01*x-1.4432056442656176e+00)*((x>=7.1517251861756570e+00)&(x<7.4071439428247876e+00))+(-4.3434994661053494e-02*x**3+1.1347618447308605e+00*x**2-8.7704738221339085e+00*x+2.0780982571183813e+01)*((x>=7.4071439428247876e+00)&(x<7.6625626994739182e+00))+(-2.0559613472832794e-01*x**3+4.8624715542815125e+00*x**2-3.7334283197004424e+01*x+9.3738309328105970e+01)*((x>=7.6625626994739182e+00)&(x<7.9179814561230488e+00))+(-3.9429027966351526e-01*x**3+9.3447017757093249e+00*x**2-7.2824498972342553e+01*x+1.8740859945575448e+02)*((x>=7.9179814561230488e+00)&(x<8.1734002127721794e+00))+(-2.4382335999215599e-01*x**3+5.6552227159377253e+00*x**2-4.2668910040187711e+01*x+1.0525070045763459e+02)*((x>=8.1734002127721794e+00)&(x<8.4288189694213109e+00))+(1.8518066560478275e-02*x**3-9.7846246183746644e-01*x**2+1.3245221423415387e+01*x-5.1845996855408885e+01)*((x>=8.4288189694213109e+00)&(x<8.6842377260704406e+00))+(7.8618258047967515e-02*x**3-2.5442355126169787e+00*x**2+2.6842766821457190e+01*x-9.1207435764610636e+01)*((x>=8.6842377260704406e+00)&(x<8.9396564827195704e+00))+(6.4007148373214307e-02*x**3-2.1523806086462400e+00*x**2+2.3339718588887990e+01*x-8.0768753150758130e+01)*((x>=8.9396564827195704e+00)&(x<9.1950752393687019e+00))+(-1.5908514931473050e-02*x**3+5.2111002026492770e-02*x**2+3.0692523641960179e+00*x-1.8639265793057348e+01)*((x>=9.1950752393687019e+00)&(x<9.4504939960178334e+00))+(3.2137705976783337e-02*x**3-1.3100705646483561e+00*x**2+1.5942541081545642e+01*x-5.9192245037160319e+01)*((x>=9.4504939960178334e+00)&(x<9.7059127526669631e+00))+(-6.3114328562559230e-01*x**3+1.8003171740336938e+01*x**2-1.7151010370176346e+02*x+5.4727409347065259e+02)*((x>=9.7059127526669631e+00)&(x<9.9613315093160928e+00))+(1.1196133556056385e+00*x**3-3.4316430145986260e+01*x**2+3.4966279512334177e+02*x-1.1832512461520564e+03)*((x>=9.9613315093160928e+00)&(x<=1.0216750265965224e+01))


axes[0][1].scatter(px, py, s = 10)
axes[0][1].plot(ZX, ZY)
axes[0][1].plot(X, Y)
axes[0][1].set_title("Nature: N=40")

px = [1.73205e-08, 0.112768, 0.325975, 0.568435, 0.821954, 1.07573, 1.3171, 1.52596, 1.67246, 1.7311, 1.70377, 1.61224, 1.47753, 1.31395, 1.13062, 0.933651, 0.727556, 0.516479, 0.306009, 0.110125, 1.73205e-08, -0.110125, -0.306009, -0.516479, -0.727556, -0.933651, -1.13062, -1.31395, -1.47753, -1.61224, -1.70377, -1.7311, -1.67246, -1.52596, -1.3171, -1.07573, -0.821954, -0.568435, -0.325975, -0.112768, -1.73205e-08]
py = [1.15479, 1.37612, 1.51469, 1.59338, 1.62081, 1.59645, 1.51499, 1.36981, 1.16243, 0.915368, 0.662388, 0.424489, 0.207804, 0.0118412, -0.165882, -0.328408, -0.479244, -0.62306, -0.767749, -0.93113, -1.15461, -0.93113, -0.767749, -0.62306, -0.479244, -0.328408, -0.165882, 0.0118412, 0.207804, 0.424489, 0.662388, 0.915368, 1.16243, 1.36981, 1.51499, 1.59645, 1.62081, 1.59338, 1.51469, 1.37612, 1.15479]
X = (1.7081448519508974e+01*x**3-9.4155955224683296e+00*x**2+1.7320508075688770e+00*x+1.7320508083340513e-08)*((x>=0)&(x<2.5541875664913061e-01))+(-5.6529491830036962e+00*x**3+8.0047792605595873e+00*x**2-2.7174396598739810e+00*x+3.7882779162597935e-01)*((x>=2.5541875664913061e-01)&(x<5.1083751329826121e-01))+(1.2583575783240910e+00*x**3-2.5868850182348577e+00*x**2+2.6931797819953953e+00*x-5.4248800206994607e-01)*((x>=5.1083751329826121e-01)&(x<7.6625626994739182e-01))+(-4.7237548004708074e-01*x**3+1.3916701545115373e+00*x**2-3.5541306445318099e-01*x+2.3617979229937713e-01)*((x>=7.6625626994739182e-01)&(x<1.0216750265965224e+00))+(-1.7165215653623278e-02*x**3-3.5607224320486353e-03*x**2+1.0700594788564715e+00*x-2.4927677390010317e-01)*((x>=1.0216750265965224e+00)&(x<1.2770937832456530e+00))+(-2.1871339043373439e-01*x**3+7.6862704067649901e-01*x**2+8.3903287092198298e-02*x+1.7052787337033948e-01)*((x>=1.2770937832456530e+00)&(x<1.5325125398947836e+00))+(-3.1458665174218936e-01*x**3+1.2094079662640382e+00*x**2-5.9159900871711102e-01*x+5.1559978638887571e-01)*((x>=1.5325125398947836e+00)&(x<1.7879312965439143e+00))+(-3.1432554209656516e-01*x**3+1.2080074279422490e+00*x**2-5.8909494241962079e-01*x+5.1410742022154921e-01)*((x>=1.7879312965439143e+00)&(x<2.0433500531930449e+00))+(4.1432287610074781e-02*x**3-9.7280591282245155e-01*x**2+3.8670701134359433e+00*x-2.5210609477518346e+00)*((x>=2.0433500531930449e+00)&(x<2.2987688098421755e+00))+(2.6226942635395645e-01*x**3-2.4957664926201062e+00*x**2+7.3680043928940790e+00*x-5.2036737900602361e+00)*((x>=2.2987688098421755e+00)&(x<2.5541875664913061e+00))+(2.1539347307736634e-01*x**3-2.1365765615405792e+00*x**2+6.4505659369222599e+00*x-4.4225704909719923e+00)*((x>=2.5541875664913061e+00)&(x<2.8096063231404367e+00))+(1.3863272399302140e-01*x**3-1.4895741035515755e+00*x**2+4.6327437398683742e+00*x-2.7201155779092687e+00)*((x>=2.8096063231404367e+00)&(x<3.0650250797895673e+00))+(8.8062719534411471e-02*x**3-1.0245791076994664e+00*x**2+3.2075224156050126e+00*x-1.2640025435373445e+00)*((x>=3.0650250797895673e+00)&(x<3.3204438364386979e+00))+(5.7144632185870847e-02*x**3-7.1659378998658951e-01*x**2+2.1848744656916779e+00*x-1.3212084949157088e-01)*((x>=3.3204438364386979e+00)&(x<3.5758625930878285e+00))+(4.8966210675970956e-02*x**3-6.2885905534334086e-01*x**2+1.8711471099667847e+00*x+2.4182778909704439e-01)*((x>=3.5758625930878285e+00)&(x<3.8312813497369591e+00))+(1.8697605562620012e-02*x**3-2.8095642858340852e-01*x**2+5.3823426453664069e-01*x+1.9440824976040858e+00)*((x>=3.8312813497369591e+00)&(x<4.0867001063860897e+00))+(1.2472176845105487e-01*x**3-1.5808233018503586e+00*x**2+5.8504003538044174e+00*x-5.2923274097797162e+00)*((x>=4.0867001063860897e+00)&(x<4.3421188630352203e+00))+(-1.8215600857729630e-01*x**3+2.4166760509930150e+00*x**2-1.1507216991147914e+01*x+1.9830618487175315e+01)*((x>=4.3421188630352203e+00)&(x<4.5975376196843509e+00))+(1.4428041638138607e+00*x**3-1.9995770518178304e+01*x**2+9.1534849259782916e+01*x-1.3808264017904523e+02)*((x>=4.5975376196843509e+00)&(x<4.8529563763334815e+00))+(-1.3178711930162137e+00*x**3+2.0196540709567369e+01*x**2-1.0351668379248531e+02*x+1.7744288683416329e+02)*((x>=4.8529563763334815e+00)&(x<5.1083751329826121e+00))+(-1.3178687063363526e+00*x**3+2.0196502600886674e+01*x**2-1.0351648911904852e+02*x+1.7744255534584875e+02)*((x>=5.1083751329826121e+00)&(x<5.3637938896317428e+00))+(1.4428029404847740e+00*x**3-2.4226518530609610e+01*x**2+1.3475944018505305e+02*x-2.4857843587003970e+02)*((x>=5.3637938896317428e+00)&(x<5.6192126462808734e+00))+(-1.8215568084676637e-01*x**3+3.1664455733983345e+00*x**2-1.9167450127306438e+01*x+3.9737540345260186e+01)*((x>=5.6192126462808734e+00)&(x<5.8746314029300040e+00))+(1.2472168070589973e-01*x**3-2.2419285816783940e+00*x**2+1.2604754522901999e+01*x-2.2479123380884403e+01)*((x>=5.8746314029300040e+00)&(x<6.1300501595791346e+00))+(1.8697628994907234e-02*x**3-2.9213031634782283e-01*x**2+6.5239335536557519e-01*x+1.9437344465818569e+00)*((x>=6.1300501595791346e+00)&(x<6.3854689162282652e+00))+(4.8966204488884557e-02*x**3-8.7196746021379568e-01*x**2+4.3549254139968525e+00*x-5.9370666773234007e+00)*((x>=6.3854689162282652e+00)&(x<6.6408876728773958e+00))+(5.7144634004215433e-02*x**3-1.0349035554692705e+00*x**2+5.4369657204460964e+00*x-8.3323027215446928e+00)*((x>=6.6408876728773958e+00)&(x<6.8963064295265264e+00))+(8.8062718607549328e-02*x**3-1.6745653123851980e+00*x**2+9.8482692073871476e+00*x-1.8472869588073081e+01)*((x>=6.8963064295265264e+00)&(x<7.1517251861756570e+00))+(1.3863272426364759e-01*x**3-2.7595536617325820e+00*x**2+1.7607807712121030e+01*x-3.6970898573878003e+01)*((x>=7.1517251861756570e+00)&(x<7.4071439428247876e+00))+(2.1539347377538931e-01*x**3-4.4652874241102154e+00*x**2+3.0242423218191107e+01*x-6.8166370479103534e+01)*((x>=7.4071439428247876e+00)&(x<7.6625626994739182e+00))+(2.6226942544967002e-01*x**3-5.5428571805151137e+00*x**2+3.8499369039700014e+01*x-8.9256158833600239e+01)*((x>=7.6625626994739182e+00)&(x<7.9179814561230488e+00))+(4.1432287695133851e-02*x**3-2.9710409582423836e-01*x**2-3.0364066082852332e+00*x+2.0370341615206598e+01)*((x>=7.9179814561230488e+00)&(x<8.1734002127721794e+00))+(-3.1432554139507829e-01*x**3+8.4261492521201262e+00*x**2-7.4335047378438503e+01*x+2.1462111682892373e+02)*((x>=8.1734002127721794e+00)&(x<8.4288189694213109e+00))+(-3.1458665275783204e-01*x**3+8.4327518333423086e+00*x**2-7.4390699340290212e+01*x+2.1477747693283800e+02)*((x>=8.4288189694213109e+00)&(x<8.6842377260704406e+00))+(-2.1871338929736162e-01*x**3+5.9349931989477511e+00*x**2-5.2699569576864633e+01*x+1.5198716779528422e+02)*((x>=8.6842377260704406e+00)&(x<8.9396564827195704e+00))+(-1.7165216465549804e-02*x**3+5.2967890943904195e-01*x**2-4.3779166475203510e+00*x+7.9941751734481841e+00)*((x>=8.9396564827195704e+00)&(x<9.1950752393687019e+00))+(-4.7237547997866036e-01*x**3+1.3086756777646613e+01*x**2-1.1984119243230089e+02*x+3.6189201124845886e+02)*((x>=9.1950752393687019e+00)&(x<9.4504939960178334e+00))+(1.2583575784859033e+00*x**3-3.5982090355540180e+01*x**2+3.4388365279139691e+02*x-1.0989176106151590e+03)*((x>=9.4504939960178334e+00)&(x<9.7059127526669631e+00))+(-5.6529491825289053e+00*x**3+1.6525953093244095e+02*x**2-1.6093499656349936e+03*x+5.2203874180590237e+03)*((x>=9.7059127526669631e+00)&(x<9.9613315093160928e+00))+(1.7081448518319043e+01*x**3-5.1413508555589897e+02*x**2+5.1583250348500296e+03*x-1.7251297324321731e+04)*((x>=9.9613315093160928e+00)&(x<=1.0216750265965224e+01))
Y = (-1.8910385953629643e+00*x**3+4.6619330707919282e-01*x**2+8.7085399427377852e-01*x+1.1547882766467819e+00)*((x>=0)&(x<2.5541875664913061e-01))+(8.3784605546252777e-01*x**3-1.6248316665790377e+00*x**2+1.4049409931678438e+00*x+1.1093163309134524e+00)*((x>=2.5541875664913061e-01)&(x<5.1083751329826121e-01))+(-8.7523547273701041e-02*x**3-2.0669114634832653e-01*x**2+6.8050161630568873e-01*x+1.2326732675173240e+00)*((x>=5.1083751329826121e-01)&(x<7.6625626994739182e-01))+(3.0749106524723402e-02*x**3-4.7857263395744098e-01*x**2+8.8883251086875248e-01*x+1.1794616494564130e+00)*((x>=7.6625626994739182e-01)&(x<1.0216750265965224e+00))+(-6.7983671449086458e-02*x**3-1.7595419327034989e-01*x**2+5.7965480743123265e-01*x+1.2847546955839668e+00)*((x>=1.0216750265965224e+00)&(x<1.2770937832456530e+00))+(-7.7552753501787919e-02*x**3-1.3929234766786180e-01*x**2+5.3283419232991491e-01*x+1.3046861344084846e+00)*((x>=1.2770937832456530e+00)&(x<1.5325125398947836e+00))+(-1.8803566683166295e-02*x**3-4.0939394419217479e-01*x**2+9.4676827604916980e-01*x+1.0932330764119769e+00)*((x>=1.5325125398947836e+00)&(x<1.7879312965439143e+00))+(2.4389985898749700e-01*x**3-1.8184809735898355e+00*x**2+3.4661190754633111e+00*x-4.0824230400322392e-01)*((x>=1.7879312965439143e+00)&(x<2.0433500531930449e+00))+(3.9426978183661632e-01*x**3-2.7402561431470147e+00*x**2+5.3496284172099990e+00*x-1.6911319418858000e+00)*((x>=2.0433500531930449e+00)&(x<2.2987688098421755e+00))+(2.0560162755229161e-01*x**3-1.4391427377091048e+00*x**2+2.3586695027217388e+00*x+6.0070907949586427e-01)*((x>=2.2987688098421755e+00)&(x<2.5541875664913061e+00))+(4.3433522484382703e-02*x**3-1.9651946477137372e-01*x**2-8.1522341084846772e-01*x+3.3029483519012643e+00)*((x>=2.5541875664913061e+00)&(x<2.8096063231404367e+00))+(-1.1250282829180849e-02*x**3+2.6440043077571596e-01*x**2-2.1102268638388444e+00*x+4.5157649819047547e+00)*((x>=2.8096063231404367e+00)&(x<3.0650250797895673e+00))+(-2.7957958480181455e-02*x**3+4.1802876546163681e-01*x**2-2.5811015626175475e+00*x+4.9968459023029794e+00)*((x>=3.0650250797895673e+00)&(x<3.3204438364386979e+00))+(-2.5954996535622943e-02*x**3+3.9807659753135027e-01*x**2-2.5148515095898034e+00*x+4.9235193755564666e+00)*((x>=3.3204438364386979e+00)&(x<3.5758625930878285e+00))+(-5.0709095108839364e-02*x**3+6.6362836287206051e-01*x**2-3.4644281338001690e+00*x+6.0553712188179531e+00)*((x>=3.5758625930878285e+00)&(x<3.8312813497369591e+00))+(1.8246280403299231e-02*x**3-1.2893396961923997e-01*x**2-4.2789885082220280e-01*x+2.1774385488834014e+00)*((x>=3.8312813497369591e+00)&(x<4.0867001063860897e+00))+(-3.0255479861693857e-01*x**3+3.8041194416631043e+00*x**2-1.6501108645132035e+01*x+2.4072901274340779e+01)*((x>=4.0867001063860897e+00)&(x<4.3421188630352203e+00))+(7.1833065245218286e-01*x**3-9.4942984805931729e+00*x**2+4.1242202663622948e+01*x-5.9503205808279404e+01)*((x>=4.3421188630352203e+00)&(x<4.5975376196843509e+00))+(-3.6400892333714410e+00*x**3+5.0619699681770243e+01*x**2-2.3513416535747888e+02*x+3.6404704391463497e+02)*((x>=4.5975376196843509e+00)&(x<4.8529563763334815e+00))+(1.1356841802752824e+01*x**3-1.6771865660980814e+02*x**2+8.2445235300590707e+02*x-1.3499953396082274e+03)*((x>=4.8529563763334815e+00)&(x<5.1083751329826121e+00))+(-1.1356841802686496e+01*x**3+1.8037139291557509e+02*x**2-9.5372220002824713e+02*x+1.6778655499991532e+03)*((x>=5.1083751329826121e+00)&(x<5.3637938896317428e+00))+(3.6400892332864982e+00*x**3-6.0949948246366603e+01*x**2+3.4067573513391449e+02*x-6.3642902845909396e+02)*((x>=5.3637938896317428e+00)&(x<5.6192126462808734e+00))+(-7.1833065247640349e-01*x**3+1.2522716173276251e+01*x**2-7.2182789928893385e+01*x+1.3688425326017114e+02)*((x>=5.6192126462808734e+00)&(x<5.8746314029300040e+00))+(3.0255479867768154e-01*x**3-5.4692610171562421e+00*x**2+3.3513444274820984e+01*x-7.0091218948023538e+01)*((x>=5.8746314029300040e+00)&(x<6.1300501595791346e+00))+(-1.8246280414402793e-02*x**3+4.3031910108858895e-01*x**2-2.6512777704747919e+00*x+3.8059677669424445e+00)*((x>=6.1300501595791346e+00)&(x<6.3854689162282652e+00))+(5.0709095129653034e-02*x**3-8.9061812034169585e-01*x**2+5.7835257972570471e+00*x-1.4147424231803992e+01)*((x>=6.3854689162282652e+00)&(x<6.6408876728773958e+00))+(2.5954996457869139e-02*x**3-3.9745055417376562e-01*x**2+2.5084553864293753e+00*x-6.8976326587804806e+00)*((x>=6.6408876728773958e+00)&(x<6.8963064295265264e+00))+(2.7957958531081850e-02*x**3-4.3888967484454611e-01*x**2+2.7942322607451615e+00*x-7.5545676240324156e+00)*((x>=6.8963064295265264e+00)&(x<7.1517251861756570e+00))+(1.1250283005787232e-02*x**3-8.0423563274450771e-02*x**2+2.3058114223874782e-01*x-1.4430581997689842e+00)*((x>=7.1517251861756570e+00)&(x<7.4071439428247876e+00))+(-4.3433522964168247e-02*x**3+1.1347289032083836e+00*x**2-8.7702280894786782e+00*x+2.0780371660642686e+01)*((x>=7.4071439428247876e+00)&(x<7.6625626994739182e+00))+(-2.0560162717586827e-01*x**3+4.8625987023391986e+00*x**2-3.7335264160794395e+01*x+9.3740831630373577e+01)*((x>=7.6625626994739182e+00)&(x<7.9179814561230488e+00))+(-3.9426978157023385e-01*x**3+9.3442115459060346e+00*x**2-7.2820591549677374e+01*x+1.8739821970691901e+02)*((x>=7.9179814561230488e+00)&(x<8.1734002127721794e+00))+(-2.4389985991772711e-01*x**3+5.6571108970184696e+00*x**2-4.2684442321547067e+01*x+1.0529328353580968e+02)*((x>=8.1734002127721794e+00)&(x<8.4288189694213109e+00))+(1.8803568169488472e-02*x**3-9.8572801696235501e-01*x**2+1.3306844327422368e+01*x-5.2020189473909340e+01)*((x>=8.4288189694213109e+00)&(x<8.6842377260704406e+00))+(7.7552751537471210e-02*x**3-2.5163036407023469e+00*x**2+2.6598726901710052e+01*x-9.0496812174604202e+01)*((x>=8.6842377260704406e+00)&(x<8.9396564827195704e+00))+(6.7983672806285256e-02*x**3-2.2596708105635912e+00*x**2+2.4304517558077805e+01*x-8.3660331030780071e+01)*((x>=8.9396564827195704e+00)&(x<9.1950752393687019e+00))+(-3.0749106153530548e-02*x**3+4.6389518281904429e-01*x**2-7.3887667045664784e-01*x-6.9016996372592985e+00)*((x>=9.1950752393687019e+00)&(x<9.4504939960178334e+00))+(8.7523546433796895e-02*x**3-2.8893097966899859e+00*x**2+3.0950566855809484e+01*x-1.0672866489796979e+02)*((x>=9.4504939960178334e+00)&(x<9.7059127526669631e+00))+(-8.3784605624670228e-01*x**3+2.4055360086071175e+01*x**2-2.3057204817568254e+02*x+7.3937656321701616e+02)*((x>=9.7059127526669631e+00)&(x<9.9613315093160928e+00))+(1.8910385977023640e+00*x**3-5.7494613979944802e+01*x**2+5.8177427807202957e+02*x-1.9579737888258314e+03)*((x>=9.9613315093160928e+00)&(x<=1.0216750265965224e+01))

axes[1][1].scatter(px, py, s = 10)
axes[1][1].plot(ZX, ZY)
axes[1][1].plot(X, Y)
axes[1][1].set_title("Complete: N=40")

px = [1.73205e-08, 0.112768, 0.325975, 0.568435, 0.821954, 1.07573, 1.3171, 1.52596, 1.67246, 1.7311, 1.70377, 1.61224, 1.47753, 1.31395, 1.13062, 0.933651, 0.727556, 0.516479, 0.306009, 0.110125, 1.73205e-08, -0.110125, -0.306009, -0.516479, -0.727556, -0.933651, -1.13062, -1.31395, -1.47753, -1.61224, -1.70377, -1.7311, -1.67246, -1.52596, -1.3171, -1.07573, -0.821954, -0.568435, -0.325975, -0.112768, -1.73205e-08]
py = [1.15479, 1.37612, 1.51469, 1.59338, 1.62081, 1.59645, 1.51499, 1.36981, 1.16243, 0.915368, 0.662388, 0.424489, 0.207804, 0.0118412, -0.165882, -0.328408, -0.479244, -0.62306, -0.767749, -0.93113, -1.15461, -0.93113, -0.767749, -0.62306, -0.479244, -0.328408, -0.165882, 0.0118412, 0.207804, 0.424489, 0.662388, 0.915368, 1.16243, 1.36981, 1.51499, 1.59645, 1.62081, 1.59338, 1.51469, 1.37612, 1.15479]
X = (1.5011561445151256e+00*x**3-1.5000000019860238e-08*x**2+3.4356977276351375e-01*x+1.7320508074666896e-08)*((x>=0)&(x<2.5541875664913061e-01))+(-1.4782224232833077e+00*x**3+2.2829674931224320e+00*x**2-2.3954294963148115e-01*x+4.9645992833981176e-02)*((x>=2.5541875664913061e-01)&(x<5.1083751329826121e-01))+(1.3974291443640929e-01*x**3-1.9658467604813801e-01*x**2+1.0271053145609192e+00*x-1.6603782366721997e-01)*((x>=5.1083751329826121e-01)&(x<7.6625626994739182e-01))+(-1.7264358421674864e-01*x**3+5.2151966367153335e-01*x**2+4.7685336177428184e-01*x-2.5493154042704802e-02)*((x>=7.6625626994739182e-01)&(x<1.0216750265965224e+00))+(-9.7478135087225581e-02*x**3+2.9113567695592479e-01*x**2+7.1223092752937589e-01*x-1.0565294762704092e-01)*((x>=1.0216750265965224e+00)&(x<1.2770937832456530e+00))+(-1.9719360852970347e-01*x**3+6.7317371063623455e-01*x**2+2.2433252975291396e-01*x+1.0204438925823212e-01)*((x>=1.2770937832456530e+00)&(x<1.5325125398947836e+00))+(-3.2035285992468232e-01*x**3+1.2394030021368820e+00*x**2-6.4342095992759596e-01*x+5.4532542408252027e-01)*((x>=1.5325125398947836e+00)&(x<1.7879312965439143e+00))+(-3.1278049127067575e-01*x**3+1.1987863774204754e+00*x**2-5.7080122543712264e-01*x+5.0204572540174297e-01)*((x>=1.7879312965439143e+00)&(x<2.0433500531930449e+00))+(4.1018292488999464e-02*x**3-9.7001791342444221e-01*x**2+3.8608251376259943e+00*x-2.5164089294972314e+00)*((x>=2.0433500531930449e+00)&(x<2.2987688098421755e+00))+(2.6238035601234344e-01*x**3-2.4965985353537405e+00*x**2+7.3700810570265389e+00*x-5.2053982805878150e+00)*((x>=2.2987688098421755e+00)&(x<2.5541875664913061e+00))+(2.1536374956495585e-01*x**3-2.1363308405342281e+00*x**2+6.4498897903101806e+00*x-4.4219512498407028e+00)*((x>=2.5541875664913061e+00)&(x<2.8096063231404367e+00))+(1.3864068838418042e-01*x**3-1.4896460470615693e+00*x**2+4.6329601054906675e+00*x-2.7203322061168933e+00)*((x>=2.8096063231404367e+00)&(x<3.0650250797895673e+00))+(8.8060585482232057e-02*x**3-1.0245581952631966e+00*x**2+3.2074541754228676e+00*x-1.2639283971023474e+00)*((x>=3.0650250797895673e+00)&(x<3.3204438364386979e+00))+(5.7145204003397509e-02*x**3-7.1659983161546847e-01*x**2+2.1848957249694649e+00*x-1.3214576236634912e-01)*((x>=3.3204438364386979e+00)&(x<3.5758625930878285e+00))+(4.8966057458019741e-02*x**3-6.2885731909040032e-01*x**2+1.8711405566074291e+00*x+2.4183602761149814e-01)*((x>=3.5758625930878285e+00)&(x<3.8312813497369591e+00))+(1.8697646616967489e-02*x**3-2.8095692526603244e-01*x**2+5.3823626618165576e-01*x+1.9440798105752606e+00)*((x>=3.8312813497369591e+00)&(x<4.0867001063860897e+00))+(1.2472175745159531e-01*x**3-1.5808231603481033e+00*x**2+5.8503997473794414e+00*x-5.2923265440081195e+00)*((x>=4.0867001063860897e+00)&(x<4.3421188630352203e+00))+(-1.8215600563377954e-01*x**3+2.4166760108690895e+00*x**2-1.1507216808930444e+01*x+1.9830618211487192e+01)*((x>=4.3421188630352203e+00)&(x<4.5975376196843509e+00))+(1.4428041630392505e+00*x**3-1.9995770507019564e+01*x**2+9.1534849206226298e+01*x-1.3808264009340664e+02)*((x>=4.5975376196843509e+00)&(x<4.8529563763334815e+00))+(-1.3178711928612916e+00*x**3+2.0196540707193162e+01*x**2-1.0351668378036706e+02*x+1.7744288681356284e+02)*((x>=4.8529563763334815e+00)&(x<5.1083751329826121e+00))+(-1.3178687061814318e+00*x**3+2.0196502598512492e+01*x**2-1.0351648910693038e+02*x+1.7744255532524861e+02)*((x>=5.1083751329826121e+00)&(x<5.3637938896317428e+00))+(1.4428029397101660e+00*x**3-2.4226518518026410e+01*x**2+1.3475944011694287e+02*x-2.4857843574719709e+02)*((x>=5.3637938896317428e+00)&(x<5.6192126462808734e+00))+(-1.8215567790325249e-01*x**3+3.1664455233028264e+00*x**2-1.9167449843211557e+01*x+3.9737539808397514e+01)*((x>=5.6192126462808734e+00)&(x<5.8746314029300040e+00))+(1.2472166970643705e-01*x**3-2.2419283860443500e+00*x**2+1.2604753363426425e+01*x-2.2479121090931585e+01)*((x>=5.8746314029300040e+00)&(x<6.1300501595791346e+00))+(1.8697670049263593e-02*x**3-2.9213107799137106e-01*x**2+6.5239806405020317e-01*x+1.9437247458299680e+00)*((x>=6.1300501595791346e+00)&(x<6.3854689162282652e+00))+(4.8966051270914690e-02*x**3-8.7196450029750849e-01*x**2+4.3549063587759065e+00*x-5.9370257968516853e+00)*((x>=6.3854689162282652e+00)&(x<6.6408876728773958e+00))+(5.7145205821756306e-02*x**3-1.0349150401912084e+00*x**2+5.4370425904457989e+00*x-8.3324741839405760e+00)*((x>=6.6408876728773958e+00)&(x<6.8963064295265264e+00))+(8.8060584555382349e-02*x**3-1.6745208155871865e+00*x**2+9.8479600116706933e+00*x-1.8472153574643926e+01)*((x>=6.8963064295265264e+00)&(x<7.1517251861756570e+00))+(1.3864068865477819e-01*x**3-2.7597258288083140e+00*x**2+1.7609048036887089e+01*x-3.6973876475335601e+01)*((x>=7.1517251861756570e+00)&(x<7.4071439428247876e+00))+(2.1536375026303034e-01*x**3-4.4646221120078167e+00*x**2+3.0237460214133080e+01*x-6.8154032064066087e+01)*((x>=7.4071439428247876e+00)&(x<7.6625626994739182e+00))+(2.6238035510799307e-01*x**3-5.5454251596300992e+00*x**2+3.8519181332324479e+01*x-8.9307101173292722e+01)*((x>=7.6625626994739182e+00)&(x<7.9179814561230488e+00))+(4.1018292574221960e-02*x**3-2.8720304093627647e-01*x**2-3.1153238956740097e+00*x+2.0579978936753832e+01)*((x>=7.9179814561230488e+00)&(x<8.1734002127721794e+00))+(-3.1278049056976442e-01*x**3+8.3880141073472032e+00*x**2-7.4021345581298647e+01*x+2.1376107651412531e+02)*((x>=8.1734002127721794e+00)&(x<8.4288189694213109e+00))+(-3.2035286093811877e-01*x**3+8.5794925243596936e+00*x**2-7.5635282494848525e+01*x+2.1829560387158199e+02)*((x>=8.4288189694213109e+00)&(x<8.6842377260704406e+00))+(-1.9719360740067771e-01*x**3+5.3708598167061723e+00*x**2-4.7770753285938554e+01*x+1.3763487194651225e+02)*((x>=8.6842377260704406e+00)&(x<8.9396564827195704e+00))+(-9.7478135874221827e-02*x**3+2.6965936323292965e+00*x**2-2.3863732254254728e+01*x+6.6394686763715526e+01)*((x>=8.9396564827195704e+00)&(x<9.1950752393687019e+00))+(-1.7264358423410409e-01*x**3+4.7700494915392682e+00*x**2-4.2929314885201507e+01*x+1.2483117568837042e+02)*((x>=9.1950752393687019e+00)&(x<9.4504939960178334e+00))+(1.3974291487757429e-01*x**3-4.0865707113365701e+00*x**2+4.0770121167085961e+01*x-1.3883583027237398e+02)*((x>=9.4504939960178334e+00)&(x<9.7059127526669631e+00))+(-1.4782224235345038e+00*x**3+4.3024920523064125e+01*x**2-4.1648990240204131e+02*x+1.3405394677424251e+03)*((x>=9.7059127526669631e+00)&(x<9.9613315093160928e+00))+(1.5011561445499220e+00*x**3-4.6010812302257222e+01*x**2+4.7042454844588144e+02*x-1.6044101540239722e+03)*((x>=9.9613315093160928e+00)&(x<=1.0216750265965224e+01))
Y = (-1.8866982273905926e+00*x**3+4.6357030436539226e-01*x**2+8.7124079822255363e-01*x+1.1547882766467819e+00)*((x>=0)&(x<2.5541875664913061e-01))+(8.3668305736947701e-01*x**3-1.6232376805393933e+00*x**2+1.4042506990924135e+00*x+1.1094080345928299e+00)*((x>=2.5541875664913061e-01)&(x<5.1083751329826121e-01))+(-8.7211922873869696e-02*x**3-2.0735703777064174e-01*x**2+6.8096575241327706e-01*x+1.2325683957820441e+00)*((x>=5.1083751329826121e-01)&(x<7.6625626994739182e-01))+(3.0665607018459440e-02*x**3-4.7833022686836557e-01*x**2+8.8860065754704465e-01*x+1.1795345464758071e+00)*((x>=7.6625626994739182e-01)&(x<1.0216750265965224e+00))+(-6.7961297823831757e-02*x**3-1.7603628998471521e-01*x**2+5.7975449154148606e-01*x+1.2847146847651487e+00)*((x>=1.0216750265965224e+00)&(x<1.2770937832456530e+00))+(-7.7558748496597829e-02*x**3-1.3926575621714221e-01*x**2+5.3279507146032756e-01*x+1.3047052125819505e+00)*((x>=1.2770937832456530e+00)&(x<1.5325125398947836e+00))+(-1.8801960329147605e-02*x**3-4.0940230022879831e-01*x**2+9.4678271264199054e-01*x+1.0932247954245113e+00)*((x>=1.5325125398947836e+00)&(x<1.7879312965439143e+00))+(2.4389942856622504e-01*x**3-1.8184784047835905e+00*x**2+3.4661139791875684e+00*x-4.0823894384834603e-01)*((x>=1.7879312965439143e+00)&(x<2.0433500531930449e+00))+(3.9426989716765970e-01*x**3-2.7402569198298039e+00*x**2+5.3496301569395257e+00*x-1.6911332378481063e+00)*((x>=2.0433500531930449e+00)&(x<2.2987688098421755e+00))+(2.0560159664943622e-01*x**3-1.4391425059181167e+00*x**2+2.3586689242033287e+00*x+6.0070955990556030e-01)*((x>=2.2987688098421755e+00)&(x<2.5541875664913061e+00))+(4.3433530764771522e-02*x**3-1.9651953322445159e-01*x**2-8.1522322248723356e-01*x+3.3029481793927999e+00)*((x>=2.5541875664913061e+00)&(x<2.8096063231404367e+00))+(-1.1250285047900266e-02*x**3+2.6440045081771535e-01*x**2-2.1102269241140061e+00*x+4.5157650422530384e+00)*((x>=2.8096063231404367e+00)&(x<3.0650250797895673e+00))+(-2.7957957885679674e-02*x**3+4.1802875963587205e-01*x**2-2.5811015436072466e+00*x+4.9968458816473387e+00)*((x>=3.0650250797895673e+00)&(x<3.3204438364386979e+00))+(-2.5954996694916854e-02*x**3+3.9807659921440575e-01*x**2-2.5148515155121629e+00*x+4.9235193824966217e+00)*((x>=3.3204438364386979e+00)&(x<3.5758625930878285e+00))+(-5.0709095066158838e-02*x**3+6.6362836238840117e-01*x**2-3.4644281319745858e+00*x+6.0553712165229570e+00)*((x>=3.5758625930878285e+00)&(x<3.8312813497369591e+00))+(1.8246280391863934e-02*x**3-1.2893396948089730e-01*x**2-4.2789885137966621e-01*x+2.1774385496319724e+00)*((x>=3.8312813497369591e+00)&(x<4.0867001063860897e+00))+(-3.0255479861387435e-01*x**3+3.8041194416236976e+00*x**2-1.6501108644963040e+01*x+2.4072901274099650e+01)*((x>=4.0867001063860897e+00)&(x<4.3421188630352203e+00))+(7.1833065245135863e-01*x**3-9.4942984805820316e+00*x**2+4.1242202663572300e+01*x-5.9503205808202438e+01)*((x>=4.3421188630352203e+00)&(x<4.5975376196843509e+00))+(-3.6400892333712154e+00*x**3+5.0619699681766946e+01*x**2-2.3513416535746319e+02*x+3.6404704391461019e+02)*((x>=4.5975376196843509e+00)&(x<4.8529563763334815e+00))+(1.1356841802752740e+01*x**3-1.6771865660980680e+02*x**2+8.2445235300590082e+02*x-1.3499953396082174e+03)*((x>=4.8529563763334815e+00)&(x<5.1083751329826121e+00))+(-1.1356841802686411e+01*x**3+1.8037139291557372e+02*x**2-9.5372220002823974e+02*x+1.6778655499991410e+03)*((x>=5.1083751329826121e+00)&(x<5.3637938896317428e+00))+(3.6400892332862709e+00*x**3-6.0949948246362879e+01*x**2+3.4067573513389414e+02*x-6.3642902845905735e+02)*((x>=5.3637938896317428e+00)&(x<5.6192126462808734e+00))+(-7.1833065247558014e-01*x**3+1.2522716173262211e+01*x**2-7.2182789928813634e+01*x+1.3688425326002107e+02)*((x>=5.6192126462808734e+00)&(x<5.8746314029300040e+00))+(3.0255479867461910e-01*x**3-5.4692610171018146e+00*x**2+3.3513444274498227e+01*x-7.0091218947386892e+01)*((x>=5.8746314029300040e+00)&(x<6.1300501595791346e+00))+(-1.8246280402965720e-02*x**3+4.3031910087641378e-01*x**2-2.6512777691633573e+00*x+3.8059677642405632e+00)*((x>=6.1300501595791346e+00)&(x<6.3854689162282652e+00))+(5.0709095086971495e-02*x**3-8.9061811951716874e-01*x**2+5.7835257919488416e+00*x-1.4147424220416006e+01)*((x>=6.3854689162282652e+00)&(x<6.6408876728773958e+00))+(2.5954996617165715e-02*x**3-3.9745055737317614e-01*x**2+2.5084554078437122e+00*x-6.8976327065464602e+00)*((x>=6.6408876728773958e+00)&(x<6.8963064295265264e+00))+(2.7957957936577849e-02*x**3-4.3888966244864491e-01*x**2+2.7942321746093057e+00*x-7.5545674245649934e+00)*((x>=6.8963064295265264e+00)&(x<7.1517251861756570e+00))+(1.1250285224512879e-02*x**3-8.0423611236824399e-02*x**2+2.3058148776908638e-01*x-1.4430590293532077e+00)*((x>=7.1517251861756570e+00)&(x<7.4071439428247876e+00))+(-4.3433531244563284e-02*x**3+1.1347290885515235e+00*x**2-8.7702294720754708e+00*x+2.0780375097887372e+01)*((x>=7.4071439428247876e+00)&(x<7.6625626994739182e+00))+(-2.0560159627300401e-01*x**3+4.8625979869497087e+00*x**2-3.7335258641471228e+01*x+9.3740817438817430e+01)*((x>=7.6625626994739182e+00)&(x<7.9179814561230488e+00))+(-3.9426989690131364e-01*x**3+9.3442143041493750e+00*x**2-7.2820613534515360e+01*x+1.8739827810784482e+02)*((x>=7.9179814561230488e+00)&(x<8.1734002127721794e+00))+(-2.4389942949629173e-01*x**3+5.6571002733008982e+00*x**2-4.2684354930262543e+01*x+1.0529304394512110e+02)*((x>=8.1734002127721794e+00)&(x<8.4288189694213109e+00))+(1.8801961814826740e-02*x**3-9.8568713782862005e-01*x**2+1.3306497610497900e+01*x-5.2019209391421100e+01)*((x>=8.4288189694213109e+00)&(x<8.6842377260704406e+00))+(7.7558746534705847e-02*x**3-2.5164607974095929e+00*x**2+2.6600099975107696e+01*x-9.0500810448120319e+01)*((x>=8.6842377260704406e+00)&(x<8.9396564827195704e+00))+(6.7961299172015543e-02*x**3-2.2590671498093684e+00*x**2+2.4299089184724380e+01*x-8.3644061771768975e+01)*((x>=8.9396564827195704e+00)&(x<9.1950752393687019e+00))+(-3.0665606613704099e-02*x**3+4.6157830816821388e-01*x**2-7.1745050102572350e-01*x-6.9677402254073968e+00)*((x>=9.1950752393687019e+00)&(x<9.4504939960178334e+00))+(8.7211921908776802e-02*x**3-2.8804243185329597e+00*x**2+3.0866125257293334e+01*x-1.0646120458431869e+02)*((x>=9.4504939960178334e+00)&(x<9.7059127526669631e+00))+(-8.3668305768636841e-01*x**3+2.4021307875199113e+01*x**2-2.3023974031068792e+02*x+7.3829571221980223e+02)*((x>=9.7059127526669631e+00)&(x<9.9613315093160928e+00))+(1.8866982279856703e+00*x**3-5.7364203563340766e+01*x**2+5.8046831918384623e+02*x-1.9536148670799939e+03)*((x>=9.9613315093160928e+00)&(x<=1.0216750265965224e+01))

axes[2][1].scatter(px, py, s = 10)
axes[2][1].plot(ZX, ZY)
axes[2][1].plot(X, Y)
axes[2][1].set_title("2nd Derivatives: N=40")

px = [1.73205e-08, 0.00896396, 0.0335455, 0.0693631, 0.112768, 0.161376, 0.213696, 0.268775, 0.325975, 0.384843, 0.445043, 0.506312, 0.568435, 0.631224, 0.694513, 0.758141, 0.821954, 0.885792, 0.94949, 1.01287, 1.07573, 1.13785, 1.19898, 1.25884, 1.3171, 1.37338, 1.42727, 1.4783, 1.52596, 1.56972, 1.60904, 1.64343, 1.67246, 1.69584, 1.71339, 1.72511, 1.7311, 1.73162, 1.72699, 1.71757, 1.70377, 1.68598, 1.66456, 1.63987, 1.61224, 1.58194, 1.54924, 1.51436, 1.47753, 1.43891, 1.39868, 1.35698, 1.31395, 1.26969, 1.22432, 1.17794, 1.13062, 1.08247, 1.03354, 0.983911, 0.933651, 0.882823, 0.83149, 0.779714, 0.727556, 0.675081, 0.622359, 0.569463, 0.516479, 0.463504, 0.41066, 0.358095, 0.306009, 0.254671, 0.204468, 0.155981, 0.110125, 0.0684082, 0.0333562, 0.00895572, 1.73205e-08, -0.00895572, -0.0333562, -0.0684082, -0.110125, -0.155981, -0.204468, -0.254671, -0.306009, -0.358095, -0.41066, -0.463504, -0.516479, -0.569463, -0.622359, -0.675081, -0.727556, -0.779714, -0.83149, -0.882823, -0.933651, -0.983911, -1.03354, -1.08247, -1.13062, -1.17794, -1.22432, -1.26969, -1.31395, -1.35698, -1.39868, -1.43891, -1.47753, -1.51436, -1.54924, -1.58194, -1.61224, -1.63987, -1.66456, -1.68598, -1.70377, -1.71757, -1.72699, -1.73162, -1.7311, -1.72511, -1.71339, -1.69584, -1.67246, -1.64343, -1.60904, -1.56972, -1.52596, -1.4783, -1.42727, -1.37338, -1.3171, -1.25884, -1.19898, -1.13785, -1.07573, -1.01287, -0.94949, -0.885792, -0.821954, -0.758141, -0.694513, -0.631224, -0.568435, -0.506312, -0.445043, -0.384843, -0.325975, -0.268775, -0.213696, -0.161376, -0.112768, -0.0693631, -0.0335455, -0.00896396, -1.73205e-08]
py = [1.15479, 1.2178, 1.27659, 1.32935, 1.37612, 1.41749, 1.45406, 1.48634, 1.51469, 1.53941, 1.56068, 1.57863, 1.59338, 1.60495, 1.61339, 1.61868, 1.62081, 1.61972, 1.61535, 1.60763, 1.59645, 1.58171, 1.5633, 1.5411, 1.51499, 1.48486, 1.45064, 1.41228, 1.36981, 1.32333, 1.27305, 1.21927, 1.16243, 1.10304, 1.04167, 0.97892, 0.915368, 0.851534, 0.787864, 0.724721, 0.662388, 0.601074, 0.540927, 0.482045, 0.424489, 0.368287, 0.313446, 0.259959, 0.207804, 0.156952, 0.107367, 0.0590111, 0.0118412, -0.0341867, -0.0791184, -0.123001, -0.165882, -0.207812, -0.248841, -0.289021, -0.328408, -0.367059, -0.405036, -0.442407, -0.479244, -0.515628, -0.551652, -0.587422, -0.62306, -0.658713, -0.694558, -0.730812, -0.767749, -0.805718, -0.845172, -0.886713, -0.93113, -0.979433, -1.03273, -1.0916, -1.15461, -1.0916, -1.03273, -0.979433, -0.93113, -0.886713, -0.845172, -0.805718, -0.767749, -0.730812, -0.694558, -0.658713, -0.62306, -0.587422, -0.551652, -0.515628, -0.479244, -0.442407, -0.405036, -0.367059, -0.328408, -0.289021, -0.248841, -0.207812, -0.165882, -0.123001, -0.0791184, -0.0341867, 0.0118412, 0.0590111, 0.107367, 0.156952, 0.207804, 0.259959, 0.313446, 0.368287, 0.424489, 0.482045, 0.540927, 0.601074, 0.662388, 0.724721, 0.787864, 0.851534, 0.915368, 0.97892, 1.04167, 1.10304, 1.16243, 1.21927, 1.27305, 1.32333, 1.36981, 1.41228, 1.45064, 1.48486, 1.51499, 1.5411, 1.5633, 1.58171, 1.59645, 1.60763, 1.61535, 1.61972, 1.62081, 1.61868, 1.61339, 1.60495, 1.59338, 1.57863, 1.56068, 1.53941, 1.51469, 1.48634, 1.45406, 1.41749, 1.37612, 1.32935, 1.27659, 1.2178, 1.15479]
X = (1.3448383609842093e+01*x**3+8.5545573436248079e-02*x+1.7320508075642678e-08)*((x>=0)&(x<6.3854689162282652e-02))+(-7.2577642920164678e+00*x**3+3.9665539140642903e+00*x**2-1.6773749379176250e-01*x+5.3911211631461307e-03)*((x>=6.3854689162282652e-02)&(x<1.2770937832456530e-01))+(-1.2462559554803505e+00*x**3+1.6633759367083876e+00*x**2+1.2639993386718995e-01*x-7.1302481796243211e-03)*((x>=1.2770937832456530e-01)&(x<1.9156406748684796e-01))+(-1.7700094977125502e+00*x**3+1.9643730134402944e+00*x**2+6.8739709546768779e-02*x-3.4483724786171788e-03)*((x>=1.9156406748684796e-01)&(x<2.5541875664913061e-01))+(-8.3545757483349803e-01*x**3+1.2482667429428744e+00*x**2+2.5164668278588209e-01*x-1.9020996374344623e-02)*((x>=2.5541875664913061e-01)&(x<3.1927344581141326e-01))+(-6.0881676646457095e-01*x**3+1.0311855673945445e+00*x**2+3.2095493772401085e-01*x-2.6397091500101943e-02)*((x>=3.1927344581141326e-01)&(x<3.8312813497369591e-01))+(-3.9093036120274860e-01*x**3+7.8075033114237158e-01*x**2+4.1690372272104526e-01*x-3.8650651183067097e-02)*((x>=3.8312813497369591e-01)&(x<4.4698282413597856e-01))+(-2.8340403020911253e-01*x**3+6.3656306185282574e-01*x**2+4.8135295555252355e-01*x-4.8253217884536070e-02)*((x>=4.4698282413597856e-01)&(x<5.1083751329826121e-01))+(-2.1035764880139141e-01*x**3+5.2461856635176218e-01*x**2+5.3853840326166846e-01*x-5.7990708519419343e-02)*((x>=5.1083751329826121e-01)&(x<5.7469220246054387e-01))+(-1.6573329609678922e-01*x**3+4.4768276373383742e-01*x**2+5.8275280911612981e-01*x-6.6460599946388754e-02)*((x>=5.7469220246054387e-01)&(x<6.3854689162282652e-01))+(-1.3655186157700427e-01*x**3+3.9178162081714163e-01*x**2+6.1844831016401258e-01*x-7.4058350359408109e-02)*((x>=6.3854689162282652e-01)&(x<7.0240158078510917e-01))+(-1.1806226268981845e-01*x**3+3.5282025035735387e-01*x**2+6.4581483836468578e-01*x-8.0465781248847179e-02)*((x>=7.0240158078510917e-01)&(x<7.6625626994739182e-01))+(-1.0678697751313848e-01*x**3+3.2690097647184757e-01*x**2+6.6567564449178462e-01*x-8.5538603656203804e-02)*((x>=7.6625626994739182e-01)&(x<8.3011095910967447e-01))+(-1.0085743505646860e-01*x**3+3.1213444194349904e-01*x**2+6.7793350663134788e-01*x-8.8930398888408035e-02)*((x>=8.3011095910967447e-01)&(x<8.9396564827195713e-01))+(-9.9098387073354388e-02*x**3+3.0741685653242712e-01*x**2+6.8215086593249907e-01*x-9.0187123668954428e-02)*((x>=8.9396564827195713e-01)&(x<9.5782033743423978e-01))+(-1.0090813256556430e-01*x**3+3.1261708964757418e-01*x**2+6.7716997689490199e-01*x-8.8596858063112904e-02)*((x>=9.5782033743423978e-01)&(x<1.0216750265965224e+00))+(-1.0599867383757555e-01*x**3+3.2821972631404606e-01*x**2+6.6122915266350901e-01*x-8.3168077389245809e-02)*((x>=1.0216750265965224e+00)&(x<1.0855297157588051e+00))+(-1.1429081850212697e-01*x**3+3.5522383463558072e-01*x**2+6.3191539063200253e-01*x-7.2561090800491002e-02)*((x>=1.0855297157588051e+00)&(x<1.1493844049210877e+00))+(-1.2585181000872581e-01*x**3+3.9508790466561550e-01*x**2+5.8609625022427281e-01*x-5.5006488990102298e-02)*((x>=1.1493844049210877e+00)&(x<1.2132390940833704e+00))+(-1.4090201198837349e-01*x**3+4.4986638491400299e-01*x**2+5.1963685647433522e-01*x-2.8129444101523404e-02)*((x>=1.2132390940833704e+00)&(x<1.2770937832456530e+00))+(-1.5962496877546073e-01*x**3+5.2159930006519062e-01*x**2+4.2802719648216225e-01*x+1.0868598318893419e-02)*((x>=1.2770937832456530e+00)&(x<1.3409484724079357e+00))+(-1.8216906892200768e-01*x**3+6.1229073002368750e-01*x**2+3.0641466201450385e-01*x+6.5227312424440242e-02)*((x>=1.3409484724079357e+00)&(x<1.4048031615702183e+00))+(-2.0846551685986014e-01*x**3+7.2311472962974221e-01*x**2+1.5072875699206634e-01*x+1.3812999628726175e-01)*((x>=1.4048031615702183e+00)&(x<1.4686578507325010e+00))+(-2.3795858484197652e-01*x**3+8.5306040712748654e-01*x**2-4.0116982435392856e-02*x+2.3155902745020285e-01)*((x>=1.4686578507325010e+00)&(x<1.5325125398947836e+00))+(-2.6941207732056682e-01*x**3+9.9766902206829400e-01*x**2-2.6173149821352126e-01*x+3.4476803560573899e-01)*((x>=1.5325125398947836e+00)&(x<1.5963672290570663e+00))+(-3.0036377718613494e-01*x**3+1.1458998601165149e+00*x**2-4.9836235040856991e-01*x+4.7068461487560853e-01)*((x>=1.5963672290570663e+00)&(x<1.6602219182193489e+00))+(-3.2698282032947645e-01*x**3+1.2784804167204129e+00*x**2-7.1847549641552177e-01*x+5.9249683803955122e-01)*((x>=1.6602219182193489e+00)&(x<1.7240766073816316e+00))+(-3.4378797460215083e-01*x**3+1.3654005368161961e+00*x**2-8.6833244218178152e-01*x+6.7861845625884598e-01)*((x>=1.7240766073816316e+00)&(x<1.7879312965439143e+00))+(-3.4423128721346075e-01*x**3+1.3677783742914471e+00*x**2-8.7258385222048673e-01*x+6.8115219928040460e-01)*((x>=1.7879312965439143e+00)&(x<1.8517859857061969e+00))+(-3.2202741890569087e-01*x**3+1.2444279378123611e+00*x**2-6.4416524261650920e-01*x+5.4015807256655535e-01)*((x>=1.8517859857061969e+00)&(x<1.9156406748684796e+00))+(-2.7342921920876506e-01*x**3+9.6513787361254799e-01*x**2-1.0914583554585988e-01*x+1.9852309323141526e-01)*((x>=1.9156406748684796e+00)&(x<1.9794953640307622e+00))+(-1.9958079339448886e-01*x**3+5.2659002399559540e-01*x**2+7.5895759967170306e-01*x-3.7427914861655154e-01)*((x>=1.9794953640307622e+00)&(x<2.0433500531930449e+00))+(-1.0759775405313121e-01*x**3-3.7270621000061510e-02*x**2+1.9111222786268627e+00*x-1.1590377346237801e+00)*((x>=2.0433500531930449e+00)&(x<2.1072047423553277e+00))+(-9.2458996969071450e-03*x**3-6.5901310275512515e-01*x**2+3.2212609846956184e+00*x-2.0792812328163564e+00)*((x>=2.1072047423553277e+00)&(x<2.1710594315176102e+00))+(8.2537771468423671e-02*x**3-1.2568165175825925e+00*x**2+4.5191277266603720e+00*x-3.0185298431370029e+00)*((x>=2.1710594315176102e+00)&(x<2.2349141206798926e+00))+(1.5759947619471859e-01*x**3-1.7600859090271115e+00*x**2+5.6438915961007297e+00*x-3.8564467278902157e+00)*((x>=2.2349141206798926e+00)&(x<2.2987688098421755e+00))+(2.1074614957660742e-01*x**3-2.1266016543813748e+00*x**2+6.4864265598334896e+00*x-4.5020444264991966e+00)*((x>=2.2987688098421755e+00)&(x<2.3626234990044583e+00))+(2.4181676616808545e-01*x**3-2.3468261610360059e+00*x**2+7.0067341543290240e+00*x-4.9118080763182661e+00)*((x>=2.3626234990044583e+00)&(x<2.4264781881667408e+00))+(2.5404937768007585e-01*x**3-2.4358726560976720e+00*x**2+7.2228035323096265e+00*x-5.0865706205931929e+00)*((x>=2.4264781881667408e+00)&(x<2.4903328773290232e+00))+(2.5216185070485153e-01*x**3-2.4217709446484150e+00*x**2+7.1876855766495282e+00*x-5.0574188207574480e+00)*((x>=2.4903328773290232e+00)&(x<2.5541875664913061e+00))+(2.4088810668172300e-01*x**3-2.3353851742194820e+00*x**2+6.9670401159237372e+00*x-4.8695621899314574e+00)*((x>=2.5541875664913061e+00)&(x<2.6180422556535889e+00))+(2.2416370355267645e-01*x**3-2.2040295919305208e+00*x**2+6.6231456509776763e+00*x-4.5694521097066172e+00)*((x>=2.6180422556535889e+00)&(x<2.6818969448158714e+00))+(2.0491462882296219e-01*x**3-2.0491574878142274e+00*x**2+6.2077946280915057e+00*x-4.1981425632766332e+00)*((x>=2.6818969448158714e+00)&(x<2.7457516339781538e+00))+(1.8509981466820591e-01*x**3-1.8859378127817763e+00*x**2+5.7596339386873296e+00*x-3.7879632481963199e+00)*((x>=2.7457516339781538e+00)&(x<2.8096063231404367e+00))+(1.6594524430968249e-01*x**3-1.7244874067891942e+00*x**2+5.3060218571263249e+00*x-3.3631394573494617e+00)*((x>=2.8096063231404367e+00)&(x<2.8734610123027196e+00))+(1.4811748078682285e-01*x**3-1.5708052565405524e+00*x**2+4.8644221900867706e+00*x-2.9401663152275432e+00)*((x>=2.8734610123027196e+00)&(x<2.9373157014650020e+00))+(1.3193850520974593e-01*x**3-1.4282369795400882e+00*x**2+4.4456541515392018e+00*x-2.5301483369694324e+00)*((x>=2.9373157014650020e+00)&(x<3.0011703906272844e+00))+(1.1749186534996170e-01*x**3-1.2981664961807837e+00*x**2+4.0552904681608197e+00*x-2.1396323608823877e+00)*((x>=3.0011703906272844e+00)&(x<3.0650250797895673e+00))+(1.0473901339639724e-01*x**3-1.1809030629356130e+00*x**2+3.6958751043566735e+00*x-1.7724266595323570e+00)*((x>=3.0650250797895673e+00)&(x<3.1288797689518502e+00))+(9.3577175315317618e-02*x**3-1.0761309148729197e+00*x**2+3.3680556499311933e+00*x-1.4305241065667360e+00)*((x>=3.1288797689518502e+00)&(x<3.1927344581141326e+00))+(8.3868167635159807e-02*x**3-9.8313606474948756e-01*x**2+3.0711477875156561e+00*x-1.1145414521852217e+00)*((x>=3.1927344581141326e+00)&(x<3.2565891472764150e+00))+(7.5414399583792147e-02*x**3-9.0054471687562909e-01*x**2+2.8021817003827891e+00*x-8.2257077205213136e-01)*((x>=3.2565891472764150e+00)&(x<3.3204438364386979e+00))+(6.8178406936226565e-02*x**3-8.2846459532811423e-01*x**2+2.5628437050363573e+00*x-5.5766798156764708e-01)*((x>=3.3204438364386979e+00)&(x<3.3842985256009808e+00))+(6.1907653519824635e-02*x**3-7.6479829069194238e-01*x**2+2.3473779241503507e+00*x-3.1460114003130002e-01)*((x>=3.3842985256009808e+00)&(x<3.4481532147632632e+00))+(5.6574522140067529e-02*x**3-7.0962992836211924e-01*x**2+2.1571489582129288e+00*x-9.5954933236498618e-02)*((x>=3.4481532147632632e+00)&(x<3.5120079039255456e+00))+(5.2083420787880641e-02*x**3-6.6231157802667440e-01*x**2+1.9909665378399950e+00*x+9.8589724730118178e-02)*((x>=3.5120079039255456e+00)&(x<3.5758625930878285e+00))+(4.8282588417237093e-02*x**3-6.2153781513006834e-01*x**2+1.8451651643081277e+00*x+2.7237828393117525e-01)*((x>=3.5758625930878285e+00)&(x<3.6397172822501114e+00))+(4.5225951666907349e-02*x**3-5.8816193431721331e-01*x**2+1.7236863941070624e+00*x+4.1976107704613241e-01)*((x>=3.6397172822501114e+00)&(x<3.7035719714123938e+00))+(4.2795753595555652e-02*x**3-5.6116069392919599e-01*x**2+1.6236853570080712e+00*x+5.4321475639881101e-01)*((x>=3.7035719714123938e+00)&(x<3.7674266605746762e+00))+(4.0997223446538555e-02*x**3-5.4083320263453061e-01*x**2+1.5471030243425048e+00*x+6.3938753033653484e-01)*((x>=3.7674266605746762e+00)&(x<3.8312813497369591e+00))+(3.9892056882308680e-02*x**3-5.2813059049276490e-01*x**2+1.4984357433713740e+00*x+7.0154021234338870e-01)*((x>=3.8312813497369591e+00)&(x<3.8951360388992420e+00))+(3.9473332950876738e-02*x**3-5.2323763046479144e-01*x**2+1.4793769984353276e+00*x+7.2628568040454411e-01)*((x>=3.8951360388992420e+00)&(x<3.9589907280615244e+00))+(3.9830017602071166e-02*x**3-5.2747396414360992e-01*x**2+1.4961486041756871e+00*x+7.0415280318775331e-01)*((x>=3.9589907280615244e+00)&(x<4.0228454172238068e+00))+(4.1148456027485736e-02*x**3-5.4338558607651066e-01*x**2+1.5601585995646019e+00*x+6.1831869766683667e-01)*((x>=4.0228454172238068e+00)&(x<4.0867001063860897e+00))+(4.3622499978141605e-02*x**3-5.7371761310332658e-01*x**2+1.6841164976576692e+00*x+4.4945911257309490e-01)*((x>=4.0867001063860897e+00)&(x<4.1505547955483726e+00))+(4.7597628106302636e-02*x**3-6.2321457445341366e-01*x**2+1.8895563479345583e+00*x+1.6522932730003959e-01)*((x>=4.1505547955483726e+00)&(x<4.2144094847106555e+00))+(5.3616895624202243e-02*x**3-6.9931754880235530e-01*x**2+2.2102854448748985e+00*x-2.8533192205941305e-01)*((x>=4.2144094847106555e+00)&(x<4.2782641738729374e+00))+(6.2502711297383939e-02*x**3-8.1336514935628657e-01*x**2+2.6982112084133405e+00*x-9.8115702663926641e-01)*((x>=4.2782641738729374e+00)&(x<4.3421188630352203e+00))+(7.5541858784106353e-02*x**3-9.8321773413817937e-01*x**2+3.4357313207128755e+00*x-2.0486236904907855e+00)*((x>=4.3421188630352203e+00)&(x<4.4059735521975032e+00))+(9.4771448262832791e-02*x**3-1.2373929221253093e+00*x**2+4.5556204766289738e+00*x-3.6933576912633725e+00)*((x>=4.4059735521975032e+00)&(x<4.4698282413597852e+00))+(1.2395029074545505e-01*x**3-1.6286661646622633e+00*x**2+6.3045446661944879e+00*x-6.2991546027697041e+00)*((x>=4.4698282413597852e+00)&(x<4.5336829305220681e+00))+(1.6823671171627552e-01*x**3-2.2310079370927269e+00*x**2+9.0353712782089133e+00*x-1.0426055268459095e+01)*((x>=4.5336829305220681e+00)&(x<4.5975376196843509e+00))+(2.4148467129742812e-01*x**3-3.2412886863105541e+00*x**2+1.3680175029179736e+01*x-1.7544275262167503e+01)*((x>=4.5975376196843509e+00)&(x<4.6613923088466338e+00))+(3.5211110533765577e-01*x**3-4.7883083126814654e+00*x**2+2.0891440417187368e+01*x-2.8749120934400707e+01)*((x>=4.6613923088466338e+00)&(x<4.7252469980089167e+00))+(5.8109969514757154e-01*x**3-8.0343912524124335e+00*x**2+3.6229984083444833e+01*x-5.2908590072011975e+01)*((x>=4.7252469980089167e+00)&(x<4.7891016871711987e+00))+(8.3922433742960578e-01*x**3-1.1742946731973461e+01*x**2+5.3990633387573780e+01*x-8.1261108587897070e+01)*((x>=4.7891016871711987e+00)&(x<4.8529563763334815e+00))+(1.8489672728627724e+00*x**3-2.6443661982877416e+01*x**2+1.2533256320110809e+02*x-1.9666753298408003e+02)*((x>=4.8529563763334815e+00)&(x<4.9168110654957644e+00))+(1.4706270343431811e+00*x**3-2.0862979569051419e+01*x**2+9.7893402155792472e+01*x-1.5169647609889506e+02)*((x>=4.9168110654957644e+00)&(x<4.9806657546580464e+00))+(7.5796947959353602e+00*x**3-1.1214465334819442e+02*x**2+5.5253690877543613e+02*x-9.0650559076493425e+02)*((x>=4.9806657546580464e+00)&(x<5.0445204438203293e+00))+(-1.3380025193619913e+01*x**3+2.0505055460398910e+02*x**2-1.0475608024211940e+03*x+1.7840696146489047e+03)*((x>=5.0445204438203293e+00)&(x<5.1083751329826121e+00))+(-1.3379866048134888e+01*x**3+2.0504811567947451e+02*x**2-1.0475483434798525e+03*x+1.7840483996668602e+03)*((x>=5.1083751329826121e+00)&(x<5.1722298221448950e+00))+(7.5796165107984024e+00*x**3-1.2017366656464731e+02*x**2+6.3457345745430666e+02*x-1.1160584480903844e+03)*((x>=5.1722298221448950e+00)&(x<5.2360845113071779e+00))+(1.4706480293233994e+00*x**3-2.4212440826902366e+01*x**2+1.3211236968284993e+02*x-2.3908220835215980e+02)*((x>=5.2360845113071779e+00)&(x<5.2999392004694599e+00))+(1.8489616256916293e+00*x**3-3.0227558005289893e+01*x**2+1.6399212501200236e+02*x-2.9540246334227413e+02)*((x>=5.2999392004694599e+00)&(x<5.3637938896317428e+00))+(8.3922580687141135e-01*x**3-1.3979513559899715e+01*x**2+7.6840963497346820e+01*x-1.3958217414006867e+02)*((x>=5.3637938896317428e+00)&(x<5.4276485787940256e+00))+(5.8109932039485557e-01*x**3-9.7764539874792717e+00*x**2+5.4028233182514668e+01*x-9.8309013049500209e+01)*((x>=5.4276485787940256e+00)&(x<5.4915032679563076e+00))+(3.5211142402440032e-01*x**3-6.0039906437559694e+00*x**2+3.3311738402215269e+01*x-6.0387446787291992e+01)*((x>=5.4915032679563076e+00)&(x<5.5553579571185905e+00))+(2.4148405360153902e-01*x**3-4.1602667160923374e+00*x**2+2.3069192009941617e+01*x-4.1420442920163623e+01)*((x>=5.5553579571185905e+00)&(x<5.6192126462808734e+00))+(1.6823745853258742e-01*x**3-2.9255021361705076e+00*x**2+1.6130787267247797e+01*x-2.8424319028446916e+01)*((x>=5.6192126462808734e+00)&(x<5.6830673354431562e+00))+(1.2394976979419425e-01*x**3-2.1704323844733153e+00*x**2+1.1839675025432371e+01*x-2.0295425757009070e+01)*((x>=5.6830673354431562e+00)&(x<5.7469220246054391e+00))+(9.4771911755572091e-02*x**3-1.6673837594980796e+00*x**2+8.9486938031004684e+00*x-1.4757344537218160e+01)*((x>=5.7469220246054391e+00)&(x<5.8107767137677211e+00))+(7.5541135604112242e-02*x**3-1.3321465207527581e+00*x**2+7.0007050625863485e+00*x-1.0984235333235119e+01)*((x>=5.8107767137677211e+00)&(x<5.8746314029300040e+00))+(6.2503388453194475e-02*x**3-1.1023706442438197e+00*x**2+5.6508564828254748e+00*x-8.3409477145178244e+00)*((x>=5.8746314029300040e+00)&(x<5.9384860920922868e+00))+(5.3616668928725630e-02*x**3-9.4404966333877383e-01*x**2+4.7106695396505529e+00*x-6.4798520191980060e+00)*((x>=5.9384860920922868e+00)&(x<6.0023407812545688e+00))+(4.7597505711507893e-02*x**3-8.3566245680231077e-01*x**2+4.0600925896869740e+00*x-5.1781904998206301e+00)*((x>=6.0023407812545688e+00)&(x<6.0661954704168517e+00))+(4.3622536873840545e-02*x**3-7.6332364291920385e-01*x**2+3.6212712045817170e+00*x-4.2908650669851340e+00)*((x>=6.0661954704168517e+00)&(x<6.1300501595791346e+00))+(4.1148641368408789e-02*x**3-7.1782833231372933e-01*x**2+3.3423826684957021e+00*x-3.7209981619525934e+00)*((x>=6.1300501595791346e+00)&(x<6.1939048487414174e+00))+(3.9829983086974607e-02*x**3-6.9332540053619596e-01*x**2+3.1906138406338869e+00*x-3.4076509356964380e+00)*((x>=6.1939048487414174e+00)&(x<6.2577595379037003e+00))+(3.9473397131814636e-02*x**3-6.8663111306159408e-01*x**2+3.1487225992750609e+00*x-3.3202691639598925e+00)*((x>=6.2577595379037003e+00)&(x<6.3216142270659823e+00))+(3.9891093728442684e-02*x**3-6.9455266330442100e-01*x**2+3.1987995839590440e+00*x-3.4257916235364974e+00)*((x>=6.3216142270659823e+00)&(x<6.3854689162282652e+00))+(4.0999146864237446e-02*x**3-7.1577897986753669e-01*x**2+3.3343395685515134e+00*x-3.7142870765819680e+00)*((x>=6.3854689162282652e+00)&(x<6.4493236053905481e+00))+(4.2793433918745905e-02*x**3-7.5049479342851555e-01*x**2+3.5582330845209071e+00*x-4.1956076555652544e+00)*((x>=6.4493236053905481e+00)&(x<6.5131782945528300e+00))+(4.5228331538737621e-02*x**3-7.9807156042261340e-01*x**2+3.8681090505560860e+00*x-4.8683667944860645e+00)*((x>=6.5131782945528300e+00)&(x<6.5770329837151129e+00))+(4.8279894263259848e-02*x**3-8.5828224648321338e-01*x**2+4.2641167187975952e+00*x-5.7365519594459329e+00)*((x>=6.5770329837151129e+00)&(x<6.6408876728773958e+00))+(5.2087175539895725e-02*x**3-9.3413342838721292e-01*x**2+4.7678358976991149e+00*x-6.8515994547924493e+00)*((x>=6.6408876728773958e+00)&(x<6.7047423620396787e+00))+(5.6570503151419871e-02*x**3-1.0243120980594540e+00*x**2+5.3724606444593519e+00*x-8.2028838390251622e+00)*((x>=6.7047423620396787e+00)&(x<6.7685970512019615e+00))+(6.1911159142709948e-02*x**3-1.1327583432321262e+00*x**2+6.1064895797171630e+00*x-9.8589992013585288e+00)*((x>=6.7685970512019615e+00)&(x<6.8324517403642435e+00))+(6.8174337213122271e-02*x**3-1.2611369289625145e+00*x**2+6.9836300711322110e+00*x-1.1856672560272273e+01)*((x>=6.8324517403642435e+00)&(x<6.8963064295265264e+00))+(7.5418536644747292e-02*x**3-1.4110115863295505e+00*x**2+8.0172116342146182e+00*x-1.4232637620239984e+01)*((x>=6.8963064295265264e+00)&(x<6.9601611186888093e+00))+(8.3866349393133532e-02*x**3-1.5874059997986478e+00*x**2+9.2449451726279221e+00*x-1.7081045365950558e+01)*((x>=6.9601611186888093e+00)&(x<7.0240158078510913e+00))+(9.3575163117407101e-02*x**3-1.7919905830276548e+00*x**2+1.0681950519239763e+01*x-2.0445561456319410e+01)*((x>=7.0240158078510913e+00)&(x<7.0878704970133741e+00))+(1.0474435456262654e-01*x**3-2.0294879306020448e+00*x**2+1.2365300962090259e+01*x-2.4422684769786429e+01)*((x>=7.0878704970133741e+00)&(x<7.1517251861756570e+00))+(1.1748646481009928e-01*x**3-2.3028721429327561e+00*x**2+1.4320469719095854e+01*x-2.9083627983985934e+01)*((x>=7.1517251861756570e+00)&(x<7.2155798753379399e+00))+(1.3193991727962384e-01*x**3-2.6157422652358946e+00*x**2+1.6578009077056777e+01*x-3.4513446503609885e+01)*((x>=7.2155798753379399e+00)&(x<7.2794345645002227e+00))+(1.4811973080600183e-01*x**3-2.9690819467396068e+00*x**2+1.9150122167513473e+01*x-4.0754622815118637e+01)*((x>=7.2794345645002227e+00)&(x<7.3432892536625047e+00))+(1.6594286976214789e-01*x**3-3.3617233410150220e+00*x**2+2.2033401498978492e+01*x-4.7812207524781115e+01)*((x>=7.3432892536625047e+00)&(x<7.4071439428247876e+00))+(1.8510093202075950e-01*x**3-3.7874429154726386e+00*x**2+2.5186767666134983e+01*x-5.5598019893106539e+01)*((x>=7.4071439428247876e+00)&(x<7.4709986319870705e+00))+(2.0491356896764046e-01*x**3-4.2315034660496167e+00*x**2+2.8504343432141468e+01*x-6.3859887895931024e+01)*((x>=7.4709986319870705e+00)&(x<7.5348533211493525e+00))+(2.2416730502959581e-01*x**3-4.6667256973742042e+00*x**2+3.1783679107291391e+01*x-7.2096325664082542e+01)*((x>=7.5348533211493525e+00)&(x<7.5987080103116353e+00))+(2.4088092115994186e-01*x**3-5.0477313636765757e+00*x**2+3.4678829915792448e+01*x-7.9429460876854137e+01)*((x>=7.5987080103116353e+00)&(x<7.6625626994739182e+00))+(2.5217162028684470e-01*x**3-5.3072784336509358e+00*x**2+3.6667625612695701e+01*x-8.4509218118560966e+01)*((x>=7.6625626994739182e+00)&(x<7.7264173886362011e+00))+(2.5403790023824513e-01*x**3-5.3505374072374252e+00*x**2+3.7001862498495029e+01*x-8.5370036014181096e+01)*((x>=7.7264173886362011e+00)&(x<7.7902720777984840e+00))+(2.4182715520919373e-01*x**3-5.0651623291123542e+00*x**2+3.4778712995612295e+01*x-7.9597056181402877e+01)*((x>=7.7902720777984840e+00)&(x<7.8541267669607659e+00))+(2.1073969306053186e-01*x**3-4.3326677233599185e+00*x**2+2.9025607505958760e+01*x-6.4535182908293791e+01)*((x>=7.8541267669607659e+00)&(x<7.9179814561230488e+00))+(1.5760194687572948e-01*x**3-3.0704366566169483e+00*x**2+1.9031285326112993e+01*x-3.8156897013192065e+01)*((x>=7.9179814561230488e+00)&(x<7.9818361452853317e+00))+(8.2538770044948251e-02*x**3-1.2730107225797838e+00*x**2+4.6845260375121143e+00*x+1.4263606281019747e-02)*((x>=7.9818361452853317e+00)&(x<8.0456908344476137e+00))+(-9.2492467845204374e-03*x**3+9.4248329454785562e-01*x**2-1.3140653869922971e+01*x+4.7819559141062200e+01)*((x>=8.0456908344476137e+00)&(x<8.1095455236098957e+00))+(-1.0759479897433266e-01*x**3+3.3350964921337436e+00*x**2-3.2543659516202752e+01*x+1.0026941166841425e+02)*((x>=8.1095455236098957e+00)&(x<8.1734002127721794e+00))+(-1.9958101527527106e-01*x**3+5.5906169717818557e+00*x**2-5.0978931084508076e+01*x+1.5049569585477002e+02)*((x>=8.1734002127721794e+00)&(x<8.2372549019344614e+00))+(-2.7342959037764558e-01*x**3+7.4155455836043984e+00*x**2-6.6011333237780491e+01*x+1.9177093862986658e+02)*((x>=8.2372549019344614e+00)&(x<8.3011095910967452e+00))+(-3.2203188399159899e-01*x**3+8.6259044805810845e+00*x**2-7.6058655086380895e+01*x+2.1957224521739408e+02)*((x>=8.3011095910967452e+00)&(x<8.3649642802590272e+00))+(-3.4422225755906766e-01*x**3+9.1827695273423160e+00*x**2-8.0716811311547644e+01*x+2.3256068202853203e+02)*((x>=8.3649642802590272e+00)&(x<8.4288189694213109e+00))+(-3.4379452576285985e-01*x**3+9.1719537057288107e+00*x**2-8.0625646708824206e+01*x+2.3230454538494814e+02)*((x>=8.4288189694213109e+00)&(x<8.4926736585835929e+00))+(-3.2698200258391807e-01*x**3+8.7436038875202939e+00*x**2-7.6987811491242610e+01*x+2.2200622960890178e+02)*((x>=8.4926736585835929e+00)&(x<8.5565283477458749e+00))+(-3.0036155350421723e-01*x**3+8.0602680059673730e+00*x**2-7.1140828649717150e+01*x+2.0532960479811300e+02)*((x>=8.5565283477458749e+00)&(x<8.6203830369081587e+00))+(-2.6941674843385499e-01*x**3+7.2599997878423892e+00*x**2-6.4242210077121854e+01*x+1.8550669329124503e+02)*((x>=8.6203830369081587e+00)&(x<8.6842377260704406e+00))+(-2.3795031531165023e-01*x**3+6.4402138309815200e+00*x**2-5.7122993943281472e+01*x+1.6489837151463144e+02)*((x>=8.6842377260704406e+00)&(x<8.7480924152327226e+00))+(-2.0847436708663736e-01*x**3+5.6666388736739464e+00*x**2-5.0355688726587687e+01*x+1.4516470103577012e+02)*((x>=8.7480924152327226e+00)&(x<8.8119471043950064e+00))+(-1.8216319956172811e-01*x**3+4.9710810242177104e+00*x**2-4.4226469749264652e+01*x+1.2716124989552191e+02)*((x>=8.8119471043950064e+00)&(x<8.8758017935572884e+00))+(-1.5962896754820122e-01*x**3+4.3710528934680042e+00*x**2-3.8900738990138052e+01*x+1.1140453968773363e+02)*((x>=8.8758017935572884e+00)&(x<8.9396564827195704e+00))+(-1.4089939993266398e-01*x**3+3.8687451917903672e+00*x**2-3.4410280688578496e+01*x+9.8023488132224884e+01)*((x>=8.9396564827195704e+00)&(x<9.0035111718818541e+00))+(-1.2585037090968854e-01*x**3+3.4622628890047054e+00*x**2-3.0750512734171934e+01*x+8.7039900910982396e+01)*((x>=9.0035111718818541e+00)&(x<9.0673658610441361e+00))+(-1.1429608250750789e-01*x**3+3.1479620083919144e+00*x**2-2.7900631659140345e+01*x+7.8426262788241729e+01)*((x>=9.0673658610441361e+00)&(x<9.1312205502064199e+00))+(-1.0599337370433659e-01*x**3+2.9205204126283206e+00*x**2-2.5823812286093016e+01*x+7.2104964208905585e+01)*((x>=9.1312205502064199e+00)&(x<9.1950752393687019e+00))+(-1.0091169022291524e-01*x**3+2.7803410267861182e+00*x**2-2.4534852286029491e+01*x+6.8154269482009113e+01)*((x>=9.1950752393687019e+00)&(x<9.2589299285309838e+00))+(-9.9095026968143429e-02*x**3+2.7298799534455611e+00*x**2-2.4067636743959156e+01*x+6.6712297493708320e+01)*((x>=9.2589299285309838e+00)&(x<9.3227846176932676e+00))+(-1.0086071321904910e-01*x**3+2.7792632913115085e+00*x**2-2.4528026966465404e+01*x+6.8143003788427450e+01)*((x>=9.3227846176932676e+00)&(x<9.3866393068555496e+00))+(-1.0678608859171845e-01*x**3+2.9461213754329947e+00*x**2-2.6094263617793331e+01*x+7.3043569960107561e+01)*((x>=9.3866393068555496e+00)&(x<9.4504939960178334e+00))+(-1.1806033072389255e-01*x**3+3.2657628481838401e+00*x**2-2.9115033436770318e+01*x+8.2559492306056200e+01)*((x>=9.4504939960178334e+00)&(x<9.5143486851801153e+00))+(-1.3655377876136754e-01*x**3+3.7936221872414535e+00*x**2-3.4137271245272132e+01*x+9.8487266202835599e+01)*((x>=9.5143486851801153e+00)&(x<9.5782033743423973e+00))+(-1.6573343318927414e-01*x**3+4.6320881807459955e+00*x**2-4.2168269053530821e+01*x+1.2412810963849188e+02)*((x>=9.5782033743423973e+00)&(x<9.6420580635046811e+00))+(-2.1035658012911540e-01*x**3+5.9228651020575853e+00*x**2-5.4614015075923817e+01*x+1.6412897823547246e+02)*((x>=9.6420580635046811e+00)&(x<9.7059127526669631e+00))+(-2.8340543547639641e-01*x**3+8.0498825521103754e+00*x**2-7.5258660869534651e+01*x+2.3092068852949888e+02)*((x>=9.7059127526669631e+00)&(x<9.7697674418292451e+00))+(-3.9092816934977748e-01*x**3+1.1201298866071738e+01*x**2-1.0604726536927410e+02*x+3.3118652380307321e+02)*((x>=9.7697674418292451e+00)&(x<9.8336221309915288e+00))+(-6.0881848740520184e-01*x**3+1.7629252027343227e+01*x**2-1.6925732783293279e+02*x+5.3838114685130131e+02)*((x>=9.8336221309915288e+00)&(x<9.8974768201538108e+00))+(-8.3545734808779315e-01*x**3+2.4358710637799049e+01*x**2-2.3586198844210958e+02*x+7.5812050834906404e+02)*((x>=9.8974768201538108e+00)&(x<9.9613315093160928e+00))+(-1.7700091248019199e+00*x**3+5.2286850819207984e+01*x**2-5.1406345122780021e+02*x+1.6818728407439885e+03)*((x>=9.9613315093160928e+00)&(x<1.0025186198478377e+01))+(-1.2462560573171810e+00*x**3+3.6534684748532470e+01*x**2-3.5614505333990542e+02*x+1.1541523930801541e+03)*((x>=1.0025186198478377e+01)&(x<1.0089040887640659e+01))+(-7.2577644164491320e+00*x**3+2.1848574564356011e+02*x**2-2.1918567462594397e+03*x+7.3276758356752225e+03)*((x>=1.0089040887640659e+01)&(x<1.0152895576802942e+01))+(1.3448383686829082e+01*x**3-4.1219633282764033e+02*x**2+4.2113925386196943e+03*x-1.4342831278196767e+04)*((x>=1.0152895576802942e+01)&(x<=1.0216750265965224e+01))
Y = (-3.0533652889029099e+00*x**3-2.8421709430404007e-14*x**2+9.9930900655394161e-01*x+1.1547882766467819e+00)*((x>=0)&(x<6.3854689162282652e-02))+(-9.8967535838141885e-01*x**3-3.9532883712223565e-01*x**2+1.0245526065652761e+00*x+1.1542509692360949e+00)*((x>=6.3854689162282652e-02)&(x<1.2770937832456530e-01))+(1.6051147557175227e-01*x**3-8.3599777368624473e-01*x**2+1.0808301625007886e+00*x+1.1518552453420465e+00)*((x>=1.2770937832456530e-01)&(x<1.9156406748684796e-01))+(4.2591305995802031e-01*x**3-9.8852199475425095e-01*x**2+1.1100483226786793e+00*x+1.1499895288059809e+00)*((x>=1.9156406748684796e-01)&(x<2.5541875664913061e-01))+(4.0262382725711632e-01*x**3-9.7067647417429725e-01*x**2+1.1054902420005703e+00*x+1.1503776019058432e+00)*((x>=2.5541875664913061e-01)&(x<3.1927344581141326e-01))+(3.1808134118966791e-01*x**3-8.8969996164189524e-01*x**2+1.0796365918146762e+00*x+1.1531290632330524e+00)*((x>=3.1927344581141326e-01)&(x<3.8312813497369591e-01))+(2.3788106866243197e-01*x**3-7.9751901912709400e-01*x**2+1.0443194792294435e+00*x+1.1576393897255883e+00)*((x>=3.8312813497369591e-01)&(x<4.4698282413597856e-01))+(1.7368780796516603e-01*x**3-7.1143916425808129e-01*x**2+1.0058432625979776e+00*x+1.1633721257161938e+00)*((x>=4.4698282413597856e-01)&(x<5.1083751329826121e-01))+(1.2449788513015392e-01*x**3-6.3605499067648452e-01*x**2+9.6733419882320959e-01*x+1.1699294171754957e+00)*((x>=5.1083751329826121e-01)&(x<5.7469220246054387e-01))+(8.6753662397995868e-02*x**3-5.7098105920090347e-01*x**2+9.2993671782107867e-01*x+1.1770934307501477e+00)*((x>=5.7469220246054387e-01)&(x<6.3854689162282652e-01))+(5.7312846137961060e-02*x**3-5.1458303407071071e-01*x**2+8.9392393418097527e-01*x+1.1847587144341105e+00)*((x>=6.3854689162282652e-01)&(x<7.0240158078510917e-01))+(3.3751879714372990e-02*x**3-4.6493525388723356e-01*x**2+8.5905125489784950e-01*x+1.1929235894526755e+00)*((x>=7.0240158078510917e-01)&(x<7.6625626994739182e-01))+(1.4341914157739666e-02*x**3-4.2031623046841560e-01*x**2+8.2486164844249288e-01*x+1.2016562562230320e+00)*((x>=7.6625626994739182e-01)&(x<8.3011095910967447e-01))+(-2.1257678433812544e-03*x**3-3.7930622056637731e-01*x**2+7.9081878978968234e-01*x+1.2110760395725038e+00)*((x>=8.3011095910967447e-01)&(x<8.9396564827195713e-01))+(-1.6482589700444805e-02*x**3-3.4080270389085854e-01*x**2+7.5639796854511587e-01*x+1.2213330501650717e+00)*((x>=8.9396564827195713e-01)&(x<9.5782033743423978e-01))+(-2.9287160945841606e-02*x**3-3.0400926763741154e-01*x**2+7.2115646701831793e-01*x+1.2325847257928899e+00)*((x>=9.5782033743423978e-01)&(x<1.0216750265965224e+00))+(-4.0866500225547497e-02*x**3-2.6851830233772489e-01*x**2+6.8489623410096101e-01*x+1.2449334506027299e+00)*((x>=1.0216750265965224e+00)&(x<1.0855297157588051e+00))+(-5.1347831903967744e-02*x**3-2.3438491134629658e-01*x**2+6.4784342387929428e-01*x+1.2583407594529490e+00)*((x>=1.0855297157588051e+00)&(x<1.1493844049210877e+00))+(-6.0664498404662481e-02*x**3-2.0225961779942736e-01*x**2+6.1091911247240205e-01*x+1.2724875020167019e+00)*((x>=1.1493844049210877e+00)&(x<1.2132390940833704e+00))+(-6.8515996676524082e-02*x**3-1.7368238384869983e-01*x**2+5.7624809504613950e-01*x+1.2865089132751564e+00)*((x>=1.2132390940833704e+00)&(x<1.2770937832456530e+00))+(-7.4334579863489125e-02*x**3-1.5138975460013171e-01*x**2+5.4777831682349643e-01*x+1.2986284388671265e+00)*((x>=1.2770937832456530e+00)&(x<1.3409484724079357e+00))+(-7.7215386332454727e-02*x**3-1.3980071549804052e-01*x**2+5.3223801254262071e-01*x+1.3055746879622347e+00)*((x>=1.3409484724079357e+00)&(x<1.4048031615702183e+00))+(-7.5843353719960760e-02*x**3-1.4558302275281676e-01*x**2+5.4036101605015574e-01*x+1.3017709476248456e+00)*((x>=1.4048031615702183e+00)&(x<1.4686578507325010e+00))+(-6.8477993114129276e-02*x**3-1.7803460678715055e-01*x**2+5.8802128971819911e-01*x+1.2784387359301945e+00)*((x>=1.4686578507325010e+00)&(x<1.5325125398947836e+00))+(-5.2937202958219132e-02*x**3-2.4948397416847001e-01*x**2+6.9751834119233536e-01*x+1.2225035344454227e+00)*((x>=1.5325125398947836e+00)&(x<1.5963672290570663e+00))+(-2.6881122140821390e-02*x**3-3.7426919477456977e-01*x**2+8.9672137803427177e-01*x+1.1165031344598901e+00)*((x>=1.5963672290570663e+00)&(x<1.6602219182193489e+00))+(1.1811122273684305e-02*x**3-5.6698233150109445e-01*x**2+1.2166679515521537e+00*x+9.3944236312108842e-01)*((x>=1.6602219182193489e+00)&(x<1.7240766073816316e+00))+(6.4109692486908898e-02*x**3-8.3748255601312849e-01*x**2+1.6830310609293520e+00*x+6.7142712064742227e-01)*((x>=1.7240766073816316e+00)&(x<1.7879312965439143e+00))+(1.2874343422004131e-01*x**3-1.1841646249804398e+00*x**2+2.3028747819862474e+00*x+3.0201445803231763e-01)*((x>=1.7879312965439143e+00)&(x<1.8517859857061969e+00))+(2.0109852900736769e-01*x**3-1.5861230765503933e+00*x**2+3.0472158094335100e+00*x-1.5743896970707283e-01)*((x>=1.8517859857061969e+00)&(x<1.9156406748684796e+00))+(2.7296157402645349e-01*x**3-1.9991143927290977e+00*x**2+3.8383587730750151e+00*x-6.6262084996833437e-01)*((x>=1.9156406748684796e+00)&(x<1.9794953640307622e+00))+(3.3378825984470950e-01*x**3-2.3603328204826539e+00*x**2+4.5533889762245963e+00*x-1.1344205073937701e+00)*((x>=1.9794953640307622e+00)&(x<2.0433500531930449e+00))+(3.7358916949460763e-01*x**3-2.6043143930355654e+00*x**2+5.0519287354727567e+00*x-1.4739842552498885e+00)*((x>=2.0433500531930449e+00)&(x<2.1072047423553277e+00))+(3.8629414153774633e-01*x**3-2.6846303250576966e+00*x**2+5.2211708483155235e+00*x-1.5928601828509272e+00)*((x>=2.1072047423553277e+00)&(x<2.1710594315176102e+00))+(3.7194336376865067e-01*x**3-2.5911611507840462e+00*x**2+5.0182437159583060e+00*x-1.4460045613013790e+00)*((x>=2.1710594315176102e+00)&(x<2.2349141206798926e+00))+(3.3584918179303713e-01*x**3-2.3491589598679639e+00*x**2+4.4773896022379631e+00*x-1.0430837293160948e+00)*((x>=2.2349141206798926e+00)&(x<2.2987688098421755e+00))+(2.8648637184858217e-01*x**3-2.0087378962671210e+00*x**2+3.6948402790258115e+00*x-4.4345040385996981e-01)*((x>=2.2987688098421755e+00)&(x<2.3626234990044583e+00))+(2.3227298788958706e-01*x**3-1.6244804515572469e+00*x**2+2.7869846104958924e+00*x+2.7152330820081261e-01)*((x>=2.3626234990044583e+00)&(x<2.4264781881667408e+00))+(1.7974116130079665e-01*x**3-1.2420784573541823e+00*x**2+1.8590945124415157e+00*x+1.0220250028442024e+00)*((x>=2.4264781881667408e+00)&(x<2.4903328773290232e+00))+(1.3289308086268647e-01*x**3-8.9207651248761977e-01*x**2+9.8747316200842761e-01*x+1.7455674380280470e+00)*((x>=2.4903328773290232e+00)&(x<2.5541875664913061e+00))+(9.3513831827522154e-02*x**3-5.9033054769815863e-01*x**2+2.1675737051100441e-01*x+2.4017516686817544e+00)*((x>=2.5541875664913061e+00)&(x<2.6180422556535889e+00))+(6.1774634391497329e-02*x**3-3.4104686755426883e-01*x**2-4.3587783775001299e-01*x+2.9712938529355597e+00)*((x>=2.6180422556535889e+00)&(x<2.6818969448158714e+00))+(3.7019348447472566e-02*x**3-1.4187349033136343e-01*x**2-9.7004030962398247e-01*x+3.4488167533781962e+00)*((x>=2.6818969448158714e+00)&(x<2.7457516339781538e+00))+(1.8168037563782491e-02*x**3+1.3409562654032925e-02*x**2-1.3964090060817398e+00*x+3.8390509350429056e+00)*((x>=2.7457516339781538e+00)&(x<2.8096063231404367e+00))+(4.1129759513296449e-03*x**3+1.3187713259048905e-01*x**2-1.7292562396614812e+00*x+4.1507741657442239e+00)*((x>=2.8096063231404367e+00)&(x<2.8734610123027196e+00))+(-6.2037475913996332e-03*x**3+2.2081124121154971e-01*x**2-1.9848049334541429e+00*x+4.3955439018645848e+00)*((x>=2.8734610123027196e+00)&(x<2.9373157014650020e+00))+(-1.3654191263981375e-02*x**3+2.8646415676075776e-01*x**2-2.1776482731393116e+00*x+4.5843578250578503e+00)*((x>=2.9373157014650020e+00)&(x<3.0011703906272844e+00))+(-1.8969811831027528e-02*x**3+3.3432340592059973e-01*x**2-2.3212820346366243e+00*x+4.7280476224232189e+00)*((x>=3.0011703906272844e+00)&(x<3.0650250797895673e+00))+(-2.2711013796524071e-02*x**3+3.6872403948041210e-01*x**2-2.4267208392536759e+00*x+4.8357718159359138e+00)*((x>=3.0650250797895673e+00)&(x<3.1288797689518502e+00))+(-2.5310731439205369e-02*x**3+3.9312665129114066e-01*x**2-2.5030736776607228e+00*x+4.9154047663992060e+00)*((x>=3.1288797689518502e+00)&(x<3.1927344581141326e+00))+(-2.7108113928888677e-02*x**3+4.1034234631860045e-01*x**2-2.5580388203953248e+00*x+4.9739011348000020e+00)*((x>=3.1927344581141326e+00)&(x<3.2565891472764150e+00))+(-2.8410806851940862e-02*x**3+4.2306935322503136e-01*x**2-2.5994854529643590e+00*x+5.0188926860722631e+00)*((x>=3.2565891472764150e+00)&(x<3.3204438364386979e+00))+(-2.9310192803080781e-02*x**3+4.3202843483925335e-01*x**2-2.6292335802904745e+00*x+5.0518183480810421e+00)*((x>=3.3204438364386979e+00)&(x<3.3842985256009808e+00))+(-3.0093205159190006e-02*x**3+4.3997827752605190e-01*x**2-2.6561382211752971e+00*x+5.0821694602395837e+00)*((x>=3.3842985256009808e+00)&(x<3.4481532147632632e+00))+(-3.0795317700068381e-02*x**3+4.4724125237121370e-01*x**2-2.6811820712323424e+00*x+5.1109544709370311e+00)*((x>=3.4481532147632632e+00)&(x<3.5120079039255456e+00))+(-3.1532917501351676e-02*x**3+4.5501262136713194e-01*x**2-2.7084751805732594e+00*x+5.1429056761789980e+00)*((x>=3.5120079039255456e+00)&(x<3.5758625930878285e+00))+(-3.2466159438911291e-02*x**3+4.6502405617184195e-01*x**2-2.7442746957940471e+00*x+5.1855770586189465e+00)*((x>=3.5758625930878285e+00)&(x<3.6397172822501114e+00))+(-3.3589956874777727e-02*x**3+4.7729497102000096e-01*x**2-2.7889373566349605e+00*x+5.2397635447960056e+00)*((x>=3.6397172822501114e+00)&(x<3.7035719714123938e+00))+(-3.5071339774674470e-02*x**3+4.9375419557964051e-01*x**2-2.8498952793870558e+00*x+5.3150175628488796e+00)*((x>=3.7035719714123938e+00)&(x<3.7674266605746762e+00))+(-3.6994970540575878e-02*x**3+5.1549560907778869e-01*x**2-2.9318044602350710e+00*x+5.4178798400607775e+00)*((x>=3.7674266605746762e+00)&(x<3.8312813497369591e+00))+(-3.9447037508409721e-02*x**3+5.4367928440569813e-01*x**2-3.0397840498808364e+00*x+5.5557799027192232e+00)*((x>=3.8312813497369591e+00)&(x<3.8951360388992420e+00))+(-4.2618620384189398e-02*x**3+5.8074052468191439e-01*x**2-3.1841426225437317e+00*x+5.7432119956974930e+00)*((x>=3.8951360388992420e+00)&(x<3.9589907280615244e+00))+(-4.6696164902868986e-02*x**3+6.2916940751301809e-01*x**2-3.3758721206286282e+00*x+5.9962304307555314e+00)*((x>=3.9589907280615244e+00)&(x<4.0228454172238068e+00))+(-5.1896944109444121e-02*x**3+6.9193519990085406e-01*x**2-3.6283692008964863e+00*x+6.3348160048481077e+00)*((x>=4.0228454172238068e+00)&(x<4.0867001063860897e+00))+(-5.8576983248656234e-02*x**3+7.7383314988583152e-01*x**2-3.9630615618152660e+00*x+6.7907451071623655e+00)*((x>=4.0867001063860897e+00)&(x<4.1505547955483726e+00))+(-6.7182361582126759e-02*x**3+8.8098443281432992e-01*x**2-4.4077988330245716e+00*x+7.4060472450801171e+00)*((x>=4.1505547955483726e+00)&(x<4.2144094847106555e+00))+(-7.8338712014840439e-02*x**3+1.0220367200481633e+00*x**2-5.0022509301925311e+00*x+8.2411354305659188e+00)*((x>=4.2144094847106555e+00)&(x<4.2782641738729374e+00))+(-9.2867171032935403e-02*x**3+1.2085064772081751e+00*x**2-5.8000178117508767e+00*x+9.3788212534127524e+00)*((x>=4.2782641738729374e+00)&(x<4.3421188630352203e+00))+(-1.1222061881250056e-01*x**3+1.4606113892077701e+00*x**2-6.8946873055901960e+00*x+1.0963216272757563e+01)*((x>=4.3421188630352203e+00)&(x<4.4059735521975032e+00))+(-1.3750018227466398e-01*x**3+1.7947546532859633e+00*x**2-8.3669136897915450e+00*x+1.3125413109963119e+01)*((x>=4.4059735521975032e+00)&(x<4.4698282413597852e+00))+(-1.7392053653424000e-01*x**3+2.2831328373777069e+00*x**2-1.0549880289483553e+01*x+1.6377908362388553e+01)*((x>=4.4698282413597852e+00)&(x<4.5336829305220681e+00))+(-2.1562929657693530e-01*x**3+2.8504157177512752e+00*x**2-1.3121761001031700e+01*x+2.0264605589487473e+01)*((x>=4.5336829305220681e+00)&(x<4.5975376196843509e+00))+(-3.0437491578527442e-01*x**3+4.0744496864326720e+00*x**2-1.8749303219788999e+01*x+2.8888884608502849e+01)*((x>=4.5975376196843509e+00)&(x<4.6613923088466338e+00))+(-3.1198982739419989e-01*x**3+4.1809379576561696e+00*x**2-1.9245686828253383e+01*x+2.9660164186730981e+01)*((x>=4.6613923088466338e+00)&(x<4.7252469980089167e+00))+(-7.5008391869084790e-01*x**3+1.0391246326884357e+01*x**2-4.8590927806704713e+01*x+7.5881334799822071e+01)*((x>=4.7252469980089167e+00)&(x<4.7891016871711987e+00))+(2.7183874158629351e-01*x**3-4.2910282825941977e+00*x**2+2.1723978297071881e+01*x-3.6367077018439886e+01)*((x>=4.7891016871711987e+00)&(x<4.8529563763334815e+00))+(-4.2124606910192597e+00*x**3+6.0995300291961030e+01*x**2-2.9510772624622768e+02*x+4.7615640324424021e+02)*((x>=4.8529563763334815e+00)&(x<4.9168110654957644e+00))+(1.2329755139052622e+01*x**3-1.8300954923138852e+02*x**2+9.0461801792478946e+02*x-1.4901185349225707e+03)*((x>=4.9168110654957644e+00)&(x<4.9806657546580464e+00))+(-4.7330805172053374e+01*x**3+7.0843837970431923e+02*x**2-3.5353861537861230e+03*x+5.8812737079372309e+03)*((x>=4.9806657546580464e+00)&(x<5.0445204438203293e+00))+(1.8244935240871428e+02*x**3-2.7689537277969885e+03*x**2+1.4006389423683737e+04*x-2.3615341465880978e+04)*((x>=5.0445204438203293e+00)&(x<5.1083751329826121e+00))+(-1.8244935222940489e+02*x**3+2.8231646786958099e+03*x**2-1.4560249184738459e+04*x+2.5027693967507250e+04)*((x>=5.1083751329826121e+00)&(x<5.1722298221448950e+00))+(4.7330804842992620e+01*x**3-7.4226266414515521e+02*x**2+3.8809604465944649e+03*x-6.7663641696945851e+03)*((x>=5.1722298221448950e+00)&(x<5.2360845113071779e+00))+(-1.2329754477077586e+01*x**3+1.9490052763006679e+02*x**2-1.0261052264269674e+03*x+1.7982393524636282e+03)*((x>=5.2360845113071779e+00)&(x<5.2999392004694599e+00))+(4.2124596751704075e+00*x**3-6.8117660114114187e+01*x**2+3.6787517723481142e+02*x-6.6443110955417797e+02)*((x>=5.2999392004694599e+00)&(x<5.3637938896317428e+00))+(-2.7183826550685808e-01*x**3+4.0408895663658768e+00*x**2-1.9168410626050900e+01*x+2.7576234308871790e+01)*((x>=5.3637938896317428e+00)&(x<5.4276485787940256e+00))+(7.5008405298376601e-01*x**3-1.2599016092419333e+01*x**2+7.1147149674121465e+01*x-1.3582413985981839e+02)*((x>=5.4276485787940256e+00)&(x<5.4915032679563076e+00))+(3.1199004146691323e-01*x**3-5.3816320046735200e+00*x**2+3.1512861370159953e+01*x-6.3273531945073046e+01)*((x>=5.4915032679563076e+00)&(x<5.5553579571185905e+00))+(3.0437383882156155e-01*x**3-5.2546998087591419e+00*x**2+3.0807707585590833e+01*x-6.1967738049046602e+01)*((x>=5.5553579571185905e+00)&(x<5.6192126462808734e+00))+(2.1563075160560174e-01*x**3-3.7587009749040590e+00*x**2+2.2401372019558039e+01*x-4.6222075675235828e+01)*((x>=5.6192126462808734e+00)&(x<5.6830673354431562e+00))+(1.7391950686368318e-01*x**3-3.0475575373566244e+00*x**2+1.8359895978872373e+01*x-3.8566082183868275e+01)*((x>=5.6830673354431562e+00)&(x<5.7469220246054391e+00))+(1.3750088660430038e-01*x**3-2.4196726247328115e+00*x**2+1.4751490345544880e+01*x-3.1653673581327894e+01)*((x>=5.7469220246054391e+00)&(x<5.8107767137677211e+00))+(1.1221972262438840e-01*x**3-1.9789630278855839e+00*x**2+1.2190625282652036e+01*x-2.6693468556419248e+01)*((x>=5.8107767137677211e+00)&(x<5.8746314029300040e+00))+(9.2867988186753792e-02*x**3-1.6379101074044229e+00*x**2+1.0187065085905488e+01*x-2.2770076006578165e+01)*((x>=5.8746314029300040e+00)&(x<5.9384860920922868e+00))+(7.8338410217043020e-02*x**3-1.3790590173093733e+00*x**2+8.6498814874794334e+00*x-1.9727228199844831e+01)*((x>=5.9384860920922868e+00)&(x<6.0023407812545688e+00))+(6.7182295194982089e-02*x**3-1.1781706048368505e+00*x**2+7.4440807768332888e+00*x-1.7314685940000345e+01)*((x>=6.0023407812545688e+00)&(x<6.0661954704168517e+00))+(5.8577025119973314e-02*x**3-1.0215668537794045e+00*x**2+6.4940918115280510e+00*x-1.5393746353875031e+01)*((x>=6.0661954704168517e+00)&(x<6.1300501595791346e+00))+(5.1897067588811296e-02*x**3-8.9872142959211487e-01*x**2+5.7410431993630482e+00*x-1.3855004432152782e+01)*((x>=6.1300501595791346e+00)&(x<6.1939048487414174e+00))+(4.6696066984992513e-02*x**3-8.0207792101828090e-01*x**2+5.1424425030309067e+00*x-1.2619112513682921e+01)*((x>=6.1939048487414174e+00)&(x<6.2577595379037003e+00))+(4.2618666298778862e-02*x**3-7.2553174191534708e-01*x**2+4.6634349206433399e+00*x-1.1619941091201326e+01)*((x>=6.2577595379037003e+00)&(x<6.3216142270659823e+00))+(3.9446797158092295e-02*x**3-6.6537774265771077e-01*x**2+4.2831645431215293e+00*x-1.0818633548318758e+01)*((x>=6.3216142270659823e+00)&(x<6.3854689162282652e+00))+(3.6995416964970218e-02*x**3-6.1841810658143004e-01*x**2+3.9833052466274239e+00*x-1.0180386142717907e+01)*((x>=6.3854689162282652e+00)&(x<6.4493236053905481e+00))+(3.5070877833248915e-02*x**3-5.8118217962737617e-01*x**2+3.7431587039645819e+00*x-9.6641252205372439e+00)*((x>=6.4493236053905481e+00)&(x<6.5131782945528300e+00))+(3.3590322568812780e-02*x**3-5.5225281838966112e-01*x**2+3.5547366162682010e+00*x-9.2550496699768701e+00)*((x>=6.5131782945528300e+00)&(x<6.5770329837151129e+00))+(3.2465890682701115e-02*x**3-5.3006654158207311e-01*x**2+3.4088167419286037e+00*x-8.9351430610877287e+00)*((x>=6.5770329837151129e+00)&(x<6.6408876728773958e+00))+(3.1533219660083489e-02*x**3-5.1148525109044840e-01*x**2+3.2854204789546202e+00*x-8.6619894872128498e+00)*((x>=6.6408876728773958e+00)&(x<6.7047423620396787e+00))+(3.0795005704732148e-02*x**3-4.9663664795406248e-01*x**2+3.1858644204949087e+00*x-8.4394902463773178e+00)*((x>=6.7047423620396787e+00)&(x<6.7685970512019615e+00))+(3.0093348607045378e-02*x**3-4.8238894546730648e-01*x**2+3.0894274634488283e+00*x-8.2219092786804140e+00)*((x>=6.7685970512019615e+00)&(x<6.8324517403642435e+00))+(2.9310200271183362e-02*x**3-4.6633647583678339e-01*x**2+2.9797497393865342e+00*x-7.9721200264611980e+00)*((x>=6.8324517403642435e+00)&(x<6.8963064295265264e+00))+(2.8410790175698253e-02*x**3-4.4772865296363307e-01*x**2+2.8514244908692490e+00*x-7.6771299476567947e+00)*((x>=6.8963064295265264e+00)&(x<6.9601611186888093e+00))+(2.7107952501779664e-02*x**3-4.2052477259721854e-01*x**2+2.6620811004668212e+00*x-7.2378431130055105e+00)*((x>=6.9601611186888093e+00)&(x<7.0240158078510913e+00))+(2.5311293333544427e-02*x**3-3.8266548540059375e-01*x**2+2.3961568687191175e+00*x-6.6152244438344496e+00)*((x>=7.0240158078510913e+00)&(x<7.0878704970133741e+00))+(2.2710019029517525e-02*x**3-3.2735299921932892e-01*x**2+2.0041091298007814e+00*x-5.6889632430975325e+00)*((x>=7.0878704970133741e+00)&(x<7.1517251861756570e+00))+(1.8970773908108640e-02*x**3-2.4712683868256136e-01*x**2+1.4303536768820777e+00*x-4.3211828020575922e+00)*((x>=7.1517251861756570e+00)&(x<7.2155798753379399e+00))+(1.3653975963791254e-02*x**3-1.3203549793706770e-01*x**2+5.9990291480789892e-01*x-2.3237881998647936e+00)*((x>=7.2155798753379399e+00)&(x<7.2794345645002227e+00))+(6.2032755812992946e-03*x**3+3.0675159747261205e-02*x**2-5.8453867072967114e-01*x+5.5023347260430455e-01)*((x>=7.2794345645002227e+00)&(x<7.3432892536625047e+00))+(-4.1124634906850588e-03*x**3+2.5792952735628205e-01*x**2-2.2533332263119519e+00*x+4.6350471813202603e+00)*((x>=7.3432892536625047e+00)&(x<7.4071439428247876e+00))+(-1.8168339569058389e-02*x**3+5.7027121941882797e-01*x**2-4.5668930987594649e+00*x+1.0347337513201637e+01)*((x>=7.4071439428247876e+00)&(x<7.4709986319870705e+00))+(-3.7018935468495329e-02*x**3+9.9276954795277561e-01*x**2-7.7233775332570076e+00*x+1.8208034477138426e+01)*((x>=7.4709986319870705e+00)&(x<7.5348533211493525e+00))+(-6.1776084520545282e-02*x**3+1.5523940082221088e+00*x**2-1.1940065756323747e+01*x+2.8798743564606411e+01)*((x>=7.5348533211493525e+00)&(x<7.5987080103116353e+00))+(-9.3510863292124213e-02*x**3+2.2758239611885074e+00*x**2-1.7437198734827689e+01*x+4.2722446363623021e+01)*((x>=7.5987080103116353e+00)&(x<7.6625626994739182e+00))+(-1.3289734890201998e-01*x**3+3.1812282076934935e+00*x**2-2.4374915541993687e+01*x+6.0442676372273127e+01)*((x>=7.6625626994739182e+00)&(x<7.7264173886362011e+00))+(-1.7973587875860630e-01*x**3+4.2669103023090429e+00*x**2-3.2763348556429264e+01*x+8.2046854607702699e+01)*((x>=7.7264173886362011e+00)&(x<7.7902720777984840e+00))+(-2.3227797388710769e-01*x**3+5.4948619520891953e+00*x**2-4.2329426006443100e+01*x+1.0688763662561541e+02)*((x>=7.7902720777984840e+00)&(x<7.8541267669607659e+00))+(-2.8648314861447943e-01*x**3+6.7720648932845506e+00*x**2-5.2360739813753753e+01*x+1.3315004005283117e+02)*((x>=7.8541267669607659e+00)&(x<7.9179814561230488e+00))+(-3.3585025449463046e-01*x**3+7.9447283799763682e+00*x**2-6.1645867555795121e+01*x+1.5765652981237508e+02)*((x>=7.9179814561230488e+00)&(x<7.9818361452853317e+00))+(-3.7194444734723220e-01*x**3+8.8090221794191166e+00*x**2-6.8544519044226035e+01*x+1.7601116508065024e+02)*((x>=7.9818361452853317e+00)&(x<8.0456908344476137e+00))+(-3.8629167377018803e-01*x**3+9.1553222238107992e+00*x**2-7.1330742137506604e+01*x+1.8348352828185307e+02)*((x>=8.0456908344476137e+00)&(x<8.1095455236098957e+00))+(-3.7359109960391379e-01*x**3+8.8463345706841210e+00*x**2-6.8824992698064307e+01*x+1.7671003189886687e+02)*((x>=8.1095455236098957e+00)&(x<8.1734002127721794e+00))+(-3.3378840822297207e-01*x**3+7.8703645920795680e+00*x**2-6.0847999467310729e+01*x+1.5497697917540791e+02)*((x>=8.1734002127721794e+00)&(x<8.2372549019344614e+00))+(-2.7296121292363296e-01*x**3+6.3672172541228065e+00*x**2-4.8466191689483821e+01*x+1.2097961023781681e+02)*((x>=8.2372549019344614e+00)&(x<8.3011095910967452e+00))+(-2.0109468423629551e-01*x**3+4.5775014624305186e+00*x**2-3.3609564765560208e+01*x+7.9870780821598601e+01)*((x>=8.3011095910967452e+00)&(x<8.3649642802590272e+00))+(-1.2875122680952700e-01*x**3+2.7620501505880384e+00*x**2-1.8423379389540059e+01*x+3.7526814746437594e+01)*((x>=8.3649642802590272e+00)&(x<8.4288189694213109e+00))+(-6.4104108504011492e-02*x**3+1.1273535792861367e+00*x**2-4.6448179202561732e+00*x-1.1855186813045293e+00)*((x>=8.4288189694213109e+00)&(x<8.4926736585835929e+00))+(-1.1811508809500992e-02*x**3-2.0495837259659311e-01*x**2+6.6700726986164227e+00*x-3.3216743183904327e+01)*((x>=8.4926736585835929e+00)&(x<8.5565283477458749e+00))+(2.6878495891423881e-02*x**3-1.1981147385704389e+00*x**2+1.5168043297890108e+01*x-5.7454451961093582e+01)*((x>=8.5565283477458749e+00)&(x<8.6203830369081587e+00))+(5.2943064878718360e-02*x**3-1.8721744436697918e+00*x**2+2.0978696145495633e+01*x-7.4151136374450289e+01)*((x>=8.6203830369081587e+00)&(x<8.6842377260704406e+00))+(6.8467307561604684e-02*x**3-2.2766230855995673e+00*x**2+2.4491024300106801e+01*x-8.4318433929700404e+01)*((x>=8.6842377260704406e+00)&(x<8.7480924152327226e+00))+(7.5854986425497373e-02*x**3-2.4705073779223312e+00*x**2+2.6187142007023795e+01*x-8.9264365412760526e+01)*((x>=8.7480924152327226e+00)&(x<8.8119471043950064e+00))+(7.7207332589068756e-02*x**3-2.5062577864846389e+00*x**2+2.6502172716514906e+01*x-9.0189710061647929e+01)*((x>=8.8119471043950064e+00)&(x<8.8758017935572884e+00))+(7.4340519920042425e-02*x**3-2.4299220034008613e+00*x**2+2.5824631436145864e+01*x-8.8185136025073007e+01)*((x>=8.8758017935572884e+00)&(x<8.9396564827195704e+00))+(6.8512232563762154e-02*x**3-2.2736133428661560e+00*x**2+2.4427285705431132e+01*x-8.4021205751341768e+01)*((x>=8.9396564827195704e+00)&(x<9.0035111718818541e+00))+(6.0661457101332417e-02*x**3-2.0615597091054951e+00*x**2+2.2518058445071802e+01*x-7.8291289428598247e+01)*((x>=9.0035111718818541e+00)&(x<9.0673658610441361e+00))+(5.1357445687926884e-02*x**3-1.8084710827388335e+00*x**2+2.0223211274133064e+01*x-7.1355216464144178e+01)*((x>=9.0673658610441361e+00)&(x<9.1312205502064199e+00))+(4.0856732281326913e-02*x**3-1.5208180925546912e+00*x**2+1.7596588379121386e+01*x-6.3360458811512217e+01)*((x>=9.1312205502064199e+00)&(x<9.1950752393687019e+00))+(2.9294291592805166e-02*x**3-1.2018655563442735e+00*x**2+1.4663795810774900e+01*x-5.4371376035385765e+01)*((x>=9.1950752393687019e+00)&(x<9.2589299285309838e+00))+(1.6474667969305301e-02*x**3-8.4577756580983987e-01*x**2+1.1366802057949826e+01*x-4.4195831325836480e+01)*((x>=9.2589299285309838e+00)&(x<9.3227846176932676e+00))+(2.1337806081191957e-03*x**3-4.4468655353193753e-01*x**2+7.6275169384316541e+00*x-3.2575648059835657e+01)*((x>=9.3227846176932676e+00)&(x<9.3866393068555496e+00))+(-1.4343013917027747e-02*x**3+1.9298627914395183e-02*x**2+3.2722553968196735e+00*x-1.8948558334377594e+01)*((x>=9.3866393068555496e+00)&(x<9.4504939960178334e+00))+(-3.3759366988874717e-02*x**3+5.6978101228378364e-01*x**2-1.9300750719266944e+00*x-2.5603607144439593e+00)*((x>=9.4504939960178334e+00)&(x<9.5143486851801153e+00))+(-5.7305776251041607e-02*x**3+1.2418672562998836e+00*x**2-8.3245379440486431e+00*x+1.7719355757581070e+01)*((x>=9.5143486851801153e+00)&(x<9.5782033743423973e+00))+(-8.6753546758473021e-02*x**3+2.0880374608314014e+00*x**2-1.6429328252328560e+01*x+4.3595799051108770e+01)*((x>=9.5782033743423973e+00)&(x<9.6420580635046811e+00))+(-1.2450221505002901e-01*x**3+3.1799620153033175e+00*x**2-2.6957728207169566e+01*x+7.7434280278161168e+01)*((x>=9.6420580635046811e+00)&(x<9.7059127526669631e+00))+(-1.7367857235001338e-01*x**3+4.6118663156303228e+00*x**2-4.0855666416464373e+01*x+1.2239833884558175e+02)*((x>=9.7059127526669631e+00)&(x<9.7697674418292451e+00))+(-2.3789585567988070e-01*x**3+6.4940300872622174e+00*x**2-5.9243968752911314e+01*x+1.8228148467116989e+02)*((x>=9.7697674418292451e+00)&(x<9.8336221309915288e+00))+(-3.1807299303864056e-01*x**3+8.8593251042475458e+00*x**2-8.2503386178432265e+01*x+2.5852292532008141e+02)*((x>=9.8336221309915288e+00)&(x<9.8974768201538108e+00))+(-4.0261884116841884e-01*x**3+1.1369696820569516e+01*x**2-1.0734973205049755e+02*x+3.4049496943224221e+02)*((x>=9.8974768201538108e+00)&(x<9.9613315093160928e+00))+(-4.2592011886642922e-01*x**3+1.2066032075792464e+01*x**2-1.1428615836927202e+02*x+3.6352698344981764e+02)*((x>=9.9613315093160928e+00)&(x<1.0025186198478377e+01))+(-1.6051504757467683e-01*x**3+4.0838263026271306e+00*x**2-3.4263059219054412e+01*x+9.6111493729404174e+01)*((x>=1.0025186198478377e+01)&(x<1.0089040887640659e+01))+(9.8968554535747444e-01*x**3-3.0729436130612157e+01*x**2+3.1696936890203506e+02*x-1.0850879490642110e+03)*((x>=1.0089040887640659e+01)&(x<1.0152895576802942e+01))+(3.0533604272402499e+00*x**3-9.3586262871296640e+01*x**2+9.5514816708967555e+02*x-3.2448755148398923e+03)*((x>=1.0152895576802942e+01)&(x<=1.0216750265965224e+01))

axes[0][2].scatter(px, py, s = 5)
axes[0][2].plot(ZX, ZY)
axes[0][2].plot(X, Y)
axes[0][2].set_title("Nature: N=160")


px = [1.73205e-08, 0.00896396, 0.0335455, 0.0693631, 0.112768, 0.161376, 0.213696, 0.268775, 0.325975, 0.384843, 0.445043, 0.506312, 0.568435, 0.631224, 0.694513, 0.758141, 0.821954, 0.885792, 0.94949, 1.01287, 1.07573, 1.13785, 1.19898, 1.25884, 1.3171, 1.37338, 1.42727, 1.4783, 1.52596, 1.56972, 1.60904, 1.64343, 1.67246, 1.69584, 1.71339, 1.72511, 1.7311, 1.73162, 1.72699, 1.71757, 1.70377, 1.68598, 1.66456, 1.63987, 1.61224, 1.58194, 1.54924, 1.51436, 1.47753, 1.43891, 1.39868, 1.35698, 1.31395, 1.26969, 1.22432, 1.17794, 1.13062, 1.08247, 1.03354, 0.983911, 0.933651, 0.882823, 0.83149, 0.779714, 0.727556, 0.675081, 0.622359, 0.569463, 0.516479, 0.463504, 0.41066, 0.358095, 0.306009, 0.254671, 0.204468, 0.155981, 0.110125, 0.0684082, 0.0333562, 0.00895572, 1.73205e-08, -0.00895572, -0.0333562, -0.0684082, -0.110125, -0.155981, -0.204468, -0.254671, -0.306009, -0.358095, -0.41066, -0.463504, -0.516479, -0.569463, -0.622359, -0.675081, -0.727556, -0.779714, -0.83149, -0.882823, -0.933651, -0.983911, -1.03354, -1.08247, -1.13062, -1.17794, -1.22432, -1.26969, -1.31395, -1.35698, -1.39868, -1.43891, -1.47753, -1.51436, -1.54924, -1.58194, -1.61224, -1.63987, -1.66456, -1.68598, -1.70377, -1.71757, -1.72699, -1.73162, -1.7311, -1.72511, -1.71339, -1.69584, -1.67246, -1.64343, -1.60904, -1.56972, -1.52596, -1.4783, -1.42727, -1.37338, -1.3171, -1.25884, -1.19898, -1.13785, -1.07573, -1.01287, -0.94949, -0.885792, -0.821954, -0.758141, -0.694513, -0.631224, -0.568435, -0.506312, -0.445043, -0.384843, -0.325975, -0.268775, -0.213696, -0.161376, -0.112768, -0.0693631, -0.0335455, -0.00896396, -1.73205e-08]
py = [1.15479, 1.2178, 1.27659, 1.32935, 1.37612, 1.41749, 1.45406, 1.48634, 1.51469, 1.53941, 1.56068, 1.57863, 1.59338, 1.60495, 1.61339, 1.61868, 1.62081, 1.61972, 1.61535, 1.60763, 1.59645, 1.58171, 1.5633, 1.5411, 1.51499, 1.48486, 1.45064, 1.41228, 1.36981, 1.32333, 1.27305, 1.21927, 1.16243, 1.10304, 1.04167, 0.97892, 0.915368, 0.851534, 0.787864, 0.724721, 0.662388, 0.601074, 0.540927, 0.482045, 0.424489, 0.368287, 0.313446, 0.259959, 0.207804, 0.156952, 0.107367, 0.0590111, 0.0118412, -0.0341867, -0.0791184, -0.123001, -0.165882, -0.207812, -0.248841, -0.289021, -0.328408, -0.367059, -0.405036, -0.442407, -0.479244, -0.515628, -0.551652, -0.587422, -0.62306, -0.658713, -0.694558, -0.730812, -0.767749, -0.805718, -0.845172, -0.886713, -0.93113, -0.979433, -1.03273, -1.0916, -1.15461, -1.0916, -1.03273, -0.979433, -0.93113, -0.886713, -0.845172, -0.805718, -0.767749, -0.730812, -0.694558, -0.658713, -0.62306, -0.587422, -0.551652, -0.515628, -0.479244, -0.442407, -0.405036, -0.367059, -0.328408, -0.289021, -0.248841, -0.207812, -0.165882, -0.123001, -0.0791184, -0.0341867, 0.0118412, 0.0590111, 0.107367, 0.156952, 0.207804, 0.259959, 0.313446, 0.368287, 0.424489, 0.482045, 0.540927, 0.601074, 0.662388, 0.724721, 0.787864, 0.851534, 0.915368, 0.97892, 1.04167, 1.10304, 1.16243, 1.21927, 1.27305, 1.32333, 1.36981, 1.41228, 1.45064, 1.48486, 1.51499, 1.5411, 1.5633, 1.58171, 1.59645, 1.60763, 1.61535, 1.61972, 1.62081, 1.61868, 1.61339, 1.60495, 1.59338, 1.57863, 1.56068, 1.53941, 1.51469, 1.48634, 1.45406, 1.41749, 1.37612, 1.32935, 1.27659, 1.2178, 1.15479]
X = (3.0905813039579050e+02*x**3-4.4661257581225662e+01*x**2+1.7320508075688772e+00*x+1.7320508069245885e-08)*((x>=0)&(x<6.3854689162282652e-02))+(-8.6466157218080127e+01*x**3+3.1106983743925305e+01*x**2-3.1061066906214565e+00*x+1.0297969837554502e-01)*((x>=6.3854689162282652e-02)&(x<1.2770937832456530e-01))+(1.9977568962825544e+01*x**3-9.6746025474158586e+00*x**2+2.1020843417353379e+00*x-1.1873191460374233e-01)*((x>=1.2770937832456530e-01)&(x<1.9156406748684796e-01))+(-7.4569162448722039e+00*x**3+6.0917821799671685e+00*x**2-9.1818844620467566e-01*x+7.4126665455467422e-02)*((x>=1.9156406748684796e-01)&(x<2.5541875664913061e-01))+(6.8834449549910914e-01*x**3-1.4957493269866973e-01*x**2+6.7597122731562820e-01*x-6.1599428448110949e-02)*((x>=2.5541875664913061e-01)&(x<3.1927344581141326e-01))+(-1.0171183006351043e+00*x**3+1.4839520181760975e+00*x**2+1.5442944888406629e-01*x-6.0946148699594360e-03)*((x>=3.1927344581141326e-01)&(x<3.8312813497369591e-01))+(-2.8152629485333591e-01*x**3+6.3847403834614624e-01*x**2+4.7835585045766038e-01*x-4.7463054237830704e-02)*((x>=3.8312813497369591e-01)&(x<4.4698282413597856e-01))+(-3.1271876143600252e-01*x**3+6.8030152876059446e-01*x**2+4.5965968066565210e-01*x-4.4677431979781801e-02)*((x>=4.4698282413597856e-01)&(x<5.1083751329826121e-01))+(-2.0250279024293150e-01*x**3+5.1139417081083138e-01*x**2+5.4594389537842858e-01*x-5.9369836540071219e-02)*((x>=5.1083751329826121e-01)&(x<5.7469220246054387e-01))+(-1.6783799910433572e-01*x**3+4.5162941530850276e-01*x**2+5.8029023434750115e-01*x-6.5949360936251367e-02)*((x>=5.7469220246054387e-01)&(x<6.3854689162282652e-01))+(-1.3598790810567607e-01*x**3+3.9061608549343418e-01*x**2+6.1925010644887379e-01*x-7.4241929345632229e-02)*((x>=6.3854689162282652e-01)&(x<7.0240158078510917e-01))+(-1.1821337356695949e-01*x**3+3.5316150202083918e-01*x**2+6.4555826508762948e-01*x-8.0401560084112589e-02)*((x>=7.0240158078510917e-01)&(x<7.6625626994739182e-01))+(-1.0674648747544779e-01*x**3+3.2680178192663334e-01*x**2+6.6575656588361198e-01*x-8.5560584960035158e-02)*((x>=7.6625626994739182e-01)&(x<8.3011095910967447e-01))+(-1.0086828432957873e-01*x**3+3.1216309937326514e-01*x**2+6.7790829669786490e-01*x-8.8923013267049100e-02)*((x>=8.3011095910967447e-01)&(x<8.9396564827195713e-01))+(-9.9095480019400384e-02*x**3+3.0740862090942755e-01*x**2+6.8215863711952807e-01*x-9.0189566043989089e-02)*((x>=8.9396564827195713e-01)&(x<9.5782033743423978e-01))+(-1.0090891150855441e-01*x**3+3.1261944559264521e-01*x**2+6.7716760326402436e-01*x-8.8596061466660103e-02)*((x>=9.5782033743423978e-01)&(x<1.0216750265965224e+00))+(-1.0599846512002387e-01*x**3+3.2821905505625182e-01*x**2+6.6122987184985504e-01*x-8.3168334077754480e-02)*((x>=1.0216750265965224e+00)&(x<1.0855297157588051e+00))+(-1.1429087442797936e-01*x**3+3.5522402521246477e-01*x**2+6.3191517427139843e-01*x-7.2561008967340968e-02)*((x>=1.0855297157588051e+00)&(x<1.1493844049210877e+00))+(-1.2585179502400479e-01*x**3+3.9508785073303443e-01*x**2+5.8609631489889580e-01*x-5.5006514829528896e-02)*((x>=1.1493844049210877e+00)&(x<1.2132390940833704e+00))+(-1.4090201600265573e-01*x**3+4.4986640012984935e-01*x**2+5.1963683725534793e-01*x-2.8129436012704900e-02)*((x>=1.2132390940833704e+00)&(x<1.2770937832456530e+00))+(-1.5962496770055168e-01*x**3+5.2159929578374431e-01*x**2+4.2802720216332091e-01*x+1.0868595807096426e-02)*((x>=1.2770937832456530e+00)&(x<1.3409484724079357e+00))+(-1.8216906920952169e-01*x**3+6.1229073122422051e-01*x**2+3.0641466034285259e-01*x+6.5227313198647607e-02)*((x>=1.3409484724079357e+00)&(x<1.4048031615702183e+00))+(-2.0846551678289416e-01*x**3+7.2311472929368392e-01*x**2+1.5072875748319348e-01*x+1.3812999605124787e-01)*((x>=1.4048031615702183e+00)&(x<1.4686578507325010e+00))+(-2.3795858486153065e-01*x**3+8.5306040721752652e-01*x**2-4.0116982571817061e-02*x+2.3155902751932445e-01)*((x>=1.4686578507325010e+00)&(x<1.5325125398947836e+00))+(-2.6941207731647410e-01*x**3+9.9766902204828511e-01*x**2-2.6173149818259844e-01*x+3.4476803558754909e-01)*((x>=1.5325125398947836e+00)&(x<1.5963672290570663e+00))+(-3.0036377718681706e-01*x**3+1.1458998601183339e+00*x**2-4.9836235041402688e-01*x+4.7068461487833702e-01)*((x>=1.5963672290570663e+00)&(x<1.6602219182193489e+00))+(-3.2698282032947645e-01*x**3+1.2784804167204129e+00*x**2-7.1847549641552177e-01*x+5.9249683803955122e-01)*((x>=1.6602219182193489e+00)&(x<1.7240766073816316e+00))+(-3.4378797460215083e-01*x**3+1.3654005368161961e+00*x**2-8.6833244218178152e-01*x+6.7861845625884598e-01)*((x>=1.7240766073816316e+00)&(x<1.7879312965439143e+00))+(-3.4423128721346075e-01*x**3+1.3677783742914471e+00*x**2-8.7258385222048673e-01*x+6.8115219928040460e-01)*((x>=1.7879312965439143e+00)&(x<1.8517859857061969e+00))+(-3.2202741890569087e-01*x**3+1.2444279378123611e+00*x**2-6.4416524261650920e-01*x+5.4015807256655535e-01)*((x>=1.8517859857061969e+00)&(x<1.9156406748684796e+00))+(-2.7342921920876506e-01*x**3+9.6513787361254799e-01*x**2-1.0914583554585988e-01*x+1.9852309323141526e-01)*((x>=1.9156406748684796e+00)&(x<1.9794953640307622e+00))+(-1.9958079339448886e-01*x**3+5.2659002399559540e-01*x**2+7.5895759967170306e-01*x-3.7427914861655154e-01)*((x>=1.9794953640307622e+00)&(x<2.0433500531930449e+00))+(-1.0759775405313121e-01*x**3-3.7270621000061510e-02*x**2+1.9111222786268627e+00*x-1.1590377346237801e+00)*((x>=2.0433500531930449e+00)&(x<2.1072047423553277e+00))+(-9.2458996969071450e-03*x**3-6.5901310275512515e-01*x**2+3.2212609846956184e+00*x-2.0792812328163564e+00)*((x>=2.1072047423553277e+00)&(x<2.1710594315176102e+00))+(8.2537771468423671e-02*x**3-1.2568165175825925e+00*x**2+4.5191277266603720e+00*x-3.0185298431370029e+00)*((x>=2.1710594315176102e+00)&(x<2.2349141206798926e+00))+(1.5759947619471859e-01*x**3-1.7600859090271115e+00*x**2+5.6438915961007297e+00*x-3.8564467278902157e+00)*((x>=2.2349141206798926e+00)&(x<2.2987688098421755e+00))+(2.1074614957660742e-01*x**3-2.1266016543813748e+00*x**2+6.4864265598334896e+00*x-4.5020444264991966e+00)*((x>=2.2987688098421755e+00)&(x<2.3626234990044583e+00))+(2.4181676616808545e-01*x**3-2.3468261610360059e+00*x**2+7.0067341543290240e+00*x-4.9118080763182661e+00)*((x>=2.3626234990044583e+00)&(x<2.4264781881667408e+00))+(2.5404937768007585e-01*x**3-2.4358726560976720e+00*x**2+7.2228035323096265e+00*x-5.0865706205931929e+00)*((x>=2.4264781881667408e+00)&(x<2.4903328773290232e+00))+(2.5216185070485153e-01*x**3-2.4217709446484150e+00*x**2+7.1876855766495282e+00*x-5.0574188207574480e+00)*((x>=2.4903328773290232e+00)&(x<2.5541875664913061e+00))+(2.4088810668172300e-01*x**3-2.3353851742194820e+00*x**2+6.9670401159237372e+00*x-4.8695621899314574e+00)*((x>=2.5541875664913061e+00)&(x<2.6180422556535889e+00))+(2.2416370355267645e-01*x**3-2.2040295919305208e+00*x**2+6.6231456509776763e+00*x-4.5694521097066172e+00)*((x>=2.6180422556535889e+00)&(x<2.6818969448158714e+00))+(2.0491462882296219e-01*x**3-2.0491574878142274e+00*x**2+6.2077946280915057e+00*x-4.1981425632766332e+00)*((x>=2.6818969448158714e+00)&(x<2.7457516339781538e+00))+(1.8509981466820591e-01*x**3-1.8859378127817763e+00*x**2+5.7596339386873296e+00*x-3.7879632481963199e+00)*((x>=2.7457516339781538e+00)&(x<2.8096063231404367e+00))+(1.6594524430968249e-01*x**3-1.7244874067891942e+00*x**2+5.3060218571263249e+00*x-3.3631394573494617e+00)*((x>=2.8096063231404367e+00)&(x<2.8734610123027196e+00))+(1.4811748078682285e-01*x**3-1.5708052565405524e+00*x**2+4.8644221900867706e+00*x-2.9401663152275432e+00)*((x>=2.8734610123027196e+00)&(x<2.9373157014650020e+00))+(1.3193850520974593e-01*x**3-1.4282369795400882e+00*x**2+4.4456541515392018e+00*x-2.5301483369694324e+00)*((x>=2.9373157014650020e+00)&(x<3.0011703906272844e+00))+(1.1749186534996170e-01*x**3-1.2981664961807837e+00*x**2+4.0552904681608197e+00*x-2.1396323608823877e+00)*((x>=3.0011703906272844e+00)&(x<3.0650250797895673e+00))+(1.0473901339639724e-01*x**3-1.1809030629356130e+00*x**2+3.6958751043566735e+00*x-1.7724266595323570e+00)*((x>=3.0650250797895673e+00)&(x<3.1288797689518502e+00))+(9.3577175315317618e-02*x**3-1.0761309148729197e+00*x**2+3.3680556499311933e+00*x-1.4305241065667360e+00)*((x>=3.1288797689518502e+00)&(x<3.1927344581141326e+00))+(8.3868167635159807e-02*x**3-9.8313606474948756e-01*x**2+3.0711477875156561e+00*x-1.1145414521852217e+00)*((x>=3.1927344581141326e+00)&(x<3.2565891472764150e+00))+(7.5414399583792147e-02*x**3-9.0054471687562909e-01*x**2+2.8021817003827891e+00*x-8.2257077205213136e-01)*((x>=3.2565891472764150e+00)&(x<3.3204438364386979e+00))+(6.8178406936226565e-02*x**3-8.2846459532811423e-01*x**2+2.5628437050363573e+00*x-5.5766798156764708e-01)*((x>=3.3204438364386979e+00)&(x<3.3842985256009808e+00))+(6.1907653519824635e-02*x**3-7.6479829069194238e-01*x**2+2.3473779241503507e+00*x-3.1460114003130002e-01)*((x>=3.3842985256009808e+00)&(x<3.4481532147632632e+00))+(5.6574522140067529e-02*x**3-7.0962992836211924e-01*x**2+2.1571489582129288e+00*x-9.5954933236498618e-02)*((x>=3.4481532147632632e+00)&(x<3.5120079039255456e+00))+(5.2083420787880641e-02*x**3-6.6231157802667440e-01*x**2+1.9909665378399950e+00*x+9.8589724730118178e-02)*((x>=3.5120079039255456e+00)&(x<3.5758625930878285e+00))+(4.8282588417237093e-02*x**3-6.2153781513006834e-01*x**2+1.8451651643081277e+00*x+2.7237828393117525e-01)*((x>=3.5758625930878285e+00)&(x<3.6397172822501114e+00))+(4.5225951666907349e-02*x**3-5.8816193431721331e-01*x**2+1.7236863941070624e+00*x+4.1976107704613241e-01)*((x>=3.6397172822501114e+00)&(x<3.7035719714123938e+00))+(4.2795753595555652e-02*x**3-5.6116069392919599e-01*x**2+1.6236853570080712e+00*x+5.4321475639881101e-01)*((x>=3.7035719714123938e+00)&(x<3.7674266605746762e+00))+(4.0997223446538555e-02*x**3-5.4083320263453061e-01*x**2+1.5471030243425048e+00*x+6.3938753033653484e-01)*((x>=3.7674266605746762e+00)&(x<3.8312813497369591e+00))+(3.9892056882308680e-02*x**3-5.2813059049276490e-01*x**2+1.4984357433713740e+00*x+7.0154021234338870e-01)*((x>=3.8312813497369591e+00)&(x<3.8951360388992420e+00))+(3.9473332950876738e-02*x**3-5.2323763046479144e-01*x**2+1.4793769984353276e+00*x+7.2628568040454411e-01)*((x>=3.8951360388992420e+00)&(x<3.9589907280615244e+00))+(3.9830017602071166e-02*x**3-5.2747396414360992e-01*x**2+1.4961486041756871e+00*x+7.0415280318775331e-01)*((x>=3.9589907280615244e+00)&(x<4.0228454172238068e+00))+(4.1148456027485736e-02*x**3-5.4338558607651066e-01*x**2+1.5601585995646019e+00*x+6.1831869766683667e-01)*((x>=4.0228454172238068e+00)&(x<4.0867001063860897e+00))+(4.3622499978141605e-02*x**3-5.7371761310332658e-01*x**2+1.6841164976576692e+00*x+4.4945911257309490e-01)*((x>=4.0867001063860897e+00)&(x<4.1505547955483726e+00))+(4.7597628106302636e-02*x**3-6.2321457445341366e-01*x**2+1.8895563479345583e+00*x+1.6522932730003959e-01)*((x>=4.1505547955483726e+00)&(x<4.2144094847106555e+00))+(5.3616895624202243e-02*x**3-6.9931754880235530e-01*x**2+2.2102854448748985e+00*x-2.8533192205941305e-01)*((x>=4.2144094847106555e+00)&(x<4.2782641738729374e+00))+(6.2502711297383939e-02*x**3-8.1336514935628657e-01*x**2+2.6982112084133405e+00*x-9.8115702663926641e-01)*((x>=4.2782641738729374e+00)&(x<4.3421188630352203e+00))+(7.5541858784106353e-02*x**3-9.8321773413817937e-01*x**2+3.4357313207128755e+00*x-2.0486236904907855e+00)*((x>=4.3421188630352203e+00)&(x<4.4059735521975032e+00))+(9.4771448262832791e-02*x**3-1.2373929221253093e+00*x**2+4.5556204766289738e+00*x-3.6933576912633725e+00)*((x>=4.4059735521975032e+00)&(x<4.4698282413597852e+00))+(1.2395029074545505e-01*x**3-1.6286661646622633e+00*x**2+6.3045446661944879e+00*x-6.2991546027697041e+00)*((x>=4.4698282413597852e+00)&(x<4.5336829305220681e+00))+(1.6823671171627552e-01*x**3-2.2310079370927269e+00*x**2+9.0353712782089133e+00*x-1.0426055268459095e+01)*((x>=4.5336829305220681e+00)&(x<4.5975376196843509e+00))+(2.4148467129742812e-01*x**3-3.2412886863105541e+00*x**2+1.3680175029179736e+01*x-1.7544275262167503e+01)*((x>=4.5975376196843509e+00)&(x<4.6613923088466338e+00))+(3.5211110533765577e-01*x**3-4.7883083126814654e+00*x**2+2.0891440417187368e+01*x-2.8749120934400707e+01)*((x>=4.6613923088466338e+00)&(x<4.7252469980089167e+00))+(5.8109969514757154e-01*x**3-8.0343912524124335e+00*x**2+3.6229984083444833e+01*x-5.2908590072011975e+01)*((x>=4.7252469980089167e+00)&(x<4.7891016871711987e+00))+(8.3922433742960578e-01*x**3-1.1742946731973461e+01*x**2+5.3990633387573780e+01*x-8.1261108587897070e+01)*((x>=4.7891016871711987e+00)&(x<4.8529563763334815e+00))+(1.8489672728627724e+00*x**3-2.6443661982877416e+01*x**2+1.2533256320110809e+02*x-1.9666753298408003e+02)*((x>=4.8529563763334815e+00)&(x<4.9168110654957644e+00))+(1.4706270343431811e+00*x**3-2.0862979569051419e+01*x**2+9.7893402155792472e+01*x-1.5169647609889506e+02)*((x>=4.9168110654957644e+00)&(x<4.9806657546580464e+00))+(7.5796947959353602e+00*x**3-1.1214465334819442e+02*x**2+5.5253690877543613e+02*x-9.0650559076493425e+02)*((x>=4.9806657546580464e+00)&(x<5.0445204438203293e+00))+(-1.3380025193619913e+01*x**3+2.0505055460398910e+02*x**2-1.0475608024211940e+03*x+1.7840696146489047e+03)*((x>=5.0445204438203293e+00)&(x<5.1083751329826121e+00))+(-1.3379866048134888e+01*x**3+2.0504811567947451e+02*x**2-1.0475483434798525e+03*x+1.7840483996668602e+03)*((x>=5.1083751329826121e+00)&(x<5.1722298221448950e+00))+(7.5796165107984024e+00*x**3-1.2017366656464731e+02*x**2+6.3457345745430666e+02*x-1.1160584480903844e+03)*((x>=5.1722298221448950e+00)&(x<5.2360845113071779e+00))+(1.4706480293233994e+00*x**3-2.4212440826902366e+01*x**2+1.3211236968284993e+02*x-2.3908220835215980e+02)*((x>=5.2360845113071779e+00)&(x<5.2999392004694599e+00))+(1.8489616256916293e+00*x**3-3.0227558005289893e+01*x**2+1.6399212501200236e+02*x-2.9540246334227413e+02)*((x>=5.2999392004694599e+00)&(x<5.3637938896317428e+00))+(8.3922580687141135e-01*x**3-1.3979513559899715e+01*x**2+7.6840963497346820e+01*x-1.3958217414006867e+02)*((x>=5.3637938896317428e+00)&(x<5.4276485787940256e+00))+(5.8109932039485557e-01*x**3-9.7764539874792717e+00*x**2+5.4028233182514668e+01*x-9.8309013049500209e+01)*((x>=5.4276485787940256e+00)&(x<5.4915032679563076e+00))+(3.5211142402440032e-01*x**3-6.0039906437559694e+00*x**2+3.3311738402215269e+01*x-6.0387446787291992e+01)*((x>=5.4915032679563076e+00)&(x<5.5553579571185905e+00))+(2.4148405360153902e-01*x**3-4.1602667160923374e+00*x**2+2.3069192009941617e+01*x-4.1420442920163623e+01)*((x>=5.5553579571185905e+00)&(x<5.6192126462808734e+00))+(1.6823745853258742e-01*x**3-2.9255021361705076e+00*x**2+1.6130787267247797e+01*x-2.8424319028446916e+01)*((x>=5.6192126462808734e+00)&(x<5.6830673354431562e+00))+(1.2394976979419425e-01*x**3-2.1704323844733153e+00*x**2+1.1839675025432371e+01*x-2.0295425757009070e+01)*((x>=5.6830673354431562e+00)&(x<5.7469220246054391e+00))+(9.4771911755572091e-02*x**3-1.6673837594980796e+00*x**2+8.9486938031004684e+00*x-1.4757344537218160e+01)*((x>=5.7469220246054391e+00)&(x<5.8107767137677211e+00))+(7.5541135604112242e-02*x**3-1.3321465207527581e+00*x**2+7.0007050625863485e+00*x-1.0984235333235119e+01)*((x>=5.8107767137677211e+00)&(x<5.8746314029300040e+00))+(6.2503388453194475e-02*x**3-1.1023706442438197e+00*x**2+5.6508564828254748e+00*x-8.3409477145178244e+00)*((x>=5.8746314029300040e+00)&(x<5.9384860920922868e+00))+(5.3616668928725630e-02*x**3-9.4404966333877383e-01*x**2+4.7106695396505529e+00*x-6.4798520191980060e+00)*((x>=5.9384860920922868e+00)&(x<6.0023407812545688e+00))+(4.7597505711507893e-02*x**3-8.3566245680231077e-01*x**2+4.0600925896869740e+00*x-5.1781904998206301e+00)*((x>=6.0023407812545688e+00)&(x<6.0661954704168517e+00))+(4.3622536873840545e-02*x**3-7.6332364291920385e-01*x**2+3.6212712045817170e+00*x-4.2908650669851340e+00)*((x>=6.0661954704168517e+00)&(x<6.1300501595791346e+00))+(4.1148641368408789e-02*x**3-7.1782833231372933e-01*x**2+3.3423826684957021e+00*x-3.7209981619525934e+00)*((x>=6.1300501595791346e+00)&(x<6.1939048487414174e+00))+(3.9829983086974607e-02*x**3-6.9332540053619596e-01*x**2+3.1906138406338869e+00*x-3.4076509356964380e+00)*((x>=6.1939048487414174e+00)&(x<6.2577595379037003e+00))+(3.9473397131814636e-02*x**3-6.8663111306159408e-01*x**2+3.1487225992750609e+00*x-3.3202691639598925e+00)*((x>=6.2577595379037003e+00)&(x<6.3216142270659823e+00))+(3.9891093728442684e-02*x**3-6.9455266330442100e-01*x**2+3.1987995839590440e+00*x-3.4257916235364974e+00)*((x>=6.3216142270659823e+00)&(x<6.3854689162282652e+00))+(4.0999146864237446e-02*x**3-7.1577897986753669e-01*x**2+3.3343395685515134e+00*x-3.7142870765819680e+00)*((x>=6.3854689162282652e+00)&(x<6.4493236053905481e+00))+(4.2793433918745905e-02*x**3-7.5049479342851555e-01*x**2+3.5582330845209071e+00*x-4.1956076555652544e+00)*((x>=6.4493236053905481e+00)&(x<6.5131782945528300e+00))+(4.5228331538737621e-02*x**3-7.9807156042261340e-01*x**2+3.8681090505560860e+00*x-4.8683667944860645e+00)*((x>=6.5131782945528300e+00)&(x<6.5770329837151129e+00))+(4.8279894263259848e-02*x**3-8.5828224648321338e-01*x**2+4.2641167187975952e+00*x-5.7365519594459329e+00)*((x>=6.5770329837151129e+00)&(x<6.6408876728773958e+00))+(5.2087175539895725e-02*x**3-9.3413342838721292e-01*x**2+4.7678358976991149e+00*x-6.8515994547924493e+00)*((x>=6.6408876728773958e+00)&(x<6.7047423620396787e+00))+(5.6570503151419871e-02*x**3-1.0243120980594540e+00*x**2+5.3724606444593519e+00*x-8.2028838390251622e+00)*((x>=6.7047423620396787e+00)&(x<6.7685970512019615e+00))+(6.1911159142709948e-02*x**3-1.1327583432321262e+00*x**2+6.1064895797171630e+00*x-9.8589992013585288e+00)*((x>=6.7685970512019615e+00)&(x<6.8324517403642435e+00))+(6.8174337213122271e-02*x**3-1.2611369289625145e+00*x**2+6.9836300711322110e+00*x-1.1856672560272273e+01)*((x>=6.8324517403642435e+00)&(x<6.8963064295265264e+00))+(7.5418536644747292e-02*x**3-1.4110115863295505e+00*x**2+8.0172116342146182e+00*x-1.4232637620239984e+01)*((x>=6.8963064295265264e+00)&(x<6.9601611186888093e+00))+(8.3866349393133532e-02*x**3-1.5874059997986478e+00*x**2+9.2449451726279221e+00*x-1.7081045365950558e+01)*((x>=6.9601611186888093e+00)&(x<7.0240158078510913e+00))+(9.3575163117407101e-02*x**3-1.7919905830276548e+00*x**2+1.0681950519239763e+01*x-2.0445561456319410e+01)*((x>=7.0240158078510913e+00)&(x<7.0878704970133741e+00))+(1.0474435456262654e-01*x**3-2.0294879306020448e+00*x**2+1.2365300962090259e+01*x-2.4422684769786429e+01)*((x>=7.0878704970133741e+00)&(x<7.1517251861756570e+00))+(1.1748646481009928e-01*x**3-2.3028721429327561e+00*x**2+1.4320469719095854e+01*x-2.9083627983985934e+01)*((x>=7.1517251861756570e+00)&(x<7.2155798753379399e+00))+(1.3193991727962384e-01*x**3-2.6157422652358946e+00*x**2+1.6578009077056777e+01*x-3.4513446503609885e+01)*((x>=7.2155798753379399e+00)&(x<7.2794345645002227e+00))+(1.4811973080600183e-01*x**3-2.9690819467396068e+00*x**2+1.9150122167513473e+01*x-4.0754622815118637e+01)*((x>=7.2794345645002227e+00)&(x<7.3432892536625047e+00))+(1.6594286976214789e-01*x**3-3.3617233410150220e+00*x**2+2.2033401498978492e+01*x-4.7812207524781115e+01)*((x>=7.3432892536625047e+00)&(x<7.4071439428247876e+00))+(1.8510093202075950e-01*x**3-3.7874429154726386e+00*x**2+2.5186767666134983e+01*x-5.5598019893106539e+01)*((x>=7.4071439428247876e+00)&(x<7.4709986319870705e+00))+(2.0491356896764046e-01*x**3-4.2315034660496167e+00*x**2+2.8504343432141468e+01*x-6.3859887895931024e+01)*((x>=7.4709986319870705e+00)&(x<7.5348533211493525e+00))+(2.2416730502959581e-01*x**3-4.6667256973742042e+00*x**2+3.1783679107291391e+01*x-7.2096325664082542e+01)*((x>=7.5348533211493525e+00)&(x<7.5987080103116353e+00))+(2.4088092115994186e-01*x**3-5.0477313636765757e+00*x**2+3.4678829915792448e+01*x-7.9429460876854137e+01)*((x>=7.5987080103116353e+00)&(x<7.6625626994739182e+00))+(2.5217162028684470e-01*x**3-5.3072784336509358e+00*x**2+3.6667625612695701e+01*x-8.4509218118560966e+01)*((x>=7.6625626994739182e+00)&(x<7.7264173886362011e+00))+(2.5403790023824513e-01*x**3-5.3505374072374252e+00*x**2+3.7001862498495029e+01*x-8.5370036014181096e+01)*((x>=7.7264173886362011e+00)&(x<7.7902720777984840e+00))+(2.4182715520919373e-01*x**3-5.0651623291123542e+00*x**2+3.4778712995612295e+01*x-7.9597056181402877e+01)*((x>=7.7902720777984840e+00)&(x<7.8541267669607659e+00))+(2.1073969306053186e-01*x**3-4.3326677233599185e+00*x**2+2.9025607505958760e+01*x-6.4535182908293791e+01)*((x>=7.8541267669607659e+00)&(x<7.9179814561230488e+00))+(1.5760194687572948e-01*x**3-3.0704366566169483e+00*x**2+1.9031285326112993e+01*x-3.8156897013192065e+01)*((x>=7.9179814561230488e+00)&(x<7.9818361452853317e+00))+(8.2538770044948251e-02*x**3-1.2730107225797838e+00*x**2+4.6845260375121143e+00*x+1.4263606281019747e-02)*((x>=7.9818361452853317e+00)&(x<8.0456908344476137e+00))+(-9.2492467845204374e-03*x**3+9.4248329454785562e-01*x**2-1.3140653869922971e+01*x+4.7819559141062200e+01)*((x>=8.0456908344476137e+00)&(x<8.1095455236098957e+00))+(-1.0759479897433266e-01*x**3+3.3350964921337436e+00*x**2-3.2543659516202752e+01*x+1.0026941166841425e+02)*((x>=8.1095455236098957e+00)&(x<8.1734002127721794e+00))+(-1.9958101527527106e-01*x**3+5.5906169717818557e+00*x**2-5.0978931084508076e+01*x+1.5049569585477002e+02)*((x>=8.1734002127721794e+00)&(x<8.2372549019344614e+00))+(-2.7342959037764558e-01*x**3+7.4155455836043984e+00*x**2-6.6011333237780491e+01*x+1.9177093862986658e+02)*((x>=8.2372549019344614e+00)&(x<8.3011095910967452e+00))+(-3.2203188399171268e-01*x**3+8.6259044805847225e+00*x**2-7.6058655086409999e+01*x+2.1957224521751050e+02)*((x>=8.3011095910967452e+00)&(x<8.3649642802590272e+00))+(-3.4422225755838554e-01*x**3+9.1827695273241261e+00*x**2-8.0716811311402125e+01*x+2.3256068202829920e+02)*((x>=8.3649642802590272e+00)&(x<8.4288189694213109e+00))+(-3.4379452576342828e-01*x**3+9.1719537057615526e+00*x**2-8.0625646708853310e+01*x+2.3230454538518097e+02)*((x>=8.4288189694213109e+00)&(x<8.4926736585835929e+00))+(-3.2698200258255383e-01*x**3+8.7436038874984661e+00*x**2-7.6987811490893364e+01*x+2.2200622960831970e+02)*((x>=8.4926736585835929e+00)&(x<8.5565283477458749e+00))+(-3.0036155350671834e-01*x**3+8.0602680060255807e+00*x**2-7.1140828650182812e+01*x+2.0532960479962640e+02)*((x>=8.5565283477458749e+00)&(x<8.6203830369081587e+00))+(-2.6941674842794328e-01*x**3+7.2599997876750422e+00*x**2-6.4242210075695766e+01*x+1.8550669328717049e+02)*((x>=8.6203830369081587e+00)&(x<8.6842377260704406e+00))+(-2.3795031533268229e-01*x**3+6.4402138315417687e+00*x**2-5.7122993948083604e+01*x+1.6489837152842665e+02)*((x>=8.6842377260704406e+00)&(x<8.7480924152327226e+00))+(-2.0847436700933031e-01*x**3+5.6666388716548681e+00*x**2-5.0355688708834350e+01*x+1.4516470098419813e+02)*((x>=8.7480924152327226e+00)&(x<8.8119471043950064e+00))+(-1.8216319984981055e-01*x**3+4.9710810318429139e+00*x**2-4.4226469816494500e+01*x+1.2716125009331154e+02)*((x>=8.8119471043950064e+00)&(x<8.8758017935572884e+00))+(-1.5962896647238267e-01*x**3+4.3710528647861793e+00*x**2-3.8900738735101186e+01*x+1.1140453893213999e+02)*((x>=8.8758017935572884e+00)&(x<8.9396564827195704e+00))+(-1.4089940394831046e-01*x**3+3.8687452996546199e+00*x**2-3.4410281654214486e+01*x+9.8023491013911553e+01)*((x>=8.9396564827195704e+00)&(x<9.0035111718818541e+00))+(-1.2585035592371696e-01*x**3+3.4622624836265459e+00*x**2-3.0750509078847244e+01*x+8.7039889924926683e+01)*((x>=9.0035111718818541e+00)&(x<9.0673658610441361e+00))+(-1.1429613843336028e-01*x**3+3.1479635319556110e+00*x**2-2.7900645494242781e+01*x+7.8426304666092619e+01)*((x>=9.0673658610441361e+00)&(x<9.1312205502064199e+00))+(-1.0599316498678490e-01*x**3+2.9205146866515861e+00*x**2-2.5823759924096521e+01*x+7.2104804599715862e+01)*((x>=9.1312205502064199e+00)&(x<9.1950752393687019e+00))+(-1.0091246916562113e-01*x**3+2.7803625456290320e+00*x**2-2.4535050442253123e+01*x+6.8154877717548516e+01)*((x>=9.1950752393687019e+00)&(x<9.2589299285309838e+00))+(-9.9092119914814702e-02*x**3+2.7297990871411457e+00*x**2-2.4066886923232232e+01*x+6.6709979978390038e+01)*((x>=9.2589299285309838e+00)&(x<9.3227846176932676e+00))+(-1.0087156249147711e-01*x**3+2.7795671667936404e+00*x**2-2.4530864010608639e+01*x+6.8151832795876544e+01)*((x>=9.3227846176932676e+00)&(x<9.3866393068555496e+00))+(-1.0674559855510779e-01*x**3+2.9449795402015297e+00*x**2-2.6083530296789831e+01*x+7.3009938926843461e+01)*((x>=9.3866393068555496e+00)&(x<9.4504939960178334e+00))+(-1.1821144159938513e-01*x**3+3.2700531827549639e+00*x**2-2.9155636803916423e+01*x+8.2687580293481005e+01)*((x>=9.4504939960178334e+00)&(x<9.5143486851801153e+00))+(-1.3598982529512682e-01*x**3+3.7775024073807799e+00*x**2-3.3983685667029931e+01*x+9.7999493744689971e+01)*((x>=9.5143486851801153e+00)&(x<9.5782033743423973e+00))+(-1.6783813618505405e-01*x**3+4.6926512038699002e+00*x**2-4.2749166957619309e+01*x+1.2598534790310077e+02)*((x>=9.5782033743423973e+00)&(x<9.6420580635046811e+00))+(-2.0250172160629631e-01*x**3+5.6953361138357650e+00*x**2-5.2417113078969123e+01*x+1.5705831385534839e+02)*((x>=9.6420580635046811e+00)&(x<9.7059127526669631e+00))+(-3.1272016645866074e-01*x**3+8.9046479422499942e+00*x**2-8.3566413681648555e+01*x+2.5783577850740403e+02)*((x>=9.7059127526669631e+00)&(x<9.7697674418292451e+00))+(-2.8152410409708750e-01*x**3+7.9903131191335888e+00*x**2-7.4633575095798733e+01*x+2.2874519331425836e+02)*((x>=9.7697674418292451e+00)&(x<9.8336221309915288e+00))+(-1.0171200184788063e+00*x**3+2.9691029908522523e+01*x**2-2.8803022397429231e+02*x+9.2823252967814915e+02)*((x>=9.8336221309915288e+00)&(x<9.8974768201538108e+00))+(6.8834471329731883e-01*x**3-2.0948363042508390e+01*x**2+2.1317199394517593e+02*x-7.2531324834447878e+02)*((x>=9.8974768201538108e+00)&(x<9.9613315093160928e+00))+(-7.4569158531589466e+00*x**3+2.2246455915418301e+02*x**2-2.2115448177074504e+03*x+7.3258227440166775e+03)*((x>=9.9613315093160928e+00)&(x<1.0025186198478377e+01))+(1.9977568854268227e+01*x**3-6.0264289319961210e+02*x**2+6.0603110258914858e+03*x-2.0316475602333543e+04)*((x>=1.0025186198478377e+01)&(x<1.0089040887640659e+01))+(-8.6466157402343271e+01*x**3+2.6191024261077364e+03*x**2-2.6444009230165262e+04*x+8.8995996427107457e+04)*((x>=1.0089040887640659e+01)&(x<1.0152895576802942e+01))+(3.0905813064926019e+02*x**3-9.4280479579240346e+03*x**2+9.5869450616950780e+04*x-3.2494926539464225e+05)*((x>=1.0152895576802942e+01)&(x<=1.0216750265965224e+01))
Y = (-2.6115881499807756e+01*x**3+3.4843268470178543e+00*x**2+8.7085399427377830e-01*x+1.1547882766467816e+00)*((x>=0)&(x<6.3854689162282652e-02))+(5.1899072357593923e+00*x**3-2.5127373790513730e+00*x**2+1.2537946663156774e+00*x+1.1466374241198376e+00)*((x>=6.3854689162282652e-02)&(x<1.2770937832456530e-01))+(-1.4953026900888062e+00*x**3+4.8554631746412724e-02*x**2+9.2669365590904818e-01*x+1.1605620463492978e+00)*((x>=1.2770937832456530e-01)&(x<1.9156406748684796e-01))+(8.6958712846092112e-01*x**3-1.3105291066526661e+00*x**2+1.1870452648918928e+00*x+1.1439373752847848e+00)*((x>=1.9156406748684796e-01)&(x<2.5541875664913061e-01))+(2.8374171890095568e-01*x**3-8.6162138835709356e-01*x**2+1.0723858136347530e+00*x+1.1536994334442010e+00)*((x>=2.5541875664913061e-01)&(x<3.1927344581141326e-01))+(3.4993570611663927e-01*x**3-9.2502333552886284e-01*x**2+1.0926283717794263e+00*x+1.1515451296805459e+00)*((x>=3.1927344581141326e-01)&(x<3.8312813497369591e-01))+(2.2934571730536391e-01*x**3-7.8641908299823626e-01*x**2+1.0395251830080952e+00*x+1.1583269049056355e+00)*((x>=3.8312813497369591e-01)&(x<4.4698282413597856e-01))+(1.7597484846817224e-01*x**3-7.1485149796126279e-01*x**2+1.0075357017310580e+00*x+1.1630931544668925e+00)*((x>=4.4698282413597856e-01)&(x<5.1083751329826121e-01))+(1.2388507447417396e-01*x**3-6.3502326611410354e-01*x**2+9.6675644628351165e-01*x+1.1700370122824779e+00)*((x>=5.1083751329826121e-01)&(x<5.7469220246054387e-01))+(8.6917864516749432e-02*x**3-5.7128896418726072e-01*x**2+9.3012883993685591e-01*x+1.1770535455366371e+00)*((x>=5.7469220246054387e-01)&(x<6.3854689162282652e-01))+(5.7268848314834031e-02*x**3-5.1449210278065038e-01*x**2+8.9386138063264298e-01*x+1.1847730366719702e+00)*((x>=6.3854689162282652e-01)&(x<7.0240158078510917e-01))+(3.3763668894152943e-02*x**3-4.6496187723369076e-01*x**2+8.5907127191239852e-01*x+1.1929185791258874e+00)*((x>=7.0240158078510917e-01)&(x<7.6625626994739182e-01))+(1.4338755256403601e-02*x**3-4.2030849163029416e-01*x**2+8.2485533521821708e-01*x+1.2016579711331588e+00)*((x>=7.6625626994739182e-01)&(x<8.3011095910967447e-01))+(-2.1249214175895759e-03*x**3-3.7930845632763521e-01*x**2+7.9082075659107431e-01*x+1.2110754633695251e+00)*((x>=8.3011095910967447e-01)&(x<8.9396564827195713e-01))+(-1.6482816501138586e-02*x**3-3.4080206136923152e-01*x**2+7.5639736225821252e-01*x+1.2213332407122834e+00)*((x>=8.9396564827195713e-01)&(x<9.5782033743423978e-01))+(-2.9287100174087755e-02*x**3-3.0400945144492653e-01*x**2+7.2115665220326264e-01*x+1.2325846636439337e+00)*((x>=9.5782033743423978e-01)&(x<1.0216750265965224e+00))+(-4.0866516510732254e-02*x**3-2.6851824996583673e-01*x**2+6.8489617799014013e-01*x+1.2449334706298032e+00)*((x>=1.0216750265965224e+00)&(x<1.0855297157588051e+00))+(-5.1347827539530044e-02*x**3-2.3438492621608020e-01*x**2+6.4784344076315392e-01*x+1.2583407530667046e+00)*((x>=1.0855297157588051e+00)&(x<1.1493844049210877e+00))+(-6.0664499574272668e-02*x**3-2.0225961358892164e-01*x**2+6.1091910742516120e-01*x+1.2724875040332790e+00)*((x>=1.1493844049210877e+00)&(x<1.2132390940833704e+00))+(-6.8515996363544218e-02*x**3-1.7368238503559041e-01*x**2+5.7624809654498677e-01*x+1.2865089126437397e+00)*((x>=1.2132390940833704e+00)&(x<1.2770937832456530e+00))+(-7.4334579946707890e-02*x**3-1.5138975426998513e-01*x**2+5.4777831638330099e-01*x+1.2986284390626679e+00)*((x>=1.2770937832456530e+00)&(x<1.3409484724079357e+00))+(-7.7215386310285794e-02*x**3-1.3980071559217322e-01*x**2+5.3223801266813098e-01*x+1.3055746879031176e+00)*((x>=1.3409484724079357e+00)&(x<1.4048031615702183e+00))+(-7.5843353725872475e-02*x**3-1.4558302272735091e-01*x**2+5.4036101601741393e-01*x+1.3017709476421260e+00)*((x>=1.4048031615702183e+00)&(x<1.4686578507325010e+00))+(-6.8477993112537661e-02*x**3-1.7803460679624550e-01*x**2+5.8802128973093204e-01*x+1.2784387359238281e+00)*((x>=1.4686578507325010e+00)&(x<1.5325125398947836e+00))+(-5.2937202958446505e-02*x**3-2.4948397416847001e-01*x**2+6.9751834118869738e-01*x+1.2225035344472417e+00)*((x>=1.5325125398947836e+00)&(x<1.5963672290570663e+00))+(-2.6881122140821390e-02*x**3-3.7426919477456977e-01*x**2+8.9672137803427177e-01*x+1.1165031344598901e+00)*((x>=1.5963672290570663e+00)&(x<1.6602219182193489e+00))+(1.1811122273684305e-02*x**3-5.6698233150109445e-01*x**2+1.2166679515521537e+00*x+9.3944236312108842e-01)*((x>=1.6602219182193489e+00)&(x<1.7240766073816316e+00))+(6.4109692486908898e-02*x**3-8.3748255601312849e-01*x**2+1.6830310609293520e+00*x+6.7142712064742227e-01)*((x>=1.7240766073816316e+00)&(x<1.7879312965439143e+00))+(1.2874343422004131e-01*x**3-1.1841646249804398e+00*x**2+2.3028747819862474e+00*x+3.0201445803231763e-01)*((x>=1.7879312965439143e+00)&(x<1.8517859857061969e+00))+(2.0109852900736769e-01*x**3-1.5861230765503933e+00*x**2+3.0472158094335100e+00*x-1.5743896970707283e-01)*((x>=1.8517859857061969e+00)&(x<1.9156406748684796e+00))+(2.7296157402645349e-01*x**3-1.9991143927290977e+00*x**2+3.8383587730750151e+00*x-6.6262084996833437e-01)*((x>=1.9156406748684796e+00)&(x<1.9794953640307622e+00))+(3.3378825984470950e-01*x**3-2.3603328204826539e+00*x**2+4.5533889762245963e+00*x-1.1344205073937701e+00)*((x>=1.9794953640307622e+00)&(x<2.0433500531930449e+00))+(3.7358916949460763e-01*x**3-2.6043143930355654e+00*x**2+5.0519287354727567e+00*x-1.4739842552498885e+00)*((x>=2.0433500531930449e+00)&(x<2.1072047423553277e+00))+(3.8629414153774633e-01*x**3-2.6846303250576966e+00*x**2+5.2211708483155235e+00*x-1.5928601828509272e+00)*((x>=2.1072047423553277e+00)&(x<2.1710594315176102e+00))+(3.7194336376865067e-01*x**3-2.5911611507840462e+00*x**2+5.0182437159583060e+00*x-1.4460045613013790e+00)*((x>=2.1710594315176102e+00)&(x<2.2349141206798926e+00))+(3.3584918179303713e-01*x**3-2.3491589598679639e+00*x**2+4.4773896022379631e+00*x-1.0430837293160948e+00)*((x>=2.2349141206798926e+00)&(x<2.2987688098421755e+00))+(2.8648637184858217e-01*x**3-2.0087378962671210e+00*x**2+3.6948402790258115e+00*x-4.4345040385996981e-01)*((x>=2.2987688098421755e+00)&(x<2.3626234990044583e+00))+(2.3227298788958706e-01*x**3-1.6244804515572469e+00*x**2+2.7869846104958924e+00*x+2.7152330820081261e-01)*((x>=2.3626234990044583e+00)&(x<2.4264781881667408e+00))+(1.7974116130079665e-01*x**3-1.2420784573541823e+00*x**2+1.8590945124415157e+00*x+1.0220250028442024e+00)*((x>=2.4264781881667408e+00)&(x<2.4903328773290232e+00))+(1.3289308086268647e-01*x**3-8.9207651248761977e-01*x**2+9.8747316200842761e-01*x+1.7455674380280470e+00)*((x>=2.4903328773290232e+00)&(x<2.5541875664913061e+00))+(9.3513831827522154e-02*x**3-5.9033054769815863e-01*x**2+2.1675737051100441e-01*x+2.4017516686817544e+00)*((x>=2.5541875664913061e+00)&(x<2.6180422556535889e+00))+(6.1774634391497329e-02*x**3-3.4104686755426883e-01*x**2-4.3587783775001299e-01*x+2.9712938529355597e+00)*((x>=2.6180422556535889e+00)&(x<2.6818969448158714e+00))+(3.7019348447472566e-02*x**3-1.4187349033136343e-01*x**2-9.7004030962398247e-01*x+3.4488167533781962e+00)*((x>=2.6818969448158714e+00)&(x<2.7457516339781538e+00))+(1.8168037563782491e-02*x**3+1.3409562654032925e-02*x**2-1.3964090060817398e+00*x+3.8390509350429056e+00)*((x>=2.7457516339781538e+00)&(x<2.8096063231404367e+00))+(4.1129759513296449e-03*x**3+1.3187713259048905e-01*x**2-1.7292562396614812e+00*x+4.1507741657442239e+00)*((x>=2.8096063231404367e+00)&(x<2.8734610123027196e+00))+(-6.2037475913996332e-03*x**3+2.2081124121154971e-01*x**2-1.9848049334541429e+00*x+4.3955439018645848e+00)*((x>=2.8734610123027196e+00)&(x<2.9373157014650020e+00))+(-1.3654191263981375e-02*x**3+2.8646415676075776e-01*x**2-2.1776482731393116e+00*x+4.5843578250578503e+00)*((x>=2.9373157014650020e+00)&(x<3.0011703906272844e+00))+(-1.8969811831027528e-02*x**3+3.3432340592059973e-01*x**2-2.3212820346366243e+00*x+4.7280476224232189e+00)*((x>=3.0011703906272844e+00)&(x<3.0650250797895673e+00))+(-2.2711013796524071e-02*x**3+3.6872403948041210e-01*x**2-2.4267208392536759e+00*x+4.8357718159359138e+00)*((x>=3.0650250797895673e+00)&(x<3.1288797689518502e+00))+(-2.5310731439205369e-02*x**3+3.9312665129114066e-01*x**2-2.5030736776607228e+00*x+4.9154047663992060e+00)*((x>=3.1288797689518502e+00)&(x<3.1927344581141326e+00))+(-2.7108113928888677e-02*x**3+4.1034234631860045e-01*x**2-2.5580388203953248e+00*x+4.9739011348000020e+00)*((x>=3.1927344581141326e+00)&(x<3.2565891472764150e+00))+(-2.8410806851940862e-02*x**3+4.2306935322503136e-01*x**2-2.5994854529643590e+00*x+5.0188926860722631e+00)*((x>=3.2565891472764150e+00)&(x<3.3204438364386979e+00))+(-2.9310192803080781e-02*x**3+4.3202843483925335e-01*x**2-2.6292335802904745e+00*x+5.0518183480810421e+00)*((x>=3.3204438364386979e+00)&(x<3.3842985256009808e+00))+(-3.0093205159190006e-02*x**3+4.3997827752605190e-01*x**2-2.6561382211752971e+00*x+5.0821694602395837e+00)*((x>=3.3842985256009808e+00)&(x<3.4481532147632632e+00))+(-3.0795317700068381e-02*x**3+4.4724125237121370e-01*x**2-2.6811820712323424e+00*x+5.1109544709370311e+00)*((x>=3.4481532147632632e+00)&(x<3.5120079039255456e+00))+(-3.1532917501351676e-02*x**3+4.5501262136713194e-01*x**2-2.7084751805732594e+00*x+5.1429056761789980e+00)*((x>=3.5120079039255456e+00)&(x<3.5758625930878285e+00))+(-3.2466159438911291e-02*x**3+4.6502405617184195e-01*x**2-2.7442746957940471e+00*x+5.1855770586189465e+00)*((x>=3.5758625930878285e+00)&(x<3.6397172822501114e+00))+(-3.3589956874777727e-02*x**3+4.7729497102000096e-01*x**2-2.7889373566349605e+00*x+5.2397635447960056e+00)*((x>=3.6397172822501114e+00)&(x<3.7035719714123938e+00))+(-3.5071339774674470e-02*x**3+4.9375419557964051e-01*x**2-2.8498952793870558e+00*x+5.3150175628488796e+00)*((x>=3.7035719714123938e+00)&(x<3.7674266605746762e+00))+(-3.6994970540575878e-02*x**3+5.1549560907778869e-01*x**2-2.9318044602350710e+00*x+5.4178798400607775e+00)*((x>=3.7674266605746762e+00)&(x<3.8312813497369591e+00))+(-3.9447037508409721e-02*x**3+5.4367928440569813e-01*x**2-3.0397840498808364e+00*x+5.5557799027192232e+00)*((x>=3.8312813497369591e+00)&(x<3.8951360388992420e+00))+(-4.2618620384189398e-02*x**3+5.8074052468191439e-01*x**2-3.1841426225437317e+00*x+5.7432119956974930e+00)*((x>=3.8951360388992420e+00)&(x<3.9589907280615244e+00))+(-4.6696164902868986e-02*x**3+6.2916940751301809e-01*x**2-3.3758721206286282e+00*x+5.9962304307555314e+00)*((x>=3.9589907280615244e+00)&(x<4.0228454172238068e+00))+(-5.1896944109444121e-02*x**3+6.9193519990085406e-01*x**2-3.6283692008964863e+00*x+6.3348160048481077e+00)*((x>=4.0228454172238068e+00)&(x<4.0867001063860897e+00))+(-5.8576983248656234e-02*x**3+7.7383314988583152e-01*x**2-3.9630615618152660e+00*x+6.7907451071623655e+00)*((x>=4.0867001063860897e+00)&(x<4.1505547955483726e+00))+(-6.7182361582126759e-02*x**3+8.8098443281432992e-01*x**2-4.4077988330245716e+00*x+7.4060472450801171e+00)*((x>=4.1505547955483726e+00)&(x<4.2144094847106555e+00))+(-7.8338712014840439e-02*x**3+1.0220367200481633e+00*x**2-5.0022509301925311e+00*x+8.2411354305659188e+00)*((x>=4.2144094847106555e+00)&(x<4.2782641738729374e+00))+(-9.2867171032935403e-02*x**3+1.2085064772081751e+00*x**2-5.8000178117508767e+00*x+9.3788212534127524e+00)*((x>=4.2782641738729374e+00)&(x<4.3421188630352203e+00))+(-1.1222061881250056e-01*x**3+1.4606113892077701e+00*x**2-6.8946873055901960e+00*x+1.0963216272757563e+01)*((x>=4.3421188630352203e+00)&(x<4.4059735521975032e+00))+(-1.3750018227466398e-01*x**3+1.7947546532859633e+00*x**2-8.3669136897915450e+00*x+1.3125413109963119e+01)*((x>=4.4059735521975032e+00)&(x<4.4698282413597852e+00))+(-1.7392053653424000e-01*x**3+2.2831328373777069e+00*x**2-1.0549880289483553e+01*x+1.6377908362388553e+01)*((x>=4.4698282413597852e+00)&(x<4.5336829305220681e+00))+(-2.1562929657693530e-01*x**3+2.8504157177512752e+00*x**2-1.3121761001031700e+01*x+2.0264605589487473e+01)*((x>=4.5336829305220681e+00)&(x<4.5975376196843509e+00))+(-3.0437491578527442e-01*x**3+4.0744496864326720e+00*x**2-1.8749303219788999e+01*x+2.8888884608502849e+01)*((x>=4.5975376196843509e+00)&(x<4.6613923088466338e+00))+(-3.1198982739419989e-01*x**3+4.1809379576561696e+00*x**2-1.9245686828253383e+01*x+2.9660164186730981e+01)*((x>=4.6613923088466338e+00)&(x<4.7252469980089167e+00))+(-7.5008391869084790e-01*x**3+1.0391246326884357e+01*x**2-4.8590927806704713e+01*x+7.5881334799822071e+01)*((x>=4.7252469980089167e+00)&(x<4.7891016871711987e+00))+(2.7183874158629351e-01*x**3-4.2910282825941977e+00*x**2+2.1723978297071881e+01*x-3.6367077018439886e+01)*((x>=4.7891016871711987e+00)&(x<4.8529563763334815e+00))+(-4.2124606910192597e+00*x**3+6.0995300291961030e+01*x**2-2.9510772624622768e+02*x+4.7615640324424021e+02)*((x>=4.8529563763334815e+00)&(x<4.9168110654957644e+00))+(1.2329755139052622e+01*x**3-1.8300954923138852e+02*x**2+9.0461801792478946e+02*x-1.4901185349225707e+03)*((x>=4.9168110654957644e+00)&(x<4.9806657546580464e+00))+(-4.7330805172053374e+01*x**3+7.0843837970431923e+02*x**2-3.5353861537861230e+03*x+5.8812737079372309e+03)*((x>=4.9806657546580464e+00)&(x<5.0445204438203293e+00))+(1.8244935240871428e+02*x**3-2.7689537277969885e+03*x**2+1.4006389423683737e+04*x-2.3615341465880978e+04)*((x>=5.0445204438203293e+00)&(x<5.1083751329826121e+00))+(-1.8244935222940489e+02*x**3+2.8231646786958099e+03*x**2-1.4560249184738459e+04*x+2.5027693967507250e+04)*((x>=5.1083751329826121e+00)&(x<5.1722298221448950e+00))+(4.7330804842992620e+01*x**3-7.4226266414515521e+02*x**2+3.8809604465944649e+03*x-6.7663641696945851e+03)*((x>=5.1722298221448950e+00)&(x<5.2360845113071779e+00))+(-1.2329754477077586e+01*x**3+1.9490052763006679e+02*x**2-1.0261052264269674e+03*x+1.7982393524636282e+03)*((x>=5.2360845113071779e+00)&(x<5.2999392004694599e+00))+(4.2124596751704075e+00*x**3-6.8117660114114187e+01*x**2+3.6787517723481142e+02*x-6.6443110955417797e+02)*((x>=5.2999392004694599e+00)&(x<5.3637938896317428e+00))+(-2.7183826550685808e-01*x**3+4.0408895663658768e+00*x**2-1.9168410626050900e+01*x+2.7576234308871790e+01)*((x>=5.3637938896317428e+00)&(x<5.4276485787940256e+00))+(7.5008405298376601e-01*x**3-1.2599016092419333e+01*x**2+7.1147149674121465e+01*x-1.3582413985981839e+02)*((x>=5.4276485787940256e+00)&(x<5.4915032679563076e+00))+(3.1199004146691323e-01*x**3-5.3816320046735200e+00*x**2+3.1512861370159953e+01*x-6.3273531945073046e+01)*((x>=5.4915032679563076e+00)&(x<5.5553579571185905e+00))+(3.0437383882156155e-01*x**3-5.2546998087591419e+00*x**2+3.0807707585590833e+01*x-6.1967738049046602e+01)*((x>=5.5553579571185905e+00)&(x<5.6192126462808734e+00))+(2.1563075160560174e-01*x**3-3.7587009749040590e+00*x**2+2.2401372019558039e+01*x-4.6222075675235828e+01)*((x>=5.6192126462808734e+00)&(x<5.6830673354431562e+00))+(1.7391950686368318e-01*x**3-3.0475575373566244e+00*x**2+1.8359895978872373e+01*x-3.8566082183868275e+01)*((x>=5.6830673354431562e+00)&(x<5.7469220246054391e+00))+(1.3750088660430038e-01*x**3-2.4196726247328115e+00*x**2+1.4751490345544880e+01*x-3.1653673581327894e+01)*((x>=5.7469220246054391e+00)&(x<5.8107767137677211e+00))+(1.1221972262438840e-01*x**3-1.9789630278855839e+00*x**2+1.2190625282652036e+01*x-2.6693468556419248e+01)*((x>=5.8107767137677211e+00)&(x<5.8746314029300040e+00))+(9.2867988186753792e-02*x**3-1.6379101074044229e+00*x**2+1.0187065085905488e+01*x-2.2770076006578165e+01)*((x>=5.8746314029300040e+00)&(x<5.9384860920922868e+00))+(7.8338410217043020e-02*x**3-1.3790590173093733e+00*x**2+8.6498814874794334e+00*x-1.9727228199844831e+01)*((x>=5.9384860920922868e+00)&(x<6.0023407812545688e+00))+(6.7182295194982089e-02*x**3-1.1781706048368505e+00*x**2+7.4440807768332888e+00*x-1.7314685940000345e+01)*((x>=6.0023407812545688e+00)&(x<6.0661954704168517e+00))+(5.8577025119973314e-02*x**3-1.0215668537794045e+00*x**2+6.4940918115280510e+00*x-1.5393746353875031e+01)*((x>=6.0661954704168517e+00)&(x<6.1300501595791346e+00))+(5.1897067588811296e-02*x**3-8.9872142959211487e-01*x**2+5.7410431993630482e+00*x-1.3855004432152782e+01)*((x>=6.1300501595791346e+00)&(x<6.1939048487414174e+00))+(4.6696066984992513e-02*x**3-8.0207792101828090e-01*x**2+5.1424425030309067e+00*x-1.2619112513682921e+01)*((x>=6.1939048487414174e+00)&(x<6.2577595379037003e+00))+(4.2618666298778862e-02*x**3-7.2553174191534708e-01*x**2+4.6634349206433399e+00*x-1.1619941091201326e+01)*((x>=6.2577595379037003e+00)&(x<6.3216142270659823e+00))+(3.9446797158092295e-02*x**3-6.6537774265771077e-01*x**2+4.2831645431215293e+00*x-1.0818633548318758e+01)*((x>=6.3216142270659823e+00)&(x<6.3854689162282652e+00))+(3.6995416964970218e-02*x**3-6.1841810658143004e-01*x**2+3.9833052466274239e+00*x-1.0180386142717907e+01)*((x>=6.3854689162282652e+00)&(x<6.4493236053905481e+00))+(3.5070877833248915e-02*x**3-5.8118217962737617e-01*x**2+3.7431587039645819e+00*x-9.6641252205372439e+00)*((x>=6.4493236053905481e+00)&(x<6.5131782945528300e+00))+(3.3590322568812780e-02*x**3-5.5225281838966112e-01*x**2+3.5547366162682010e+00*x-9.2550496699768701e+00)*((x>=6.5131782945528300e+00)&(x<6.5770329837151129e+00))+(3.2465890682701115e-02*x**3-5.3006654158207311e-01*x**2+3.4088167419286037e+00*x-8.9351430610877287e+00)*((x>=6.5770329837151129e+00)&(x<6.6408876728773958e+00))+(3.1533219660083489e-02*x**3-5.1148525109044840e-01*x**2+3.2854204789546202e+00*x-8.6619894872128498e+00)*((x>=6.6408876728773958e+00)&(x<6.7047423620396787e+00))+(3.0795005704732148e-02*x**3-4.9663664795406248e-01*x**2+3.1858644204949087e+00*x-8.4394902463773178e+00)*((x>=6.7047423620396787e+00)&(x<6.7685970512019615e+00))+(3.0093348607045378e-02*x**3-4.8238894546730648e-01*x**2+3.0894274634488283e+00*x-8.2219092786804140e+00)*((x>=6.7685970512019615e+00)&(x<6.8324517403642435e+00))+(2.9310200271183362e-02*x**3-4.6633647583678339e-01*x**2+2.9797497393865342e+00*x-7.9721200264611980e+00)*((x>=6.8324517403642435e+00)&(x<6.8963064295265264e+00))+(2.8410790175698253e-02*x**3-4.4772865296363307e-01*x**2+2.8514244908692490e+00*x-7.6771299476567947e+00)*((x>=6.8963064295265264e+00)&(x<6.9601611186888093e+00))+(2.7107952501779664e-02*x**3-4.2052477259721854e-01*x**2+2.6620811004668212e+00*x-7.2378431130055105e+00)*((x>=6.9601611186888093e+00)&(x<7.0240158078510913e+00))+(2.5311293333544427e-02*x**3-3.8266548540059375e-01*x**2+2.3961568687191175e+00*x-6.6152244438344496e+00)*((x>=7.0240158078510913e+00)&(x<7.0878704970133741e+00))+(2.2710019029517525e-02*x**3-3.2735299921932892e-01*x**2+2.0041091298007814e+00*x-5.6889632430975325e+00)*((x>=7.0878704970133741e+00)&(x<7.1517251861756570e+00))+(1.8970773908108640e-02*x**3-2.4712683868256136e-01*x**2+1.4303536768820777e+00*x-4.3211828020575922e+00)*((x>=7.1517251861756570e+00)&(x<7.2155798753379399e+00))+(1.3653975963791254e-02*x**3-1.3203549793706770e-01*x**2+5.9990291480789892e-01*x-2.3237881998647936e+00)*((x>=7.2155798753379399e+00)&(x<7.2794345645002227e+00))+(6.2032755812992946e-03*x**3+3.0675159747261205e-02*x**2-5.8453867072967114e-01*x+5.5023347260430455e-01)*((x>=7.2794345645002227e+00)&(x<7.3432892536625047e+00))+(-4.1124634906850588e-03*x**3+2.5792952735628205e-01*x**2-2.2533332263119519e+00*x+4.6350471813202603e+00)*((x>=7.3432892536625047e+00)&(x<7.4071439428247876e+00))+(-1.8168339569058389e-02*x**3+5.7027121941882797e-01*x**2-4.5668930987594649e+00*x+1.0347337513201637e+01)*((x>=7.4071439428247876e+00)&(x<7.4709986319870705e+00))+(-3.7018935468495329e-02*x**3+9.9276954795277561e-01*x**2-7.7233775332570076e+00*x+1.8208034477138426e+01)*((x>=7.4709986319870705e+00)&(x<7.5348533211493525e+00))+(-6.1776084520545282e-02*x**3+1.5523940082221088e+00*x**2-1.1940065756323747e+01*x+2.8798743564606411e+01)*((x>=7.5348533211493525e+00)&(x<7.5987080103116353e+00))+(-9.3510863292124213e-02*x**3+2.2758239611885074e+00*x**2-1.7437198734827689e+01*x+4.2722446363623021e+01)*((x>=7.5987080103116353e+00)&(x<7.6625626994739182e+00))+(-1.3289734890201998e-01*x**3+3.1812282076934935e+00*x**2-2.4374915541993687e+01*x+6.0442676372273127e+01)*((x>=7.6625626994739182e+00)&(x<7.7264173886362011e+00))+(-1.7973587875860630e-01*x**3+4.2669103023090429e+00*x**2-3.2763348556429264e+01*x+8.2046854607702699e+01)*((x>=7.7264173886362011e+00)&(x<7.7902720777984840e+00))+(-2.3227797388710769e-01*x**3+5.4948619520891953e+00*x**2-4.2329426006443100e+01*x+1.0688763662561541e+02)*((x>=7.7902720777984840e+00)&(x<7.8541267669607659e+00))+(-2.8648314861447943e-01*x**3+6.7720648932845506e+00*x**2-5.2360739813753753e+01*x+1.3315004005283117e+02)*((x>=7.8541267669607659e+00)&(x<7.9179814561230488e+00))+(-3.3585025449463046e-01*x**3+7.9447283799763682e+00*x**2-6.1645867555795121e+01*x+1.5765652981237508e+02)*((x>=7.9179814561230488e+00)&(x<7.9818361452853317e+00))+(-3.7194444734723220e-01*x**3+8.8090221794191166e+00*x**2-6.8544519044226035e+01*x+1.7601116508065024e+02)*((x>=7.9818361452853317e+00)&(x<8.0456908344476137e+00))+(-3.8629167377018803e-01*x**3+9.1553222238107992e+00*x**2-7.1330742137506604e+01*x+1.8348352828185307e+02)*((x>=8.0456908344476137e+00)&(x<8.1095455236098957e+00))+(-3.7359109960391379e-01*x**3+8.8463345706841210e+00*x**2-6.8824992698064307e+01*x+1.7671003189886687e+02)*((x>=8.1095455236098957e+00)&(x<8.1734002127721794e+00))+(-3.3378840822297207e-01*x**3+7.8703645920795680e+00*x**2-6.0847999467310729e+01*x+1.5497697917540791e+02)*((x>=8.1734002127721794e+00)&(x<8.2372549019344614e+00))+(-2.7296121292363296e-01*x**3+6.3672172541228065e+00*x**2-4.8466191689483821e+01*x+1.2097961023781681e+02)*((x>=8.2372549019344614e+00)&(x<8.3011095910967452e+00))+(-2.0109468423629551e-01*x**3+4.5775014624305186e+00*x**2-3.3609564765560208e+01*x+7.9870780821598601e+01)*((x>=8.3011095910967452e+00)&(x<8.3649642802590272e+00))+(-1.2875122680952700e-01*x**3+2.7620501505880384e+00*x**2-1.8423379389540059e+01*x+3.7526814746437594e+01)*((x>=8.3649642802590272e+00)&(x<8.4288189694213109e+00))+(-6.4104108504011492e-02*x**3+1.1273535792861367e+00*x**2-4.6448179202561732e+00*x-1.1855186813045293e+00)*((x>=8.4288189694213109e+00)&(x<8.4926736585835929e+00))+(-1.1811508809500992e-02*x**3-2.0495837259659311e-01*x**2+6.6700726986164227e+00*x-3.3216743183904327e+01)*((x>=8.4926736585835929e+00)&(x<8.5565283477458749e+00))+(2.6878495891423881e-02*x**3-1.1981147385704389e+00*x**2+1.5168043297890108e+01*x-5.7454451961093582e+01)*((x>=8.5565283477458749e+00)&(x<8.6203830369081587e+00))+(5.2943064878832047e-02*x**3-1.8721744436734298e+00*x**2+2.0978696145524736e+01*x-7.4151136374566704e+01)*((x>=8.6203830369081587e+00)&(x<8.6842377260704406e+00))+(6.8467307560467816e-02*x**3-2.2766230855668255e+00*x**2+2.4491024299815763e+01*x-8.4318433929001912e+01)*((x>=8.6842377260704406e+00)&(x<8.7480924152327226e+00))+(7.5854986431068028e-02*x**3-2.4705073780532985e+00*x**2+2.6187142008246155e+01*x-8.9264365416485816e+01)*((x>=8.7480924152327226e+00)&(x<8.8119471043950064e+00))+(7.7207332567695630e-02*x**3-2.5062577859062003e+00*x**2+2.6502172711218009e+01*x-9.0189710046281107e+01)*((x>=8.8119471043950064e+00)&(x<8.8758017935572884e+00))+(7.4340520003488564e-02*x**3-2.4299220056236663e+00*x**2+2.5824631455790950e+01*x-8.8185136083164252e+01)*((x>=8.8758017935572884e+00)&(x<8.9396564827195704e+00))+(6.8512232251123351e-02*x**3-2.2736133344624250e+00*x**2+2.4427285630255938e+01*x-8.4021205526660196e+01)*((x>=8.9396564827195704e+00)&(x<9.0035111718818541e+00))+(6.0661458270487856e-02*x**3-2.0615597407449968e+00*x**2+2.2518058730143821e+01*x-7.8291290285415016e+01)*((x>=9.0035111718818541e+00)&(x<9.0673658610441361e+00))+(5.1357441324626052e-02*x**3-1.8084709638933418e+00*x**2+2.0223210194963031e+01*x-7.1355213197064586e+01)*((x>=9.0673658610441361e+00)&(x<9.1312205502064199e+00))+(4.0856748564010559e-02*x**3-1.5208185392439191e+00*x**2+1.7596592464193236e+01*x-6.3360471263178624e+01)*((x>=9.1312205502064199e+00)&(x<9.1950752393687019e+00))+(2.9294230823097678e-02*x**3-1.2018638775261934e+00*x**2+1.4663780351227615e+01*x-5.4371328583103605e+01)*((x>=9.1950752393687019e+00)&(x<9.2589299285309838e+00))+(1.6474894767952719e-02*x**3-8.4578387473811745e-01*x**2+1.1366860556474421e+01*x-4.4196012130472809e+01)*((x>=9.2589299285309838e+00)&(x<9.3227846176932676e+00))+(2.1329341826685777e-03*x**3-4.4466284614100005e-01*x**2+7.6272956012981012e+00*x-3.2574959249468520e+01)*((x>=9.3227846176932676e+00)&(x<9.3866393068555496e+00))+(-1.4339855015009562e-02*x**3+1.9209545611374779e-02*x**2+3.2730927757802419e+00*x-1.8951182118616998e+01)*((x>=9.3866393068555496e+00)&(x<9.4504939960178334e+00))+(-3.3771156169336791e-02*x**3+5.7011573027557461e-01*x**2-1.9332428149064071e+00*x-2.5503677048254758e+00)*((x>=9.4504939960178334e+00)&(x<9.5143486851801153e+00))+(-5.7261778430984123e-02*x**3+1.2406096433660423e+00*x**2-8.3125556954182684e+00*x+1.7681301332428120e+01)*((x>=9.5143486851801153e+00)&(x<9.5782033743423973e+00))+(-8.6917748858923005e-02*x**3+2.0927623914467404e+00*x**2-1.6474648022325709e+01*x+4.3740694755455479e+01)*((x>=9.5782033743423973e+00)&(x<9.6420580635046811e+00))+(-1.2388940447010555e-01*x**3+3.1622109417803586e+00*x**2-2.6786333040392492e+01*x+7.6882649981649593e+01)*((x>=9.6420580635046811e+00)&(x<9.7059127526669631e+00))+(-1.7596561256004861e-01*x**3+4.6785523383769032e+00*x**2-4.1503810339374468e+01*x+1.2449816684902180e+02)*((x>=9.7059127526669631e+00)&(x<9.7697674418292451e+00))+(-2.2936050543137299e-01*x**3+6.2435193961682671e+00*x**2-5.6793174548191018e+01*x+1.7428934440063313e+02)*((x>=9.7697674418292451e+00)&(x<9.8336221309915288e+00))+(-3.4992735390551388e-01*x**3+9.8003458844286797e+00*x**2-9.1769662219478050e+01*x+2.8893786547589116e+02)*((x>=9.8336221309915288e+00)&(x<9.8974768201538108e+00))+(-2.8373674776457847e-01*x**3+7.8349859144727816e+00*x**2-7.2317557473346824e+01*x+2.2476228020025883e+02)*((x>=9.8974768201538108e+00)&(x<9.9613315093160928e+00))+(-8.6959413269835295e-01*x**3+2.5342744799992943e+01*x**2-2.4671814771692152e+02*x+8.0384964514640160e+02)*((x>=9.9613315093160928e+00)&(x<1.0025186198478377e+01))+(1.4952989189951040e+00*x**3-4.5782734748157964e+01*x**2+4.6632802820910001e+02*x-1.5789572487775004e+03)*((x>=1.0025186198478377e+01)&(x<1.0089040887640659e+01))+(-5.1898963123885551e+00*x**3+1.5655888934570976e+02*x**2-1.5751048905455682e+03*x+5.2864094801192405e+03)*((x>=1.0089040887640659e+01)&(x<1.0152895576802942e+01))+(2.6115873886226950e+01*x**3-7.9697375798806388e+02*x**2+8.1060125069069036e+03*x-2.7477381854248582e+04)*((x>=1.0152895576802942e+01)&(x<=1.0216750265965224e+01))

axes[1][2].scatter(px, py, s = 5)
axes[1][2].plot(ZX, ZY)
axes[1][2].plot(X, Y)
axes[1][2].set_title("Complete: N=160")

px = [1.73205e-08, 0.00896396, 0.0335455, 0.0693631, 0.112768, 0.161376, 0.213696, 0.268775, 0.325975, 0.384843, 0.445043, 0.506312, 0.568435, 0.631224, 0.694513, 0.758141, 0.821954, 0.885792, 0.94949, 1.01287, 1.07573, 1.13785, 1.19898, 1.25884, 1.3171, 1.37338, 1.42727, 1.4783, 1.52596, 1.56972, 1.60904, 1.64343, 1.67246, 1.69584, 1.71339, 1.72511, 1.7311, 1.73162, 1.72699, 1.71757, 1.70377, 1.68598, 1.66456, 1.63987, 1.61224, 1.58194, 1.54924, 1.51436, 1.47753, 1.43891, 1.39868, 1.35698, 1.31395, 1.26969, 1.22432, 1.17794, 1.13062, 1.08247, 1.03354, 0.983911, 0.933651, 0.882823, 0.83149, 0.779714, 0.727556, 0.675081, 0.622359, 0.569463, 0.516479, 0.463504, 0.41066, 0.358095, 0.306009, 0.254671, 0.204468, 0.155981, 0.110125, 0.0684082, 0.0333562, 0.00895572, 1.73205e-08, -0.00895572, -0.0333562, -0.0684082, -0.110125, -0.155981, -0.204468, -0.254671, -0.306009, -0.358095, -0.41066, -0.463504, -0.516479, -0.569463, -0.622359, -0.675081, -0.727556, -0.779714, -0.83149, -0.882823, -0.933651, -0.983911, -1.03354, -1.08247, -1.13062, -1.17794, -1.22432, -1.26969, -1.31395, -1.35698, -1.39868, -1.43891, -1.47753, -1.51436, -1.54924, -1.58194, -1.61224, -1.63987, -1.66456, -1.68598, -1.70377, -1.71757, -1.72699, -1.73162, -1.7311, -1.72511, -1.71339, -1.69584, -1.67246, -1.64343, -1.60904, -1.56972, -1.52596, -1.4783, -1.42727, -1.37338, -1.3171, -1.25884, -1.19898, -1.13785, -1.07573, -1.01287, -0.94949, -0.885792, -0.821954, -0.758141, -0.694513, -0.631224, -0.568435, -0.506312, -0.445043, -0.384843, -0.325975, -0.268775, -0.213696, -0.161376, -0.112768, -0.0693631, -0.0335455, -0.00896396, -1.73205e-08]
py = [1.15479, 1.2178, 1.27659, 1.32935, 1.37612, 1.41749, 1.45406, 1.48634, 1.51469, 1.53941, 1.56068, 1.57863, 1.59338, 1.60495, 1.61339, 1.61868, 1.62081, 1.61972, 1.61535, 1.60763, 1.59645, 1.58171, 1.5633, 1.5411, 1.51499, 1.48486, 1.45064, 1.41228, 1.36981, 1.32333, 1.27305, 1.21927, 1.16243, 1.10304, 1.04167, 0.97892, 0.915368, 0.851534, 0.787864, 0.724721, 0.662388, 0.601074, 0.540927, 0.482045, 0.424489, 0.368287, 0.313446, 0.259959, 0.207804, 0.156952, 0.107367, 0.0590111, 0.0118412, -0.0341867, -0.0791184, -0.123001, -0.165882, -0.207812, -0.248841, -0.289021, -0.328408, -0.367059, -0.405036, -0.442407, -0.479244, -0.515628, -0.551652, -0.587422, -0.62306, -0.658713, -0.694558, -0.730812, -0.767749, -0.805718, -0.845172, -0.886713, -0.93113, -0.979433, -1.03273, -1.0916, -1.15461, -1.0916, -1.03273, -0.979433, -0.93113, -0.886713, -0.845172, -0.805718, -0.767749, -0.730812, -0.694558, -0.658713, -0.62306, -0.587422, -0.551652, -0.515628, -0.479244, -0.442407, -0.405036, -0.367059, -0.328408, -0.289021, -0.248841, -0.207812, -0.165882, -0.123001, -0.0791184, -0.0341867, 0.0118412, 0.0590111, 0.107367, 0.156952, 0.207804, 0.259959, 0.313446, 0.368287, 0.424489, 0.482045, 0.540927, 0.601074, 0.662388, 0.724721, 0.787864, 0.851534, 0.915368, 0.97892, 1.04167, 1.10304, 1.16243, 1.21927, 1.27305, 1.32333, 1.36981, 1.41228, 1.45064, 1.48486, 1.51499, 1.5411, 1.5633, 1.58171, 1.59645, 1.60763, 1.61535, 1.61972, 1.62081, 1.61868, 1.61339, 1.60495, 1.59338, 1.57863, 1.56068, 1.53941, 1.51469, 1.48634, 1.45406, 1.41749, 1.37612, 1.32935, 1.27659, 1.2178, 1.15479]
X = (1.3448383709126045e+01*x**3-1.4999999908837935e-08*x**2+8.5545573989245921e-02*x+1.7320508075751098e-08)*((x>=0)&(x<6.3854689162282652e-02))+(-7.2577643186195360e+00*x**3+3.9665539231797222e+00*x**2-1.6773749477864797e-01*x+5.3911211959223864e-03)*((x>=6.3854689162282652e-02)&(x<1.2770937832456530e-01))+(-1.2462559483520721e+00*x**3+1.6633759329003901e+00*x**2+1.2639993453074760e-01*x-7.1302482171070880e-03)*((x>=1.2770937832456530e-01)&(x<1.9156406748684796e-01))+(-1.7700094996225602e+00*x**3+1.9643730148265206e+00*x**2+6.8739709215297040e-02*x-3.4483724525626869e-03)*((x>=1.9156406748684796e-01)&(x<2.5541875664913061e-01))+(-8.3545757432167989e-01*x**3+1.2482667424733620e+00*x**2+2.5164668292838499e-01*x-1.9020996388645628e-02)*((x>=2.5541875664913061e-01)&(x<3.1927344581141326e-01))+(-6.0881676660173412e-01*x**3+1.0311855675465722e+00*x**2+3.2095493766807692e-01*x-2.6397091493284286e-02)*((x>=3.1927344581141326e-01)&(x<3.8312813497369591e-01))+(-3.9093036116588564e-01*x**3+7.8075033109453784e-01*x**2+4.1690372274169363e-01*x-3.8650651186030061e-02)*((x>=3.8312813497369591e-01)&(x<4.4698282413597856e-01))+(-2.8340403021911698e-01*x**3+6.3656306186754819e-01*x**2+4.8135295554507707e-01*x-4.8253217883324595e-02)*((x>=4.4698282413597856e-01)&(x<5.1083751329826121e-01))+(-2.1035764879877661e-01*x**3+5.2461856634721471e-01*x**2+5.3853840326416957e-01*x-5.7990708519888301e-02)*((x>=5.1083751329826121e-01)&(x<5.7469220246054387e-01))+(-1.6573329609747134e-01*x**3+4.4768276373520166e-01*x**2+5.8275280911533400e-01*x-6.6460599946232435e-02)*((x>=5.7469220246054387e-01)&(x<6.3854689162282652e-01))+(-1.3655186157689059e-01*x**3+3.9178162081668688e-01*x**2+6.1844831016412627e-01*x-7.4058350359408109e-02)*((x>=6.3854689162282652e-01)&(x<7.0240158078510917e-01))+(-1.1806226268981845e-01*x**3+3.5282025035735387e-01*x**2+6.4581483836468578e-01*x-8.0465781248847179e-02)*((x>=7.0240158078510917e-01)&(x<7.6625626994739182e-01))+(-1.0678697751313848e-01*x**3+3.2690097647184757e-01*x**2+6.6567564449178462e-01*x-8.5538603656203804e-02)*((x>=7.6625626994739182e-01)&(x<8.3011095910967447e-01))+(-1.0085743505646860e-01*x**3+3.1213444194349904e-01*x**2+6.7793350663134788e-01*x-8.8930398888408035e-02)*((x>=8.3011095910967447e-01)&(x<8.9396564827195713e-01))+(-9.9098387073354388e-02*x**3+3.0741685653242712e-01*x**2+6.8215086593249907e-01*x-9.0187123668954428e-02)*((x>=8.9396564827195713e-01)&(x<9.5782033743423978e-01))+(-1.0090813256556430e-01*x**3+3.1261708964757418e-01*x**2+6.7716997689490199e-01*x-8.8596858063112904e-02)*((x>=9.5782033743423978e-01)&(x<1.0216750265965224e+00))+(-1.0599867383757555e-01*x**3+3.2821972631404606e-01*x**2+6.6122915266350901e-01*x-8.3168077389245809e-02)*((x>=1.0216750265965224e+00)&(x<1.0855297157588051e+00))+(-1.1429081850212697e-01*x**3+3.5522383463558072e-01*x**2+6.3191539063200253e-01*x-7.2561090800491002e-02)*((x>=1.0855297157588051e+00)&(x<1.1493844049210877e+00))+(-1.2585181000872581e-01*x**3+3.9508790466561550e-01*x**2+5.8609625022427281e-01*x-5.5006488990102298e-02)*((x>=1.1493844049210877e+00)&(x<1.2132390940833704e+00))+(-1.4090201198837349e-01*x**3+4.4986638491400299e-01*x**2+5.1963685647433522e-01*x-2.8129444101523404e-02)*((x>=1.2132390940833704e+00)&(x<1.2770937832456530e+00))+(-1.5962496877546073e-01*x**3+5.2159930006519062e-01*x**2+4.2802719648216225e-01*x+1.0868598318893419e-02)*((x>=1.2770937832456530e+00)&(x<1.3409484724079357e+00))+(-1.8216906892200768e-01*x**3+6.1229073002368750e-01*x**2+3.0641466201450385e-01*x+6.5227312424440242e-02)*((x>=1.3409484724079357e+00)&(x<1.4048031615702183e+00))+(-2.0846551685986014e-01*x**3+7.2311472962974221e-01*x**2+1.5072875699206634e-01*x+1.3812999628726175e-01)*((x>=1.4048031615702183e+00)&(x<1.4686578507325010e+00))+(-2.3795858484197652e-01*x**3+8.5306040712748654e-01*x**2-4.0116982435392856e-02*x+2.3155902745020285e-01)*((x>=1.4686578507325010e+00)&(x<1.5325125398947836e+00))+(-2.6941207732056682e-01*x**3+9.9766902206829400e-01*x**2-2.6173149821352126e-01*x+3.4476803560573899e-01)*((x>=1.5325125398947836e+00)&(x<1.5963672290570663e+00))+(-3.0036377718613494e-01*x**3+1.1458998601165149e+00*x**2-4.9836235040856991e-01*x+4.7068461487560853e-01)*((x>=1.5963672290570663e+00)&(x<1.6602219182193489e+00))+(-3.2698282032947645e-01*x**3+1.2784804167204129e+00*x**2-7.1847549641552177e-01*x+5.9249683803955122e-01)*((x>=1.6602219182193489e+00)&(x<1.7240766073816316e+00))+(-3.4378797460215083e-01*x**3+1.3654005368161961e+00*x**2-8.6833244218178152e-01*x+6.7861845625884598e-01)*((x>=1.7240766073816316e+00)&(x<1.7879312965439143e+00))+(-3.4423128721346075e-01*x**3+1.3677783742914471e+00*x**2-8.7258385222048673e-01*x+6.8115219928040460e-01)*((x>=1.7879312965439143e+00)&(x<1.8517859857061969e+00))+(-3.2202741890569087e-01*x**3+1.2444279378123611e+00*x**2-6.4416524261650920e-01*x+5.4015807256655535e-01)*((x>=1.8517859857061969e+00)&(x<1.9156406748684796e+00))+(-2.7342921920876506e-01*x**3+9.6513787361254799e-01*x**2-1.0914583554585988e-01*x+1.9852309323141526e-01)*((x>=1.9156406748684796e+00)&(x<1.9794953640307622e+00))+(-1.9958079339448886e-01*x**3+5.2659002399559540e-01*x**2+7.5895759967170306e-01*x-3.7427914861655154e-01)*((x>=1.9794953640307622e+00)&(x<2.0433500531930449e+00))+(-1.0759775405313121e-01*x**3-3.7270621000061510e-02*x**2+1.9111222786268627e+00*x-1.1590377346237801e+00)*((x>=2.0433500531930449e+00)&(x<2.1072047423553277e+00))+(-9.2458996969071450e-03*x**3-6.5901310275512515e-01*x**2+3.2212609846956184e+00*x-2.0792812328163564e+00)*((x>=2.1072047423553277e+00)&(x<2.1710594315176102e+00))+(8.2537771468423671e-02*x**3-1.2568165175825925e+00*x**2+4.5191277266603720e+00*x-3.0185298431370029e+00)*((x>=2.1710594315176102e+00)&(x<2.2349141206798926e+00))+(1.5759947619471859e-01*x**3-1.7600859090271115e+00*x**2+5.6438915961007297e+00*x-3.8564467278902157e+00)*((x>=2.2349141206798926e+00)&(x<2.2987688098421755e+00))+(2.1074614957660742e-01*x**3-2.1266016543813748e+00*x**2+6.4864265598334896e+00*x-4.5020444264991966e+00)*((x>=2.2987688098421755e+00)&(x<2.3626234990044583e+00))+(2.4181676616808545e-01*x**3-2.3468261610360059e+00*x**2+7.0067341543290240e+00*x-4.9118080763182661e+00)*((x>=2.3626234990044583e+00)&(x<2.4264781881667408e+00))+(2.5404937768007585e-01*x**3-2.4358726560976720e+00*x**2+7.2228035323096265e+00*x-5.0865706205931929e+00)*((x>=2.4264781881667408e+00)&(x<2.4903328773290232e+00))+(2.5216185070485153e-01*x**3-2.4217709446484150e+00*x**2+7.1876855766495282e+00*x-5.0574188207574480e+00)*((x>=2.4903328773290232e+00)&(x<2.5541875664913061e+00))+(2.4088810668172300e-01*x**3-2.3353851742194820e+00*x**2+6.9670401159237372e+00*x-4.8695621899314574e+00)*((x>=2.5541875664913061e+00)&(x<2.6180422556535889e+00))+(2.2416370355267645e-01*x**3-2.2040295919305208e+00*x**2+6.6231456509776763e+00*x-4.5694521097066172e+00)*((x>=2.6180422556535889e+00)&(x<2.6818969448158714e+00))+(2.0491462882296219e-01*x**3-2.0491574878142274e+00*x**2+6.2077946280915057e+00*x-4.1981425632766332e+00)*((x>=2.6818969448158714e+00)&(x<2.7457516339781538e+00))+(1.8509981466820591e-01*x**3-1.8859378127817763e+00*x**2+5.7596339386873296e+00*x-3.7879632481963199e+00)*((x>=2.7457516339781538e+00)&(x<2.8096063231404367e+00))+(1.6594524430968249e-01*x**3-1.7244874067891942e+00*x**2+5.3060218571263249e+00*x-3.3631394573494617e+00)*((x>=2.8096063231404367e+00)&(x<2.8734610123027196e+00))+(1.4811748078682285e-01*x**3-1.5708052565405524e+00*x**2+4.8644221900867706e+00*x-2.9401663152275432e+00)*((x>=2.8734610123027196e+00)&(x<2.9373157014650020e+00))+(1.3193850520974593e-01*x**3-1.4282369795400882e+00*x**2+4.4456541515392018e+00*x-2.5301483369694324e+00)*((x>=2.9373157014650020e+00)&(x<3.0011703906272844e+00))+(1.1749186534996170e-01*x**3-1.2981664961807837e+00*x**2+4.0552904681608197e+00*x-2.1396323608823877e+00)*((x>=3.0011703906272844e+00)&(x<3.0650250797895673e+00))+(1.0473901339639724e-01*x**3-1.1809030629356130e+00*x**2+3.6958751043566735e+00*x-1.7724266595323570e+00)*((x>=3.0650250797895673e+00)&(x<3.1288797689518502e+00))+(9.3577175315317618e-02*x**3-1.0761309148729197e+00*x**2+3.3680556499311933e+00*x-1.4305241065667360e+00)*((x>=3.1288797689518502e+00)&(x<3.1927344581141326e+00))+(8.3868167635159807e-02*x**3-9.8313606474948756e-01*x**2+3.0711477875156561e+00*x-1.1145414521852217e+00)*((x>=3.1927344581141326e+00)&(x<3.2565891472764150e+00))+(7.5414399583792147e-02*x**3-9.0054471687562909e-01*x**2+2.8021817003827891e+00*x-8.2257077205213136e-01)*((x>=3.2565891472764150e+00)&(x<3.3204438364386979e+00))+(6.8178406936226565e-02*x**3-8.2846459532811423e-01*x**2+2.5628437050363573e+00*x-5.5766798156764708e-01)*((x>=3.3204438364386979e+00)&(x<3.3842985256009808e+00))+(6.1907653519824635e-02*x**3-7.6479829069194238e-01*x**2+2.3473779241503507e+00*x-3.1460114003130002e-01)*((x>=3.3842985256009808e+00)&(x<3.4481532147632632e+00))+(5.6574522140067529e-02*x**3-7.0962992836211924e-01*x**2+2.1571489582129288e+00*x-9.5954933236498618e-02)*((x>=3.4481532147632632e+00)&(x<3.5120079039255456e+00))+(5.2083420787880641e-02*x**3-6.6231157802667440e-01*x**2+1.9909665378399950e+00*x+9.8589724730118178e-02)*((x>=3.5120079039255456e+00)&(x<3.5758625930878285e+00))+(4.8282588417237093e-02*x**3-6.2153781513006834e-01*x**2+1.8451651643081277e+00*x+2.7237828393117525e-01)*((x>=3.5758625930878285e+00)&(x<3.6397172822501114e+00))+(4.5225951666907349e-02*x**3-5.8816193431721331e-01*x**2+1.7236863941070624e+00*x+4.1976107704613241e-01)*((x>=3.6397172822501114e+00)&(x<3.7035719714123938e+00))+(4.2795753595555652e-02*x**3-5.6116069392919599e-01*x**2+1.6236853570080712e+00*x+5.4321475639881101e-01)*((x>=3.7035719714123938e+00)&(x<3.7674266605746762e+00))+(4.0997223446538555e-02*x**3-5.4083320263453061e-01*x**2+1.5471030243425048e+00*x+6.3938753033653484e-01)*((x>=3.7674266605746762e+00)&(x<3.8312813497369591e+00))+(3.9892056882308680e-02*x**3-5.2813059049276490e-01*x**2+1.4984357433713740e+00*x+7.0154021234338870e-01)*((x>=3.8312813497369591e+00)&(x<3.8951360388992420e+00))+(3.9473332950876738e-02*x**3-5.2323763046479144e-01*x**2+1.4793769984353276e+00*x+7.2628568040454411e-01)*((x>=3.8951360388992420e+00)&(x<3.9589907280615244e+00))+(3.9830017602071166e-02*x**3-5.2747396414360992e-01*x**2+1.4961486041756871e+00*x+7.0415280318775331e-01)*((x>=3.9589907280615244e+00)&(x<4.0228454172238068e+00))+(4.1148456027485736e-02*x**3-5.4338558607651066e-01*x**2+1.5601585995646019e+00*x+6.1831869766683667e-01)*((x>=4.0228454172238068e+00)&(x<4.0867001063860897e+00))+(4.3622499978141605e-02*x**3-5.7371761310332658e-01*x**2+1.6841164976576692e+00*x+4.4945911257309490e-01)*((x>=4.0867001063860897e+00)&(x<4.1505547955483726e+00))+(4.7597628106302636e-02*x**3-6.2321457445341366e-01*x**2+1.8895563479345583e+00*x+1.6522932730003959e-01)*((x>=4.1505547955483726e+00)&(x<4.2144094847106555e+00))+(5.3616895624202243e-02*x**3-6.9931754880235530e-01*x**2+2.2102854448748985e+00*x-2.8533192205941305e-01)*((x>=4.2144094847106555e+00)&(x<4.2782641738729374e+00))+(6.2502711297383939e-02*x**3-8.1336514935628657e-01*x**2+2.6982112084133405e+00*x-9.8115702663926641e-01)*((x>=4.2782641738729374e+00)&(x<4.3421188630352203e+00))+(7.5541858784106353e-02*x**3-9.8321773413817937e-01*x**2+3.4357313207128755e+00*x-2.0486236904907855e+00)*((x>=4.3421188630352203e+00)&(x<4.4059735521975032e+00))+(9.4771448262832791e-02*x**3-1.2373929221253093e+00*x**2+4.5556204766289738e+00*x-3.6933576912633725e+00)*((x>=4.4059735521975032e+00)&(x<4.4698282413597852e+00))+(1.2395029074545505e-01*x**3-1.6286661646622633e+00*x**2+6.3045446661944879e+00*x-6.2991546027697041e+00)*((x>=4.4698282413597852e+00)&(x<4.5336829305220681e+00))+(1.6823671171627552e-01*x**3-2.2310079370927269e+00*x**2+9.0353712782089133e+00*x-1.0426055268459095e+01)*((x>=4.5336829305220681e+00)&(x<4.5975376196843509e+00))+(2.4148467129742812e-01*x**3-3.2412886863105541e+00*x**2+1.3680175029179736e+01*x-1.7544275262167503e+01)*((x>=4.5975376196843509e+00)&(x<4.6613923088466338e+00))+(3.5211110533765577e-01*x**3-4.7883083126814654e+00*x**2+2.0891440417187368e+01*x-2.8749120934400707e+01)*((x>=4.6613923088466338e+00)&(x<4.7252469980089167e+00))+(5.8109969514757154e-01*x**3-8.0343912524124335e+00*x**2+3.6229984083444833e+01*x-5.2908590072011975e+01)*((x>=4.7252469980089167e+00)&(x<4.7891016871711987e+00))+(8.3922433742960578e-01*x**3-1.1742946731973461e+01*x**2+5.3990633387573780e+01*x-8.1261108587897070e+01)*((x>=4.7891016871711987e+00)&(x<4.8529563763334815e+00))+(1.8489672728627724e+00*x**3-2.6443661982877416e+01*x**2+1.2533256320110809e+02*x-1.9666753298408003e+02)*((x>=4.8529563763334815e+00)&(x<4.9168110654957644e+00))+(1.4706270343431811e+00*x**3-2.0862979569051419e+01*x**2+9.7893402155792472e+01*x-1.5169647609889506e+02)*((x>=4.9168110654957644e+00)&(x<4.9806657546580464e+00))+(7.5796947959353602e+00*x**3-1.1214465334819442e+02*x**2+5.5253690877543613e+02*x-9.0650559076493425e+02)*((x>=4.9806657546580464e+00)&(x<5.0445204438203293e+00))+(-1.3380025193619913e+01*x**3+2.0505055460398910e+02*x**2-1.0475608024211940e+03*x+1.7840696146489047e+03)*((x>=5.0445204438203293e+00)&(x<5.1083751329826121e+00))+(-1.3379866048134888e+01*x**3+2.0504811567947451e+02*x**2-1.0475483434798525e+03*x+1.7840483996668602e+03)*((x>=5.1083751329826121e+00)&(x<5.1722298221448950e+00))+(7.5796165107984024e+00*x**3-1.2017366656464731e+02*x**2+6.3457345745430666e+02*x-1.1160584480903844e+03)*((x>=5.1722298221448950e+00)&(x<5.2360845113071779e+00))+(1.4706480293233994e+00*x**3-2.4212440826902366e+01*x**2+1.3211236968284993e+02*x-2.3908220835215980e+02)*((x>=5.2360845113071779e+00)&(x<5.2999392004694599e+00))+(1.8489616256916293e+00*x**3-3.0227558005289893e+01*x**2+1.6399212501200236e+02*x-2.9540246334227413e+02)*((x>=5.2999392004694599e+00)&(x<5.3637938896317428e+00))+(8.3922580687141135e-01*x**3-1.3979513559899715e+01*x**2+7.6840963497346820e+01*x-1.3958217414006867e+02)*((x>=5.3637938896317428e+00)&(x<5.4276485787940256e+00))+(5.8109932039485557e-01*x**3-9.7764539874792717e+00*x**2+5.4028233182514668e+01*x-9.8309013049500209e+01)*((x>=5.4276485787940256e+00)&(x<5.4915032679563076e+00))+(3.5211142402440032e-01*x**3-6.0039906437559694e+00*x**2+3.3311738402215269e+01*x-6.0387446787291992e+01)*((x>=5.4915032679563076e+00)&(x<5.5553579571185905e+00))+(2.4148405360153902e-01*x**3-4.1602667160923374e+00*x**2+2.3069192009941617e+01*x-4.1420442920163623e+01)*((x>=5.5553579571185905e+00)&(x<5.6192126462808734e+00))+(1.6823745853258742e-01*x**3-2.9255021361705076e+00*x**2+1.6130787267247797e+01*x-2.8424319028446916e+01)*((x>=5.6192126462808734e+00)&(x<5.6830673354431562e+00))+(1.2394976979419425e-01*x**3-2.1704323844733153e+00*x**2+1.1839675025432371e+01*x-2.0295425757009070e+01)*((x>=5.6830673354431562e+00)&(x<5.7469220246054391e+00))+(9.4771911755572091e-02*x**3-1.6673837594980796e+00*x**2+8.9486938031004684e+00*x-1.4757344537218160e+01)*((x>=5.7469220246054391e+00)&(x<5.8107767137677211e+00))+(7.5541135604112242e-02*x**3-1.3321465207527581e+00*x**2+7.0007050625863485e+00*x-1.0984235333235119e+01)*((x>=5.8107767137677211e+00)&(x<5.8746314029300040e+00))+(6.2503388453194475e-02*x**3-1.1023706442438197e+00*x**2+5.6508564828254748e+00*x-8.3409477145178244e+00)*((x>=5.8746314029300040e+00)&(x<5.9384860920922868e+00))+(5.3616668928725630e-02*x**3-9.4404966333877383e-01*x**2+4.7106695396505529e+00*x-6.4798520191980060e+00)*((x>=5.9384860920922868e+00)&(x<6.0023407812545688e+00))+(4.7597505711507893e-02*x**3-8.3566245680231077e-01*x**2+4.0600925896869740e+00*x-5.1781904998206301e+00)*((x>=6.0023407812545688e+00)&(x<6.0661954704168517e+00))+(4.3622536873840545e-02*x**3-7.6332364291920385e-01*x**2+3.6212712045817170e+00*x-4.2908650669851340e+00)*((x>=6.0661954704168517e+00)&(x<6.1300501595791346e+00))+(4.1148641368408789e-02*x**3-7.1782833231372933e-01*x**2+3.3423826684957021e+00*x-3.7209981619525934e+00)*((x>=6.1300501595791346e+00)&(x<6.1939048487414174e+00))+(3.9829983086974607e-02*x**3-6.9332540053619596e-01*x**2+3.1906138406338869e+00*x-3.4076509356964380e+00)*((x>=6.1939048487414174e+00)&(x<6.2577595379037003e+00))+(3.9473397131814636e-02*x**3-6.8663111306159408e-01*x**2+3.1487225992750609e+00*x-3.3202691639598925e+00)*((x>=6.2577595379037003e+00)&(x<6.3216142270659823e+00))+(3.9891093728442684e-02*x**3-6.9455266330442100e-01*x**2+3.1987995839590440e+00*x-3.4257916235364974e+00)*((x>=6.3216142270659823e+00)&(x<6.3854689162282652e+00))+(4.0999146864237446e-02*x**3-7.1577897986753669e-01*x**2+3.3343395685515134e+00*x-3.7142870765819680e+00)*((x>=6.3854689162282652e+00)&(x<6.4493236053905481e+00))+(4.2793433918745905e-02*x**3-7.5049479342851555e-01*x**2+3.5582330845209071e+00*x-4.1956076555652544e+00)*((x>=6.4493236053905481e+00)&(x<6.5131782945528300e+00))+(4.5228331538737621e-02*x**3-7.9807156042261340e-01*x**2+3.8681090505560860e+00*x-4.8683667944860645e+00)*((x>=6.5131782945528300e+00)&(x<6.5770329837151129e+00))+(4.8279894263259848e-02*x**3-8.5828224648321338e-01*x**2+4.2641167187975952e+00*x-5.7365519594459329e+00)*((x>=6.5770329837151129e+00)&(x<6.6408876728773958e+00))+(5.2087175539895725e-02*x**3-9.3413342838721292e-01*x**2+4.7678358976991149e+00*x-6.8515994547924493e+00)*((x>=6.6408876728773958e+00)&(x<6.7047423620396787e+00))+(5.6570503151419871e-02*x**3-1.0243120980594540e+00*x**2+5.3724606444593519e+00*x-8.2028838390251622e+00)*((x>=6.7047423620396787e+00)&(x<6.7685970512019615e+00))+(6.1911159142709948e-02*x**3-1.1327583432321262e+00*x**2+6.1064895797171630e+00*x-9.8589992013585288e+00)*((x>=6.7685970512019615e+00)&(x<6.8324517403642435e+00))+(6.8174337213122271e-02*x**3-1.2611369289625145e+00*x**2+6.9836300711322110e+00*x-1.1856672560272273e+01)*((x>=6.8324517403642435e+00)&(x<6.8963064295265264e+00))+(7.5418536644747292e-02*x**3-1.4110115863295505e+00*x**2+8.0172116342146182e+00*x-1.4232637620239984e+01)*((x>=6.8963064295265264e+00)&(x<6.9601611186888093e+00))+(8.3866349393133532e-02*x**3-1.5874059997986478e+00*x**2+9.2449451726279221e+00*x-1.7081045365950558e+01)*((x>=6.9601611186888093e+00)&(x<7.0240158078510913e+00))+(9.3575163117407101e-02*x**3-1.7919905830276548e+00*x**2+1.0681950519239763e+01*x-2.0445561456319410e+01)*((x>=7.0240158078510913e+00)&(x<7.0878704970133741e+00))+(1.0474435456262654e-01*x**3-2.0294879306020448e+00*x**2+1.2365300962090259e+01*x-2.4422684769786429e+01)*((x>=7.0878704970133741e+00)&(x<7.1517251861756570e+00))+(1.1748646481009928e-01*x**3-2.3028721429327561e+00*x**2+1.4320469719095854e+01*x-2.9083627983985934e+01)*((x>=7.1517251861756570e+00)&(x<7.2155798753379399e+00))+(1.3193991727962384e-01*x**3-2.6157422652358946e+00*x**2+1.6578009077056777e+01*x-3.4513446503609885e+01)*((x>=7.2155798753379399e+00)&(x<7.2794345645002227e+00))+(1.4811973080600183e-01*x**3-2.9690819467396068e+00*x**2+1.9150122167513473e+01*x-4.0754622815118637e+01)*((x>=7.2794345645002227e+00)&(x<7.3432892536625047e+00))+(1.6594286976214789e-01*x**3-3.3617233410150220e+00*x**2+2.2033401498978492e+01*x-4.7812207524781115e+01)*((x>=7.3432892536625047e+00)&(x<7.4071439428247876e+00))+(1.8510093202075950e-01*x**3-3.7874429154726386e+00*x**2+2.5186767666134983e+01*x-5.5598019893106539e+01)*((x>=7.4071439428247876e+00)&(x<7.4709986319870705e+00))+(2.0491356896764046e-01*x**3-4.2315034660496167e+00*x**2+2.8504343432141468e+01*x-6.3859887895931024e+01)*((x>=7.4709986319870705e+00)&(x<7.5348533211493525e+00))+(2.2416730502959581e-01*x**3-4.6667256973742042e+00*x**2+3.1783679107291391e+01*x-7.2096325664082542e+01)*((x>=7.5348533211493525e+00)&(x<7.5987080103116353e+00))+(2.4088092115994186e-01*x**3-5.0477313636765757e+00*x**2+3.4678829915792448e+01*x-7.9429460876854137e+01)*((x>=7.5987080103116353e+00)&(x<7.6625626994739182e+00))+(2.5217162028684470e-01*x**3-5.3072784336509358e+00*x**2+3.6667625612695701e+01*x-8.4509218118560966e+01)*((x>=7.6625626994739182e+00)&(x<7.7264173886362011e+00))+(2.5403790023824513e-01*x**3-5.3505374072374252e+00*x**2+3.7001862498495029e+01*x-8.5370036014181096e+01)*((x>=7.7264173886362011e+00)&(x<7.7902720777984840e+00))+(2.4182715520919373e-01*x**3-5.0651623291123542e+00*x**2+3.4778712995612295e+01*x-7.9597056181402877e+01)*((x>=7.7902720777984840e+00)&(x<7.8541267669607659e+00))+(2.1073969306053186e-01*x**3-4.3326677233599185e+00*x**2+2.9025607505958760e+01*x-6.4535182908293791e+01)*((x>=7.8541267669607659e+00)&(x<7.9179814561230488e+00))+(1.5760194687572948e-01*x**3-3.0704366566169483e+00*x**2+1.9031285326112993e+01*x-3.8156897013192065e+01)*((x>=7.9179814561230488e+00)&(x<7.9818361452853317e+00))+(8.2538770044948251e-02*x**3-1.2730107225797838e+00*x**2+4.6845260375121143e+00*x+1.4263606281019747e-02)*((x>=7.9818361452853317e+00)&(x<8.0456908344476137e+00))+(-9.2492467845204374e-03*x**3+9.4248329454785562e-01*x**2-1.3140653869922971e+01*x+4.7819559141062200e+01)*((x>=8.0456908344476137e+00)&(x<8.1095455236098957e+00))+(-1.0759479897433266e-01*x**3+3.3350964921337436e+00*x**2-3.2543659516202752e+01*x+1.0026941166841425e+02)*((x>=8.1095455236098957e+00)&(x<8.1734002127721794e+00))+(-1.9958101527527106e-01*x**3+5.5906169717818557e+00*x**2-5.0978931084508076e+01*x+1.5049569585477002e+02)*((x>=8.1734002127721794e+00)&(x<8.2372549019344614e+00))+(-2.7342959037764558e-01*x**3+7.4155455836043984e+00*x**2-6.6011333237780491e+01*x+1.9177093862986658e+02)*((x>=8.2372549019344614e+00)&(x<8.3011095910967452e+00))+(-3.2203188399159899e-01*x**3+8.6259044805810845e+00*x**2-7.6058655086380895e+01*x+2.1957224521739408e+02)*((x>=8.3011095910967452e+00)&(x<8.3649642802590272e+00))+(-3.4422225755906766e-01*x**3+9.1827695273423160e+00*x**2-8.0716811311547644e+01*x+2.3256068202853203e+02)*((x>=8.3649642802590272e+00)&(x<8.4288189694213109e+00))+(-3.4379452576285985e-01*x**3+9.1719537057288107e+00*x**2-8.0625646708824206e+01*x+2.3230454538494814e+02)*((x>=8.4288189694213109e+00)&(x<8.4926736585835929e+00))+(-3.2698200258391807e-01*x**3+8.7436038875202939e+00*x**2-7.6987811491242610e+01*x+2.2200622960890178e+02)*((x>=8.4926736585835929e+00)&(x<8.5565283477458749e+00))+(-3.0036155350421723e-01*x**3+8.0602680059673730e+00*x**2-7.1140828649717150e+01*x+2.0532960479811300e+02)*((x>=8.5565283477458749e+00)&(x<8.6203830369081587e+00))+(-2.6941674843385499e-01*x**3+7.2599997878423892e+00*x**2-6.4242210077121854e+01*x+1.8550669329124503e+02)*((x>=8.6203830369081587e+00)&(x<8.6842377260704406e+00))+(-2.3795031531165023e-01*x**3+6.4402138309815200e+00*x**2-5.7122993943281472e+01*x+1.6489837151463144e+02)*((x>=8.6842377260704406e+00)&(x<8.7480924152327226e+00))+(-2.0847436708663736e-01*x**3+5.6666388736739464e+00*x**2-5.0355688726587687e+01*x+1.4516470103577012e+02)*((x>=8.7480924152327226e+00)&(x<8.8119471043950064e+00))+(-1.8216319956172811e-01*x**3+4.9710810242177104e+00*x**2-4.4226469749264652e+01*x+1.2716124989552191e+02)*((x>=8.8119471043950064e+00)&(x<8.8758017935572884e+00))+(-1.5962896754820122e-01*x**3+4.3710528934680042e+00*x**2-3.8900738990138052e+01*x+1.1140453968773363e+02)*((x>=8.8758017935572884e+00)&(x<8.9396564827195704e+00))+(-1.4089939993266398e-01*x**3+3.8687451917903672e+00*x**2-3.4410280688578496e+01*x+9.8023488132224884e+01)*((x>=8.9396564827195704e+00)&(x<9.0035111718818541e+00))+(-1.2585037090968854e-01*x**3+3.4622628890047054e+00*x**2-3.0750512734171934e+01*x+8.7039900910982396e+01)*((x>=9.0035111718818541e+00)&(x<9.0673658610441361e+00))+(-1.1429608250750789e-01*x**3+3.1479620083919144e+00*x**2-2.7900631659140345e+01*x+7.8426262788241729e+01)*((x>=9.0673658610441361e+00)&(x<9.1312205502064199e+00))+(-1.0599337370433659e-01*x**3+2.9205204126283206e+00*x**2-2.5823812286093016e+01*x+7.2104964208905585e+01)*((x>=9.1312205502064199e+00)&(x<9.1950752393687019e+00))+(-1.0091169022291524e-01*x**3+2.7803410267861182e+00*x**2-2.4534852286029491e+01*x+6.8154269482009113e+01)*((x>=9.1950752393687019e+00)&(x<9.2589299285309838e+00))+(-9.9095026968143429e-02*x**3+2.7298799534455611e+00*x**2-2.4067636743959156e+01*x+6.6712297493708320e+01)*((x>=9.2589299285309838e+00)&(x<9.3227846176932676e+00))+(-1.0086071321904910e-01*x**3+2.7792632913115085e+00*x**2-2.4528026966465404e+01*x+6.8143003788427450e+01)*((x>=9.3227846176932676e+00)&(x<9.3866393068555496e+00))+(-1.0678608859171845e-01*x**3+2.9461213754329947e+00*x**2-2.6094263617793331e+01*x+7.3043569960107561e+01)*((x>=9.3866393068555496e+00)&(x<9.4504939960178334e+00))+(-1.1806033072389255e-01*x**3+3.2657628481838401e+00*x**2-2.9115033436770318e+01*x+8.2559492306056200e+01)*((x>=9.4504939960178334e+00)&(x<9.5143486851801153e+00))+(-1.3655377876131070e-01*x**3+3.7936221872396345e+00*x**2-3.4137271245257580e+01*x+9.8487266202777391e+01)*((x>=9.5143486851801153e+00)&(x<9.5782033743423973e+00))+(-1.6573343318981415e-01*x**3+4.6320881807632759e+00*x**2-4.2168269053683616e+01*x+1.2412810963901575e+02)*((x>=9.5782033743423973e+00)&(x<9.6420580635046811e+00))+(-2.1035658012658587e-01*x**3+5.9228651019839162e+00*x**2-5.4614015075239877e+01*x+1.6412897823317326e+02)*((x>=9.6420580635046811e+00)&(x<9.7059127526669631e+00))+(-2.8340543548608821e-01*x**3+8.0498825523959567e+00*x**2-7.5258660872277687e+01*x+2.3092068853843375e+02)*((x>=9.7059127526669631e+00)&(x<9.7697674418292451e+00))+(-3.9092816931298557e-01*x**3+1.1201298864990349e+01*x**2-1.0604726535869486e+02*x+3.3118652376867249e+02)*((x>=9.7697674418292451e+00)&(x<9.8336221309915288e+00))+(-6.0881848754249290e-01*x**3+1.7629252031398210e+01*x**2-1.6925732787285233e+02*x+5.3838114698231220e+02)*((x>=9.8336221309915288e+00)&(x<9.8974768201538108e+00))+(-8.3545734757584000e-01*x**3+2.4358710622578883e+01*x**2-2.3586198829126624e+02*x+7.5812050785080646e+02)*((x>=9.8974768201538108e+00)&(x<9.9613315093160928e+00))+(-1.7700091267119902e+00*x**3+5.2286850876366657e+01*x**2-5.1406345179793698e+02*x+1.6818728426396301e+03)*((x>=9.9613315093160928e+00)&(x<1.0025186198478377e+01))+(-1.2462560501888920e+00*x**3+3.6534684533856279e+01*x**2-3.5614505118485999e+02*x+1.1541523858689848e+03)*((x>=1.0025186198478377e+01)&(x<1.0089040887640659e+01))+(-7.2577644430521877e+00*x**3+2.1848574644983506e+02*x**2-2.1918567544048033e+03*x+7.3276758631044759e+03)*((x>=1.0089040887640659e+01)&(x<1.0152895576802942e+01))+(1.3448383786113036e+01*x**3-4.1219633585571842e+02*x**2+4.2113925694041136e+03*x-1.4342831382517532e+04)*((x>=1.0152895576802942e+01)&(x<=1.0216750265965224e+01))
Y = (-6.1217047784857641e+00*x**3+4.6357030436536206e-01*x**2+9.8221878174022947e-01*x+1.1547882766467819e+00)*((x>=0)&(x<6.3854689162282652e-02))+(-1.6751627004487091e-01*x**3-6.7703826489497487e-01*x**2+1.0550519873861877e+00*x+1.1532380294110431e+00)*((x>=6.3854689162282652e-02)&(x<1.2770937832456530e-01))+(-5.9785388196587519e-02*x**3-7.1831299673658577e-01*x**2+1.0603231577302239e+00*x+1.1530136367818193e+00)*((x>=1.2770937832456530e-01)&(x<1.9156406748684796e-01))+(4.8494142669869689e-01*x**3-1.0313632497285425e+00*x**2+1.1202923375210219e+00*x+1.1491843234469519e+00)*((x>=1.9156406748684796e-01)&(x<2.5541875664913061e-01))+(3.8680722405922552e-01*x**3-9.5616730165897934e-01*x**2+1.1010858819602731e+00*x+1.1508195531132905e+00)*((x>=2.5541875664913061e-01)&(x<3.1927344581141326e-01))+(3.2231938724328302e-01*x**3-8.9439954004080846e-01*x**2+1.0813650758682911e+00*x+1.1529183296850043e+00)*((x>=3.1927344581141326e-01)&(x<3.8312813497369591e-01))+(2.3674548764438441e-01*x**3-7.9604223437218025e-01*x**2+1.0436816247865295e+00*x+1.1577308597957838e+00)*((x>=3.8312813497369591e-01)&(x<4.4698282413597856e-01))+(1.7399208598283167e-01*x**3-7.1189315627611904e-01*x**2+1.0060684322103270e+00*x+1.1633350101432285e+00)*((x>=4.4698282413597856e-01)&(x<5.1083751329826121e-01))+(1.2441635407992635e-01*x**3-6.3591772545987624e-01*x**2+9.6725733206096720e-01*x+1.1699437321060771e+00)*((x>=5.1083751329826121e-01)&(x<5.7469220246054387e-01))+(8.6775508576920402e-02*x**3-5.7102202424789539e-01*x**2+9.2996227860044200e-01*x+1.1770881242441362e+00)*((x>=5.7469220246054387e-01)&(x<6.3854689162282652e-01))+(5.7306992472490492e-02*x**3-5.1457093616772909e-01*x**2+8.9391561177944823e-01*x+1.1847606199282836e+00)*((x>=6.3854689162282652e-01)&(x<7.0240158078510917e-01))+(3.3753448198694969e-02*x**3-4.6493879597665000e-01*x**2+8.5905391805113140e-01*x+1.1929229228564395e+00)*((x>=7.0240158078510917e-01)&(x<7.6625626994739182e-01))+(1.4341493883875955e-02*x**3-4.2031520085856755e-01*x**2+8.2486080850389953e-01*x+1.2016564843821129e+00)*((x>=7.6625626994739182e-01)&(x<8.3011095910967447e-01))+(-2.1256552317936439e-03*x**3-3.7930651802071225e-01*x**2+7.9081905146040299e-01*x+1.2110759629118775e+00)*((x>=8.3011095910967447e-01)&(x<8.9396564827195713e-01))+(-1.6482619875205273e-02*x**3-3.4080261840699677e-01*x**2+7.5639788788066653e-01*x+1.2213330755159859e+00)*((x>=8.9396564827195713e-01)&(x<9.5782033743423978e-01))+(-2.9287152860433707e-02*x**3-3.0400929209326932e-01*x**2+7.2115649165834839e-01*x+1.2325847175242188e+00)*((x>=9.5782033743423978e-01)&(x<1.0216750265965224e+00))+(-4.0866502392418624e-02*x**3-2.6851829537008598e-01*x**2+6.8489622663628325e-01*x+1.2449334532670946e+00)*((x>=1.0216750265965224e+00)&(x<1.0855297157588051e+00))+(-5.1347831323482751e-02*x**3-2.3438491332262856e-01*x**2+6.4784342612529144e-01*x+1.2583407586037083e+00)*((x>=1.0855297157588051e+00)&(x<1.1493844049210877e+00))+(-6.0664498559731328e-02*x**3-2.0225961724327135e-01*x**2+6.1091911180665193e-01*x+1.2724875022845481e+00)*((x>=1.1493844049210877e+00)&(x<1.2132390940833704e+00))+(-6.8515996635596821e-02*x**3-1.7368238400285918e-01*x**2+5.7624809524259035e-01*x+1.2865089131923924e+00)*((x>=1.2132390940833704e+00)&(x<1.2770937832456530e+00))+(-7.4334579874175688e-02*x**3-1.5138975455738546e-01*x**2+5.4777831676892674e-01*x+1.2986284388925924e+00)*((x>=1.2770937832456530e+00)&(x<1.3409484724079357e+00))+(-7.7215386329726243e-02*x**3-1.3980071551077344e-01*x**2+5.3223801255899161e-01*x+1.3055746879549588e+00)*((x>=1.3409484724079357e+00)&(x<1.4048031615702183e+00))+(-7.5843353720415507e-02*x**3-1.4558302275099777e-01*x**2+5.4036101604833675e-01*x+1.3017709476257551e+00)*((x>=1.4048031615702183e+00)&(x<1.4686578507325010e+00))+(-6.8477993114129276e-02*x**3-1.7803460678715055e-01*x**2+5.8802128971819911e-01*x+1.2784387359301945e+00)*((x>=1.4686578507325010e+00)&(x<1.5325125398947836e+00))+(-5.2937202958219132e-02*x**3-2.4948397416847001e-01*x**2+6.9751834119233536e-01*x+1.2225035344454227e+00)*((x>=1.5325125398947836e+00)&(x<1.5963672290570663e+00))+(-2.6881122140821390e-02*x**3-3.7426919477456977e-01*x**2+8.9672137803427177e-01*x+1.1165031344598901e+00)*((x>=1.5963672290570663e+00)&(x<1.6602219182193489e+00))+(1.1811122273684305e-02*x**3-5.6698233150109445e-01*x**2+1.2166679515521537e+00*x+9.3944236312108842e-01)*((x>=1.6602219182193489e+00)&(x<1.7240766073816316e+00))+(6.4109692486908898e-02*x**3-8.3748255601312849e-01*x**2+1.6830310609293520e+00*x+6.7142712064742227e-01)*((x>=1.7240766073816316e+00)&(x<1.7879312965439143e+00))+(1.2874343422004131e-01*x**3-1.1841646249804398e+00*x**2+2.3028747819862474e+00*x+3.0201445803231763e-01)*((x>=1.7879312965439143e+00)&(x<1.8517859857061969e+00))+(2.0109852900736769e-01*x**3-1.5861230765503933e+00*x**2+3.0472158094335100e+00*x-1.5743896970707283e-01)*((x>=1.8517859857061969e+00)&(x<1.9156406748684796e+00))+(2.7296157402645349e-01*x**3-1.9991143927290977e+00*x**2+3.8383587730750151e+00*x-6.6262084996833437e-01)*((x>=1.9156406748684796e+00)&(x<1.9794953640307622e+00))+(3.3378825984470950e-01*x**3-2.3603328204826539e+00*x**2+4.5533889762245963e+00*x-1.1344205073937701e+00)*((x>=1.9794953640307622e+00)&(x<2.0433500531930449e+00))+(3.7358916949460763e-01*x**3-2.6043143930355654e+00*x**2+5.0519287354727567e+00*x-1.4739842552498885e+00)*((x>=2.0433500531930449e+00)&(x<2.1072047423553277e+00))+(3.8629414153774633e-01*x**3-2.6846303250576966e+00*x**2+5.2211708483155235e+00*x-1.5928601828509272e+00)*((x>=2.1072047423553277e+00)&(x<2.1710594315176102e+00))+(3.7194336376865067e-01*x**3-2.5911611507840462e+00*x**2+5.0182437159583060e+00*x-1.4460045613013790e+00)*((x>=2.1710594315176102e+00)&(x<2.2349141206798926e+00))+(3.3584918179303713e-01*x**3-2.3491589598679639e+00*x**2+4.4773896022379631e+00*x-1.0430837293160948e+00)*((x>=2.2349141206798926e+00)&(x<2.2987688098421755e+00))+(2.8648637184858217e-01*x**3-2.0087378962671210e+00*x**2+3.6948402790258115e+00*x-4.4345040385996981e-01)*((x>=2.2987688098421755e+00)&(x<2.3626234990044583e+00))+(2.3227298788958706e-01*x**3-1.6244804515572469e+00*x**2+2.7869846104958924e+00*x+2.7152330820081261e-01)*((x>=2.3626234990044583e+00)&(x<2.4264781881667408e+00))+(1.7974116130079665e-01*x**3-1.2420784573541823e+00*x**2+1.8590945124415157e+00*x+1.0220250028442024e+00)*((x>=2.4264781881667408e+00)&(x<2.4903328773290232e+00))+(1.3289308086268647e-01*x**3-8.9207651248761977e-01*x**2+9.8747316200842761e-01*x+1.7455674380280470e+00)*((x>=2.4903328773290232e+00)&(x<2.5541875664913061e+00))+(9.3513831827522154e-02*x**3-5.9033054769815863e-01*x**2+2.1675737051100441e-01*x+2.4017516686817544e+00)*((x>=2.5541875664913061e+00)&(x<2.6180422556535889e+00))+(6.1774634391497329e-02*x**3-3.4104686755426883e-01*x**2-4.3587783775001299e-01*x+2.9712938529355597e+00)*((x>=2.6180422556535889e+00)&(x<2.6818969448158714e+00))+(3.7019348447472566e-02*x**3-1.4187349033136343e-01*x**2-9.7004030962398247e-01*x+3.4488167533781962e+00)*((x>=2.6818969448158714e+00)&(x<2.7457516339781538e+00))+(1.8168037563782491e-02*x**3+1.3409562654032925e-02*x**2-1.3964090060817398e+00*x+3.8390509350429056e+00)*((x>=2.7457516339781538e+00)&(x<2.8096063231404367e+00))+(4.1129759513296449e-03*x**3+1.3187713259048905e-01*x**2-1.7292562396614812e+00*x+4.1507741657442239e+00)*((x>=2.8096063231404367e+00)&(x<2.8734610123027196e+00))+(-6.2037475913996332e-03*x**3+2.2081124121154971e-01*x**2-1.9848049334541429e+00*x+4.3955439018645848e+00)*((x>=2.8734610123027196e+00)&(x<2.9373157014650020e+00))+(-1.3654191263981375e-02*x**3+2.8646415676075776e-01*x**2-2.1776482731393116e+00*x+4.5843578250578503e+00)*((x>=2.9373157014650020e+00)&(x<3.0011703906272844e+00))+(-1.8969811831027528e-02*x**3+3.3432340592059973e-01*x**2-2.3212820346366243e+00*x+4.7280476224232189e+00)*((x>=3.0011703906272844e+00)&(x<3.0650250797895673e+00))+(-2.2711013796524071e-02*x**3+3.6872403948041210e-01*x**2-2.4267208392536759e+00*x+4.8357718159359138e+00)*((x>=3.0650250797895673e+00)&(x<3.1288797689518502e+00))+(-2.5310731439205369e-02*x**3+3.9312665129114066e-01*x**2-2.5030736776607228e+00*x+4.9154047663992060e+00)*((x>=3.1288797689518502e+00)&(x<3.1927344581141326e+00))+(-2.7108113928888677e-02*x**3+4.1034234631860045e-01*x**2-2.5580388203953248e+00*x+4.9739011348000020e+00)*((x>=3.1927344581141326e+00)&(x<3.2565891472764150e+00))+(-2.8410806851940862e-02*x**3+4.2306935322503136e-01*x**2-2.5994854529643590e+00*x+5.0188926860722631e+00)*((x>=3.2565891472764150e+00)&(x<3.3204438364386979e+00))+(-2.9310192803080781e-02*x**3+4.3202843483925335e-01*x**2-2.6292335802904745e+00*x+5.0518183480810421e+00)*((x>=3.3204438364386979e+00)&(x<3.3842985256009808e+00))+(-3.0093205159190006e-02*x**3+4.3997827752605190e-01*x**2-2.6561382211752971e+00*x+5.0821694602395837e+00)*((x>=3.3842985256009808e+00)&(x<3.4481532147632632e+00))+(-3.0795317700068381e-02*x**3+4.4724125237121370e-01*x**2-2.6811820712323424e+00*x+5.1109544709370311e+00)*((x>=3.4481532147632632e+00)&(x<3.5120079039255456e+00))+(-3.1532917501351676e-02*x**3+4.5501262136713194e-01*x**2-2.7084751805732594e+00*x+5.1429056761789980e+00)*((x>=3.5120079039255456e+00)&(x<3.5758625930878285e+00))+(-3.2466159438911291e-02*x**3+4.6502405617184195e-01*x**2-2.7442746957940471e+00*x+5.1855770586189465e+00)*((x>=3.5758625930878285e+00)&(x<3.6397172822501114e+00))+(-3.3589956874777727e-02*x**3+4.7729497102000096e-01*x**2-2.7889373566349605e+00*x+5.2397635447960056e+00)*((x>=3.6397172822501114e+00)&(x<3.7035719714123938e+00))+(-3.5071339774674470e-02*x**3+4.9375419557964051e-01*x**2-2.8498952793870558e+00*x+5.3150175628488796e+00)*((x>=3.7035719714123938e+00)&(x<3.7674266605746762e+00))+(-3.6994970540575878e-02*x**3+5.1549560907778869e-01*x**2-2.9318044602350710e+00*x+5.4178798400607775e+00)*((x>=3.7674266605746762e+00)&(x<3.8312813497369591e+00))+(-3.9447037508409721e-02*x**3+5.4367928440569813e-01*x**2-3.0397840498808364e+00*x+5.5557799027192232e+00)*((x>=3.8312813497369591e+00)&(x<3.8951360388992420e+00))+(-4.2618620384189398e-02*x**3+5.8074052468191439e-01*x**2-3.1841426225437317e+00*x+5.7432119956974930e+00)*((x>=3.8951360388992420e+00)&(x<3.9589907280615244e+00))+(-4.6696164902868986e-02*x**3+6.2916940751301809e-01*x**2-3.3758721206286282e+00*x+5.9962304307555314e+00)*((x>=3.9589907280615244e+00)&(x<4.0228454172238068e+00))+(-5.1896944109444121e-02*x**3+6.9193519990085406e-01*x**2-3.6283692008964863e+00*x+6.3348160048481077e+00)*((x>=4.0228454172238068e+00)&(x<4.0867001063860897e+00))+(-5.8576983248656234e-02*x**3+7.7383314988583152e-01*x**2-3.9630615618152660e+00*x+6.7907451071623655e+00)*((x>=4.0867001063860897e+00)&(x<4.1505547955483726e+00))+(-6.7182361582126759e-02*x**3+8.8098443281432992e-01*x**2-4.4077988330245716e+00*x+7.4060472450801171e+00)*((x>=4.1505547955483726e+00)&(x<4.2144094847106555e+00))+(-7.8338712014840439e-02*x**3+1.0220367200481633e+00*x**2-5.0022509301925311e+00*x+8.2411354305659188e+00)*((x>=4.2144094847106555e+00)&(x<4.2782641738729374e+00))+(-9.2867171032935403e-02*x**3+1.2085064772081751e+00*x**2-5.8000178117508767e+00*x+9.3788212534127524e+00)*((x>=4.2782641738729374e+00)&(x<4.3421188630352203e+00))+(-1.1222061881250056e-01*x**3+1.4606113892077701e+00*x**2-6.8946873055901960e+00*x+1.0963216272757563e+01)*((x>=4.3421188630352203e+00)&(x<4.4059735521975032e+00))+(-1.3750018227466398e-01*x**3+1.7947546532859633e+00*x**2-8.3669136897915450e+00*x+1.3125413109963119e+01)*((x>=4.4059735521975032e+00)&(x<4.4698282413597852e+00))+(-1.7392053653424000e-01*x**3+2.2831328373777069e+00*x**2-1.0549880289483553e+01*x+1.6377908362388553e+01)*((x>=4.4698282413597852e+00)&(x<4.5336829305220681e+00))+(-2.1562929657693530e-01*x**3+2.8504157177512752e+00*x**2-1.3121761001031700e+01*x+2.0264605589487473e+01)*((x>=4.5336829305220681e+00)&(x<4.5975376196843509e+00))+(-3.0437491578527442e-01*x**3+4.0744496864326720e+00*x**2-1.8749303219788999e+01*x+2.8888884608502849e+01)*((x>=4.5975376196843509e+00)&(x<4.6613923088466338e+00))+(-3.1198982739419989e-01*x**3+4.1809379576561696e+00*x**2-1.9245686828253383e+01*x+2.9660164186730981e+01)*((x>=4.6613923088466338e+00)&(x<4.7252469980089167e+00))+(-7.5008391869084790e-01*x**3+1.0391246326884357e+01*x**2-4.8590927806704713e+01*x+7.5881334799822071e+01)*((x>=4.7252469980089167e+00)&(x<4.7891016871711987e+00))+(2.7183874158629351e-01*x**3-4.2910282825941977e+00*x**2+2.1723978297071881e+01*x-3.6367077018439886e+01)*((x>=4.7891016871711987e+00)&(x<4.8529563763334815e+00))+(-4.2124606910192597e+00*x**3+6.0995300291961030e+01*x**2-2.9510772624622768e+02*x+4.7615640324424021e+02)*((x>=4.8529563763334815e+00)&(x<4.9168110654957644e+00))+(1.2329755139052622e+01*x**3-1.8300954923138852e+02*x**2+9.0461801792478946e+02*x-1.4901185349225707e+03)*((x>=4.9168110654957644e+00)&(x<4.9806657546580464e+00))+(-4.7330805172053374e+01*x**3+7.0843837970431923e+02*x**2-3.5353861537861230e+03*x+5.8812737079372309e+03)*((x>=4.9806657546580464e+00)&(x<5.0445204438203293e+00))+(1.8244935240871428e+02*x**3-2.7689537277969885e+03*x**2+1.4006389423683737e+04*x-2.3615341465880978e+04)*((x>=5.0445204438203293e+00)&(x<5.1083751329826121e+00))+(-1.8244935222940489e+02*x**3+2.8231646786958099e+03*x**2-1.4560249184738459e+04*x+2.5027693967507250e+04)*((x>=5.1083751329826121e+00)&(x<5.1722298221448950e+00))+(4.7330804842992620e+01*x**3-7.4226266414515521e+02*x**2+3.8809604465944649e+03*x-6.7663641696945851e+03)*((x>=5.1722298221448950e+00)&(x<5.2360845113071779e+00))+(-1.2329754477077586e+01*x**3+1.9490052763006679e+02*x**2-1.0261052264269674e+03*x+1.7982393524636282e+03)*((x>=5.2360845113071779e+00)&(x<5.2999392004694599e+00))+(4.2124596751704075e+00*x**3-6.8117660114114187e+01*x**2+3.6787517723481142e+02*x-6.6443110955417797e+02)*((x>=5.2999392004694599e+00)&(x<5.3637938896317428e+00))+(-2.7183826550685808e-01*x**3+4.0408895663658768e+00*x**2-1.9168410626050900e+01*x+2.7576234308871790e+01)*((x>=5.3637938896317428e+00)&(x<5.4276485787940256e+00))+(7.5008405298376601e-01*x**3-1.2599016092419333e+01*x**2+7.1147149674121465e+01*x-1.3582413985981839e+02)*((x>=5.4276485787940256e+00)&(x<5.4915032679563076e+00))+(3.1199004146691323e-01*x**3-5.3816320046735200e+00*x**2+3.1512861370159953e+01*x-6.3273531945073046e+01)*((x>=5.4915032679563076e+00)&(x<5.5553579571185905e+00))+(3.0437383882156155e-01*x**3-5.2546998087591419e+00*x**2+3.0807707585590833e+01*x-6.1967738049046602e+01)*((x>=5.5553579571185905e+00)&(x<5.6192126462808734e+00))+(2.1563075160560174e-01*x**3-3.7587009749040590e+00*x**2+2.2401372019558039e+01*x-4.6222075675235828e+01)*((x>=5.6192126462808734e+00)&(x<5.6830673354431562e+00))+(1.7391950686368318e-01*x**3-3.0475575373566244e+00*x**2+1.8359895978872373e+01*x-3.8566082183868275e+01)*((x>=5.6830673354431562e+00)&(x<5.7469220246054391e+00))+(1.3750088660430038e-01*x**3-2.4196726247328115e+00*x**2+1.4751490345544880e+01*x-3.1653673581327894e+01)*((x>=5.7469220246054391e+00)&(x<5.8107767137677211e+00))+(1.1221972262438840e-01*x**3-1.9789630278855839e+00*x**2+1.2190625282652036e+01*x-2.6693468556419248e+01)*((x>=5.8107767137677211e+00)&(x<5.8746314029300040e+00))+(9.2867988186753792e-02*x**3-1.6379101074044229e+00*x**2+1.0187065085905488e+01*x-2.2770076006578165e+01)*((x>=5.8746314029300040e+00)&(x<5.9384860920922868e+00))+(7.8338410217043020e-02*x**3-1.3790590173093733e+00*x**2+8.6498814874794334e+00*x-1.9727228199844831e+01)*((x>=5.9384860920922868e+00)&(x<6.0023407812545688e+00))+(6.7182295194982089e-02*x**3-1.1781706048368505e+00*x**2+7.4440807768332888e+00*x-1.7314685940000345e+01)*((x>=6.0023407812545688e+00)&(x<6.0661954704168517e+00))+(5.8577025119973314e-02*x**3-1.0215668537794045e+00*x**2+6.4940918115280510e+00*x-1.5393746353875031e+01)*((x>=6.0661954704168517e+00)&(x<6.1300501595791346e+00))+(5.1897067588811296e-02*x**3-8.9872142959211487e-01*x**2+5.7410431993630482e+00*x-1.3855004432152782e+01)*((x>=6.1300501595791346e+00)&(x<6.1939048487414174e+00))+(4.6696066984992513e-02*x**3-8.0207792101828090e-01*x**2+5.1424425030309067e+00*x-1.2619112513682921e+01)*((x>=6.1939048487414174e+00)&(x<6.2577595379037003e+00))+(4.2618666298778862e-02*x**3-7.2553174191534708e-01*x**2+4.6634349206433399e+00*x-1.1619941091201326e+01)*((x>=6.2577595379037003e+00)&(x<6.3216142270659823e+00))+(3.9446797158092295e-02*x**3-6.6537774265771077e-01*x**2+4.2831645431215293e+00*x-1.0818633548318758e+01)*((x>=6.3216142270659823e+00)&(x<6.3854689162282652e+00))+(3.6995416964970218e-02*x**3-6.1841810658143004e-01*x**2+3.9833052466274239e+00*x-1.0180386142717907e+01)*((x>=6.3854689162282652e+00)&(x<6.4493236053905481e+00))+(3.5070877833248915e-02*x**3-5.8118217962737617e-01*x**2+3.7431587039645819e+00*x-9.6641252205372439e+00)*((x>=6.4493236053905481e+00)&(x<6.5131782945528300e+00))+(3.3590322568812780e-02*x**3-5.5225281838966112e-01*x**2+3.5547366162682010e+00*x-9.2550496699768701e+00)*((x>=6.5131782945528300e+00)&(x<6.5770329837151129e+00))+(3.2465890682701115e-02*x**3-5.3006654158207311e-01*x**2+3.4088167419286037e+00*x-8.9351430610877287e+00)*((x>=6.5770329837151129e+00)&(x<6.6408876728773958e+00))+(3.1533219660083489e-02*x**3-5.1148525109044840e-01*x**2+3.2854204789546202e+00*x-8.6619894872128498e+00)*((x>=6.6408876728773958e+00)&(x<6.7047423620396787e+00))+(3.0795005704732148e-02*x**3-4.9663664795406248e-01*x**2+3.1858644204949087e+00*x-8.4394902463773178e+00)*((x>=6.7047423620396787e+00)&(x<6.7685970512019615e+00))+(3.0093348607045378e-02*x**3-4.8238894546730648e-01*x**2+3.0894274634488283e+00*x-8.2219092786804140e+00)*((x>=6.7685970512019615e+00)&(x<6.8324517403642435e+00))+(2.9310200271183362e-02*x**3-4.6633647583678339e-01*x**2+2.9797497393865342e+00*x-7.9721200264611980e+00)*((x>=6.8324517403642435e+00)&(x<6.8963064295265264e+00))+(2.8410790175698253e-02*x**3-4.4772865296363307e-01*x**2+2.8514244908692490e+00*x-7.6771299476567947e+00)*((x>=6.8963064295265264e+00)&(x<6.9601611186888093e+00))+(2.7107952501779664e-02*x**3-4.2052477259721854e-01*x**2+2.6620811004668212e+00*x-7.2378431130055105e+00)*((x>=6.9601611186888093e+00)&(x<7.0240158078510913e+00))+(2.5311293333544427e-02*x**3-3.8266548540059375e-01*x**2+2.3961568687191175e+00*x-6.6152244438344496e+00)*((x>=7.0240158078510913e+00)&(x<7.0878704970133741e+00))+(2.2710019029517525e-02*x**3-3.2735299921932892e-01*x**2+2.0041091298007814e+00*x-5.6889632430975325e+00)*((x>=7.0878704970133741e+00)&(x<7.1517251861756570e+00))+(1.8970773908108640e-02*x**3-2.4712683868256136e-01*x**2+1.4303536768820777e+00*x-4.3211828020575922e+00)*((x>=7.1517251861756570e+00)&(x<7.2155798753379399e+00))+(1.3653975963791254e-02*x**3-1.3203549793706770e-01*x**2+5.9990291480789892e-01*x-2.3237881998647936e+00)*((x>=7.2155798753379399e+00)&(x<7.2794345645002227e+00))+(6.2032755812992946e-03*x**3+3.0675159747261205e-02*x**2-5.8453867072967114e-01*x+5.5023347260430455e-01)*((x>=7.2794345645002227e+00)&(x<7.3432892536625047e+00))+(-4.1124634906850588e-03*x**3+2.5792952735628205e-01*x**2-2.2533332263119519e+00*x+4.6350471813202603e+00)*((x>=7.3432892536625047e+00)&(x<7.4071439428247876e+00))+(-1.8168339569058389e-02*x**3+5.7027121941882797e-01*x**2-4.5668930987594649e+00*x+1.0347337513201637e+01)*((x>=7.4071439428247876e+00)&(x<7.4709986319870705e+00))+(-3.7018935468495329e-02*x**3+9.9276954795277561e-01*x**2-7.7233775332570076e+00*x+1.8208034477138426e+01)*((x>=7.4709986319870705e+00)&(x<7.5348533211493525e+00))+(-6.1776084520545282e-02*x**3+1.5523940082221088e+00*x**2-1.1940065756323747e+01*x+2.8798743564606411e+01)*((x>=7.5348533211493525e+00)&(x<7.5987080103116353e+00))+(-9.3510863292124213e-02*x**3+2.2758239611885074e+00*x**2-1.7437198734827689e+01*x+4.2722446363623021e+01)*((x>=7.5987080103116353e+00)&(x<7.6625626994739182e+00))+(-1.3289734890201998e-01*x**3+3.1812282076934935e+00*x**2-2.4374915541993687e+01*x+6.0442676372273127e+01)*((x>=7.6625626994739182e+00)&(x<7.7264173886362011e+00))+(-1.7973587875860630e-01*x**3+4.2669103023090429e+00*x**2-3.2763348556429264e+01*x+8.2046854607702699e+01)*((x>=7.7264173886362011e+00)&(x<7.7902720777984840e+00))+(-2.3227797388710769e-01*x**3+5.4948619520891953e+00*x**2-4.2329426006443100e+01*x+1.0688763662561541e+02)*((x>=7.7902720777984840e+00)&(x<7.8541267669607659e+00))+(-2.8648314861447943e-01*x**3+6.7720648932845506e+00*x**2-5.2360739813753753e+01*x+1.3315004005283117e+02)*((x>=7.8541267669607659e+00)&(x<7.9179814561230488e+00))+(-3.3585025449463046e-01*x**3+7.9447283799763682e+00*x**2-6.1645867555795121e+01*x+1.5765652981237508e+02)*((x>=7.9179814561230488e+00)&(x<7.9818361452853317e+00))+(-3.7194444734723220e-01*x**3+8.8090221794191166e+00*x**2-6.8544519044226035e+01*x+1.7601116508065024e+02)*((x>=7.9818361452853317e+00)&(x<8.0456908344476137e+00))+(-3.8629167377018803e-01*x**3+9.1553222238107992e+00*x**2-7.1330742137506604e+01*x+1.8348352828185307e+02)*((x>=8.0456908344476137e+00)&(x<8.1095455236098957e+00))+(-3.7359109960391379e-01*x**3+8.8463345706841210e+00*x**2-6.8824992698064307e+01*x+1.7671003189886687e+02)*((x>=8.1095455236098957e+00)&(x<8.1734002127721794e+00))+(-3.3378840822297207e-01*x**3+7.8703645920795680e+00*x**2-6.0847999467310729e+01*x+1.5497697917540791e+02)*((x>=8.1734002127721794e+00)&(x<8.2372549019344614e+00))+(-2.7296121292363296e-01*x**3+6.3672172541228065e+00*x**2-4.8466191689483821e+01*x+1.2097961023781681e+02)*((x>=8.2372549019344614e+00)&(x<8.3011095910967452e+00))+(-2.0109468423629551e-01*x**3+4.5775014624305186e+00*x**2-3.3609564765560208e+01*x+7.9870780821598601e+01)*((x>=8.3011095910967452e+00)&(x<8.3649642802590272e+00))+(-1.2875122680952700e-01*x**3+2.7620501505880384e+00*x**2-1.8423379389540059e+01*x+3.7526814746437594e+01)*((x>=8.3649642802590272e+00)&(x<8.4288189694213109e+00))+(-6.4104108504011492e-02*x**3+1.1273535792861367e+00*x**2-4.6448179202561732e+00*x-1.1855186813045293e+00)*((x>=8.4288189694213109e+00)&(x<8.4926736585835929e+00))+(-1.1811508809500992e-02*x**3-2.0495837259659311e-01*x**2+6.6700726986164227e+00*x-3.3216743183904327e+01)*((x>=8.4926736585835929e+00)&(x<8.5565283477458749e+00))+(2.6878495891423881e-02*x**3-1.1981147385704389e+00*x**2+1.5168043297890108e+01*x-5.7454451961093582e+01)*((x>=8.5565283477458749e+00)&(x<8.6203830369081587e+00))+(5.2943064878718360e-02*x**3-1.8721744436697918e+00*x**2+2.0978696145495633e+01*x-7.4151136374450289e+01)*((x>=8.6203830369081587e+00)&(x<8.6842377260704406e+00))+(6.8467307561604684e-02*x**3-2.2766230855995673e+00*x**2+2.4491024300106801e+01*x-8.4318433929700404e+01)*((x>=8.6842377260704406e+00)&(x<8.7480924152327226e+00))+(7.5854986425838433e-02*x**3-2.4705073779296072e+00*x**2+2.6187142007082002e+01*x-8.9264365412876941e+01)*((x>=8.7480924152327226e+00)&(x<8.8119471043950064e+00))+(7.7207332586681332e-02*x**3-2.5062577864337072e+00*x**2+2.6502172715961933e+01*x-9.0189710060018115e+01)*((x>=8.8119471043950064e+00)&(x<8.8758017935572884e+00))+(7.4340519930501614e-02*x**3-2.4299220036882616e+00*x**2+2.5824631438677898e+01*x-8.8185136032057926e+01)*((x>=8.8758017935572884e+00)&(x<8.9396564827195704e+00))+(6.8512232523062266e-02*x**3-2.2736133417602105e+00*x**2+2.4427285695594037e+01*x-8.4021205721539445e+01)*((x>=8.9396564827195704e+00)&(x<9.0035111718818541e+00))+(6.0661457257310758e-02*x**3-2.0615597133219126e+00*x**2+2.2518058482964989e+01*x-7.8291289542685263e+01)*((x>=9.0035111718818541e+00)&(x<9.0673658610441361e+00))+(5.1357445106532396e-02*x**3-1.8084710669172637e+00*x**2+2.0223211130534764e+01*x-7.1355216029332951e+01)*((x>=9.0673658610441361e+00)&(x<9.1312205502064199e+00))+(4.0856734447515919e-02*x**3-1.5208181519992650e+00*x**2+1.7596588922751835e+01*x-6.3360460468451492e+01)*((x>=9.1312205502064199e+00)&(x<9.1950752393687019e+00))+(2.9294283507397267e-02*x**3-1.2018653329760127e+00*x**2+1.4663793753832579e+01*x-5.4371369721484371e+01)*((x>=9.1950752393687019e+00)&(x<9.2589299285309838e+00))+(1.6474698144520517e-02*x**3-8.4577840519705205e-01*x**2+1.1366809841070790e+01*x-4.4195855381200090e+01)*((x>=9.2589299285309838e+00)&(x<9.3227846176932676e+00))+(2.1336679947125958e-03*x**3-4.4468339937156998e-01*x**2+7.6274874904192984e+00*x-3.2575556416762993e+01)*((x>=9.3227846176932676e+00)&(x<9.3866393068555496e+00))+(-1.4342593641913481e-02*x**3+1.9286775994260097e-02*x**2+3.2723668054677546e+00*x-1.8948907415266149e+01)*((x>=9.3866393068555496e+00)&(x<9.4504939960178334e+00))+(-3.3760935474674625e-02*x**3+5.6982554467685986e-01*x**2-1.9304965227493085e+00*x-2.5590311994310468e+00)*((x>=9.4504939960178334e+00)&(x<9.5143486851801153e+00))+(-5.7299922584434171e-02*x**3+1.2416999378619948e+00*x**2-8.3229437721311115e+00*x+1.7714292827644385e+01)*((x>=9.5143486851801153e+00)&(x<9.5782033743423973e+00))+(-8.6775392937738616e-02*x**3+2.0886660866453894e+00*x**2-1.6435357796552125e+01*x+4.3615076621295884e+01)*((x>=9.5782033743423973e+00)&(x<9.6420580635046811e+00))+(-1.2442068400082462e-01*x**3+3.1776003334234701e+00*x**2-2.6934925030916929e+01*x+7.7360888926894404e+01)*((x>=9.6420580635046811e+00)&(x<9.7059127526669631e+00))+(-1.7398285036449579e-01*x**3+4.6207385210473149e+00*x**2-4.0941898370336276e+01*x+1.2267770931392442e+02)*((x>=9.7059127526669631e+00)&(x<9.7697674418292451e+00))+(-2.3676027467445238e-01*x**3+6.4607010293693747e+00*x**2-5.8917904178291792e+01*x+1.8121817473997362e+02)*((x>=9.7697674418292451e+00)&(x<9.8336221309915288e+00))+(-3.2231103905780856e-01*x**3+8.9845226992692915e+00*x**2-8.3736212806310505e+01*x+2.6256946439831518e+02)*((x>=9.8336221309915288e+00)&(x<9.8974768201538108e+00))+(-3.8680223807102720e-01*x**3+1.0899423141283478e+01*x**2-1.0268889554386260e+02*x+3.2509737709001638e+02)*((x>=9.8974768201538108e+00)&(x<9.9613315093160928e+00))+(-4.8494848538246060e-01*x**3+1.3832425058903027e+01*x**2-1.3190549996230402e+02*x+4.2210947115428280e+02)*((x>=9.9613315093160928e+00)&(x<1.0025186198478377e+01))+(5.9781816010513467e-02*x**3-2.5506430393870687e+00*x**2+3.2337808224896435e+01*x-1.2674711099022534e+02)*((x>=1.0025186198478377e+01)&(x<1.0089040887640659e+01))+(1.6752645682788625e-01*x**3-5.8117632992507424e+00*x**2+6.5239383866195567e+01*x-2.3739555829484016e+02)*((x>=1.0089040887640659e+01)&(x<1.0152895576802942e+01))+(6.1216999170505915e+00*x**3-1.8716806746269867e+02*x**2+1.9065310022328049e+03*x-6.4688760675331578e+03)*((x>=1.0152895576802942e+01)&(x<=1.0216750265965224e+01))

axes[2][2].scatter(px, py, s = 5)
axes[2][2].plot(X, Y)
axes[2][2].plot(ZX, ZY)
axes[2][2].set_title("2nd Derivatives: N=160")
# Out:
# Text(0.5, 1.0, '2nd Derivatives: N=160')

# %% [markdown]
# # 误差收敛阶

# %%
h = [0.111111, 0.0909091, 0.0769231, 0.0666667, 0.0588235, 0.0526316, 0.047619, 0.0434783, 0.04, 0.037037, 0.0344828, 0.0322581, 0.030303, 0.0285714, 0.027027, 0.025641, 0.0243902, 0.0232558, 0.0222222, 0.0212766, 0.0204082, 0.0196078, 0.0188679, 0.0181818, 0.0175439, 0.0169492, 0.0163934, 0.015873, 0.0153846, 0.0149254, 0.0144928, 0.0140845, 0.0136986, 0.0133333, 0.012987, 0.0126582, 0.0123457, 0.0120482, 0.0117647, 0.0114943, 0.011236, 0.010989, 0.0107527, 0.0105263, 0.0103093, 0.010101]
# ------------------- ppForm linear -------------------
pp1_i = [0.235849, 0.171233, 0.128866, 0.1, 0.0796178, 0.0647668, 0.0536481, 0.0451264, 0.0384615, 0.0331565, 0.0288684, 0.025355, 0.0224416, 0.02, 0.017934, 0.0161708, 0.0146542, 0.0133404, 0.0121951, 0.0111907, 0.010305, 0.00952018, 0.00882145, 0.00819672, 0.00763592, 0.00713063, 0.00667378, 0.00625939, 0.00588235, 0.00553832, 0.00522357, 0.00493486, 0.0046694, 0.00442478, 0.00419886, 0.00398978, 0.00379593, 0.00361585, 0.00344827, 0.00329207, 0.00314623, 0.00300987, 0.00288217, 0.00276243, 0.00264999, 0.00254427]
pp1_2 = [0.0601265, 0.0395928, 0.0273342, 0.0198625, 0.0151358, 0.011991, 0.00978419, 0.0081611, 0.00692223, 0.00594979, 0.00517009, 0.0045344, 0.00400898, 0.00356963, 0.00319854, 0.00288227, 0.00261056, 0.00237544, 0.00217063, 0.00199116, 0.001833, 0.00169294, 0.0015683, 0.00145692, 0.00135698, 0.00126696, 0.0011856, 0.00111182, 0.00104472, 0.000983498, 0.000927502, 0.000876151, 0.000828945, 0.000785451, 0.000745289, 0.000708128, 0.000673676, 0.000641677, 0.000611903, 0.000584153, 0.000558247, 0.000534026, 0.000511347, 0.000490082, 0.000470116, 0.000451344]
# ------------------- ppForm order 3 (complete) -------------------
pp3_i = [0.142871, 0.0841281, 0.0504639, 0.0308907, 0.0193118, 0.0123356, 0.00805262, 0.00537246, 0.00366263, 0.00255051, 0.00181306, 0.00131462, 0.000971336, 0.000730557, 0.000558664, 0.000433855, 0.000341762, 0.000272766, 0.000220331, 0.000179943, 0.000148445, 0.000123593, 0.000103773, 8.78073e-05, 7.48277e-05, 6.41848e-05, 5.53886e-05, 4.8065e-05, 4.19257e-05, 3.67465e-05, 3.23511e-05, 2.86005e-05, 2.53833e-05, 2.26105e-05, 2.02096e-05, 1.81221e-05, 1.62996e-05, 1.47026e-05, 1.3298e-05, 1.20586e-05, 1.09614e-05, 9.98707e-06, 9.11944e-06, 8.34466e-06, 7.651e-06, 7.02841e-06]
pp3_2 = [0.04083, 0.0232342, 0.0133093, 0.00767447, 0.00446325, 0.00262689, 0.00157179, 0.000961221, 0.000604049, 0.000391797, 0.000262922, 0.000182518, 0.000130766, 9.63502e-05, 7.27305e-05, 5.60482e-05, 4.39653e-05, 3.50206e-05, 2.8273e-05, 2.3098e-05, 1.90711e-05, 1.58966e-05, 1.33647e-05, 1.13239e-05, 9.6631e-06, 8.29965e-06, 7.17127e-06, 6.23049e-06, 5.44075e-06, 4.7736e-06, 4.20669e-06, 3.72233e-06, 3.30637e-06, 2.94745e-06, 2.63637e-06, 2.36561e-06, 2.12902e-06, 1.92151e-06, 1.73886e-06, 1.57757e-06, 1.43468e-06, 1.30772e-06, 1.19459e-06, 1.09351e-06, 1.00296e-06, 9.21644e-07]
# ------------------- B-Form linear -------------------
b1_i = [0.235849, 0.171233, 0.128866, 0.1, 0.0796178, 0.0647668, 0.0536481, 0.0451264, 0.0384615, 0.0331565, 0.0288684, 0.025355, 0.0224416, 0.02, 0.017934, 0.0161708, 0.0146542, 0.0133404, 0.0121951, 0.0111907, 0.010305, 0.00952018, 0.00882145, 0.00819672, 0.00763592, 0.00713063, 0.00667378, 0.00625939, 0.00588235, 0.00553832, 0.00522357, 0.00493486, 0.0046694, 0.00442478, 0.00419886, 0.00398978, 0.00379593, 0.00361585, 0.00344827, 0.00329207, 0.00314623, 0.00300987, 0.00288217, 0.00276243, 0.00264999, 0.00254427]
b1_2 = [0.0601265, 0.0395928, 0.0273342, 0.0198625, 0.0151358, 0.011991, 0.00978419, 0.0081611, 0.00692223, 0.00594979, 0.00517009, 0.0045344, 0.00400898, 0.00356963, 0.00319854, 0.00288227, 0.00261056, 0.00237544, 0.00217063, 0.00199116, 0.001833, 0.00169294, 0.0015683, 0.00145692, 0.00135698, 0.00126696, 0.0011856, 0.00111182, 0.00104472, 0.000983498, 0.000927502, 0.000876151, 0.000828945, 0.000785451, 0.000745289, 0.000708128, 0.000673676, 0.000641677, 0.000611903, 0.000584153, 0.000558247, 0.000534026, 0.000511347, 0.000490082, 0.000470116, 0.000451344]
# ------------------- B-Form order 2 -------------------
b2_i = [0.0424301, 0.0119295, 0.0157125, 0.0191682, 0.0178722, 0.0148226, 0.011696, 0.00892191, 0.00674066, 0.00504169, 0.00379529, 0.00285698, 0.00218268, 0.00167423, 0.00130894, 0.00102787, 0.000824116, 0.000662487, 0.000543907, 0.000446483, 0.00038731, 0.000344175, 0.000303568, 0.000270451, 0.000239292, 0.000214019, 0.000190117, 0.0001708, 0.000152377, 0.000137533, 0.000123637, 0.000112873, 0.000104052, 9.51404e-05, 8.80675e-05, 8.13485e-05, 7.58556e-05, 7.01362e-05, 6.54773e-05, 6.06151e-05, 5.66687e-05, 5.25339e-05, 4.91904e-05, 4.56691e-05, 4.28331e-05, 4.02451e-05]
b2_2 = [0.00855842, 0.0038703, 0.005499, 0.00526268, 0.00433027, 0.00328165, 0.00240831, 0.00173005, 0.00124609, 0.000901346, 0.000665022, 0.000499077, 0.000384068, 0.000301318, 0.000241599, 0.000196833, 0.000162962, 0.000136558, 0.00011577, 9.90588e-05, 8.55022e-05, 7.43449e-05, 6.50878e-05, 5.73265e-05, 5.07727e-05, 4.51941e-05, 4.04159e-05, 3.62967e-05, 3.27263e-05, 2.9615e-05, 2.68908e-05, 2.44947e-05, 2.23783e-05, 2.05016e-05, 1.88313e-05, 1.73396e-05, 1.6003e-05, 1.48017e-05, 1.37189e-05, 1.27401e-05, 1.18532e-05, 1.10475e-05, 1.03138e-05, 9.64429e-06, 9.03195e-06, 8.4708e-06]
# ------------------- B-Form order 3 (complete) -------------------
b3_i = [0.142871, 0.0841281, 0.0504639, 0.0308907, 0.0193118, 0.0123356, 0.00805262, 0.00537246, 0.00366263, 0.00255051, 0.00181306, 0.00131462, 0.000971336, 0.000730557, 0.000558664, 0.000433855, 0.000341762, 0.000272766, 0.000220331, 0.000179943, 0.000148445, 0.000123593, 0.000103773, 8.78073e-05, 7.48277e-05, 6.41848e-05, 5.53886e-05, 4.8065e-05, 4.19257e-05, 3.67465e-05, 3.23511e-05, 2.86005e-05, 2.53833e-05, 2.26105e-05, 2.02096e-05, 1.81221e-05, 1.62996e-05, 1.47026e-05, 1.3298e-05, 1.20586e-05, 1.09614e-05, 9.98707e-06, 9.11944e-06, 8.34466e-06, 7.651e-06, 7.02841e-06]
b3_2 = [0.04083, 0.0232342, 0.0133093, 0.00767447, 0.00446325, 0.00262689, 0.00157179, 0.000961221, 0.000604049, 0.000391797, 0.000262922, 0.000182518, 0.000130766, 9.63502e-05, 7.27305e-05, 5.60482e-05, 4.39653e-05, 3.50206e-05, 2.8273e-05, 2.3098e-05, 1.90711e-05, 1.58966e-05, 1.33647e-05, 1.13239e-05, 9.6631e-06, 8.29965e-06, 7.17127e-06, 6.23049e-06, 5.44075e-06, 4.7736e-06, 4.20669e-06, 3.72233e-06, 3.30637e-06, 2.94745e-06, 2.63637e-06, 2.36561e-06, 2.12902e-06, 1.92151e-06, 1.73886e-06, 1.57757e-06, 1.43468e-06, 1.30772e-06, 1.19459e-06, 1.09351e-06, 1.00296e-06, 9.21644e-07]
# ------------------- B-Form order 4 -------------------
b4_i = [0.0874947, 0.0382606, 0.0146901, 0.00405705, 0.000881701, 0.00176752, 0.00198745, 0.00174271, 0.00137851, 0.00103334, 0.000751184, 0.00053662, 0.00037987, 0.000268083, 0.000189423, 0.000134476, 9.61552e-05, 6.93969e-05, 5.06163e-05, 3.73511e-05, 2.78938e-05, 2.10889e-05, 1.61348e-05, 1.24905e-05, 9.7755e-06, 7.73206e-06, 6.17457e-06, 4.97652e-06, 4.04391e-06, 3.31231e-06, 2.73202e-06, 2.26891e-06, 1.89545e-06, 1.59298e-06, 1.34559e-06, 1.14263e-06, 9.74531e-07, 8.351e-07, 7.18309e-07, 6.20543e-07, 5.44295e-07, 4.81014e-07, 4.25801e-07, 3.77558e-07, 3.35871e-07, 2.99081e-07]
b4_2 = [0.0219448, 0.00897058, 0.00316533, 0.00074953, 0.000270577, 0.000469392, 0.000454925, 0.000366239, 0.000270378, 0.000190358, 0.000130396, 8.8012e-05, 5.90546e-05, 3.96782e-05, 2.68523e-05, 1.83972e-05, 1.28079e-05, 9.08452e-06, 6.57131e-06, 4.84738e-06, 3.64224e-06, 2.78346e-06, 2.1596e-06, 1.69836e-06, 1.35173e-06, 1.08745e-06, 8.83303e-07, 7.23778e-07, 5.97803e-07, 4.97378e-07, 4.16622e-07, 3.51165e-07, 2.97718e-07, 2.53777e-07, 2.17422e-07, 1.87164e-07, 1.61839e-07, 1.40532e-07, 1.22517e-07, 1.07214e-07, 9.41567e-08, 8.29698e-08, 7.33468e-08, 6.5038e-08, 5.78384e-08, 5.15782e-08]
# ------------------- B-Form order 5 -------------------
b5_i = [0.128472, 0.0718874, 0.0404914, 0.0230114, 0.0132071, 0.00765968, 0.00449141, 0.00266416, 0.00159955, 0.000972645, 0.000599377, 0.00037454, 0.000237466, 0.00015284, 9.99059e-05, 6.63455e-05, 4.47696e-05, 3.06993e-05, 2.13898e-05, 1.51393e-05, 1.08808e-05, 7.9369e-06, 5.8723e-06, 4.40392e-06, 3.34525e-06, 2.57189e-06, 1.99977e-06, 1.57144e-06, 1.24708e-06, 9.98793e-07, 8.06807e-07, 6.56932e-07, 5.38879e-07, 4.45107e-07, 3.70032e-07, 3.09482e-07, 2.60306e-07, 2.20106e-07, 1.87042e-07, 1.5969e-07, 1.36941e-07, 1.17922e-07, 1.01945e-07, 8.84611e-08, 7.70324e-08, 6.73054e-08]
b5_2 = [0.0370674, 0.0205878, 0.0114629, 0.00639509, 0.00357482, 0.00200276, 0.00112514, 0.000634392, 0.000359413, 0.000204921, 0.000117812, 6.84606e-05, 4.03238e-05, 2.41485e-05, 1.47497e-05, 9.21409e-06, 5.89904e-06, 3.87443e-06, 2.61023e-06, 1.80189e-06, 1.27236e-06, 9.17197e-07, 6.73599e-07, 5.03046e-07, 3.81372e-07, 2.93078e-07, 2.28009e-07, 1.7938e-07, 1.42568e-07, 1.14375e-07, 9.25487e-08, 7.54837e-08, 6.20184e-08, 5.13036e-08, 4.27094e-08, 3.57663e-08, 3.01179e-08, 2.54939e-08, 2.16852e-08, 1.85317e-08, 1.59047e-08, 1.37127e-08, 1.1866e-08, 1.03069e-08, 8.9858e-09, 7.87361e-09]

def PLOT(x, y, c) :
    plt.plot([-math.log2(xx) for xx in x], [-math.log(yy) for yy in y], label = c)
    
PLOT(h, pp1_i, "Linear(ppForm)")
PLOT(h, pp3_i, "Cubic(ppForm)")
plt.title("$\infty$- norm - ppForm")
plt.xlabel("$-\log_2(h)$")
plt.xlabel("$-\log_2(\text{error})$")
plt.legend()
plt.show()
PLOT(h,  b1_i, "Linear(BForm)")
PLOT(h,  b2_i, "Quadratic(BForm)")
PLOT(h,  b3_i, "Cubic(BForm)")
PLOT(h,  b4_i, "Order4(BForm)")
PLOT(h,  b5_i, "Order5(BForm)")
plt.title("$\infty$- norm - BForm")
plt.xlabel("$-\log_2(h)$")
plt.xlabel("$-\log_2(\text{error})$")
plt.legend()
plt.show()

PLOT(h, pp1_2, "Linear(ppForm)")
PLOT(h, pp3_2, "Cubic(ppForm)")
plt.title("$2$- norm - ppForm")
plt.xlabel("$-\log_2(h)$")
plt.xlabel("$-\log_2(\text{error})$")
plt.legend()
plt.show()
PLOT(h,  b1_2, "Linear(BForm)")
PLOT(h,  b2_2, "Quadratic(BForm)")
PLOT(h,  b3_2, "Cubic(BForm)")
PLOT(h,  b4_2, "Order4(BForm)")
PLOT(h,  b5_2, "Order5(BForm)")
plt.title("$2$- norm - BForm")
plt.xlabel("$-\log_2(h)$")
plt.xlabel("$-\log_2(\text{error})$")
plt.legend()
plt.show()
